# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sastrawi in /usr/local/lib/python3.9/dist-packages (1.0.1)

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.4.5)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from nltk) (1.16.0)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import os
import re
import nltk
import random
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from nltk.tokenize import sent_tokenize, LineTokenizer, RegexpTokenizer
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

print(os.listdir("/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/"))
factory = StemmerFactory()
stemmer = factory.create_stemmer()
import string
from nltk.stem import PorterStemmer, WordNetLemmatizer
stopwords_indonesia = stopwords.words('indonesian')
stop_words = set(stopwords.words('indonesian'))
import sys
import os
# Out:
# ['Indonesian Query Answering Dataset for Online Essay Test System.zip', 'dict.json', 'Preprocessing', 'Analysis Data', 'Text Preprocessing', 'Data', 'dataset.py', '__pycache__']

# %%
sheets_dict_Lifestyle = pd.read_excel('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Data/Analisis_Essay_Grading_Lifestyle.xlsx', sheet_name=None, index_col=1, skiprows = 1)
sheets_dict_Olahraga = pd.read_excel('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Data/Analisis_Essay_Grading_Olahraga.xlsx', sheet_name=None, index_col=1, skiprows = 1)
sheets_dict_Politik = pd.read_excel('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Data/Analisis_Essay_Grading_Politik.xlsx', sheet_name=None, index_col=1, skiprows = 1)
sheets_dict_Teknologi = pd.read_excel('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Data/Analisis_Essay_Grading_Teknologi.xlsx', sheet_name=None, index_col=1, skiprows = 1)

Lifestyle_keys = list(sheets_dict_Lifestyle.keys())
Olahraga_keys = list(sheets_dict_Olahraga.keys())
Politik_keys = list(sheets_dict_Politik.keys())
Teknologi_keys = list(sheets_dict_Teknologi.keys())


Lifestyle_Soal = sheets_dict_Lifestyle[Lifestyle_keys[0]].drop(['Unnamed: 0'], axis = 1)
Olahraga_Soal = sheets_dict_Olahraga[Olahraga_keys[0]].drop(['Unnamed: 0'], axis = 1)
Politik_Soal = sheets_dict_Politik[Politik_keys[0]].drop(['Unnamed: 0'], axis = 1)
Teknologi_Soal = sheets_dict_Teknologi[Teknologi_keys[0]].drop(['Unnamed: 0'], axis = 1)


Lifestyle_all_sheets = []
index = 1
for keys in Lifestyle_keys[index:len(Lifestyle_keys)-1]:
    new_sheets = sheets_dict_Lifestyle[keys].drop(['Unnamed: 0'], axis = 1)
    new_sheets = new_sheets.dropna()
    Lifestyle_all_sheets.append(new_sheets)

Olahraga_all_sheets = []
index = 1
for keys in Olahraga_keys[index:len(Olahraga_keys)-1]:
    new_sheets = sheets_dict_Olahraga[keys].drop(['Unnamed: 0'], axis = 1)
    new_sheets = new_sheets.dropna()
    Olahraga_all_sheets.append(new_sheets)



Politik_all_sheets = []
index = 1
for keys in Politik_keys[index:len(Politik_keys)-1]:
    new_sheets = sheets_dict_Politik[keys].drop(['Unnamed: 0'], axis = 1)
    new_sheets = new_sheets.dropna()
    Politik_all_sheets.append(new_sheets)

Teknologi_all_sheets = []
index = 1
for keys in Teknologi_keys[index:len(Teknologi_keys)-1]:
    new_sheets = sheets_dict_Teknologi[keys].drop(['Unnamed: 0'], axis = 1)
    new_sheets = new_sheets.dropna()
    Teknologi_all_sheets.append(new_sheets)

# %% [markdown]
# ### Lowercasing

# %%
list_df_teknologi = []

soal_teknologi = 0
# Loop untuk setiap sheet dalam file Excel
for df in Teknologi_all_sheets:
    soal_teknologi = soal_teknologi + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    
    print(f"Soal: {soal_teknologi}:")
    print(df[['Jawaban', 'Jawaban Lowercase']].head())
    list_df_teknologi.append(df)
# Out:
# Soal: 1:
#                                                Jawaban  \
# No
# 1    Komputer adalah serangkaian ataupun sekelompok...
# 2                    komputer adalah mesin penghitung
# 3    mesin yang membantu manusia untuk menjalankan ...
# 4    Komputer adalah alat komputasi yang diciptakan...
# 5                      alat untuk memudahkan masnusia
#
#                                      Jawaban Lowercase
# No
# 1    komputer adalah serangkaian ataupun sekelompok...
# 2                    komputer adalah mesin penghitung
# 3    mesin yang membantu manusia untuk menjalankan ...
# 4    komputer adalah alat komputasi yang diciptakan...
# 5                      alat untuk memudahkan masnusia
# Soal: 2:
#                                                Jawaban  \
# No
# 1    - Teknologi informasi dapat digunakan untuk me...
# 2    bisnis menjadi lebih efisien, efektif, jangkau...
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...
# 4    1. Mempersingkat waktu. 2. Memudahkan dalam tr...
# 5                          untuk memudahkan kehidupan
#
#                                      Jawaban Lowercase
# No
# 1    - teknologi informasi dapat digunakan untuk me...
# 2    bisnis menjadi lebih efisien, efektif, jangkau...
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...
# 4    1. mempersingkat waktu. 2. memudahkan dalam tr...
# 5                          untuk memudahkan kehidupan
# Soal: 3:
#                                                Jawaban  \
# No
# 1    Hardware yaitu perangkat keras komputer. conto...
# 2    Hardware adalah perangkat keras, contohnya CPU...
# 3    perangkat keras komputer. mouse,keyboard,hardi...
# 4    Hardware adalah tampat atau perangkat keras ya...
# 5                                     perangkat keras
#
#                                      Jawaban Lowercase
# No
# 1    hardware yaitu perangkat keras komputer. conto...
# 2    hardware adalah perangkat keras, contohnya cpu...
# 3    perangkat keras komputer. mouse,keyboard,hardi...
# 4    hardware adalah tampat atau perangkat keras ya...
# 5                                     perangkat keras
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Data adalah kumpulan kejadian yang diangkat da...
# 2    Data adalah fakta mentah atau rincian peristiw...
# 3    data adalah sekumpulan informasi, informasi ad...
# 4    Data adalah kumpulan dari beberapa bahan menta...
# 5                               data berisi informasi
#
#                                      Jawaban Lowercase
# No
# 1    data adalah kumpulan kejadian yang diangkat da...
# 2    data adalah fakta mentah atau rincian peristiw...
# 3    data adalah sekumpulan informasi, informasi ad...
# 4    data adalah kumpulan dari beberapa bahan menta...
# 5                               data berisi informasi
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Recycle yaitu mendaur ulang sesuatu atau men...
# 2    dengan menerapkan program extended producer re...
# 3    di daur ulang, memanfaatkan yang masih bisa di...
# 4    1. Mendaur ulang. 2. Mengubah menjadi kerajina...
# 5                                dibuang di tempatnya
#
#                                      Jawaban Lowercase
# No
# 1    - recycle yaitu mendaur ulang sesuatu atau men...
# 2    dengan menerapkan program extended producer re...
# 3    di daur ulang, memanfaatkan yang masih bisa di...
# 4    1. mendaur ulang. 2. mengubah menjadi kerajina...
# 5                                dibuang di tempatnya
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Volatile memory adalah memory yang datanya dap...
# 2    merupakan memory yang datanya dapat ditulis se...
# 3                                   memori penyimapan
# 4    Merupakan memory yang datanya dapat ditulis se...
# 5                                memori jangka pendek
#
#                                      Jawaban Lowercase
# No
# 1    volatile memory adalah memory yang datanya dap...
# 2    merupakan memory yang datanya dapat ditulis se...
# 3                                   memori penyimapan
# 4    merupakan memory yang datanya dapat ditulis se...
# 5                                memori jangka pendek
# Soal: 7:
#                                                Jawaban  \
# No
# 1    LCD (Liquid Cristal Display), CPU (Central Pro...
# 2    liquid crystal display, central processing uni...
# 3    liquid crystal display, central prosesor unit,...
# 4    LCD = Liquid Crystal Display. CPU = Control Pr...
# 5    LCD = liquid crystal display CPU=Central perso...
#
#                                      Jawaban Lowercase
# No
# 1    lcd (liquid cristal display), cpu (central pro...
# 2    liquid crystal display, central processing uni...
# 3    liquid crystal display, central prosesor unit,...
# 4    lcd = liquid crystal display. cpu = control pr...
# 5    lcd = liquid crystal display cpu=central perso...
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Cupcake, Donat, Eclair, Froyo, Gingerbread, Ho...
# 2    cupcake,doughnat, eclair, froyo, gingerbread, ...
# 3    donut,eclair,froyo,gingerbread,honeycomb,ice c...
# 4    Cupkace, Donut, Eclair, Froyo, Gingerbread, Ho...
# 5                    gingerbread , ice cream sandwich
#
#                                      Jawaban Lowercase
# No
# 1    cupcake, donat, eclair, froyo, gingerbread, ho...
# 2    cupcake,doughnat, eclair, froyo, gingerbread, ...
# 3    donut,eclair,froyo,gingerbread,honeycomb,ice c...
# 4    cupkace, donut, eclair, froyo, gingerbread, ho...
# 5                    gingerbread , ice cream sandwich
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Topologi adalah cara stasiun atau host (node) ...
# 2    Pengertian Topologi jaringan adalah bagian yan...
# 3    topologi jaringan komputer. topologi bus,topol...
# 4    LAN (Local Are Network) menghubungkan satu kom...
# 5                               jaringan dengan kabel
#
#                                      Jawaban Lowercase
# No
# 1    topologi adalah cara stasiun atau host (node) ...
# 2    pengertian topologi jaringan adalah bagian yan...
# 3    topologi jaringan komputer. topologi bus,topol...
# 4    lan (local are network) menghubungkan satu kom...
# 5                               jaringan dengan kabel
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Bluetooth adalah suatu peralatan media komunik...
# 2    Bluetooth adalah spesifikasi industri untuk ja...
# 3                        untuk menstranfer suatu file
# 4    Bluetooth adalah spesifikasi industri untuk ja...
# 5                                 transfer antar hape
#
#                                      Jawaban Lowercase
# No
# 1    bluetooth adalah suatu peralatan media komunik...
# 2    bluetooth adalah spesifikasi industri untuk ja...
# 3                        untuk menstranfer suatu file
# 4    bluetooth adalah spesifikasi industri untuk ja...
# 5                                 transfer antar hape
# <ipython-input-8-0d946b27382c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-0d946b27382c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-0d946b27382c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-0d946b27382c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-0d946b27382c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-0d946b27382c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-0d946b27382c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-0d946b27382c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-0d946b27382c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-0d946b27382c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())

# %%
list_df_teknologi[1]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    - Teknologi informasi dapat digunakan untuk me...      20.0      40.0
# 2    bisnis menjadi lebih efisien, efektif, jangkau...      30.0      25.0
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...      28.0      25.0
# 4    1. Mempersingkat waktu. 2. Memudahkan dalam tr...      25.0      30.0
# 5                          untuk memudahkan kehidupan        5.0       4.0
# 6    Semakin maraknya penggunaan TIK akan semakin m...      22.0      30.0
# 7    dapat memudahkan proses perencanaan, distribus...      18.0      30.0
# 8    Penerapan Teknologi Informasi Dunia Bisnis .Te...      15.0      30.0
# 9    -Semakin maraknya penggunaan TIK akan Semakin ...      22.0      35.0
# 10   1. Semakin maraknya penggunaan TIK akan semaki...      22.0      40.0
# 11   Memperluas Pangsa Pasar, Mengurangi biaya prod...      40.0      50.0
# 12             Dapat menyimpan file-file yang penting       18.0      10.0
# 13   mempercepat kinerja bisnis, membuat pekerjaan ...      29.0      20.0
# 14   1. untuk pengembang bisnis 2. untuk memperluas...      22.0      20.0
# 15   untuk memudahkan pemasaran , memudahkan pengol...      37.0      28.0
# 16   mempermudah koneksi antar perusahaan, menambah...      30.0      29.0
# 17             -lebih efisien -lebih hemat -lebih aman      26.0      30.0
# 18   mempermudah transaksi bisnis, mempermudah kegi...      21.0      25.0
# 19   Berikut ini adalah keuntungan dari teknologi I...      37.0      45.0
# 20                                praktis, memudahkan       10.0      10.0
# 21   kecepatan transaksi. kenyamanan pelanggan. ket...      17.0      15.0
# 22   - Sebagai media pemasaran / transaksi - Sebaga...      22.0      35.0
# 23   -Dengan adanya Teknologi, kita dapat memanfaat...      30.0      40.0
# 24   -mempermudah Dalam menjalankan Bisnis -memberi...      27.0      25.0
# 25   bisnis dapat terstruktur dengan lebih baik leb...      12.0      20.0
# 26   bisnis dapat menjadi lebih terstruktur, lebih ...      22.0      30.0
# 27   Pemasaran semakin luas dan mudah, Pengelolaan ...      27.0      30.0
# 28   -mempermudah Dalam bidang pemasaran. -mempermu...      21.0      25.0
# 29              mempermudah dalam transaksi jual beli       18.0      15.0
# 30   - mendapat keuntungan - memudahkan transaksi -...      20.0      35.0
# 31       - cepat - efektif - efisien - praktis - mudah      14.0      30.0
# 32   -mempermudah proses transaksi Bisnis -memperlu...      18.0      30.0
# 33   Menghemat waktu karena pesan lebih cepat diter...      30.0      50.0
# 34   - membantu mempercepat pekerjaan manusia - mem...      33.0      45.0
# 35   -Kemajuan Teknologi komunikasi yang cepat dapa...      28.0      40.0
# 36   - Membantu mempercepat pekerjaan manusia. Deng...      22.0      25.0
# 37   -Semakin maraknya penggunaan TIK akan Semakin ...      24.0      25.0
# 38   - komunikasi yang cepat - Teknologi Sebagai me...      28.0      35.0
# 39   - Munculnya peluang Bisnis baru yakni e-Busine...      31.0      35.0
# 40   memperbanyak keuntungan. mempermudah pekerjaan...      25.0      20.0
# 41   tidak ada jarak tempat aantara penjual dan pem...      18.0      40.0
# 42   Kegiatan bisnis mudah berjalan, tidak ada bata...      25.0      45.0
# 43   mempermudah dalam pengolahan data-data yang ad...      15.0      10.0
# 44   pekerjaan lebih efisien menejemen database mud...      20.0      20.0
# 45   - jaringan Bisnis turun menurun - jika Bisnis ...      15.0      15.0
# 46   bisnis berjalan cepat , dapat maju dengan peas...      24.0      20.0
# 47               hemat waktu. hemat biaya. lebih rapi       17.0      25.0
# 48                 efisien, hemat, cepat, dan efektif       22.0      25.0
# 49                                  cepat tepat mudah       17.0      10.0
# 50   Informasi yang dibutuhkan akan semakin cepat d...      22.0      30.0
# 51         mempermudah pekerjaan dan pengolahan angka        7.0       5.0
# 52            -lebih ringkas -lebih cepat -lebih mudah      15.0      20.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase
# No
# 1        25.0    28.333333  - teknologi informasi dapat digunakan untuk me...
# 2        25.0    26.666667  bisnis menjadi lebih efisien, efektif, jangkau...
# 3        25.0    26.000000  mempersingkat waktu,memperoleh koneksi bisnis ...
# 4        25.0    26.666667  1. mempersingkat waktu. 2. memudahkan dalam tr...
# 5        10.0     6.333333                        untuk memudahkan kehidupan
# 6        25.0    25.666667  semakin maraknya penggunaan tik akan semakin m...
# 7        25.0    24.333333  dapat memudahkan proses perencanaan, distribus...
# 8        25.0    23.333333  penerapan teknologi informasi dunia bisnis .te...
# 9        25.0    27.333333  -semakin maraknya penggunaan tik akan semakin ...
# 10       25.0    29.000000  1. semakin maraknya penggunaan tik akan semaki...
# 11       50.0    46.666667  memperluas pangsa pasar, mengurangi biaya prod...
# 12       10.0    12.666667            dapat menyimpan file-file yang penting
# 13       25.0    24.666667  mempercepat kinerja bisnis, membuat pekerjaan ...
# 14       25.0    22.333333  1. untuk pengembang bisnis 2. untuk memperluas...
# 15       25.0    30.000000  untuk memudahkan pemasaran , memudahkan pengol...
# 16       25.0    28.000000  mempermudah koneksi antar perusahaan, menambah...
# 17       25.0    27.000000            -lebih efisien -lebih hemat -lebih aman
# 18       25.0    23.666667  mempermudah transaksi bisnis, mempermudah kegi...
# 19       50.0    44.000000  berikut ini adalah keuntungan dari teknologi i...
# 20       10.0    10.000000                               praktis, memudahkan
# 21       25.0    19.000000  kecepatan transaksi. kenyamanan pelanggan. ket...
# 22       25.0    27.333333  - sebagai media pemasaran / transaksi - sebaga...
# 23       50.0    40.000000  -dengan adanya teknologi, kita dapat memanfaat...
# 24       25.0    25.666667  -mempermudah dalam menjalankan bisnis -memberi...
# 25       25.0    19.000000  bisnis dapat terstruktur dengan lebih baik leb...
# 26       25.0    25.666667  bisnis dapat menjadi lebih terstruktur, lebih ...
# 27       25.0    27.333333  pemasaran semakin luas dan mudah, pengelolaan ...
# 28       25.0    23.666667  -mempermudah dalam bidang pemasaran. -mempermu...
# 29       25.0    19.333333             mempermudah dalam transaksi jual beli
# 30       25.0    26.666667  - mendapat keuntungan - memudahkan transaksi -...
# 31       25.0    23.000000      - cepat - efektif - efisien - praktis - mudah
# 32       25.0    24.333333  -mempermudah proses transaksi bisnis -memperlu...
# 33       50.0    43.333333  menghemat waktu karena pesan lebih cepat diter...
# 34       50.0    42.666667  - membantu mempercepat pekerjaan manusia - mem...
# 35       50.0    39.333333  -kemajuan teknologi komunikasi yang cepat dapa...
# 36       25.0    24.000000  - membantu mempercepat pekerjaan manusia. deng...
# 37       25.0    24.666667  -semakin maraknya penggunaan tik akan semakin ...
# 38       25.0    29.333333  - komunikasi yang cepat - teknologi sebagai me...
# 39       25.0    30.333333  - munculnya peluang bisnis baru yakni e-busine...
# 40       25.0    23.333333  memperbanyak keuntungan. mempermudah pekerjaan...
# 41       25.0    27.666667  tidak ada jarak tempat aantara penjual dan pem...
# 42       25.0    31.666667  kegiatan bisnis mudah berjalan, tidak ada bata...
# 43       10.0    11.666667  mempermudah dalam pengolahan data-data yang ad...
# 44       25.0    21.666667  pekerjaan lebih efisien menejemen database mud...
# 45       10.0    13.333333  - jaringan bisnis turun menurun - jika bisnis ...
# 46       25.0    23.000000  bisnis berjalan cepat , dapat maju dengan peas...
# 47       25.0    22.333333              hemat waktu. hemat biaya. lebih rapi
# 48       25.0    24.000000                efisien, hemat, cepat, dan efektif
# 49       25.0    17.333333                                 cepat tepat mudah
# 50       25.0    25.666667  informasi yang dibutuhkan akan semakin cepat d...
# 51       10.0     7.333333        mempermudah pekerjaan dan pengolahan angka
# 52       25.0    20.000000           -lebih ringkas -lebih cepat -lebih mudah

# %% [markdown]
# ### Remove Punctuation

# %%
import re

list_df_teknologi = []
# Membuat list punctuation yang akan dihapus
punctuation = r'[^\w\s]'

soal_teknologi = 0
for df in Teknologi_all_sheets:
    soal_teknologi = soal_teknologi + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
    
    print(f"Soal: {soal_teknologi}:")
    print(df[['Jawaban', 'Jawaban tanpa Punctuation']].head())
    list_df_teknologi.append(df)
# Out:
# Soal: 1:
#                                                Jawaban  \
# No
# 1    Komputer adalah serangkaian ataupun sekelompok...
# 2                    komputer adalah mesin penghitung
# 3    mesin yang membantu manusia untuk menjalankan ...
# 4    Komputer adalah alat komputasi yang diciptakan...
# 5                      alat untuk memudahkan masnusia
#
#                              Jawaban tanpa Punctuation
# No
# 1    komputer adalah serangkaian ataupun sekelompok...
# 2                    komputer adalah mesin penghitung
# 3    mesin yang membantu manusia untuk menjalankan ...
# 4    komputer adalah alat komputasi yang diciptakan...
# 5                      alat untuk memudahkan masnusia
# Soal: 2:
#                                                Jawaban  \
# No
# 1    - Teknologi informasi dapat digunakan untuk me...
# 2    bisnis menjadi lebih efisien, efektif, jangkau...
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...
# 4    1. Mempersingkat waktu. 2. Memudahkan dalam tr...
# 5                          untuk memudahkan kehidupan
#
#                              Jawaban tanpa Punctuation
# No
# 1     teknologi informasi dapat digunakan untuk men...
# 2    bisnis menjadi lebih efisien efektif jangkauan...
# 3    mempersingkat waktumemperoleh koneksi bisnis d...
# 4    1 mempersingkat waktu 2 memudahkan dalam trans...
# 5                          untuk memudahkan kehidupan
# Soal: 3:
#                                                Jawaban  \
# No
# 1    Hardware yaitu perangkat keras komputer. conto...
# 2    Hardware adalah perangkat keras, contohnya CPU...
# 3    perangkat keras komputer. mouse,keyboard,hardi...
# 4    Hardware adalah tampat atau perangkat keras ya...
# 5                                     perangkat keras
#
#                              Jawaban tanpa Punctuation
# No
# 1    hardware yaitu perangkat keras komputer contoh...
# 2    hardware adalah perangkat keras contohnya cpu ...
# 3    perangkat keras komputer mousekeyboardhardiskf...
# 4    hardware adalah tampat atau perangkat keras ya...
# 5                                     perangkat keras
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Data adalah kumpulan kejadian yang diangkat da...
# 2    Data adalah fakta mentah atau rincian peristiw...
# 3    data adalah sekumpulan informasi, informasi ad...
# 4    Data adalah kumpulan dari beberapa bahan menta...
# 5                               data berisi informasi
#
#                              Jawaban tanpa Punctuation
# No
# 1    data adalah kumpulan kejadian yang diangkat da...
# 2    data adalah fakta mentah atau rincian peristiw...
# 3    data adalah sekumpulan informasi informasi ada...
# 4    data adalah kumpulan dari beberapa bahan menta...
# 5                               data berisi informasi
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Recycle yaitu mendaur ulang sesuatu atau men...
# 2    dengan menerapkan program extended producer re...
# 3    di daur ulang, memanfaatkan yang masih bisa di...
# 4    1. Mendaur ulang. 2. Mengubah menjadi kerajina...
# 5                                dibuang di tempatnya
#
#                              Jawaban tanpa Punctuation
# No
# 1     recycle yaitu mendaur ulang sesuatu atau meng...
# 2    dengan menerapkan program extended producer re...
# 3    di daur ulang memanfaatkan yang masih bisa di ...
# 4    1 mendaur ulang 2 mengubah menjadi kerajinan t...
# 5                                dibuang di tempatnya
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Volatile memory adalah memory yang datanya dap...
# 2    merupakan memory yang datanya dapat ditulis se...
# 3                                   memori penyimapan
# 4    Merupakan memory yang datanya dapat ditulis se...
# 5                                memori jangka pendek
#
#                              Jawaban tanpa Punctuation
# No
# 1    volatile memory adalah memory yang datanya dap...
# 2    merupakan memory yang datanya dapat ditulis se...
# 3                                   memori penyimapan
# 4    merupakan memory yang datanya dapat ditulis se...
# 5                                memori jangka pendek
# Soal: 7:
#                                                Jawaban  \
# No
# 1    LCD (Liquid Cristal Display), CPU (Central Pro...
# 2    liquid crystal display, central processing uni...
# 3    liquid crystal display, central prosesor unit,...
# 4    LCD = Liquid Crystal Display. CPU = Control Pr...
# 5    LCD = liquid crystal display CPU=Central perso...
#
#                              Jawaban tanpa Punctuation
# No
# 1    lcd liquid cristal display cpu central process...
# 2    liquid crystal display central processing unit...
# 3    liquid crystal display central prosesor unit g...
# 4    lcd  liquid crystal display cpu  control proce...
# 5    lcd  liquid crystal display cpucentral persona...
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Cupcake, Donat, Eclair, Froyo, Gingerbread, Ho...
# 2    cupcake,doughnat, eclair, froyo, gingerbread, ...
# 3    donut,eclair,froyo,gingerbread,honeycomb,ice c...
# 4    Cupkace, Donut, Eclair, Froyo, Gingerbread, Ho...
# 5                    gingerbread , ice cream sandwich
#
#                              Jawaban tanpa Punctuation
# No
# 1    cupcake donat eclair froyo gingerbread honeyco...
# 2    cupcakedoughnat eclair froyo gingerbread honey...
# 3    donuteclairfroyogingerbreadhoneycombice cream ...
# 4    cupkace donut eclair froyo gingerbread honeyco...
# 5                     gingerbread  ice cream sandwich
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Topologi adalah cara stasiun atau host (node) ...
# 2    Pengertian Topologi jaringan adalah bagian yan...
# 3    topologi jaringan komputer. topologi bus,topol...
# 4    LAN (Local Are Network) menghubungkan satu kom...
# 5                               jaringan dengan kabel
#
#                              Jawaban tanpa Punctuation
# No
# 1    topologi adalah cara stasiun atau host node sa...
# 2    pengertian topologi jaringan adalah bagian yan...
# 3    topologi jaringan komputer topologi bustopolog...
# 4    lan local are network menghubungkan satu kompu...
# 5                               jaringan dengan kabel
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Bluetooth adalah suatu peralatan media komunik...
# 2    Bluetooth adalah spesifikasi industri untuk ja...
# 3                        untuk menstranfer suatu file
# 4    Bluetooth adalah spesifikasi industri untuk ja...
# 5                                 transfer antar hape
#
#                              Jawaban tanpa Punctuation
# No
# 1    bluetooth adalah suatu peralatan media komunik...
# 2    bluetooth adalah spesifikasi industri untuk ja...
# 3                        untuk menstranfer suatu file
# 4    bluetooth adalah spesifikasi industri untuk ja...
# 5                                 transfer antar hape
# <ipython-input-10-3d14d97d7891>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-3d14d97d7891>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-3d14d97d7891>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-3d14d97d7891>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-3d14d97d7891>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-3d14d97d7891>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-3d14d97d7891>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-3d14d97d7891>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-3d14d97d7891>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-3d14d97d7891>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-3d14d97d7891>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-3d14d97d7891>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-3d14d97d7891>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-3d14d97d7891>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-3d14d97d7891>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-3d14d97d7891>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-3d14d97d7891>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-3d14d97d7891>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-3d14d97d7891>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-3d14d97d7891>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))

# %%
list_df_teknologi[1]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    - Teknologi informasi dapat digunakan untuk me...      20.0      40.0
# 2    bisnis menjadi lebih efisien, efektif, jangkau...      30.0      25.0
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...      28.0      25.0
# 4    1. Mempersingkat waktu. 2. Memudahkan dalam tr...      25.0      30.0
# 5                          untuk memudahkan kehidupan        5.0       4.0
# 6    Semakin maraknya penggunaan TIK akan semakin m...      22.0      30.0
# 7    dapat memudahkan proses perencanaan, distribus...      18.0      30.0
# 8    Penerapan Teknologi Informasi Dunia Bisnis .Te...      15.0      30.0
# 9    -Semakin maraknya penggunaan TIK akan Semakin ...      22.0      35.0
# 10   1. Semakin maraknya penggunaan TIK akan semaki...      22.0      40.0
# 11   Memperluas Pangsa Pasar, Mengurangi biaya prod...      40.0      50.0
# 12             Dapat menyimpan file-file yang penting       18.0      10.0
# 13   mempercepat kinerja bisnis, membuat pekerjaan ...      29.0      20.0
# 14   1. untuk pengembang bisnis 2. untuk memperluas...      22.0      20.0
# 15   untuk memudahkan pemasaran , memudahkan pengol...      37.0      28.0
# 16   mempermudah koneksi antar perusahaan, menambah...      30.0      29.0
# 17             -lebih efisien -lebih hemat -lebih aman      26.0      30.0
# 18   mempermudah transaksi bisnis, mempermudah kegi...      21.0      25.0
# 19   Berikut ini adalah keuntungan dari teknologi I...      37.0      45.0
# 20                                praktis, memudahkan       10.0      10.0
# 21   kecepatan transaksi. kenyamanan pelanggan. ket...      17.0      15.0
# 22   - Sebagai media pemasaran / transaksi - Sebaga...      22.0      35.0
# 23   -Dengan adanya Teknologi, kita dapat memanfaat...      30.0      40.0
# 24   -mempermudah Dalam menjalankan Bisnis -memberi...      27.0      25.0
# 25   bisnis dapat terstruktur dengan lebih baik leb...      12.0      20.0
# 26   bisnis dapat menjadi lebih terstruktur, lebih ...      22.0      30.0
# 27   Pemasaran semakin luas dan mudah, Pengelolaan ...      27.0      30.0
# 28   -mempermudah Dalam bidang pemasaran. -mempermu...      21.0      25.0
# 29              mempermudah dalam transaksi jual beli       18.0      15.0
# 30   - mendapat keuntungan - memudahkan transaksi -...      20.0      35.0
# 31       - cepat - efektif - efisien - praktis - mudah      14.0      30.0
# 32   -mempermudah proses transaksi Bisnis -memperlu...      18.0      30.0
# 33   Menghemat waktu karena pesan lebih cepat diter...      30.0      50.0
# 34   - membantu mempercepat pekerjaan manusia - mem...      33.0      45.0
# 35   -Kemajuan Teknologi komunikasi yang cepat dapa...      28.0      40.0
# 36   - Membantu mempercepat pekerjaan manusia. Deng...      22.0      25.0
# 37   -Semakin maraknya penggunaan TIK akan Semakin ...      24.0      25.0
# 38   - komunikasi yang cepat - Teknologi Sebagai me...      28.0      35.0
# 39   - Munculnya peluang Bisnis baru yakni e-Busine...      31.0      35.0
# 40   memperbanyak keuntungan. mempermudah pekerjaan...      25.0      20.0
# 41   tidak ada jarak tempat aantara penjual dan pem...      18.0      40.0
# 42   Kegiatan bisnis mudah berjalan, tidak ada bata...      25.0      45.0
# 43   mempermudah dalam pengolahan data-data yang ad...      15.0      10.0
# 44   pekerjaan lebih efisien menejemen database mud...      20.0      20.0
# 45   - jaringan Bisnis turun menurun - jika Bisnis ...      15.0      15.0
# 46   bisnis berjalan cepat , dapat maju dengan peas...      24.0      20.0
# 47               hemat waktu. hemat biaya. lebih rapi       17.0      25.0
# 48                 efisien, hemat, cepat, dan efektif       22.0      25.0
# 49                                  cepat tepat mudah       17.0      10.0
# 50   Informasi yang dibutuhkan akan semakin cepat d...      22.0      30.0
# 51         mempermudah pekerjaan dan pengolahan angka        7.0       5.0
# 52            -lebih ringkas -lebih cepat -lebih mudah      15.0      20.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase  \
# No
# 1        25.0    28.333333  - teknologi informasi dapat digunakan untuk me...
# 2        25.0    26.666667  bisnis menjadi lebih efisien, efektif, jangkau...
# 3        25.0    26.000000  mempersingkat waktu,memperoleh koneksi bisnis ...
# 4        25.0    26.666667  1. mempersingkat waktu. 2. memudahkan dalam tr...
# 5        10.0     6.333333                        untuk memudahkan kehidupan
# 6        25.0    25.666667  semakin maraknya penggunaan tik akan semakin m...
# 7        25.0    24.333333  dapat memudahkan proses perencanaan, distribus...
# 8        25.0    23.333333  penerapan teknologi informasi dunia bisnis .te...
# 9        25.0    27.333333  -semakin maraknya penggunaan tik akan semakin ...
# 10       25.0    29.000000  1. semakin maraknya penggunaan tik akan semaki...
# 11       50.0    46.666667  memperluas pangsa pasar, mengurangi biaya prod...
# 12       10.0    12.666667            dapat menyimpan file-file yang penting
# 13       25.0    24.666667  mempercepat kinerja bisnis, membuat pekerjaan ...
# 14       25.0    22.333333  1. untuk pengembang bisnis 2. untuk memperluas...
# 15       25.0    30.000000  untuk memudahkan pemasaran , memudahkan pengol...
# 16       25.0    28.000000  mempermudah koneksi antar perusahaan, menambah...
# 17       25.0    27.000000            -lebih efisien -lebih hemat -lebih aman
# 18       25.0    23.666667  mempermudah transaksi bisnis, mempermudah kegi...
# 19       50.0    44.000000  berikut ini adalah keuntungan dari teknologi i...
# 20       10.0    10.000000                               praktis, memudahkan
# 21       25.0    19.000000  kecepatan transaksi. kenyamanan pelanggan. ket...
# 22       25.0    27.333333  - sebagai media pemasaran / transaksi - sebaga...
# 23       50.0    40.000000  -dengan adanya teknologi, kita dapat memanfaat...
# 24       25.0    25.666667  -mempermudah dalam menjalankan bisnis -memberi...
# 25       25.0    19.000000  bisnis dapat terstruktur dengan lebih baik leb...
# 26       25.0    25.666667  bisnis dapat menjadi lebih terstruktur, lebih ...
# 27       25.0    27.333333  pemasaran semakin luas dan mudah, pengelolaan ...
# 28       25.0    23.666667  -mempermudah dalam bidang pemasaran. -mempermu...
# 29       25.0    19.333333             mempermudah dalam transaksi jual beli
# 30       25.0    26.666667  - mendapat keuntungan - memudahkan transaksi -...
# 31       25.0    23.000000      - cepat - efektif - efisien - praktis - mudah
# 32       25.0    24.333333  -mempermudah proses transaksi bisnis -memperlu...
# 33       50.0    43.333333  menghemat waktu karena pesan lebih cepat diter...
# 34       50.0    42.666667  - membantu mempercepat pekerjaan manusia - mem...
# 35       50.0    39.333333  -kemajuan teknologi komunikasi yang cepat dapa...
# 36       25.0    24.000000  - membantu mempercepat pekerjaan manusia. deng...
# 37       25.0    24.666667  -semakin maraknya penggunaan tik akan semakin ...
# 38       25.0    29.333333  - komunikasi yang cepat - teknologi sebagai me...
# 39       25.0    30.333333  - munculnya peluang bisnis baru yakni e-busine...
# 40       25.0    23.333333  memperbanyak keuntungan. mempermudah pekerjaan...
# 41       25.0    27.666667  tidak ada jarak tempat aantara penjual dan pem...
# 42       25.0    31.666667  kegiatan bisnis mudah berjalan, tidak ada bata...
# 43       10.0    11.666667  mempermudah dalam pengolahan data-data yang ad...
# 44       25.0    21.666667  pekerjaan lebih efisien menejemen database mud...
# 45       10.0    13.333333  - jaringan bisnis turun menurun - jika bisnis ...
# 46       25.0    23.000000  bisnis berjalan cepat , dapat maju dengan peas...
# 47       25.0    22.333333              hemat waktu. hemat biaya. lebih rapi
# 48       25.0    24.000000                efisien, hemat, cepat, dan efektif
# 49       25.0    17.333333                                 cepat tepat mudah
# 50       25.0    25.666667  informasi yang dibutuhkan akan semakin cepat d...
# 51       10.0     7.333333        mempermudah pekerjaan dan pengolahan angka
# 52       25.0    20.000000           -lebih ringkas -lebih cepat -lebih mudah
#
#                              Jawaban tanpa Punctuation
# No
# 1     teknologi informasi dapat digunakan untuk men...
# 2    bisnis menjadi lebih efisien efektif jangkauan...
# 3    mempersingkat waktumemperoleh koneksi bisnis d...
# 4    1 mempersingkat waktu 2 memudahkan dalam trans...
# 5                          untuk memudahkan kehidupan
# 6    semakin maraknya penggunaan tik akan semakin m...
# 7    dapat memudahkan proses perencanaan distribusi...
# 8    penerapan teknologi informasi dunia bisnis tek...
# 9    semakin maraknya penggunaan tik akan semakin m...
# 10   1 semakin maraknya penggunaan tik akan semakin...
# 11   memperluas pangsa pasar mengurangi biaya produ...
# 12              dapat menyimpan filefile yang penting
# 13   mempercepat kinerja bisnis membuat pekerjaan b...
# 14   1 untuk pengembang bisnis 2 untuk memperluas b...
# 15   untuk memudahkan pemasaran  memudahkan pengola...
# 16   mempermudah koneksi antar perusahaan menambah ...
# 17                lebih efisien lebih hemat lebih aman
# 18   mempermudah transaksi bisnis mempermudah kegia...
# 19   berikut ini adalah keuntungan dari teknologi i...
# 20                                 praktis memudahkan
# 21   kecepatan transaksi kenyamanan pelanggan ketep...
# 22    sebagai media pemasaran  transaksi  sebagai m...
# 23   dengan adanya teknologi kita dapat memanfaatka...
# 24   mempermudah dalam menjalankan bisnis memberika...
# 25   bisnis dapat terstruktur dengan lebih baik leb...
# 26   bisnis dapat menjadi lebih terstruktur lebih m...
# 27   pemasaran semakin luas dan mudah pengelolaan d...
# 28   mempermudah dalam bidang pemasaran mempermudah...
# 29              mempermudah dalam transaksi jual beli
# 30    mendapat keuntungan  memudahkan transaksi  me...
# 31             cepat  efektif  efisien  praktis  mudah
# 32   mempermudah proses transaksi bisnis memperluas...
# 33   menghemat waktu karena pesan lebih cepat diter...
# 34    membantu mempercepat pekerjaan manusia  mempe...
# 35   kemajuan teknologi komunikasi yang cepat dapat...
# 36    membantu mempercepat pekerjaan manusia dengan...
# 37   semakin maraknya penggunaan tik akan semakin m...
# 38    komunikasi yang cepat  teknologi sebagai medi...
# 39    munculnya peluang bisnis baru yakni ebusiness...
# 40   memperbanyak keuntungan mempermudah pekerjaan ...
# 41   tidak ada jarak tempat aantara penjual dan pem...
# 42   kegiatan bisnis mudah berjalan tidak ada batas...
# 43   mempermudah dalam pengolahan datadata yang ada...
# 44   pekerjaan lebih efisien menejemen database mud...
# 45    jaringan bisnis turun menurun  jika bisnis la...
# 46   bisnis berjalan cepat  dapat maju dengan peasa...
# 47                 hemat waktu hemat biaya lebih rapi
# 48                    efisien hemat cepat dan efektif
# 49                                  cepat tepat mudah
# 50   informasi yang dibutuhkan akan semakin cepat d...
# 51         mempermudah pekerjaan dan pengolahan angka
# 52               lebih ringkas lebih cepat lebih mudah

# %% [markdown]
# ### Tokenization

# %%
import nltk
list_df_teknologi = []

soal_teknologi = 0
for df in Teknologi_all_sheets:
    soal_teknologi = soal_teknologi + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
    df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
    
    print(f"Soal: {soal_teknologi}:")
    print(df[['Jawaban', 'Jawaban Tokenization']].head())
    list_df_teknologi.append(df)
# Out:
# <ipython-input-12-676900edbffb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-676900edbffb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-676900edbffb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-676900edbffb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-676900edbffb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-676900edbffb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# Soal: 1:
#                                                Jawaban  \
# No
# 1    Komputer adalah serangkaian ataupun sekelompok...
# 2                    komputer adalah mesin penghitung
# 3    mesin yang membantu manusia untuk menjalankan ...
# 4    Komputer adalah alat komputasi yang diciptakan...
# 5                      alat untuk memudahkan masnusia
#
#                                   Jawaban Tokenization
# No
# 1    [komputer, adalah, serangkaian, ataupun, sekel...
# 2                [komputer, adalah, mesin, penghitung]
# 3    [mesin, yang, membantu, manusia, untuk, menjal...
# 4    [komputer, adalah, alat, komputasi, yang, dici...
# 5                  [alat, untuk, memudahkan, masnusia]
# <ipython-input-12-676900edbffb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-676900edbffb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-676900edbffb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-676900edbffb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-676900edbffb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-676900edbffb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-676900edbffb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-676900edbffb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-676900edbffb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-676900edbffb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-676900edbffb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-676900edbffb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-676900edbffb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-676900edbffb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# Soal: 2:
#                                                Jawaban  \
# No
# 1    - Teknologi informasi dapat digunakan untuk me...
# 2    bisnis menjadi lebih efisien, efektif, jangkau...
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...
# 4    1. Mempersingkat waktu. 2. Memudahkan dalam tr...
# 5                          untuk memudahkan kehidupan
#
#                                   Jawaban Tokenization
# No
# 1    [teknologi, informasi, dapat, digunakan, untuk...
# 2    [bisnis, menjadi, lebih, efisien, efektif, jan...
# 3    [mempersingkat, waktumemperoleh, koneksi, bisn...
# 4    [1, mempersingkat, waktu, 2, memudahkan, dalam...
# 5                       [untuk, memudahkan, kehidupan]
# Soal: 3:
#                                                Jawaban  \
# No
# 1    Hardware yaitu perangkat keras komputer. conto...
# 2    Hardware adalah perangkat keras, contohnya CPU...
# 3    perangkat keras komputer. mouse,keyboard,hardi...
# 4    Hardware adalah tampat atau perangkat keras ya...
# 5                                     perangkat keras
#
#                                   Jawaban Tokenization
# No
# 1    [hardware, yaitu, perangkat, keras, komputer, ...
# 2    [hardware, adalah, perangkat, keras, contohnya...
# 3    [perangkat, keras, komputer, mousekeyboardhard...
# 4    [hardware, adalah, tampat, atau, perangkat, ke...
# 5                                   [perangkat, keras]
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Data adalah kumpulan kejadian yang diangkat da...
# 2    Data adalah fakta mentah atau rincian peristiw...
# 3    data adalah sekumpulan informasi, informasi ad...
# 4    Data adalah kumpulan dari beberapa bahan menta...
# 5                               data berisi informasi
#
#                                   Jawaban Tokenization
# No
# 1    [data, adalah, kumpulan, kejadian, yang, diang...
# 2    [data, adalah, fakta, mentah, atau, rincian, p...
# 3    [data, adalah, sekumpulan, informasi, informas...
# 4    [data, adalah, kumpulan, dari, beberapa, bahan...
# 5                            [data, berisi, informasi]
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Recycle yaitu mendaur ulang sesuatu atau men...
# 2    dengan menerapkan program extended producer re...
# 3    di daur ulang, memanfaatkan yang masih bisa di...
# 4    1. Mendaur ulang. 2. Mengubah menjadi kerajina...
# 5                                dibuang di tempatnya
#
#                                   Jawaban Tokenization
# No
# 1    [recycle, yaitu, mendaur, ulang, sesuatu, atau...
# 2    [dengan, menerapkan, program, extended, produc...
# 3    [di, daur, ulang, memanfaatkan, yang, masih, b...
# 4    [1, mendaur, ulang, 2, mengubah, menjadi, kera...
# 5                             [dibuang, di, tempatnya]
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Volatile memory adalah memory yang datanya dap...
# 2    merupakan memory yang datanya dapat ditulis se...
# 3                                   memori penyimapan
# 4    Merupakan memory yang datanya dapat ditulis se...
# 5                                memori jangka pendek
#
#                                   Jawaban Tokenization
# No
# 1    [volatile, memory, adalah, memory, yang, datan...
# 2    [merupakan, memory, yang, datanya, dapat, ditu...
# 3                                 [memori, penyimapan]
# 4    [merupakan, memory, yang, datanya, dapat, ditu...
# 5                             [memori, jangka, pendek]
# Soal: 7:
#                                                Jawaban  \
# No
# 1    LCD (Liquid Cristal Display), CPU (Central Pro...
# 2    liquid crystal display, central processing uni...
# 3    liquid crystal display, central prosesor unit,...
# 4    LCD = Liquid Crystal Display. CPU = Control Pr...
# 5    LCD = liquid crystal display CPU=Central perso...
#
#                                   Jawaban Tokenization
# No
# 1    [lcd, liquid, cristal, display, cpu, central, ...
# 2    [liquid, crystal, display, central, processing...
# 3    [liquid, crystal, display, central, prosesor, ...
# 4    [lcd, liquid, crystal, display, cpu, control, ...
# 5    [lcd, liquid, crystal, display, cpucentral, pe...
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Cupcake, Donat, Eclair, Froyo, Gingerbread, Ho...
# 2    cupcake,doughnat, eclair, froyo, gingerbread, ...
# 3    donut,eclair,froyo,gingerbread,honeycomb,ice c...
# 4    Cupkace, Donut, Eclair, Froyo, Gingerbread, Ho...
# 5                    gingerbread , ice cream sandwich
#
#                                   Jawaban Tokenization
# No
# 1    [cupcake, donat, eclair, froyo, gingerbread, h...
# 2    [cupcakedoughnat, eclair, froyo, gingerbread, ...
# 3    [donuteclairfroyogingerbreadhoneycombice, crea...
# 4    [cupkace, donut, eclair, froyo, gingerbread, h...
# 5                  [gingerbread, ice, cream, sandwich]
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Topologi adalah cara stasiun atau host (node) ...
# 2    Pengertian Topologi jaringan adalah bagian yan...
# 3    topologi jaringan komputer. topologi bus,topol...
# 4    LAN (Local Are Network) menghubungkan satu kom...
# 5                               jaringan dengan kabel
#
#                                   Jawaban Tokenization
# No
# 1    [topologi, adalah, cara, stasiun, atau, host, ...
# 2    [pengertian, topologi, jaringan, adalah, bagia...
# 3    [topologi, jaringan, komputer, topologi, busto...
# 4    [lan, local, are, network, menghubungkan, satu...
# 5                            [jaringan, dengan, kabel]
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Bluetooth adalah suatu peralatan media komunik...
# 2    Bluetooth adalah spesifikasi industri untuk ja...
# 3                        untuk menstranfer suatu file
# 4    Bluetooth adalah spesifikasi industri untuk ja...
# 5                                 transfer antar hape
#
#                                   Jawaban Tokenization
# No
# 1    [bluetooth, adalah, suatu, peralatan, media, k...
# 2    [bluetooth, adalah, spesifikasi, industri, unt...
# 3                    [untuk, menstranfer, suatu, file]
# 4    [bluetooth, adalah, spesifikasi, industri, unt...
# 5                              [transfer, antar, hape]
# <ipython-input-12-676900edbffb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-676900edbffb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-676900edbffb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-676900edbffb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-676900edbffb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-676900edbffb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-676900edbffb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-676900edbffb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-676900edbffb>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-676900edbffb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)

# %%
list_df_teknologi[1]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    - Teknologi informasi dapat digunakan untuk me...      20.0      40.0
# 2    bisnis menjadi lebih efisien, efektif, jangkau...      30.0      25.0
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...      28.0      25.0
# 4    1. Mempersingkat waktu. 2. Memudahkan dalam tr...      25.0      30.0
# 5                          untuk memudahkan kehidupan        5.0       4.0
# 6    Semakin maraknya penggunaan TIK akan semakin m...      22.0      30.0
# 7    dapat memudahkan proses perencanaan, distribus...      18.0      30.0
# 8    Penerapan Teknologi Informasi Dunia Bisnis .Te...      15.0      30.0
# 9    -Semakin maraknya penggunaan TIK akan Semakin ...      22.0      35.0
# 10   1. Semakin maraknya penggunaan TIK akan semaki...      22.0      40.0
# 11   Memperluas Pangsa Pasar, Mengurangi biaya prod...      40.0      50.0
# 12             Dapat menyimpan file-file yang penting       18.0      10.0
# 13   mempercepat kinerja bisnis, membuat pekerjaan ...      29.0      20.0
# 14   1. untuk pengembang bisnis 2. untuk memperluas...      22.0      20.0
# 15   untuk memudahkan pemasaran , memudahkan pengol...      37.0      28.0
# 16   mempermudah koneksi antar perusahaan, menambah...      30.0      29.0
# 17             -lebih efisien -lebih hemat -lebih aman      26.0      30.0
# 18   mempermudah transaksi bisnis, mempermudah kegi...      21.0      25.0
# 19   Berikut ini adalah keuntungan dari teknologi I...      37.0      45.0
# 20                                praktis, memudahkan       10.0      10.0
# 21   kecepatan transaksi. kenyamanan pelanggan. ket...      17.0      15.0
# 22   - Sebagai media pemasaran / transaksi - Sebaga...      22.0      35.0
# 23   -Dengan adanya Teknologi, kita dapat memanfaat...      30.0      40.0
# 24   -mempermudah Dalam menjalankan Bisnis -memberi...      27.0      25.0
# 25   bisnis dapat terstruktur dengan lebih baik leb...      12.0      20.0
# 26   bisnis dapat menjadi lebih terstruktur, lebih ...      22.0      30.0
# 27   Pemasaran semakin luas dan mudah, Pengelolaan ...      27.0      30.0
# 28   -mempermudah Dalam bidang pemasaran. -mempermu...      21.0      25.0
# 29              mempermudah dalam transaksi jual beli       18.0      15.0
# 30   - mendapat keuntungan - memudahkan transaksi -...      20.0      35.0
# 31       - cepat - efektif - efisien - praktis - mudah      14.0      30.0
# 32   -mempermudah proses transaksi Bisnis -memperlu...      18.0      30.0
# 33   Menghemat waktu karena pesan lebih cepat diter...      30.0      50.0
# 34   - membantu mempercepat pekerjaan manusia - mem...      33.0      45.0
# 35   -Kemajuan Teknologi komunikasi yang cepat dapa...      28.0      40.0
# 36   - Membantu mempercepat pekerjaan manusia. Deng...      22.0      25.0
# 37   -Semakin maraknya penggunaan TIK akan Semakin ...      24.0      25.0
# 38   - komunikasi yang cepat - Teknologi Sebagai me...      28.0      35.0
# 39   - Munculnya peluang Bisnis baru yakni e-Busine...      31.0      35.0
# 40   memperbanyak keuntungan. mempermudah pekerjaan...      25.0      20.0
# 41   tidak ada jarak tempat aantara penjual dan pem...      18.0      40.0
# 42   Kegiatan bisnis mudah berjalan, tidak ada bata...      25.0      45.0
# 43   mempermudah dalam pengolahan data-data yang ad...      15.0      10.0
# 44   pekerjaan lebih efisien menejemen database mud...      20.0      20.0
# 45   - jaringan Bisnis turun menurun - jika Bisnis ...      15.0      15.0
# 46   bisnis berjalan cepat , dapat maju dengan peas...      24.0      20.0
# 47               hemat waktu. hemat biaya. lebih rapi       17.0      25.0
# 48                 efisien, hemat, cepat, dan efektif       22.0      25.0
# 49                                  cepat tepat mudah       17.0      10.0
# 50   Informasi yang dibutuhkan akan semakin cepat d...      22.0      30.0
# 51         mempermudah pekerjaan dan pengolahan angka        7.0       5.0
# 52            -lebih ringkas -lebih cepat -lebih mudah      15.0      20.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase  \
# No
# 1        25.0    28.333333  - teknologi informasi dapat digunakan untuk me...
# 2        25.0    26.666667  bisnis menjadi lebih efisien, efektif, jangkau...
# 3        25.0    26.000000  mempersingkat waktu,memperoleh koneksi bisnis ...
# 4        25.0    26.666667  1. mempersingkat waktu. 2. memudahkan dalam tr...
# 5        10.0     6.333333                        untuk memudahkan kehidupan
# 6        25.0    25.666667  semakin maraknya penggunaan tik akan semakin m...
# 7        25.0    24.333333  dapat memudahkan proses perencanaan, distribus...
# 8        25.0    23.333333  penerapan teknologi informasi dunia bisnis .te...
# 9        25.0    27.333333  -semakin maraknya penggunaan tik akan semakin ...
# 10       25.0    29.000000  1. semakin maraknya penggunaan tik akan semaki...
# 11       50.0    46.666667  memperluas pangsa pasar, mengurangi biaya prod...
# 12       10.0    12.666667            dapat menyimpan file-file yang penting
# 13       25.0    24.666667  mempercepat kinerja bisnis, membuat pekerjaan ...
# 14       25.0    22.333333  1. untuk pengembang bisnis 2. untuk memperluas...
# 15       25.0    30.000000  untuk memudahkan pemasaran , memudahkan pengol...
# 16       25.0    28.000000  mempermudah koneksi antar perusahaan, menambah...
# 17       25.0    27.000000            -lebih efisien -lebih hemat -lebih aman
# 18       25.0    23.666667  mempermudah transaksi bisnis, mempermudah kegi...
# 19       50.0    44.000000  berikut ini adalah keuntungan dari teknologi i...
# 20       10.0    10.000000                               praktis, memudahkan
# 21       25.0    19.000000  kecepatan transaksi. kenyamanan pelanggan. ket...
# 22       25.0    27.333333  - sebagai media pemasaran / transaksi - sebaga...
# 23       50.0    40.000000  -dengan adanya teknologi, kita dapat memanfaat...
# 24       25.0    25.666667  -mempermudah dalam menjalankan bisnis -memberi...
# 25       25.0    19.000000  bisnis dapat terstruktur dengan lebih baik leb...
# 26       25.0    25.666667  bisnis dapat menjadi lebih terstruktur, lebih ...
# 27       25.0    27.333333  pemasaran semakin luas dan mudah, pengelolaan ...
# 28       25.0    23.666667  -mempermudah dalam bidang pemasaran. -mempermu...
# 29       25.0    19.333333             mempermudah dalam transaksi jual beli
# 30       25.0    26.666667  - mendapat keuntungan - memudahkan transaksi -...
# 31       25.0    23.000000      - cepat - efektif - efisien - praktis - mudah
# 32       25.0    24.333333  -mempermudah proses transaksi bisnis -memperlu...
# 33       50.0    43.333333  menghemat waktu karena pesan lebih cepat diter...
# 34       50.0    42.666667  - membantu mempercepat pekerjaan manusia - mem...
# 35       50.0    39.333333  -kemajuan teknologi komunikasi yang cepat dapa...
# 36       25.0    24.000000  - membantu mempercepat pekerjaan manusia. deng...
# 37       25.0    24.666667  -semakin maraknya penggunaan tik akan semakin ...
# 38       25.0    29.333333  - komunikasi yang cepat - teknologi sebagai me...
# 39       25.0    30.333333  - munculnya peluang bisnis baru yakni e-busine...
# 40       25.0    23.333333  memperbanyak keuntungan. mempermudah pekerjaan...
# 41       25.0    27.666667  tidak ada jarak tempat aantara penjual dan pem...
# 42       25.0    31.666667  kegiatan bisnis mudah berjalan, tidak ada bata...
# 43       10.0    11.666667  mempermudah dalam pengolahan data-data yang ad...
# 44       25.0    21.666667  pekerjaan lebih efisien menejemen database mud...
# 45       10.0    13.333333  - jaringan bisnis turun menurun - jika bisnis ...
# 46       25.0    23.000000  bisnis berjalan cepat , dapat maju dengan peas...
# 47       25.0    22.333333              hemat waktu. hemat biaya. lebih rapi
# 48       25.0    24.000000                efisien, hemat, cepat, dan efektif
# 49       25.0    17.333333                                 cepat tepat mudah
# 50       25.0    25.666667  informasi yang dibutuhkan akan semakin cepat d...
# 51       10.0     7.333333        mempermudah pekerjaan dan pengolahan angka
# 52       25.0    20.000000           -lebih ringkas -lebih cepat -lebih mudah
#
#                              Jawaban tanpa Punctuation  \
# No
# 1     teknologi informasi dapat digunakan untuk men...
# 2    bisnis menjadi lebih efisien efektif jangkauan...
# 3    mempersingkat waktumemperoleh koneksi bisnis d...
# 4    1 mempersingkat waktu 2 memudahkan dalam trans...
# 5                          untuk memudahkan kehidupan
# 6    semakin maraknya penggunaan tik akan semakin m...
# 7    dapat memudahkan proses perencanaan distribusi...
# 8    penerapan teknologi informasi dunia bisnis tek...
# 9    semakin maraknya penggunaan tik akan semakin m...
# 10   1 semakin maraknya penggunaan tik akan semakin...
# 11   memperluas pangsa pasar mengurangi biaya produ...
# 12              dapat menyimpan filefile yang penting
# 13   mempercepat kinerja bisnis membuat pekerjaan b...
# 14   1 untuk pengembang bisnis 2 untuk memperluas b...
# 15   untuk memudahkan pemasaran  memudahkan pengola...
# 16   mempermudah koneksi antar perusahaan menambah ...
# 17                lebih efisien lebih hemat lebih aman
# 18   mempermudah transaksi bisnis mempermudah kegia...
# 19   berikut ini adalah keuntungan dari teknologi i...
# 20                                 praktis memudahkan
# 21   kecepatan transaksi kenyamanan pelanggan ketep...
# 22    sebagai media pemasaran  transaksi  sebagai m...
# 23   dengan adanya teknologi kita dapat memanfaatka...
# 24   mempermudah dalam menjalankan bisnis memberika...
# 25   bisnis dapat terstruktur dengan lebih baik leb...
# 26   bisnis dapat menjadi lebih terstruktur lebih m...
# 27   pemasaran semakin luas dan mudah pengelolaan d...
# 28   mempermudah dalam bidang pemasaran mempermudah...
# 29              mempermudah dalam transaksi jual beli
# 30    mendapat keuntungan  memudahkan transaksi  me...
# 31             cepat  efektif  efisien  praktis  mudah
# 32   mempermudah proses transaksi bisnis memperluas...
# 33   menghemat waktu karena pesan lebih cepat diter...
# 34    membantu mempercepat pekerjaan manusia  mempe...
# 35   kemajuan teknologi komunikasi yang cepat dapat...
# 36    membantu mempercepat pekerjaan manusia dengan...
# 37   semakin maraknya penggunaan tik akan semakin m...
# 38    komunikasi yang cepat  teknologi sebagai medi...
# 39    munculnya peluang bisnis baru yakni ebusiness...
# 40   memperbanyak keuntungan mempermudah pekerjaan ...
# 41   tidak ada jarak tempat aantara penjual dan pem...
# 42   kegiatan bisnis mudah berjalan tidak ada batas...
# 43   mempermudah dalam pengolahan datadata yang ada...
# 44   pekerjaan lebih efisien menejemen database mud...
# 45    jaringan bisnis turun menurun  jika bisnis la...
# 46   bisnis berjalan cepat  dapat maju dengan peasa...
# 47                 hemat waktu hemat biaya lebih rapi
# 48                    efisien hemat cepat dan efektif
# 49                                  cepat tepat mudah
# 50   informasi yang dibutuhkan akan semakin cepat d...
# 51         mempermudah pekerjaan dan pengolahan angka
# 52               lebih ringkas lebih cepat lebih mudah
#
#                                   Jawaban Tokenization
# No
# 1    [teknologi, informasi, dapat, digunakan, untuk...
# 2    [bisnis, menjadi, lebih, efisien, efektif, jan...
# 3    [mempersingkat, waktumemperoleh, koneksi, bisn...
# 4    [1, mempersingkat, waktu, 2, memudahkan, dalam...
# 5                       [untuk, memudahkan, kehidupan]
# 6    [semakin, maraknya, penggunaan, tik, akan, sem...
# 7    [dapat, memudahkan, proses, perencanaan, distr...
# 8    [penerapan, teknologi, informasi, dunia, bisni...
# 9    [semakin, maraknya, penggunaan, tik, akan, sem...
# 10   [1, semakin, maraknya, penggunaan, tik, akan, ...
# 11   [memperluas, pangsa, pasar, mengurangi, biaya,...
# 12         [dapat, menyimpan, filefile, yang, penting]
# 13   [mempercepat, kinerja, bisnis, membuat, pekerj...
# 14   [1, untuk, pengembang, bisnis, 2, untuk, mempe...
# 15   [untuk, memudahkan, pemasaran, memudahkan, pen...
# 16   [mempermudah, koneksi, antar, perusahaan, mena...
# 17         [lebih, efisien, lebih, hemat, lebih, aman]
# 18   [mempermudah, transaksi, bisnis, mempermudah, ...
# 19   [berikut, ini, adalah, keuntungan, dari, tekno...
# 20                               [praktis, memudahkan]
# 21   [kecepatan, transaksi, kenyamanan, pelanggan, ...
# 22   [sebagai, media, pemasaran, transaksi, sebagai...
# 23   [dengan, adanya, teknologi, kita, dapat, meman...
# 24   [mempermudah, dalam, menjalankan, bisnis, memb...
# 25   [bisnis, dapat, terstruktur, dengan, lebih, ba...
# 26   [bisnis, dapat, menjadi, lebih, terstruktur, l...
# 27   [pemasaran, semakin, luas, dan, mudah, pengelo...
# 28   [mempermudah, dalam, bidang, pemasaran, memper...
# 29         [mempermudah, dalam, transaksi, jual, beli]
# 30   [mendapat, keuntungan, memudahkan, transaksi, ...
# 31           [cepat, efektif, efisien, praktis, mudah]
# 32   [mempermudah, proses, transaksi, bisnis, mempe...
# 33   [menghemat, waktu, karena, pesan, lebih, cepat...
# 34   [membantu, mempercepat, pekerjaan, manusia, me...
# 35   [kemajuan, teknologi, komunikasi, yang, cepat,...
# 36   [membantu, mempercepat, pekerjaan, manusia, de...
# 37   [semakin, maraknya, penggunaan, tik, akan, sem...
# 38   [komunikasi, yang, cepat, teknologi, sebagai, ...
# 39   [munculnya, peluang, bisnis, baru, yakni, ebus...
# 40   [memperbanyak, keuntungan, mempermudah, pekerj...
# 41   [tidak, ada, jarak, tempat, aantara, penjual, ...
# 42   [kegiatan, bisnis, mudah, berjalan, tidak, ada...
# 43   [mempermudah, dalam, pengolahan, datadata, yan...
# 44   [pekerjaan, lebih, efisien, menejemen, databas...
# 45   [jaringan, bisnis, turun, menurun, jika, bisni...
# 46   [bisnis, berjalan, cepat, dapat, maju, dengan,...
# 47           [hemat, waktu, hemat, biaya, lebih, rapi]
# 48               [efisien, hemat, cepat, dan, efektif]
# 49                               [cepat, tepat, mudah]
# 50   [informasi, yang, dibutuhkan, akan, semakin, c...
# 51    [mempermudah, pekerjaan, dan, pengolahan, angka]
# 52        [lebih, ringkas, lebih, cepat, lebih, mudah]

# %% [markdown]
# ### Remove Stopword

# %%
def remove_stopword(token):
    return ' '. join(token)

# %%
list_df_teknologi = []

soal_teknologi = 0
for df in Teknologi_all_sheets:
    soal_teknologi = soal_teknologi + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
    df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
    df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
    df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
    
    print(f"Soal: {soal_teknologi}:")
    print(df[['Jawaban', 'Jawaban Tanpa Stopword']].head())
    list_df_teknologi.append(df)
# Out:
# <ipython-input-15-4bcc107cf802>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-4bcc107cf802>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-4bcc107cf802>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-4bcc107cf802>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-4bcc107cf802>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-4bcc107cf802>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-4bcc107cf802>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-4bcc107cf802>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-4bcc107cf802>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-4bcc107cf802>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-4bcc107cf802>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-4bcc107cf802>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-4bcc107cf802>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-4bcc107cf802>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-4bcc107cf802>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-4bcc107cf802>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-4bcc107cf802>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-4bcc107cf802>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-4bcc107cf802>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-4bcc107cf802>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-4bcc107cf802>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-4bcc107cf802>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-4bcc107cf802>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-4bcc107cf802>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-4bcc107cf802>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-4bcc107cf802>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-4bcc107cf802>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# Soal: 1:
#                                                Jawaban  \
# No
# 1    Komputer adalah serangkaian ataupun sekelompok...
# 2                    komputer adalah mesin penghitung
# 3    mesin yang membantu manusia untuk menjalankan ...
# 4    Komputer adalah alat komputasi yang diciptakan...
# 5                      alat untuk memudahkan masnusia
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [komputer, serangkaian, sekelompok, mesin, ele...
# 2                        [komputer, mesin, penghitung]
# 3    [mesin, membantu, manusia, menjalankan, segara...
# 4    [komputer, alat, komputasi, diciptakan, menghi...
# 5                         [alat, memudahkan, masnusia]
# Soal: 2:
#                                                Jawaban  \
# No
# 1    - Teknologi informasi dapat digunakan untuk me...
# 2    bisnis menjadi lebih efisien, efektif, jangkau...
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...
# 4    1. Mempersingkat waktu. 2. Memudahkan dalam tr...
# 5                          untuk memudahkan kehidupan
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [teknologi, informasi, mengontrol, barang, dih...
# 2    [bisnis, efisien, efektif, jangkauan, pemasara...
# 3    [mempersingkat, waktumemperoleh, koneksi, bisn...
# 4    [1, mempersingkat, 2, memudahkan, transaksi, 3...
# 5                              [memudahkan, kehidupan]
# Soal: 3:
#                                                Jawaban  \
# No
# 1    Hardware yaitu perangkat keras komputer. conto...
# 2    Hardware adalah perangkat keras, contohnya CPU...
# 3    perangkat keras komputer. mouse,keyboard,hardi...
# 4    Hardware adalah tampat atau perangkat keras ya...
# 5                                     perangkat keras
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [hardware, perangkat, keras, komputer, contohn...
# 2    [hardware, perangkat, keras, contohnya, cpu, m...
# 3    [perangkat, keras, komputer, mousekeyboardhard...
# 4    [hardware, tampat, perangkat, keras, mendukung...
# 5                                   [perangkat, keras]
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Data adalah kumpulan kejadian yang diangkat da...
# 2    Data adalah fakta mentah atau rincian peristiw...
# 3    data adalah sekumpulan informasi, informasi ad...
# 4    Data adalah kumpulan dari beberapa bahan menta...
# 5                               data berisi informasi
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [data, kumpulan, kejadian, diangkat, kenyataan...
# 2    [data, fakta, mentah, rincian, peristiwa, diol...
# 3    [data, sekumpulan, informasi, informasi, sekum...
# 4    [data, kumpulan, bahan, mentah, kejadian, info...
# 5                            [data, berisi, informasi]
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Recycle yaitu mendaur ulang sesuatu atau men...
# 2    dengan menerapkan program extended producer re...
# 3    di daur ulang, memanfaatkan yang masih bisa di...
# 4    1. Mendaur ulang. 2. Mengubah menjadi kerajina...
# 5                                dibuang di tempatnya
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [recycle, mendaur, ulang, mengolah, barang, di...
# 2    [menerapkan, program, extended, producer, resp...
# 3           [daur, ulang, memanfaatkan, pakai, pendam]
# 4    [1, mendaur, ulang, 2, mengubah, kerajinan, ta...
# 5                                 [dibuang, tempatnya]
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Volatile memory adalah memory yang datanya dap...
# 2    merupakan memory yang datanya dapat ditulis se...
# 3                                   memori penyimapan
# 4    Merupakan memory yang datanya dapat ditulis se...
# 5                                memori jangka pendek
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [volatile, memory, memory, datanya, ditulis, d...
# 2    [memory, datanya, ditulis, dihapustetapi, hila...
# 3                                 [memori, penyimapan]
# 4    [memory, datanya, ditulis, dihapus, hilang, ke...
# 5                             [memori, jangka, pendek]
# Soal: 7:
#                                                Jawaban  \
# No
# 1    LCD (Liquid Cristal Display), CPU (Central Pro...
# 2    liquid crystal display, central processing uni...
# 3    liquid crystal display, central prosesor unit,...
# 4    LCD = Liquid Crystal Display. CPU = Control Pr...
# 5    LCD = liquid crystal display CPU=Central perso...
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [lcd, liquid, cristal, display, cpu, central, ...
# 2    [liquid, crystal, display, central, processing...
# 3    [liquid, crystal, display, central, prosesor, ...
# 4    [lcd, liquid, crystal, display, cpu, control, ...
# 5    [lcd, liquid, crystal, display, cpucentral, pe...
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Cupcake, Donat, Eclair, Froyo, Gingerbread, Ho...
# 2    cupcake,doughnat, eclair, froyo, gingerbread, ...
# 3    donut,eclair,froyo,gingerbread,honeycomb,ice c...
# 4    Cupkace, Donut, Eclair, Froyo, Gingerbread, Ho...
# 5                    gingerbread , ice cream sandwich
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [cupcake, donat, eclair, froyo, gingerbread, h...
# 2    [cupcakedoughnat, eclair, froyo, gingerbread, ...
# 3    [donuteclairfroyogingerbreadhoneycombice, crea...
# 4    [cupkace, donut, eclair, froyo, gingerbread, h...
# 5                  [gingerbread, ice, cream, sandwich]
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Topologi adalah cara stasiun atau host (node) ...
# 2    Pengertian Topologi jaringan adalah bagian yan...
# 3    topologi jaringan komputer. topologi bus,topol...
# 4    LAN (Local Are Network) menghubungkan satu kom...
# 5                               jaringan dengan kabel
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [topologi, stasiun, host, node, dihubungkan, b...
# 2    [pengertian, topologi, jaringan, hubungan, kom...
# 3    [topologi, jaringan, komputer, topologi, busto...
# 4    [lan, local, are, network, menghubungkan, komp...
# 5                                    [jaringan, kabel]
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Bluetooth adalah suatu peralatan media komunik...
# 2    Bluetooth adalah spesifikasi industri untuk ja...
# 3                        untuk menstranfer suatu file
# 4    Bluetooth adalah spesifikasi industri untuk ja...
# 5                                 transfer antar hape
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [bluetooth, peralatan, media, komunikasi, meng...
# 2    [bluetooth, spesifikasi, industri, jaringan, k...
# 3                                  [menstranfer, file]
# 4    [bluetooth, spesifikasi, industri, jaringan, k...
# 5                                     [transfer, hape]
# <ipython-input-15-4bcc107cf802>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-4bcc107cf802>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-4bcc107cf802>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-4bcc107cf802>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-4bcc107cf802>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-4bcc107cf802>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-4bcc107cf802>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-4bcc107cf802>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-4bcc107cf802>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-4bcc107cf802>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-4bcc107cf802>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-4bcc107cf802>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-4bcc107cf802>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-4bcc107cf802>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-4bcc107cf802>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-4bcc107cf802>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-4bcc107cf802>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-4bcc107cf802>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-4bcc107cf802>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-4bcc107cf802>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-4bcc107cf802>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-4bcc107cf802>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-4bcc107cf802>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))

# %%
list_df_teknologi[1]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    - Teknologi informasi dapat digunakan untuk me...      20.0      40.0
# 2    bisnis menjadi lebih efisien, efektif, jangkau...      30.0      25.0
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...      28.0      25.0
# 4    1. Mempersingkat waktu. 2. Memudahkan dalam tr...      25.0      30.0
# 5                          untuk memudahkan kehidupan        5.0       4.0
# 6    Semakin maraknya penggunaan TIK akan semakin m...      22.0      30.0
# 7    dapat memudahkan proses perencanaan, distribus...      18.0      30.0
# 8    Penerapan Teknologi Informasi Dunia Bisnis .Te...      15.0      30.0
# 9    -Semakin maraknya penggunaan TIK akan Semakin ...      22.0      35.0
# 10   1. Semakin maraknya penggunaan TIK akan semaki...      22.0      40.0
# 11   Memperluas Pangsa Pasar, Mengurangi biaya prod...      40.0      50.0
# 12             Dapat menyimpan file-file yang penting       18.0      10.0
# 13   mempercepat kinerja bisnis, membuat pekerjaan ...      29.0      20.0
# 14   1. untuk pengembang bisnis 2. untuk memperluas...      22.0      20.0
# 15   untuk memudahkan pemasaran , memudahkan pengol...      37.0      28.0
# 16   mempermudah koneksi antar perusahaan, menambah...      30.0      29.0
# 17             -lebih efisien -lebih hemat -lebih aman      26.0      30.0
# 18   mempermudah transaksi bisnis, mempermudah kegi...      21.0      25.0
# 19   Berikut ini adalah keuntungan dari teknologi I...      37.0      45.0
# 20                                praktis, memudahkan       10.0      10.0
# 21   kecepatan transaksi. kenyamanan pelanggan. ket...      17.0      15.0
# 22   - Sebagai media pemasaran / transaksi - Sebaga...      22.0      35.0
# 23   -Dengan adanya Teknologi, kita dapat memanfaat...      30.0      40.0
# 24   -mempermudah Dalam menjalankan Bisnis -memberi...      27.0      25.0
# 25   bisnis dapat terstruktur dengan lebih baik leb...      12.0      20.0
# 26   bisnis dapat menjadi lebih terstruktur, lebih ...      22.0      30.0
# 27   Pemasaran semakin luas dan mudah, Pengelolaan ...      27.0      30.0
# 28   -mempermudah Dalam bidang pemasaran. -mempermu...      21.0      25.0
# 29              mempermudah dalam transaksi jual beli       18.0      15.0
# 30   - mendapat keuntungan - memudahkan transaksi -...      20.0      35.0
# 31       - cepat - efektif - efisien - praktis - mudah      14.0      30.0
# 32   -mempermudah proses transaksi Bisnis -memperlu...      18.0      30.0
# 33   Menghemat waktu karena pesan lebih cepat diter...      30.0      50.0
# 34   - membantu mempercepat pekerjaan manusia - mem...      33.0      45.0
# 35   -Kemajuan Teknologi komunikasi yang cepat dapa...      28.0      40.0
# 36   - Membantu mempercepat pekerjaan manusia. Deng...      22.0      25.0
# 37   -Semakin maraknya penggunaan TIK akan Semakin ...      24.0      25.0
# 38   - komunikasi yang cepat - Teknologi Sebagai me...      28.0      35.0
# 39   - Munculnya peluang Bisnis baru yakni e-Busine...      31.0      35.0
# 40   memperbanyak keuntungan. mempermudah pekerjaan...      25.0      20.0
# 41   tidak ada jarak tempat aantara penjual dan pem...      18.0      40.0
# 42   Kegiatan bisnis mudah berjalan, tidak ada bata...      25.0      45.0
# 43   mempermudah dalam pengolahan data-data yang ad...      15.0      10.0
# 44   pekerjaan lebih efisien menejemen database mud...      20.0      20.0
# 45   - jaringan Bisnis turun menurun - jika Bisnis ...      15.0      15.0
# 46   bisnis berjalan cepat , dapat maju dengan peas...      24.0      20.0
# 47               hemat waktu. hemat biaya. lebih rapi       17.0      25.0
# 48                 efisien, hemat, cepat, dan efektif       22.0      25.0
# 49                                  cepat tepat mudah       17.0      10.0
# 50   Informasi yang dibutuhkan akan semakin cepat d...      22.0      30.0
# 51         mempermudah pekerjaan dan pengolahan angka        7.0       5.0
# 52            -lebih ringkas -lebih cepat -lebih mudah      15.0      20.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase  \
# No
# 1        25.0    28.333333  - teknologi informasi dapat digunakan untuk me...
# 2        25.0    26.666667  bisnis menjadi lebih efisien, efektif, jangkau...
# 3        25.0    26.000000  mempersingkat waktu,memperoleh koneksi bisnis ...
# 4        25.0    26.666667  1. mempersingkat waktu. 2. memudahkan dalam tr...
# 5        10.0     6.333333                        untuk memudahkan kehidupan
# 6        25.0    25.666667  semakin maraknya penggunaan tik akan semakin m...
# 7        25.0    24.333333  dapat memudahkan proses perencanaan, distribus...
# 8        25.0    23.333333  penerapan teknologi informasi dunia bisnis .te...
# 9        25.0    27.333333  -semakin maraknya penggunaan tik akan semakin ...
# 10       25.0    29.000000  1. semakin maraknya penggunaan tik akan semaki...
# 11       50.0    46.666667  memperluas pangsa pasar, mengurangi biaya prod...
# 12       10.0    12.666667            dapat menyimpan file-file yang penting
# 13       25.0    24.666667  mempercepat kinerja bisnis, membuat pekerjaan ...
# 14       25.0    22.333333  1. untuk pengembang bisnis 2. untuk memperluas...
# 15       25.0    30.000000  untuk memudahkan pemasaran , memudahkan pengol...
# 16       25.0    28.000000  mempermudah koneksi antar perusahaan, menambah...
# 17       25.0    27.000000            -lebih efisien -lebih hemat -lebih aman
# 18       25.0    23.666667  mempermudah transaksi bisnis, mempermudah kegi...
# 19       50.0    44.000000  berikut ini adalah keuntungan dari teknologi i...
# 20       10.0    10.000000                               praktis, memudahkan
# 21       25.0    19.000000  kecepatan transaksi. kenyamanan pelanggan. ket...
# 22       25.0    27.333333  - sebagai media pemasaran / transaksi - sebaga...
# 23       50.0    40.000000  -dengan adanya teknologi, kita dapat memanfaat...
# 24       25.0    25.666667  -mempermudah dalam menjalankan bisnis -memberi...
# 25       25.0    19.000000  bisnis dapat terstruktur dengan lebih baik leb...
# 26       25.0    25.666667  bisnis dapat menjadi lebih terstruktur, lebih ...
# 27       25.0    27.333333  pemasaran semakin luas dan mudah, pengelolaan ...
# 28       25.0    23.666667  -mempermudah dalam bidang pemasaran. -mempermu...
# 29       25.0    19.333333             mempermudah dalam transaksi jual beli
# 30       25.0    26.666667  - mendapat keuntungan - memudahkan transaksi -...
# 31       25.0    23.000000      - cepat - efektif - efisien - praktis - mudah
# 32       25.0    24.333333  -mempermudah proses transaksi bisnis -memperlu...
# 33       50.0    43.333333  menghemat waktu karena pesan lebih cepat diter...
# 34       50.0    42.666667  - membantu mempercepat pekerjaan manusia - mem...
# 35       50.0    39.333333  -kemajuan teknologi komunikasi yang cepat dapa...
# 36       25.0    24.000000  - membantu mempercepat pekerjaan manusia. deng...
# 37       25.0    24.666667  -semakin maraknya penggunaan tik akan semakin ...
# 38       25.0    29.333333  - komunikasi yang cepat - teknologi sebagai me...
# 39       25.0    30.333333  - munculnya peluang bisnis baru yakni e-busine...
# 40       25.0    23.333333  memperbanyak keuntungan. mempermudah pekerjaan...
# 41       25.0    27.666667  tidak ada jarak tempat aantara penjual dan pem...
# 42       25.0    31.666667  kegiatan bisnis mudah berjalan, tidak ada bata...
# 43       10.0    11.666667  mempermudah dalam pengolahan data-data yang ad...
# 44       25.0    21.666667  pekerjaan lebih efisien menejemen database mud...
# 45       10.0    13.333333  - jaringan bisnis turun menurun - jika bisnis ...
# 46       25.0    23.000000  bisnis berjalan cepat , dapat maju dengan peas...
# 47       25.0    22.333333              hemat waktu. hemat biaya. lebih rapi
# 48       25.0    24.000000                efisien, hemat, cepat, dan efektif
# 49       25.0    17.333333                                 cepat tepat mudah
# 50       25.0    25.666667  informasi yang dibutuhkan akan semakin cepat d...
# 51       10.0     7.333333        mempermudah pekerjaan dan pengolahan angka
# 52       25.0    20.000000           -lebih ringkas -lebih cepat -lebih mudah
#
#                              Jawaban tanpa Punctuation  \
# No
# 1     teknologi informasi dapat digunakan untuk men...
# 2    bisnis menjadi lebih efisien efektif jangkauan...
# 3    mempersingkat waktumemperoleh koneksi bisnis d...
# 4    1 mempersingkat waktu 2 memudahkan dalam trans...
# 5                          untuk memudahkan kehidupan
# 6    semakin maraknya penggunaan tik akan semakin m...
# 7    dapat memudahkan proses perencanaan distribusi...
# 8    penerapan teknologi informasi dunia bisnis tek...
# 9    semakin maraknya penggunaan tik akan semakin m...
# 10   1 semakin maraknya penggunaan tik akan semakin...
# 11   memperluas pangsa pasar mengurangi biaya produ...
# 12              dapat menyimpan filefile yang penting
# 13   mempercepat kinerja bisnis membuat pekerjaan b...
# 14   1 untuk pengembang bisnis 2 untuk memperluas b...
# 15   untuk memudahkan pemasaran  memudahkan pengola...
# 16   mempermudah koneksi antar perusahaan menambah ...
# 17                lebih efisien lebih hemat lebih aman
# 18   mempermudah transaksi bisnis mempermudah kegia...
# 19   berikut ini adalah keuntungan dari teknologi i...
# 20                                 praktis memudahkan
# 21   kecepatan transaksi kenyamanan pelanggan ketep...
# 22    sebagai media pemasaran  transaksi  sebagai m...
# 23   dengan adanya teknologi kita dapat memanfaatka...
# 24   mempermudah dalam menjalankan bisnis memberika...
# 25   bisnis dapat terstruktur dengan lebih baik leb...
# 26   bisnis dapat menjadi lebih terstruktur lebih m...
# 27   pemasaran semakin luas dan mudah pengelolaan d...
# 28   mempermudah dalam bidang pemasaran mempermudah...
# 29              mempermudah dalam transaksi jual beli
# 30    mendapat keuntungan  memudahkan transaksi  me...
# 31             cepat  efektif  efisien  praktis  mudah
# 32   mempermudah proses transaksi bisnis memperluas...
# 33   menghemat waktu karena pesan lebih cepat diter...
# 34    membantu mempercepat pekerjaan manusia  mempe...
# 35   kemajuan teknologi komunikasi yang cepat dapat...
# 36    membantu mempercepat pekerjaan manusia dengan...
# 37   semakin maraknya penggunaan tik akan semakin m...
# 38    komunikasi yang cepat  teknologi sebagai medi...
# 39    munculnya peluang bisnis baru yakni ebusiness...
# 40   memperbanyak keuntungan mempermudah pekerjaan ...
# 41   tidak ada jarak tempat aantara penjual dan pem...
# 42   kegiatan bisnis mudah berjalan tidak ada batas...
# 43   mempermudah dalam pengolahan datadata yang ada...
# 44   pekerjaan lebih efisien menejemen database mud...
# 45    jaringan bisnis turun menurun  jika bisnis la...
# 46   bisnis berjalan cepat  dapat maju dengan peasa...
# 47                 hemat waktu hemat biaya lebih rapi
# 48                    efisien hemat cepat dan efektif
# 49                                  cepat tepat mudah
# 50   informasi yang dibutuhkan akan semakin cepat d...
# 51         mempermudah pekerjaan dan pengolahan angka
# 52               lebih ringkas lebih cepat lebih mudah
#
#                                   Jawaban Tokenization  \
# No
# 1    [teknologi, informasi, dapat, digunakan, untuk...
# 2    [bisnis, menjadi, lebih, efisien, efektif, jan...
# 3    [mempersingkat, waktumemperoleh, koneksi, bisn...
# 4    [1, mempersingkat, waktu, 2, memudahkan, dalam...
# 5                       [untuk, memudahkan, kehidupan]
# 6    [semakin, maraknya, penggunaan, tik, akan, sem...
# 7    [dapat, memudahkan, proses, perencanaan, distr...
# 8    [penerapan, teknologi, informasi, dunia, bisni...
# 9    [semakin, maraknya, penggunaan, tik, akan, sem...
# 10   [1, semakin, maraknya, penggunaan, tik, akan, ...
# 11   [memperluas, pangsa, pasar, mengurangi, biaya,...
# 12         [dapat, menyimpan, filefile, yang, penting]
# 13   [mempercepat, kinerja, bisnis, membuat, pekerj...
# 14   [1, untuk, pengembang, bisnis, 2, untuk, mempe...
# 15   [untuk, memudahkan, pemasaran, memudahkan, pen...
# 16   [mempermudah, koneksi, antar, perusahaan, mena...
# 17         [lebih, efisien, lebih, hemat, lebih, aman]
# 18   [mempermudah, transaksi, bisnis, mempermudah, ...
# 19   [berikut, ini, adalah, keuntungan, dari, tekno...
# 20                               [praktis, memudahkan]
# 21   [kecepatan, transaksi, kenyamanan, pelanggan, ...
# 22   [sebagai, media, pemasaran, transaksi, sebagai...
# 23   [dengan, adanya, teknologi, kita, dapat, meman...
# 24   [mempermudah, dalam, menjalankan, bisnis, memb...
# 25   [bisnis, dapat, terstruktur, dengan, lebih, ba...
# 26   [bisnis, dapat, menjadi, lebih, terstruktur, l...
# 27   [pemasaran, semakin, luas, dan, mudah, pengelo...
# 28   [mempermudah, dalam, bidang, pemasaran, memper...
# 29         [mempermudah, dalam, transaksi, jual, beli]
# 30   [mendapat, keuntungan, memudahkan, transaksi, ...
# 31           [cepat, efektif, efisien, praktis, mudah]
# 32   [mempermudah, proses, transaksi, bisnis, mempe...
# 33   [menghemat, waktu, karena, pesan, lebih, cepat...
# 34   [membantu, mempercepat, pekerjaan, manusia, me...
# 35   [kemajuan, teknologi, komunikasi, yang, cepat,...
# 36   [membantu, mempercepat, pekerjaan, manusia, de...
# 37   [semakin, maraknya, penggunaan, tik, akan, sem...
# 38   [komunikasi, yang, cepat, teknologi, sebagai, ...
# 39   [munculnya, peluang, bisnis, baru, yakni, ebus...
# 40   [memperbanyak, keuntungan, mempermudah, pekerj...
# 41   [tidak, ada, jarak, tempat, aantara, penjual, ...
# 42   [kegiatan, bisnis, mudah, berjalan, tidak, ada...
# 43   [mempermudah, dalam, pengolahan, datadata, yan...
# 44   [pekerjaan, lebih, efisien, menejemen, databas...
# 45   [jaringan, bisnis, turun, menurun, jika, bisni...
# 46   [bisnis, berjalan, cepat, dapat, maju, dengan,...
# 47           [hemat, waktu, hemat, biaya, lebih, rapi]
# 48               [efisien, hemat, cepat, dan, efektif]
# 49                               [cepat, tepat, mudah]
# 50   [informasi, yang, dibutuhkan, akan, semakin, c...
# 51    [mempermudah, pekerjaan, dan, pengolahan, angka]
# 52        [lebih, ringkas, lebih, cepat, lebih, mudah]
#
#                                 Jawaban Tanpa Stopword  \
# No
# 1    [teknologi, informasi, mengontrol, barang, dih...
# 2    [bisnis, efisien, efektif, jangkauan, pemasara...
# 3    [mempersingkat, waktumemperoleh, koneksi, bisn...
# 4    [1, mempersingkat, 2, memudahkan, transaksi, 3...
# 5                              [memudahkan, kehidupan]
# 6    [maraknya, penggunaan, tik, membuka, lapangan,...
# 7    [memudahkan, proses, perencanaan, distribusi, ...
# 8    [penerapan, teknologi, informasi, dunia, bisni...
# 9    [maraknya, penggunaan, tik, membuka, lapangan,...
# 10   [1, maraknya, penggunaan, tik, membuka, lapang...
# 11   [memperluas, pangsa, pasar, mengurangi, biaya,...
# 12                               [menyimpan, filefile]
# 13   [mempercepat, kinerja, bisnis, pekerjaan, bisn...
# 14   [1, pengembang, bisnis, 2, memperluas, bisnis,...
# 15   [memudahkan, pemasaran, memudahkan, pengolahan...
# 16   [mempermudah, koneksi, perusahaan, menambah, p...
# 17                              [efisien, hemat, aman]
# 18   [mempermudah, transaksi, bisnis, mempermudah, ...
# 19   [keuntungan, teknologi, informasi, komunikasi,...
# 20                               [praktis, memudahkan]
# 21   [kecepatan, transaksi, kenyamanan, pelanggan, ...
# 22   [media, pemasaran, transaksi, media, komunikas...
# 23   [teknologi, memanfaatkannya, promosi, produk, ...
# 24   [mempermudah, menjalankan, bisnis, layanan, re...
# 25          [bisnis, terstruktur, mudah, mengelolanya]
# 26   [bisnis, terstruktur, mudah, pengelolaannya, m...
# 27   [pemasaran, luas, mudah, pengelolaan, data, ua...
# 28   [mempermudah, bidang, pemasaran, mempermudah, ...
# 29                [mempermudah, transaksi, jual, beli]
# 30   [keuntungan, memudahkan, transaksi, memudahkan...
# 31           [cepat, efektif, efisien, praktis, mudah]
# 32   [mempermudah, proses, transaksi, bisnis, mempe...
# 33   [menghemat, pesan, cepat, diterima, penerima, ...
# 34   [membantu, mempercepat, pekerjaan, manusia, me...
# 35   [kemajuan, teknologi, komunikasi, cepat, mempe...
# 36   [membantu, mempercepat, pekerjaan, manusia, te...
# 37   [maraknya, penggunaan, tik, membuka, lapangan,...
# 38   [komunikasi, cepat, teknologi, media, promosi,...
# 39   [munculnya, peluang, bisnis, ebusiness, memper...
# 40   [memperbanyak, keuntungan, mempermudah, pekerj...
# 41   [jarak, aantara, penjual, pembeli, jarak, aant...
# 42   [kegiatan, bisnis, mudah, berjalan, batas, jar...
# 43   [mempermudah, pengolahan, datadata, dunia, bis...
# 44   [pekerjaan, efisien, menejemen, database, muda...
# 45   [jaringan, bisnis, turun, menurun, bisnis, lan...
# 46   [bisnis, berjalan, cepat, maju, peasat, inform...
# 47                         [hemat, hemat, biaya, rapi]
# 48                    [efisien, hemat, cepat, efektif]
# 49                                      [cepat, mudah]
# 50   [informasi, dibutuhkan, cepat, mudah, akses, k...
# 51         [mempermudah, pekerjaan, pengolahan, angka]
# 52                             [ringkas, cepat, mudah]
#
#                Jawaban Tanpa Stopword Not Tokenization
# No
# 1    teknologi informasi mengontrol barang dihasilk...
# 2    bisnis efisien efektif jangkauan pemasaran lua...
# 3    mempersingkat waktumemperoleh koneksi bisnis c...
# 4    1 mempersingkat 2 memudahkan transaksi 3 memud...
# 5                                 memudahkan kehidupan
# 6    maraknya penggunaan tik membuka lapangan peker...
# 7    memudahkan proses perencanaan distribusi produ...
# 8    penerapan teknologi informasi dunia bisnis tek...
# 9    maraknya penggunaan tik membuka lapangan peker...
# 10   1 maraknya penggunaan tik membuka lapangan pek...
# 11   memperluas pangsa pasar mengurangi biaya produ...
# 12                                  menyimpan filefile
# 13   mempercepat kinerja bisnis pekerjaan bisnis mu...
# 14   1 pengembang bisnis 2 memperluas bisnis 3 meng...
# 15   memudahkan pemasaran memudahkan pengolahan dat...
# 16   mempermudah koneksi perusahaan menambah pengha...
# 17                                  efisien hemat aman
# 18   mempermudah transaksi bisnis mempermudah kegia...
# 19   keuntungan teknologi informasi komunikasi 1 me...
# 20                                  praktis memudahkan
# 21   kecepatan transaksi kenyamanan pelanggan ketep...
# 22   media pemasaran transaksi media komunikasi med...
# 23   teknologi memanfaatkannya promosi produk konsu...
# 24   mempermudah menjalankan bisnis layanan real ti...
# 25               bisnis terstruktur mudah mengelolanya
# 26   bisnis terstruktur mudah pengelolaannya memant...
# 27   pemasaran luas mudah pengelolaan data uang mud...
# 28   mempermudah bidang pemasaran mempermudah bidan...
# 29                     mempermudah transaksi jual beli
# 30   keuntungan memudahkan transaksi memudahkan men...
# 31                 cepat efektif efisien praktis mudah
# 32   mempermudah proses transaksi bisnis memperluas...
# 33   menghemat pesan cepat diterima penerima pengir...
# 34   membantu mempercepat pekerjaan manusia memperm...
# 35   kemajuan teknologi komunikasi cepat mempermuda...
# 36   membantu mempercepat pekerjaan manusia teknolo...
# 37   maraknya penggunaan tik membuka lapangan peker...
# 38   komunikasi cepat teknologi media promosi kecep...
# 39   munculnya peluang bisnis ebusiness memperluas ...
# 40   memperbanyak keuntungan mempermudah pekerjaan ...
# 41   jarak aantara penjual pembeli jarak aantara pe...
# 42   kegiatan bisnis mudah berjalan batas jarak pen...
# 43        mempermudah pengolahan datadata dunia bisnis
# 44   pekerjaan efisien menejemen database mudah tra...
# 45   jaringan bisnis turun menurun bisnis lancar ua...
# 46         bisnis berjalan cepat maju peasat informasi
# 47                              hemat hemat biaya rapi
# 48                         efisien hemat cepat efektif
# 49                                         cepat mudah
# 50   informasi dibutuhkan cepat mudah akses kepenti...
# 51              mempermudah pekerjaan pengolahan angka
# 52                                 ringkas cepat mudah

# %% [markdown]
# ### Convert Negation

# %%
# fungsi untuk menghapus kata negasi
def hapus_kata_negasi(kalimat):
    # membuat daftar kata negasi
    negasi = ['tidak', 'bukan', 'belum', 'tak', 'jangan', 'tidaklah', 'bukannya', 'tiada', 'gak', 'ngga', 'nggak', 'enggak']
    # melakukan split kalimat menjadi token
    result = []
    negate = False
    for word in kalimat:
        if any(neg == word for neg in negasi):
            negate = True
        elif negate and word not in string.punctuation:
            word = 'tidak_' + word
            negate = False
        result.append(word)
    return result

# %%
list_df_teknologi = []

soal_teknologi = 0
for df in Teknologi_all_sheets:
    soal_teknologi = soal_teknologi + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
    df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
    df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
    df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
    df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
    df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
    
    print(f"Soal: {soal_teknologi}:")
    print(df[['Jawaban', 'Jawaban Tanpa Stopword']].head())
    list_df_teknologi.append(df)
# Out:
# <ipython-input-18-d2b099226ec8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-d2b099226ec8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-d2b099226ec8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-d2b099226ec8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-d2b099226ec8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-d2b099226ec8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-d2b099226ec8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-d2b099226ec8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-d2b099226ec8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-d2b099226ec8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-d2b099226ec8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-d2b099226ec8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-d2b099226ec8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-d2b099226ec8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-d2b099226ec8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-d2b099226ec8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-d2b099226ec8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-d2b099226ec8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-d2b099226ec8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-d2b099226ec8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-d2b099226ec8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-d2b099226ec8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# Soal: 1:
#                                                Jawaban  \
# No
# 1    Komputer adalah serangkaian ataupun sekelompok...
# 2                    komputer adalah mesin penghitung
# 3    mesin yang membantu manusia untuk menjalankan ...
# 4    Komputer adalah alat komputasi yang diciptakan...
# 5                      alat untuk memudahkan masnusia
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [komputer, serangkaian, sekelompok, mesin, ele...
# 2                        [komputer, mesin, penghitung]
# 3    [mesin, membantu, manusia, menjalankan, segara...
# 4    [komputer, alat, komputasi, diciptakan, menghi...
# 5                         [alat, memudahkan, masnusia]
# Soal: 2:
#                                                Jawaban  \
# No
# 1    - Teknologi informasi dapat digunakan untuk me...
# 2    bisnis menjadi lebih efisien, efektif, jangkau...
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...
# 4    1. Mempersingkat waktu. 2. Memudahkan dalam tr...
# 5                          untuk memudahkan kehidupan
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [teknologi, informasi, mengontrol, barang, dih...
# 2    [bisnis, efisien, efektif, jangkauan, pemasara...
# 3    [mempersingkat, waktumemperoleh, koneksi, bisn...
# 4    [1, mempersingkat, 2, memudahkan, transaksi, 3...
# 5                              [memudahkan, kehidupan]
# Soal: 3:
#                                                Jawaban  \
# No
# 1    Hardware yaitu perangkat keras komputer. conto...
# 2    Hardware adalah perangkat keras, contohnya CPU...
# 3    perangkat keras komputer. mouse,keyboard,hardi...
# 4    Hardware adalah tampat atau perangkat keras ya...
# 5                                     perangkat keras
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [hardware, perangkat, keras, komputer, contohn...
# 2    [hardware, perangkat, keras, contohnya, cpu, m...
# 3    [perangkat, keras, komputer, mousekeyboardhard...
# 4    [hardware, tampat, perangkat, keras, mendukung...
# 5                                   [perangkat, keras]
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Data adalah kumpulan kejadian yang diangkat da...
# 2    Data adalah fakta mentah atau rincian peristiw...
# 3    data adalah sekumpulan informasi, informasi ad...
# 4    Data adalah kumpulan dari beberapa bahan menta...
# 5                               data berisi informasi
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [data, kumpulan, kejadian, diangkat, kenyataan...
# 2    [data, fakta, mentah, rincian, peristiwa, diol...
# 3    [data, sekumpulan, informasi, informasi, sekum...
# 4    [data, kumpulan, bahan, mentah, kejadian, info...
# 5                            [data, berisi, informasi]
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Recycle yaitu mendaur ulang sesuatu atau men...
# 2    dengan menerapkan program extended producer re...
# 3    di daur ulang, memanfaatkan yang masih bisa di...
# 4    1. Mendaur ulang. 2. Mengubah menjadi kerajina...
# 5                                dibuang di tempatnya
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [recycle, mendaur, ulang, mengolah, barang, di...
# 2    [menerapkan, program, extended, producer, resp...
# 3           [daur, ulang, memanfaatkan, pakai, pendam]
# 4    [1, mendaur, ulang, 2, mengubah, kerajinan, ta...
# 5                                 [dibuang, tempatnya]
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Volatile memory adalah memory yang datanya dap...
# 2    merupakan memory yang datanya dapat ditulis se...
# 3                                   memori penyimapan
# 4    Merupakan memory yang datanya dapat ditulis se...
# 5                                memori jangka pendek
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [volatile, memory, memory, datanya, ditulis, d...
# 2    [memory, datanya, ditulis, dihapustetapi, hila...
# 3                                 [memori, penyimapan]
# 4    [memory, datanya, ditulis, dihapus, hilang, ke...
# 5                             [memori, jangka, pendek]
# Soal: 7:
#                                                Jawaban  \
# No
# 1    LCD (Liquid Cristal Display), CPU (Central Pro...
# 2    liquid crystal display, central processing uni...
# 3    liquid crystal display, central prosesor unit,...
# 4    LCD = Liquid Crystal Display. CPU = Control Pr...
# 5    LCD = liquid crystal display CPU=Central perso...
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [lcd, liquid, cristal, display, cpu, central, ...
# 2    [liquid, crystal, display, central, processing...
# 3    [liquid, crystal, display, central, prosesor, ...
# 4    [lcd, liquid, crystal, display, cpu, control, ...
# 5    [lcd, liquid, crystal, display, cpucentral, pe...
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Cupcake, Donat, Eclair, Froyo, Gingerbread, Ho...
# 2    cupcake,doughnat, eclair, froyo, gingerbread, ...
# 3    donut,eclair,froyo,gingerbread,honeycomb,ice c...
# 4    Cupkace, Donut, Eclair, Froyo, Gingerbread, Ho...
# 5                    gingerbread , ice cream sandwich
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [cupcake, donat, eclair, froyo, gingerbread, h...
# 2    [cupcakedoughnat, eclair, froyo, gingerbread, ...
# 3    [donuteclairfroyogingerbreadhoneycombice, crea...
# 4    [cupkace, donut, eclair, froyo, gingerbread, h...
# 5                  [gingerbread, ice, cream, sandwich]
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Topologi adalah cara stasiun atau host (node) ...
# 2    Pengertian Topologi jaringan adalah bagian yan...
# 3    topologi jaringan komputer. topologi bus,topol...
# 4    LAN (Local Are Network) menghubungkan satu kom...
# 5                               jaringan dengan kabel
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [topologi, stasiun, host, node, dihubungkan, b...
# 2    [pengertian, topologi, jaringan, hubungan, kom...
# 3    [topologi, jaringan, komputer, topologi, busto...
# 4    [lan, local, are, network, menghubungkan, komp...
# 5                                    [jaringan, kabel]
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Bluetooth adalah suatu peralatan media komunik...
# 2    Bluetooth adalah spesifikasi industri untuk ja...
# 3                        untuk menstranfer suatu file
# 4    Bluetooth adalah spesifikasi industri untuk ja...
# 5                                 transfer antar hape
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [bluetooth, peralatan, media, komunikasi, meng...
# 2    [bluetooth, spesifikasi, industri, jaringan, k...
# 3                                  [menstranfer, file]
# 4    [bluetooth, spesifikasi, industri, jaringan, k...
# 5                                     [transfer, hape]
# <ipython-input-18-d2b099226ec8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-d2b099226ec8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-d2b099226ec8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-d2b099226ec8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-d2b099226ec8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-d2b099226ec8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-d2b099226ec8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-d2b099226ec8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-d2b099226ec8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-d2b099226ec8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-d2b099226ec8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-d2b099226ec8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-d2b099226ec8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-d2b099226ec8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-d2b099226ec8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-d2b099226ec8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-d2b099226ec8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-d2b099226ec8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-d2b099226ec8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-d2b099226ec8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-d2b099226ec8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-d2b099226ec8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-d2b099226ec8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-d2b099226ec8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-d2b099226ec8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-d2b099226ec8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-d2b099226ec8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-d2b099226ec8>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-d2b099226ec8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-d2b099226ec8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))

# %%
list_df_teknologi[3]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    Data adalah kumpulan kejadian yang diangkat da...      55.0      60.0
# 2    Data adalah fakta mentah atau rincian peristiw...      30.0      45.0
# 3    data adalah sekumpulan informasi, informasi ad...      10.0      10.0
# 4    Data adalah kumpulan dari beberapa bahan menta...      40.0      65.0
# 5                               data berisi informasi       10.0       5.0
# 6    Data adalah sebuah fakta atau serangkaian fakt...      65.0      90.0
# 7    data adalah fakta mentah sperti kumpulan angka...      60.0      70.0
# 8    Pengertian Data Data adalah catatan atas kumpu...      48.0      60.0
# 9    -Data adalah sebuah fakta atau serangkaian fak...      48.0      60.0
# 10   Data adalah sebuah fakta atau serangkaian fakt...      60.0      65.0
# 11   data adalah kumpulan dari fakta. Informasi ada...      36.0      45.0
# 12   Data adalah sesuatu yang tersimpan,informasi a...      26.0      20.0
# 13   data adalah kumpulan informasi dan pengetahuan...      30.0      45.0
# 14   Data adalah sekumpulan fakta yang berupa angka...      45.0      40.0
# 15   data adalah data sebelum diolah , informasi da...      21.0      20.0
# 16   data adalah kumpulan informasi yang belum diol...      40.0      50.0
# 17   -Data adalah fakta mentah yang belum diolah -i...      50.0      65.0
# 18   data adalah sekumpulan informasi, informasi ad...      20.0      18.0
# 19   - Data adalah sebuah fakta atau serangkaian fa...      60.0      75.0
# 20                                 data isi informasi       10.0       5.0
# 21   data adalah suatu kumpulan data yang masih men...      40.0      55.0
# 22   Data merupakan bahan informasi yang belum diol...      45.0      60.0
# 23   -Data adalah sebuah fakta atau serangkaian fak...      85.0      95.0
# 24   data adalah kumpulan dari data mentah yang bel...      40.0      55.0
# 25   data adalah catatan atas kumpulan fakta inform...      45.0      65.0
# 26   data adalah sebuah catatan atas sekumpulan fak...      60.0      68.0
# 27   Data adalah suatu yang tidak dapat digunakan t...      37.0      50.0
# 28   -Data ialah keterangan atau bahan yang bisa di...      18.0      25.0
# 29   data : tempat untuk meyimpan data informasi : ...      25.0      35.0
# 30   - Data : sesuatu yang belum mempunyai arti bag...      30.0      45.0
# 31   data adalah angka, gambar, video dll. informas...      38.0      45.0
# 32   Data adalah informasi dari sebuah fakta, infor...      37.0      45.0
# 33   Data adalah sesuatu yang belum mempunyai arti ...      55.0      65.0
# 34   Data adalah sebuah fakta atau serangkaian fakt...      66.0      80.0
# 35   -Data adalah sebuah fakta atau serangkaian fak...      46.0      60.0
# 36   - Data adalah sebuah fakta atau serangkaian fa...      47.0      60.0
# 37   -Data adalah sebuah fakta atau serangkaian fak...      46.0      60.0
# 38   - Data dari tiga sumber di atas dapat ditarik ...      40.0      55.0
# 39   - Data adalah sebuah fakta atau serangkaian fa...      60.0      75.0
# 40   data merupakan sekumpulan informasi secara ter...      26.0      35.0
# 41   data adalah sumber dari informasi, informasi k...      35.0      45.0
# 42   Data adalah sumber dari informasi, informasi a...      34.0      45.0
# 43   Data adalah sumber informasi informasi adalah ...      30.0      40.0
# 44   data ' informasi data tidak sama dengan indorm...      20.0      15.0
# 45   data : serangkaian fakta yang mewakili suatu k...      60.0      75.0
# 46   data adalah kumpulan informasi , informasi ada...      30.0      55.0
# 47   data merupakan sekumpulan informasi, informasi...      20.0      20.0
# 48   data adalah bahan baku informasi, informasi ad...      30.0      45.0
# 49   Data adalah suatu rincian peristiwa yang belum...      46.0      55.0
# 50   Data adalah sebuah fakta atau serangkaian fakt...      60.0      70.0
# 51   -Data adalah kumpulan informasi berupa angka a...      40.0      50.0
# 52   -Data adalah kumpulan informasi yang belum dio...      45.0      50.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase  \
# No
# 1        50.0    55.000000  data adalah kumpulan kejadian yang diangkat da...
# 2        50.0    41.666667  data adalah fakta mentah atau rincian peristiw...
# 3        10.0    10.000000  data adalah sekumpulan informasi, informasi ad...
# 4        50.0    51.666667  data adalah kumpulan dari beberapa bahan menta...
# 5        10.0     8.333333                             data berisi informasi
# 6        90.0    81.666667  data adalah sebuah fakta atau serangkaian fakt...
# 7        75.0    68.333333  data adalah fakta mentah sperti kumpulan angka...
# 8        50.0    52.666667  pengertian data data adalah catatan atas kumpu...
# 9        50.0    52.666667  -data adalah sebuah fakta atau serangkaian fak...
# 10       50.0    58.333333  data adalah sebuah fakta atau serangkaian fakt...
# 11       50.0    43.666667  data adalah kumpulan dari fakta. informasi ada...
# 12       25.0    23.666667  data adalah sesuatu yang tersimpan,informasi a...
# 13       50.0    41.666667  data adalah kumpulan informasi dan pengetahuan...
# 14       50.0    45.000000  data adalah sekumpulan fakta yang berupa angka...
# 15       25.0    22.000000  data adalah data sebelum diolah , informasi da...
# 16       50.0    46.666667  data adalah kumpulan informasi yang belum diol...
# 17       50.0    55.000000  -data adalah fakta mentah yang belum diolah -i...
# 18       25.0    21.000000  data adalah sekumpulan informasi, informasi ad...
# 19       75.0    70.000000  - data adalah sebuah fakta atau serangkaian fa...
# 20       10.0     8.333333                                data isi informasi
# 21       50.0    48.333333  data adalah suatu kumpulan data yang masih men...
# 22       50.0    51.666667  data merupakan bahan informasi yang belum diol...
# 23       90.0    90.000000  -data adalah sebuah fakta atau serangkaian fak...
# 24       50.0    48.333333  data adalah kumpulan dari data mentah yang bel...
# 25       50.0    53.333333  data adalah catatan atas kumpulan fakta inform...
# 26       50.0    59.333333  data adalah sebuah catatan atas sekumpulan fak...
# 27       50.0    45.666667  data adalah suatu yang tidak dapat digunakan t...
# 28       25.0    22.666667  -data ialah keterangan atau bahan yang bisa di...
# 29       25.0    28.333333  data : tempat untuk meyimpan data informasi : ...
# 30       50.0    41.666667  - data : sesuatu yang belum mempunyai arti bag...
# 31       50.0    44.333333  data adalah angka, gambar, video dll. informas...
# 32       50.0    44.000000  data adalah informasi dari sebuah fakta, infor...
# 33       50.0    56.666667  data adalah sesuatu yang belum mempunyai arti ...
# 34       75.0    73.666667  data adalah sebuah fakta atau serangkaian fakt...
# 35       50.0    52.000000  -data adalah sebuah fakta atau serangkaian fak...
# 36       50.0    52.333333  - data adalah sebuah fakta atau serangkaian fa...
# 37       50.0    52.000000  -data adalah sebuah fakta atau serangkaian fak...
# 38       50.0    48.333333  - data dari tiga sumber di atas dapat ditarik ...
# 39       75.0    70.000000  - data adalah sebuah fakta atau serangkaian fa...
# 40       25.0    28.666667  data merupakan sekumpulan informasi secara ter...
# 41       50.0    43.333333  data adalah sumber dari informasi, informasi k...
# 42       50.0    43.000000  data adalah sumber dari informasi, informasi a...
# 43       50.0    40.000000  data adalah sumber informasi informasi adalah ...
# 44       25.0    20.000000  data ' informasi data tidak sama dengan indorm...
# 45       75.0    70.000000  data : serangkaian fakta yang mewakili suatu k...
# 46       50.0    45.000000  data adalah kumpulan informasi , informasi ada...
# 47       25.0    21.666667  data merupakan sekumpulan informasi, informasi...
# 48       50.0    41.666667  data adalah bahan baku informasi, informasi ad...
# 49       50.0    50.333333  data adalah suatu rincian peristiwa yang belum...
# 50       50.0    60.000000  data adalah sebuah fakta atau serangkaian fakt...
# 51       50.0    46.666667  -data adalah kumpulan informasi berupa angka a...
# 52       50.0    48.333333  -data adalah kumpulan informasi yang belum dio...
#
#                              Jawaban tanpa Punctuation  \
# No
# 1    data adalah kumpulan kejadian yang diangkat da...
# 2    data adalah fakta mentah atau rincian peristiw...
# 3    data adalah sekumpulan informasi informasi ada...
# 4    data adalah kumpulan dari beberapa bahan menta...
# 5                               data berisi informasi
# 6    data adalah sebuah fakta atau serangkaian fakt...
# 7    data adalah fakta mentah sperti kumpulan angka...
# 8    pengertian data data adalah catatan atas kumpu...
# 9    data adalah sebuah fakta atau serangkaian fakt...
# 10   data adalah sebuah fakta atau serangkaian fakt...
# 11   data adalah kumpulan dari fakta informasi adal...
# 12   data adalah sesuatu yang tersimpaninformasi ad...
# 13   data adalah kumpulan informasi dan pengetahuan...
# 14   data adalah sekumpulan fakta yang berupa angka...
# 15   data adalah data sebelum diolah  informasi dat...
# 16   data adalah kumpulan informasi yang belum diol...
# 17   data adalah fakta mentah yang belum diolah inf...
# 18   data adalah sekumpulan informasi informasi ada...
# 19    data adalah sebuah fakta atau serangkaian fak...
# 20                                 data isi informasi
# 21   data adalah suatu kumpulan data yang masih men...
# 22   data merupakan bahan informasi yang belum diol...
# 23   data adalah sebuah fakta atau serangkaian fakt...
# 24   data adalah kumpulan dari data mentah yang bel...
# 25   data adalah catatan atas kumpulan fakta inform...
# 26   data adalah sebuah catatan atas sekumpulan fak...
# 27   data adalah suatu yang tidak dapat digunakan t...
# 28   data ialah keterangan atau bahan yang bisa dij...
# 29   data  tempat untuk meyimpan data informasi  ya...
# 30    data  sesuatu yang belum mempunyai arti bagi ...
# 31   data adalah angka gambar video dll informasi a...
# 32   data adalah informasi dari sebuah fakta inform...
# 33   data adalah sesuatu yang belum mempunyai arti ...
# 34   data adalah sebuah fakta atau serangkaian fakt...
# 35   data adalah sebuah fakta atau serangkaian fakt...
# 36    data adalah sebuah fakta atau serangkaian fak...
# 37   data adalah sebuah fakta atau serangkaian fakt...
# 38    data dari tiga sumber di atas dapat ditarik k...
# 39    data adalah sebuah fakta atau serangkaian fak...
# 40   data merupakan sekumpulan informasi secara ter...
# 41   data adalah sumber dari informasi informasi ku...
# 42   data adalah sumber dari informasi informasi ad...
# 43   data adalah sumber informasi informasi adalah ...
# 44   data  informasi data tidak sama dengan indorma...
# 45   data  serangkaian fakta yang mewakili suatu ke...
# 46   data adalah kumpulan informasi  informasi adal...
# 47   data merupakan sekumpulan informasi informasi ...
# 48   data adalah bahan baku informasi informasi ada...
# 49   data adalah suatu rincian peristiwa yang belum...
# 50   data adalah sebuah fakta atau serangkaian fakt...
# 51   data adalah kumpulan informasi berupa angka at...
# 52   data adalah kumpulan informasi yang belum diol...
#
#                                   Jawaban Tokenization  \
# No
# 1    [data, adalah, kumpulan, kejadian, yang, diang...
# 2    [data, adalah, fakta, mentah, atau, rincian, p...
# 3    [data, adalah, sekumpulan, informasi, informas...
# 4    [data, adalah, kumpulan, dari, beberapa, bahan...
# 5                            [data, berisi, informasi]
# 6    [data, adalah, sebuah, fakta, atau, serangkaia...
# 7    [data, adalah, fakta, mentah, sperti, kumpulan...
# 8    [pengertian, data, data, adalah, catatan, atas...
# 9    [data, adalah, sebuah, fakta, atau, serangkaia...
# 10   [data, adalah, sebuah, fakta, atau, serangkaia...
# 11   [data, adalah, kumpulan, dari, fakta, informas...
# 12   [data, adalah, sesuatu, yang, tersimpaninforma...
# 13   [data, adalah, kumpulan, informasi, dan, penge...
# 14   [data, adalah, sekumpulan, fakta, yang, berupa...
# 15   [data, adalah, data, sebelum, diolah, informas...
# 16   [data, adalah, kumpulan, informasi, yang, belu...
# 17   [data, adalah, fakta, mentah, yang, belum, dio...
# 18   [data, adalah, sekumpulan, informasi, informas...
# 19   [data, adalah, sebuah, fakta, atau, serangkaia...
# 20                              [data, isi, informasi]
# 21   [data, adalah, suatu, kumpulan, data, yang, ma...
# 22   [data, merupakan, bahan, informasi, yang, belu...
# 23   [data, adalah, sebuah, fakta, atau, serangkaia...
# 24   [data, adalah, kumpulan, dari, data, mentah, y...
# 25   [data, adalah, catatan, atas, kumpulan, fakta,...
# 26   [data, adalah, sebuah, catatan, atas, sekumpul...
# 27   [data, adalah, suatu, yang, tidak, dapat, digu...
# 28   [data, ialah, keterangan, atau, bahan, yang, b...
# 29   [data, tempat, untuk, meyimpan, data, informas...
# 30   [data, sesuatu, yang, belum, mempunyai, arti, ...
# 31   [data, adalah, angka, gambar, video, dll, info...
# 32   [data, adalah, informasi, dari, sebuah, fakta,...
# 33   [data, adalah, sesuatu, yang, belum, mempunyai...
# 34   [data, adalah, sebuah, fakta, atau, serangkaia...
# 35   [data, adalah, sebuah, fakta, atau, serangkaia...
# 36   [data, adalah, sebuah, fakta, atau, serangkaia...
# 37   [data, adalah, sebuah, fakta, atau, serangkaia...
# 38   [data, dari, tiga, sumber, di, atas, dapat, di...
# 39   [data, adalah, sebuah, fakta, atau, serangkaia...
# 40   [data, merupakan, sekumpulan, informasi, secar...
# 41   [data, adalah, sumber, dari, informasi, inform...
# 42   [data, adalah, sumber, dari, informasi, inform...
# 43   [data, adalah, sumber, informasi, informasi, a...
# 44   [data, informasi, data, tidak, sama, dengan, i...
# 45   [data, serangkaian, fakta, yang, mewakili, sua...
# 46   [data, adalah, kumpulan, informasi, informasi,...
# 47   [data, merupakan, sekumpulan, informasi, infor...
# 48   [data, adalah, bahan, baku, informasi, informa...
# 49   [data, adalah, suatu, rincian, peristiwa, yang...
# 50   [data, adalah, sebuah, fakta, atau, serangkaia...
# 51   [data, adalah, kumpulan, informasi, berupa, an...
# 52   [data, adalah, kumpulan, informasi, yang, belu...
#
#                                 Jawaban Tanpa Stopword  \
# No
# 1    [data, kumpulan, kejadian, diangkat, kenyataan...
# 2    [data, fakta, mentah, rincian, peristiwa, diol...
# 3    [data, sekumpulan, informasi, informasi, sekum...
# 4    [data, kumpulan, bahan, mentah, kejadian, info...
# 5                            [data, berisi, informasi]
# 6    [data, fakta, serangkaian, fakta, mewakili, ke...
# 7    [data, fakta, mentah, sperti, kumpulan, angka,...
# 8    [pengertian, data, data, catatan, kumpulan, fa...
# 9    [data, fakta, serangkaian, fakta, mewakili, ke...
# 10   [data, fakta, serangkaian, fakta, mewakili, ke...
# 11   [data, kumpulan, fakta, informasi, kumpulan, d...
# 12   [data, tersimpaninformasi, katakata, bersifat,...
# 13   [data, kumpulan, informasi, pengetahuan, infor...
# 14   [data, sekumpulan, fakta, angka, huruf, gambar...
# 15   [data, data, diolah, informasi, data, diolah, ...
# 16   [data, kumpulan, informasi, diolah, informasi,...
# 17   [data, fakta, mentah, diolah, informasi, fakta...
# 18   [data, sekumpulan, informasi, informasi, penge...
# 19   [data, fakta, serangkaian, fakta, mewakili, ke...
# 20                              [data, isi, informasi]
# 21   [data, kumpulan, data, mentah, informasi, data...
# 22   [data, bahan, informasi, diolah, informasi, da...
# 23   [data, fakta, serangkaian, fakta, mewakili, ke...
# 24   [data, kumpulan, data, mentah, diolah, informa...
# 25   [data, catatan, kumpulan, fakta, informasi, ku...
# 26   [data, catatan, sekumpulan, fakta, informasi, ...
# 27   [data, data, informasi, kumpulan, data, data, ...
# 28   [data, keterangan, bahan, dijadikan, dasar, pe...
# 29   [data, meyimpan, data, informasi, bersisikan, ...
# 30   [data, arti, penerimanya, pengolahan, informas...
# 31   [data, angka, gambar, video, dll, informasi, k...
# 32   [data, informasi, fakta, informasih, data, ola...
# 33   [data, arti, penerimanya, pengolahan, informas...
# 34   [data, fakta, serangkaian, fakta, mewakili, ke...
# 35   [data, fakta, serangkaian, fakta, mewakili, ke...
# 36   [data, fakta, serangkaian, fakta, mewakili, ke...
# 37   [data, fakta, serangkaian, fakta, mewakili, ke...
# 38   [data, sumber, ditarik, kesimpulan, persamaan,...
# 39   [data, fakta, serangkaian, fakta, mewakili, ke...
# 40   [data, sekumpulan, informasi, terstruktur, inf...
# 41   [data, sumber, informasi, informasi, kumpulan,...
# 42   [data, sumber, informasi, informasi, kumpulan,...
# 43   [data, sumber, informasi, informasi, sekumpula...
# 44   [data, informasi, data, indormasi, sendangkan,...
# 45   [data, serangkaian, fakta, mewakili, kejadian,...
# 46   [data, kumpulan, informasi, informasi, sekumpu...
# 47   [data, sekumpulan, informasi, informasi, dimas...
# 48   [data, bahan, baku, informasi, informasi, hasi...
# 49   [data, rincian, peristiwa, olah, informasi, ha...
# 50   [data, fakta, serangkaian, fakta, mewakili, ke...
# 51   [data, kumpulan, informasi, angka, huruf, info...
# 52   [data, kumpulan, informasi, diolah, informasi,...
#
#                Jawaban Tanpa Stopword Not Tokenization  \
# No
# 1    data kumpulan kejadian diangkat kenyataan fakt...
# 2    data fakta mentah rincian peristiwa diolah ter...
# 3    data sekumpulan informasi informasi sekumpulan...
# 4    data kumpulan bahan mentah kejadian informasi ...
# 5                                data berisi informasi
# 6    data fakta serangkaian fakta mewakili kejadian...
# 7    data fakta mentah sperti kumpulan angka huruf ...
# 8    pengertian data data catatan kumpulan fakta da...
# 9    data fakta serangkaian fakta mewakili kejadian...
# 10   data fakta serangkaian fakta mewakili kejadian...
# 11   data kumpulan fakta informasi kumpulan data di...
# 12   data tersimpaninformasi katakata bersifat pent...
# 13   data kumpulan informasi pengetahuan informasi ...
# 14   data sekumpulan fakta angka huruf gambar gamba...
# 15   data data diolah informasi data diolah pengeta...
# 16   data kumpulan informasi diolah informasi kumpu...
# 17   data fakta mentah diolah informasi fakta menga...
# 18   data sekumpulan informasi informasi pengetahua...
# 19   data fakta serangkaian fakta mewakili kejadian...
# 20                                  data isi informasi
# 21   data kumpulan data mentah informasi data diola...
# 22   data bahan informasi diolah informasi data dio...
# 23   data fakta serangkaian fakta mewakili kejadian...
# 24   data kumpulan data mentah diolah informasi has...
# 25   data catatan kumpulan fakta informasi kumpulan...
# 26   data catatan sekumpulan fakta informasi sekump...
# 27   data data informasi kumpulan data data dihubun...
# 28   data keterangan bahan dijadikan dasar peneliti...
# 29   data meyimpan data informasi bersisikan data t...
# 30   data arti penerimanya pengolahan informasi pes...
# 31   data angka gambar video dll informasi kumpulan...
# 32   data informasi fakta informasih data olah kebe...
# 33   data arti penerimanya pengolahan informasi dat...
# 34   data fakta serangkaian fakta mewakili kejadian...
# 35   data fakta serangkaian fakta mewakili kejadian...
# 36   data fakta serangkaian fakta mewakili kejadian...
# 37   data fakta serangkaian fakta mewakili kejadian...
# 38   data sumber ditarik kesimpulan persamaan data ...
# 39   data fakta serangkaian fakta mewakili kejadian...
# 40   data sekumpulan informasi terstruktur informas...
# 41   data sumber informasi informasi kumpulan data ...
# 42   data sumber informasi informasi kumpulan data ...
# 43   data sumber informasi informasi sekumpulan dat...
# 44   data informasi data indormasi sendangkan penge...
# 45   data serangkaian fakta mewakili kejadian infor...
# 46   data kumpulan informasi informasi sekumpulan d...
# 47   data sekumpulan informasi informasi dimasukkan...
# 48   data bahan baku informasi informasi hasil peng...
# 49   data rincian peristiwa olah informasi hasil pe...
# 50   data fakta serangkaian fakta mewakili kejadian...
# 51   data kumpulan informasi angka huruf informasi ...
# 52   data kumpulan informasi diolah informasi kumpu...
#
#                                   Jawaban Tanpa Negasi  \
# No
# 1    [data, kumpulan, kejadian, diangkat, kenyataan...
# 2    [data, fakta, mentah, rincian, peristiwa, diol...
# 3    [data, sekumpulan, informasi, informasi, sekum...
# 4    [data, kumpulan, bahan, mentah, kejadian, info...
# 5                            [data, berisi, informasi]
# 6    [data, fakta, serangkaian, fakta, mewakili, ke...
# 7    [data, fakta, mentah, sperti, kumpulan, angka,...
# 8    [pengertian, data, data, catatan, kumpulan, fa...
# 9    [data, fakta, serangkaian, fakta, mewakili, ke...
# 10   [data, fakta, serangkaian, fakta, mewakili, ke...
# 11   [data, kumpulan, fakta, informasi, kumpulan, d...
# 12   [data, tersimpaninformasi, katakata, bersifat,...
# 13   [data, kumpulan, informasi, pengetahuan, infor...
# 14   [data, sekumpulan, fakta, angka, huruf, gambar...
# 15   [data, data, diolah, informasi, data, diolah, ...
# 16   [data, kumpulan, informasi, diolah, informasi,...
# 17   [data, fakta, mentah, diolah, informasi, fakta...
# 18   [data, sekumpulan, informasi, informasi, penge...
# 19   [data, fakta, serangkaian, fakta, mewakili, ke...
# 20                              [data, isi, informasi]
# 21   [data, kumpulan, data, mentah, informasi, data...
# 22   [data, bahan, informasi, diolah, informasi, da...
# 23   [data, fakta, serangkaian, fakta, mewakili, ke...
# 24   [data, kumpulan, data, mentah, diolah, informa...
# 25   [data, catatan, kumpulan, fakta, informasi, ku...
# 26   [data, catatan, sekumpulan, fakta, informasi, ...
# 27   [data, data, informasi, kumpulan, data, data, ...
# 28   [data, keterangan, bahan, dijadikan, dasar, pe...
# 29   [data, meyimpan, data, informasi, bersisikan, ...
# 30   [data, arti, penerimanya, pengolahan, informas...
# 31   [data, angka, gambar, video, dll, informasi, k...
# 32   [data, informasi, fakta, informasih, data, ola...
# 33   [data, arti, penerimanya, pengolahan, informas...
# 34   [data, fakta, serangkaian, fakta, mewakili, ke...
# 35   [data, fakta, serangkaian, fakta, mewakili, ke...
# 36   [data, fakta, serangkaian, fakta, mewakili, ke...
# 37   [data, fakta, serangkaian, fakta, mewakili, ke...
# 38   [data, sumber, ditarik, kesimpulan, persamaan,...
# 39   [data, fakta, serangkaian, fakta, mewakili, ke...
# 40   [data, sekumpulan, informasi, terstruktur, inf...
# 41   [data, sumber, informasi, informasi, kumpulan,...
# 42   [data, sumber, informasi, informasi, kumpulan,...
# 43   [data, sumber, informasi, informasi, sekumpula...
# 44   [data, informasi, data, indormasi, sendangkan,...
# 45   [data, serangkaian, fakta, mewakili, kejadian,...
# 46   [data, kumpulan, informasi, informasi, sekumpu...
# 47   [data, sekumpulan, informasi, informasi, dimas...
# 48   [data, bahan, baku, informasi, informasi, hasi...
# 49   [data, rincian, peristiwa, olah, informasi, ha...
# 50   [data, fakta, serangkaian, fakta, mewakili, ke...
# 51   [data, kumpulan, informasi, angka, huruf, info...
# 52   [data, kumpulan, informasi, diolah, informasi,...
#
#                         Jawaban Tanpa Negasi Not Token
# No
# 1    data kumpulan kejadian diangkat kenyataan fakt...
# 2    data fakta mentah rincian peristiwa diolah ter...
# 3    data sekumpulan informasi informasi sekumpulan...
# 4    data kumpulan bahan mentah kejadian informasi ...
# 5                                data berisi informasi
# 6    data fakta serangkaian fakta mewakili kejadian...
# 7    data fakta mentah sperti kumpulan angka huruf ...
# 8    pengertian data data catatan kumpulan fakta da...
# 9    data fakta serangkaian fakta mewakili kejadian...
# 10   data fakta serangkaian fakta mewakili kejadian...
# 11   data kumpulan fakta informasi kumpulan data di...
# 12   data tersimpaninformasi katakata bersifat pent...
# 13   data kumpulan informasi pengetahuan informasi ...
# 14   data sekumpulan fakta angka huruf gambar gamba...
# 15   data data diolah informasi data diolah pengeta...
# 16   data kumpulan informasi diolah informasi kumpu...
# 17   data fakta mentah diolah informasi fakta menga...
# 18   data sekumpulan informasi informasi pengetahua...
# 19   data fakta serangkaian fakta mewakili kejadian...
# 20                                  data isi informasi
# 21   data kumpulan data mentah informasi data diola...
# 22   data bahan informasi diolah informasi data dio...
# 23   data fakta serangkaian fakta mewakili kejadian...
# 24   data kumpulan data mentah diolah informasi has...
# 25   data catatan kumpulan fakta informasi kumpulan...
# 26   data catatan sekumpulan fakta informasi sekump...
# 27   data data informasi kumpulan data data dihubun...
# 28   data keterangan bahan dijadikan dasar peneliti...
# 29   data meyimpan data informasi bersisikan data t...
# 30   data arti penerimanya pengolahan informasi pes...
# 31   data angka gambar video dll informasi kumpulan...
# 32   data informasi fakta informasih data olah kebe...
# 33   data arti penerimanya pengolahan informasi dat...
# 34   data fakta serangkaian fakta mewakili kejadian...
# 35   data fakta serangkaian fakta mewakili kejadian...
# 36   data fakta serangkaian fakta mewakili kejadian...
# 37   data fakta serangkaian fakta mewakili kejadian...
# 38   data sumber ditarik kesimpulan persamaan data ...
# 39   data fakta serangkaian fakta mewakili kejadian...
# 40   data sekumpulan informasi terstruktur informas...
# 41   data sumber informasi informasi kumpulan data ...
# 42   data sumber informasi informasi kumpulan data ...
# 43   data sumber informasi informasi sekumpulan dat...
# 44   data informasi data indormasi sendangkan penge...
# 45   data serangkaian fakta mewakili kejadian infor...
# 46   data kumpulan informasi informasi sekumpulan d...
# 47   data sekumpulan informasi informasi dimasukkan...
# 48   data bahan baku informasi informasi hasil peng...
# 49   data rincian peristiwa olah informasi hasil pe...
# 50   data fakta serangkaian fakta mewakili kejadian...
# 51   data kumpulan informasi angka huruf informasi ...
# 52   data kumpulan informasi diolah informasi kumpu...

# %% [markdown]
# ### Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

list_df_teknologi = []

soal_teknologi = 0
for df in Teknologi_all_sheets:
    soal_teknologi = soal_teknologi + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
    df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
    df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
    df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
    df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
    df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))    
    df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
    df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x)) 
    
    print(f"Soal: {soal_teknologi}:")
    print(df[['Jawaban', 'Jawaban Stemmed']].head())
    list_df_teknologi.append(df)
# Out:
# <ipython-input-20-22f9a5d95ca9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-22f9a5d95ca9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-22f9a5d95ca9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-22f9a5d95ca9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-22f9a5d95ca9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-22f9a5d95ca9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-22f9a5d95ca9>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-22f9a5d95ca9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-22f9a5d95ca9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-22f9a5d95ca9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-22f9a5d95ca9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-22f9a5d95ca9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 1:
#                                                Jawaban  \
# No
# 1    Komputer adalah serangkaian ataupun sekelompok...
# 2                    komputer adalah mesin penghitung
# 3    mesin yang membantu manusia untuk menjalankan ...
# 4    Komputer adalah alat komputasi yang diciptakan...
# 5                      alat untuk memudahkan masnusia
#
#                                        Jawaban Stemmed
# No
# 1    [komputer, rangkai, kelompok, mesin, elektroni...
# 2                            [komputer, mesin, hitung]
# 3        [mesin, bantu, manusia, jalan, segara, kerja]
# 4     [komputer, alat, komputasi, cipta, hitung, kali]
# 5                              [alat, mudah, masnusia]
# <ipython-input-20-22f9a5d95ca9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-22f9a5d95ca9>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-22f9a5d95ca9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-22f9a5d95ca9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-22f9a5d95ca9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-22f9a5d95ca9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-22f9a5d95ca9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 2:
#                                                Jawaban  \
# No
# 1    - Teknologi informasi dapat digunakan untuk me...
# 2    bisnis menjadi lebih efisien, efektif, jangkau...
# 3    mempersingkat waktu,memperoleh koneksi bisnis ...
# 4    1. Mempersingkat waktu. 2. Memudahkan dalam tr...
# 5                          untuk memudahkan kehidupan
#
#                                        Jawaban Stemmed
# No
# 1    [teknologi, informasi, kontrol, barang, hasil,...
# 2    [bisnis, efisien, efektif, jangkau, pasar, lua...
# 3    [singkat, waktumemperoleh, koneksi, bisnis, ce...
# 4    [1, singkat, 2, mudah, transaksi, 3, mudah, ba...
# 5                                       [mudah, hidup]
# <ipython-input-20-22f9a5d95ca9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-22f9a5d95ca9>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-22f9a5d95ca9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-22f9a5d95ca9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-22f9a5d95ca9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-22f9a5d95ca9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-22f9a5d95ca9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 3:
#                                                Jawaban  \
# No
# 1    Hardware yaitu perangkat keras komputer. conto...
# 2    Hardware adalah perangkat keras, contohnya CPU...
# 3    perangkat keras komputer. mouse,keyboard,hardi...
# 4    Hardware adalah tampat atau perangkat keras ya...
# 5                                     perangkat keras
#
#                                        Jawaban Stemmed
# No
# 1    [hardware, perangkat, keras, komputer, contoh,...
# 2    [hardware, perangkat, keras, contoh, cpu, moni...
# 3    [perangkat, keras, komputer, mousekeyboardhard...
# 4    [hardware, tampat, perangkat, keras, dukung, k...
# 5                                   [perangkat, keras]
# <ipython-input-20-22f9a5d95ca9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-22f9a5d95ca9>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-22f9a5d95ca9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-22f9a5d95ca9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-22f9a5d95ca9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-22f9a5d95ca9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-22f9a5d95ca9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Data adalah kumpulan kejadian yang diangkat da...
# 2    Data adalah fakta mentah atau rincian peristiw...
# 3    data adalah sekumpulan informasi, informasi ad...
# 4    Data adalah kumpulan dari beberapa bahan menta...
# 5                               data berisi informasi
#
#                                        Jawaban Stemmed
# No
# 1    [data, kumpul, jadi, angkat, nyata, fakta, ang...
# 2    [data, fakta, mentah, rincian, peristiwa, olah...
# 3    [data, kumpul, informasi, informasi, kumpul, d...
# 4    [data, kumpul, bahan, mentah, jadi, informasi,...
# 5                               [data, isi, informasi]
# <ipython-input-20-22f9a5d95ca9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-22f9a5d95ca9>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-22f9a5d95ca9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-22f9a5d95ca9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-22f9a5d95ca9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-22f9a5d95ca9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-22f9a5d95ca9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Recycle yaitu mendaur ulang sesuatu atau men...
# 2    dengan menerapkan program extended producer re...
# 3    di daur ulang, memanfaatkan yang masih bisa di...
# 4    1. Mendaur ulang. 2. Mengubah menjadi kerajina...
# 5                                dibuang di tempatnya
#
#                                        Jawaban Stemmed
# No
# 1    [recycle, daur, ulang, olah, barang, manfaat, ...
# 2    [terap, program, extended, producer, responsib...
# 3                [daur, ulang, manfaat, pakai, pendam]
# 4    [1, daur, ulang, 2, ubah, rajin, tangan, 3, ma...
# 5                                      [buang, tempat]
# <ipython-input-20-22f9a5d95ca9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-22f9a5d95ca9>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-22f9a5d95ca9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-22f9a5d95ca9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-22f9a5d95ca9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-22f9a5d95ca9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-22f9a5d95ca9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Volatile memory adalah memory yang datanya dap...
# 2    merupakan memory yang datanya dapat ditulis se...
# 3                                   memori penyimapan
# 4    Merupakan memory yang datanya dapat ditulis se...
# 5                                memori jangka pendek
#
#                                        Jawaban Stemmed
# No
# 1    [volatile, memory, memory, data, tulis, hapus,...
# 2    [memory, data, tulis, dihapustetapi, hilang, h...
# 3                                 [memori, penyimapan]
# 4    [memory, data, tulis, hapus, hilang, hilang, p...
# 5                             [memori, jangka, pendek]
# <ipython-input-20-22f9a5d95ca9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-22f9a5d95ca9>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-22f9a5d95ca9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-22f9a5d95ca9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-22f9a5d95ca9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-22f9a5d95ca9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-22f9a5d95ca9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 7:
#                                                Jawaban  \
# No
# 1    LCD (Liquid Cristal Display), CPU (Central Pro...
# 2    liquid crystal display, central processing uni...
# 3    liquid crystal display, central prosesor unit,...
# 4    LCD = Liquid Crystal Display. CPU = Control Pr...
# 5    LCD = liquid crystal display CPU=Central perso...
#
#                                        Jawaban Stemmed
# No
# 1    [lcd, liquid, cristal, display, cpu, central, ...
# 2    [liquid, crystal, display, central, processing...
# 3    [liquid, crystal, display, central, prosesor, ...
# 4    [lcd, liquid, crystal, display, cpu, control, ...
# 5    [lcd, liquid, crystal, display, cpucentral, pe...
# <ipython-input-20-22f9a5d95ca9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-22f9a5d95ca9>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-22f9a5d95ca9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-22f9a5d95ca9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-22f9a5d95ca9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-22f9a5d95ca9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-22f9a5d95ca9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Cupcake, Donat, Eclair, Froyo, Gingerbread, Ho...
# 2    cupcake,doughnat, eclair, froyo, gingerbread, ...
# 3    donut,eclair,froyo,gingerbread,honeycomb,ice c...
# 4    Cupkace, Donut, Eclair, Froyo, Gingerbread, Ho...
# 5                    gingerbread , ice cream sandwich
#
#                                        Jawaban Stemmed
# No
# 1    [cupcake, donat, eclair, froyo, gingerbread, h...
# 2    [cupcakedoughnat, eclair, froyo, gingerbread, ...
# 3    [donuteclairfroyogingerbreadhoneycombice, crea...
# 4    [cupkace, donut, eclair, froyo, gingerbread, h...
# 5                  [gingerbread, ice, cream, sandwich]
# <ipython-input-20-22f9a5d95ca9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-22f9a5d95ca9>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-22f9a5d95ca9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-22f9a5d95ca9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-22f9a5d95ca9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-22f9a5d95ca9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-22f9a5d95ca9>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-22f9a5d95ca9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Topologi adalah cara stasiun atau host (node) ...
# 2    Pengertian Topologi jaringan adalah bagian yan...
# 3    topologi jaringan komputer. topologi bus,topol...
# 4    LAN (Local Are Network) menghubungkan satu kom...
# 5                               jaringan dengan kabel
#
#                                        Jawaban Stemmed
# No
# 1    [topologi, stasiun, host, node, hubung, beberp...
# 2    [erti, topologi, jaring, hubung, komputer, ban...
# 3    [topologi, jaring, komputer, topologi, bustopo...
# 4    [lan, local, are, network, hubung, komputer, k...
# 5                                      [jaring, kabel]
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Bluetooth adalah suatu peralatan media komunik...
# 2    Bluetooth adalah spesifikasi industri untuk ja...
# 3                        untuk menstranfer suatu file
# 4    Bluetooth adalah spesifikasi industri untuk ja...
# 5                                 transfer antar hape
#
#                                        Jawaban Stemmed
# No
# 1    [bluetooth, alat, media, komunikasi, hubung, p...
# 2    [bluetooth, spesifikasi, industri, jaring, kaw...
# 3                                  [menstranfer, file]
# 4    [bluetooth, spesifikasi, industri, jaring, kaw...
# 5                                     [transfer, hape]
# <ipython-input-20-22f9a5d95ca9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-22f9a5d95ca9>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))

# %%
list_df_teknologi[0]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    Komputer adalah serangkaian ataupun sekelompok...      60.0      95.0
# 2                    komputer adalah mesin penghitung       10.0      15.0
# 3    mesin yang membantu manusia untuk menjalankan ...      30.0      20.0
# 4    Komputer adalah alat komputasi yang diciptakan...      12.0      10.0
# 5                      alat untuk memudahkan masnusia       14.0      10.0
# 6    Komputer adalah alat yang dipakai untuk mengol...      20.0      30.0
# 7    komputer merupakan alat untuk mengolah data. m...      40.0      40.0
# 8    Komputer adalah alat yang dipakai untuk mengol...      28.0      35.0
# 9    Komputer adalah alat yang dipakai untuk mengol...      28.0      35.0
# 10   Komputer adalah serangkaian ataupun sekelompok...      60.0      70.0
# 11   Komputer adalah alat yang dipakai untuk mengol...      28.0      40.0
# 12   alat yang dipakai untuk mengolah data menurut ...      30.0      20.0
# 13   komputer adalah barang elektronik pintar yang ...      18.0      15.0
# 14   Komputer adalah alat yang dipakai untuk mengol...      28.0      40.0
# 15     alat bantu untuk mempermudah pekerjaan manusia       33.0      25.0
# 16   komputer adalah alat untuk mempermudah manusia...      30.0      30.0
# 17   Komputer adalah sebuah perangkat yang saat ini...      20.0      40.0
# 18   serangkaian atau sekelompok mesin elektronik y...      35.0      35.0
# 19   Komputer adalah serangkaian ataupun sekelompok...      60.0      70.0
# 20   alat yang membantu manusia untuk mengerjakan p...      30.0      20.0
# 21   Komputer adalah alat yang dipakai untuk mengol...      30.0      35.0
# 22   Apa yang dimaksud dengan komputer? (Jawab dala...       8.0       0.0
# 23   Komputer adalah alat yang dapat digunakan untu...      35.0      35.0
# 24                suatu mesin yang bisa mengerti saya        4.0       2.0
# 25   komputer adalah alat pengolah data menurut pro...      30.0      20.0
# 26   komputer adalah alat elektronik yang memiliki ...      25.0      15.0
# 27   Komputer adalah alat bantu hitung manusia, yan...      29.0      35.0
# 28   alat elektronik yang dapat menghitung dan meng...      17.0      20.0
# 29             alat yang dipakai untuk mengelola data       12.0      10.0
# 30   adalah alat yang dipakai untuk mengolah data m...      28.0      40.0
# 31   pada awal komputer adalah mesin hitung untuk m...      29.0      25.0
# 32   Komputer adalah mesin hitung. komputer digunak...      17.0      20.0
# 33   Komputer adalah alat yang dipakai untuk mengol...      33.0      40.0
# 34   alat yang dipakai untuk mengolah data menurut ...      28.0      35.0
# 35   Secara umum komputer adalah sekumpulan alat el...      30.0      30.0
# 36   Komputer adalah alat yang dipakai untuk mengol...      28.0      35.0
# 37   Komputer adalah alat yang dipakai untuk mengol...      25.0      45.0
# 38   Komputer adalah alat yang dipakai untuk mengol...      30.0      25.0
# 39   adalah alat yang dipakai untuk mengolah data m...      25.0      35.0
# 40        menerima, mengolah dan memberikan informasi        5.0       7.0
# 41                  tempat menerima dan mengolah data        5.0       3.0
# 42   Komputer adalah sebuah alat yang digunakan unt...      10.0      15.0
# 43   komputer adalah sebuah mesin yang berfungsi un...      31.0      20.0
# 44                                 mesin pegolah kata        5.0       4.0
# 45   komputer adalah sebuah hardware yg berfungsi m...      20.0      20.0
# 46   alat untuk mempermudah pekerjaan manusia. alat...      22.0      20.0
# 47   komputer adalah alat bantu manusia yang dapat ...      30.0      20.0
# 48   komputer adalah alat komputasi elektronik. yan...      25.0      23.0
# 49   alat yang dipakai untuk mengolah data menurut ...      28.0      33.0
# 50   Serangkaian ataupun sekelompok mesin elektroni...      30.0      27.0
# 51   komputer adalah alat yang digunakan untuk meng...      12.0      10.0
# 52   alat elektronik yang terdiri dari hardware dan...      15.0      12.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase  \
# No
# 1        75.0    76.666667  komputer adalah serangkaian ataupun sekelompok...
# 2        10.0    11.666667                  komputer adalah mesin penghitung
# 3        25.0    25.000000  mesin yang membantu manusia untuk menjalankan ...
# 4        10.0    10.666667  komputer adalah alat komputasi yang diciptakan...
# 5        10.0    11.333333                    alat untuk memudahkan masnusia
# 6        25.0    25.000000  komputer adalah alat yang dipakai untuk mengol...
# 7        50.0    43.333333  komputer merupakan alat untuk mengolah data. m...
# 8        25.0    29.333333  komputer adalah alat yang dipakai untuk mengol...
# 9        25.0    29.333333  komputer adalah alat yang dipakai untuk mengol...
# 10       50.0    60.000000  komputer adalah serangkaian ataupun sekelompok...
# 11       50.0    39.333333  komputer adalah alat yang dipakai untuk mengol...
# 12       25.0    25.000000  alat yang dipakai untuk mengolah data menurut ...
# 13       25.0    19.333333  komputer adalah barang elektronik pintar yang ...
# 14       25.0    31.000000  komputer adalah alat yang dipakai untuk mengol...
# 15       25.0    27.666667    alat bantu untuk mempermudah pekerjaan manusia
# 16       25.0    28.333333  komputer adalah alat untuk mempermudah manusia...
# 17       25.0    28.333333  komputer adalah sebuah perangkat yang saat ini...
# 18       25.0    31.666667  serangkaian atau sekelompok mesin elektronik y...
# 19       50.0    60.000000  komputer adalah serangkaian ataupun sekelompok...
# 20       25.0    25.000000  alat yang membantu manusia untuk mengerjakan p...
# 21       25.0    30.000000  komputer adalah alat yang dipakai untuk mengol...
# 22       10.0     6.000000  apa yang dimaksud dengan komputer? (jawab dala...
# 23       25.0    31.666667  komputer adalah alat yang dapat digunakan untu...
# 24       10.0     5.333333               suatu mesin yang bisa mengerti saya
# 25       25.0    25.000000  komputer adalah alat pengolah data menurut pro...
# 26       25.0    21.666667  komputer adalah alat elektronik yang memiliki ...
# 27       25.0    29.666667  komputer adalah alat bantu hitung manusia, yan...
# 28       25.0    20.666667  alat elektronik yang dapat menghitung dan meng...
# 29       10.0    10.666667            alat yang dipakai untuk mengelola data
# 30       50.0    39.333333  adalah alat yang dipakai untuk mengolah data m...
# 31       25.0    26.333333  pada awal komputer adalah mesin hitung untuk m...
# 32       25.0    20.666667  komputer adalah mesin hitung. komputer digunak...
# 33       50.0    41.000000  komputer adalah alat yang dipakai untuk mengol...
# 34       25.0    29.333333  alat yang dipakai untuk mengolah data menurut ...
# 35       25.0    28.333333  secara umum komputer adalah sekumpulan alat el...
# 36       25.0    29.333333  komputer adalah alat yang dipakai untuk mengol...
# 37       50.0    40.000000  komputer adalah alat yang dipakai untuk mengol...
# 38       25.0    26.666667  komputer adalah alat yang dipakai untuk mengol...
# 39       25.0    28.333333  adalah alat yang dipakai untuk mengolah data m...
# 40       10.0     7.333333       menerima, mengolah dan memberikan informasi
# 41       10.0     6.000000                 tempat menerima dan mengolah data
# 42       10.0    11.666667  komputer adalah sebuah alat yang digunakan unt...
# 43       25.0    25.333333  komputer adalah sebuah mesin yang berfungsi un...
# 44       10.0     6.333333                                mesin pegolah kata
# 45       25.0    21.666667  komputer adalah sebuah hardware yg berfungsi m...
# 46       25.0    22.333333  alat untuk mempermudah pekerjaan manusia. alat...
# 47       25.0    25.000000  komputer adalah alat bantu manusia yang dapat ...
# 48       25.0    24.333333  komputer adalah alat komputasi elektronik. yan...
# 49       25.0    28.666667  alat yang dipakai untuk mengolah data menurut ...
# 50       25.0    27.333333  serangkaian ataupun sekelompok mesin elektroni...
# 51       10.0    10.666667  komputer adalah alat yang digunakan untuk meng...
# 52       10.0    12.333333  alat elektronik yang terdiri dari hardware dan...
#
#                              Jawaban tanpa Punctuation  \
# No
# 1    komputer adalah serangkaian ataupun sekelompok...
# 2                    komputer adalah mesin penghitung
# 3    mesin yang membantu manusia untuk menjalankan ...
# 4    komputer adalah alat komputasi yang diciptakan...
# 5                      alat untuk memudahkan masnusia
# 6    komputer adalah alat yang dipakai untuk mengol...
# 7    komputer merupakan alat untuk mengolah data me...
# 8    komputer adalah alat yang dipakai untuk mengol...
# 9    komputer adalah alat yang dipakai untuk mengol...
# 10   komputer adalah serangkaian ataupun sekelompok...
# 11   komputer adalah alat yang dipakai untuk mengol...
# 12   alat yang dipakai untuk mengolah data menurut ...
# 13   komputer adalah barang elektronik pintar yang ...
# 14   komputer adalah alat yang dipakai untuk mengol...
# 15     alat bantu untuk mempermudah pekerjaan manusia
# 16   komputer adalah alat untuk mempermudah manusia...
# 17   komputer adalah sebuah perangkat yang saat ini...
# 18   serangkaian atau sekelompok mesin elektronik y...
# 19   komputer adalah serangkaian ataupun sekelompok...
# 20   alat yang membantu manusia untuk mengerjakan p...
# 21   komputer adalah alat yang dipakai untuk mengol...
# 22   apa yang dimaksud dengan komputer jawab dalam ...
# 23   komputer adalah alat yang dapat digunakan untu...
# 24                suatu mesin yang bisa mengerti saya
# 25   komputer adalah alat pengolah data menurut pro...
# 26   komputer adalah alat elektronik yang memiliki ...
# 27   komputer adalah alat bantu hitung manusia yang...
# 28   alat elektronik yang dapat menghitung dan meng...
# 29             alat yang dipakai untuk mengelola data
# 30   adalah alat yang dipakai untuk mengolah data m...
# 31   pada awal komputer adalah mesin hitung untuk m...
# 32   komputer adalah mesin hitung komputer digunaka...
# 33   komputer adalah alat yang dipakai untuk mengol...
# 34   alat yang dipakai untuk mengolah data menurut ...
# 35   secara umum komputer adalah sekumpulan alat el...
# 36   komputer adalah alat yang dipakai untuk mengol...
# 37   komputer adalah alat yang dipakai untuk mengol...
# 38   komputer adalah alat yang dipakai untuk mengol...
# 39   adalah alat yang dipakai untuk mengolah data m...
# 40         menerima mengolah dan memberikan informasi
# 41                  tempat menerima dan mengolah data
# 42   komputer adalah sebuah alat yang digunakan unt...
# 43   komputer adalah sebuah mesin yang berfungsi un...
# 44                                 mesin pegolah kata
# 45   komputer adalah sebuah hardware yg berfungsi m...
# 46   alat untuk mempermudah pekerjaan manusia alat ...
# 47   komputer adalah alat bantu manusia yang dapat ...
# 48   komputer adalah alat komputasi elektronik yang...
# 49   alat yang dipakai untuk mengolah data menurut ...
# 50   serangkaian ataupun sekelompok mesin elektroni...
# 51   komputer adalah alat yang digunakan untuk meng...
# 52   alat elektronik yang terdiri dari hardware dan...
#
#                                   Jawaban Tokenization  \
# No
# 1    [komputer, adalah, serangkaian, ataupun, sekel...
# 2                [komputer, adalah, mesin, penghitung]
# 3    [mesin, yang, membantu, manusia, untuk, menjal...
# 4    [komputer, adalah, alat, komputasi, yang, dici...
# 5                  [alat, untuk, memudahkan, masnusia]
# 6    [komputer, adalah, alat, yang, dipakai, untuk,...
# 7    [komputer, merupakan, alat, untuk, mengolah, d...
# 8    [komputer, adalah, alat, yang, dipakai, untuk,...
# 9    [komputer, adalah, alat, yang, dipakai, untuk,...
# 10   [komputer, adalah, serangkaian, ataupun, sekel...
# 11   [komputer, adalah, alat, yang, dipakai, untuk,...
# 12   [alat, yang, dipakai, untuk, mengolah, data, m...
# 13   [komputer, adalah, barang, elektronik, pintar,...
# 14   [komputer, adalah, alat, yang, dipakai, untuk,...
# 15   [alat, bantu, untuk, mempermudah, pekerjaan, m...
# 16   [komputer, adalah, alat, untuk, mempermudah, m...
# 17   [komputer, adalah, sebuah, perangkat, yang, sa...
# 18   [serangkaian, atau, sekelompok, mesin, elektro...
# 19   [komputer, adalah, serangkaian, ataupun, sekel...
# 20   [alat, yang, membantu, manusia, untuk, mengerj...
# 21   [komputer, adalah, alat, yang, dipakai, untuk,...
# 22   [apa, yang, dimaksud, dengan, komputer, jawab,...
# 23   [komputer, adalah, alat, yang, dapat, digunaka...
# 24          [suatu, mesin, yang, bisa, mengerti, saya]
# 25   [komputer, adalah, alat, pengolah, data, menur...
# 26   [komputer, adalah, alat, elektronik, yang, mem...
# 27   [komputer, adalah, alat, bantu, hitung, manusi...
# 28   [alat, elektronik, yang, dapat, menghitung, da...
# 29       [alat, yang, dipakai, untuk, mengelola, data]
# 30   [adalah, alat, yang, dipakai, untuk, mengolah,...
# 31   [pada, awal, komputer, adalah, mesin, hitung, ...
# 32   [komputer, adalah, mesin, hitung, komputer, di...
# 33   [komputer, adalah, alat, yang, dipakai, untuk,...
# 34   [alat, yang, dipakai, untuk, mengolah, data, m...
# 35   [secara, umum, komputer, adalah, sekumpulan, a...
# 36   [komputer, adalah, alat, yang, dipakai, untuk,...
# 37   [komputer, adalah, alat, yang, dipakai, untuk,...
# 38   [komputer, adalah, alat, yang, dipakai, untuk,...
# 39   [adalah, alat, yang, dipakai, untuk, mengolah,...
# 40    [menerima, mengolah, dan, memberikan, informasi]
# 41             [tempat, menerima, dan, mengolah, data]
# 42   [komputer, adalah, sebuah, alat, yang, digunak...
# 43   [komputer, adalah, sebuah, mesin, yang, berfun...
# 44                              [mesin, pegolah, kata]
# 45   [komputer, adalah, sebuah, hardware, yg, berfu...
# 46   [alat, untuk, mempermudah, pekerjaan, manusia,...
# 47   [komputer, adalah, alat, bantu, manusia, yang,...
# 48   [komputer, adalah, alat, komputasi, elektronik...
# 49   [alat, yang, dipakai, untuk, mengolah, data, m...
# 50   [serangkaian, ataupun, sekelompok, mesin, elek...
# 51   [komputer, adalah, alat, yang, digunakan, untu...
# 52   [alat, elektronik, yang, terdiri, dari, hardwa...
#
#                                 Jawaban Tanpa Stopword  \
# No
# 1    [komputer, serangkaian, sekelompok, mesin, ele...
# 2                        [komputer, mesin, penghitung]
# 3    [mesin, membantu, manusia, menjalankan, segara...
# 4    [komputer, alat, komputasi, diciptakan, menghi...
# 5                         [alat, memudahkan, masnusia]
# 6    [komputer, alat, dipakai, mengolah, data, pros...
# 7    [komputer, alat, mengolah, data, perhitungan, ...
# 8    [komputer, alat, dipakai, mengolah, data, pros...
# 9    [komputer, alat, dipakai, mengolah, data, pros...
# 10   [komputer, serangkaian, sekelompok, mesin, ele...
# 11   [komputer, alat, dipakai, mengolah, data, pros...
# 12   [alat, dipakai, mengolah, data, prosedur, diru...
# 13   [komputer, barang, elektronik, pintar, dikemba...
# 14   [komputer, alat, dipakai, mengolah, data, pros...
# 15      [alat, bantu, mempermudah, pekerjaan, manusia]
# 16   [komputer, alat, mempermudah, manusia, aktivit...
# 17   [komputer, perangkat, keperluan, fungsi, kompu...
# 18   [serangkaian, sekelompok, mesin, elektronik, r...
# 19   [komputer, serangkaian, sekelompok, mesin, ele...
# 20                [alat, membantu, manusia, pekerjaan]
# 21   [komputer, alat, dipakai, mengolah, data, pros...
# 22                             [komputer, 13, kalimat]
# 23   [komputer, alat, mengolah, data, prosedur, dir...
# 24                                   [mesin, mengerti]
# 25   [komputer, alat, pengolah, data, prosedur, rum...
# 26   [komputer, alat, elektronik, memiliki, komputa...
# 27   [komputer, alat, bantu, hitung, manusia, dikem...
# 28   [alat, elektronik, menghitung, menganalisa, da...
# 29                    [alat, dipakai, mengelola, data]
# 30   [alat, dipakai, mengolah, data, prosedur, diru...
# 31   [komputer, mesin, hitung, memudahkan, pekerjaa...
# 32   [komputer, mesin, hitung, komputer, mengolah, ...
# 33   [komputer, alat, dipakai, mengolah, data, pros...
# 34   [alat, dipakai, mengolah, data, prosedur, diru...
# 35   [komputer, sekumpulan, alat, elektronik, diman...
# 36   [komputer, alat, dipakai, mengolah, data, pros...
# 37   [komputer, alat, dipakai, mengolah, data, pros...
# 38   [komputer, alat, dipakai, mengolah, data, pros...
# 39   [alat, dipakai, mengolah, data, prosedur, diru...
# 40                     [menerima, mengolah, informasi]
# 41                          [menerima, mengolah, data]
# 42   [komputer, alat, manipulasi, data, komputer, b...
# 43   [komputer, mesin, berfungsi, mempermudah, peke...
# 44                                    [mesin, pegolah]
# 45   [komputer, hardware, yg, berfungsi, membantu, ...
# 46   [alat, mempermudah, pekerjaan, manusia, alat, ...
# 47   [komputer, alat, bantu, manusia, mempermudah, ...
# 48   [komputer, alat, komputasi, elektronik, bergun...
# 49   [alat, dipakai, mengolah, data, prosedur, diru...
# 50   [serangkaian, sekelompok, mesin, elektronik, r...
# 51             [komputer, alat, mengolah, data, angka]
# 52   [alat, elektronik, hardware, software, mejalan...
#
#                Jawaban Tanpa Stopword Not Tokenization  \
# No
# 1    komputer serangkaian sekelompok mesin elektron...
# 2                            komputer mesin penghitung
# 3    mesin membantu manusia menjalankan segara peke...
# 4    komputer alat komputasi diciptakan menghitung ...
# 5                             alat memudahkan masnusia
# 6    komputer alat dipakai mengolah data prosedur d...
# 7    komputer alat mengolah data perhitungan aritma...
# 8    komputer alat dipakai mengolah data prosedur d...
# 9    komputer alat dipakai mengolah data prosedur d...
# 10   komputer serangkaian sekelompok mesin elektron...
# 11   komputer alat dipakai mengolah data prosedur d...
# 12      alat dipakai mengolah data prosedur dirumuskan
# 13   komputer barang elektronik pintar dikembangkan...
# 14   komputer alat dipakai mengolah data prosedur d...
# 15            alat bantu mempermudah pekerjaan manusia
# 16   komputer alat mempermudah manusia aktivitas shari
# 17   komputer perangkat keperluan fungsi komputer d...
# 18   serangkaian sekelompok mesin elektronik ratusa...
# 19   komputer serangkaian sekelompok mesin elektron...
# 20                     alat membantu manusia pekerjaan
# 21   komputer alat dipakai mengolah data prosedur d...
# 22                                 komputer 13 kalimat
# 23   komputer alat mengolah data prosedur dirumuska...
# 24                                      mesin mengerti
# 25       komputer alat pengolah data prosedur rumuskan
# 26   komputer alat elektronik memiliki komputasi sp...
# 27   komputer alat bantu hitung manusia dikembangka...
# 28   alat elektronik menghitung menganalisa data ce...
# 29                         alat dipakai mengelola data
# 30   alat dipakai mengolah data prosedur dirumuskan...
# 31   komputer mesin hitung memudahkan pekerjaan man...
# 32   komputer mesin hitung komputer mengolah data m...
# 33   komputer alat dipakai mengolah data prosedur d...
# 34   alat dipakai mengolah data prosedur dirumuskan...
# 35   komputer sekumpulan alat elektronik dimana ter...
# 36   komputer alat dipakai mengolah data prosedur d...
# 37   komputer alat dipakai mengolah data prosedur d...
# 38   komputer alat dipakai mengolah data prosedur d...
# 39   alat dipakai mengolah data prosedur dirumuskan...
# 40                         menerima mengolah informasi
# 41                              menerima mengolah data
# 42   komputer alat manipulasi data komputer berisi ...
# 43   komputer mesin berfungsi mempermudah pekerjaan...
# 44                                       mesin pegolah
# 45     komputer hardware yg berfungsi membantu manusia
# 46   alat mempermudah pekerjaan manusia alat memper...
# 47   komputer alat bantu manusia mempermudah pekerj...
# 48   komputer alat komputasi elektronik berguna mer...
# 49   alat dipakai mengolah data prosedur dirumuskan...
# 50   serangkaian sekelompok mesin elektronik ribuan...
# 51                   komputer alat mengolah data angka
# 52   alat elektronik hardware software mejalankan t...
#
#                                   Jawaban Tanpa Negasi  \
# No
# 1    [komputer, serangkaian, sekelompok, mesin, ele...
# 2                        [komputer, mesin, penghitung]
# 3    [mesin, membantu, manusia, menjalankan, segara...
# 4    [komputer, alat, komputasi, diciptakan, menghi...
# 5                         [alat, memudahkan, masnusia]
# 6    [komputer, alat, dipakai, mengolah, data, pros...
# 7    [komputer, alat, mengolah, data, perhitungan, ...
# 8    [komputer, alat, dipakai, mengolah, data, pros...
# 9    [komputer, alat, dipakai, mengolah, data, pros...
# 10   [komputer, serangkaian, sekelompok, mesin, ele...
# 11   [komputer, alat, dipakai, mengolah, data, pros...
# 12   [alat, dipakai, mengolah, data, prosedur, diru...
# 13   [komputer, barang, elektronik, pintar, dikemba...
# 14   [komputer, alat, dipakai, mengolah, data, pros...
# 15      [alat, bantu, mempermudah, pekerjaan, manusia]
# 16   [komputer, alat, mempermudah, manusia, aktivit...
# 17   [komputer, perangkat, keperluan, fungsi, kompu...
# 18   [serangkaian, sekelompok, mesin, elektronik, r...
# 19   [komputer, serangkaian, sekelompok, mesin, ele...
# 20                [alat, membantu, manusia, pekerjaan]
# 21   [komputer, alat, dipakai, mengolah, data, pros...
# 22                             [komputer, 13, kalimat]
# 23   [komputer, alat, mengolah, data, prosedur, dir...
# 24                                   [mesin, mengerti]
# 25   [komputer, alat, pengolah, data, prosedur, rum...
# 26   [komputer, alat, elektronik, memiliki, komputa...
# 27   [komputer, alat, bantu, hitung, manusia, dikem...
# 28   [alat, elektronik, menghitung, menganalisa, da...
# 29                    [alat, dipakai, mengelola, data]
# 30   [alat, dipakai, mengolah, data, prosedur, diru...
# 31   [komputer, mesin, hitung, memudahkan, pekerjaa...
# 32   [komputer, mesin, hitung, komputer, mengolah, ...
# 33   [komputer, alat, dipakai, mengolah, data, pros...
# 34   [alat, dipakai, mengolah, data, prosedur, diru...
# 35   [komputer, sekumpulan, alat, elektronik, diman...
# 36   [komputer, alat, dipakai, mengolah, data, pros...
# 37   [komputer, alat, dipakai, mengolah, data, pros...
# 38   [komputer, alat, dipakai, mengolah, data, pros...
# 39   [alat, dipakai, mengolah, data, prosedur, diru...
# 40                     [menerima, mengolah, informasi]
# 41                          [menerima, mengolah, data]
# 42   [komputer, alat, manipulasi, data, komputer, b...
# 43   [komputer, mesin, berfungsi, mempermudah, peke...
# 44                                    [mesin, pegolah]
# 45   [komputer, hardware, yg, berfungsi, membantu, ...
# 46   [alat, mempermudah, pekerjaan, manusia, alat, ...
# 47   [komputer, alat, bantu, manusia, mempermudah, ...
# 48   [komputer, alat, komputasi, elektronik, bergun...
# 49   [alat, dipakai, mengolah, data, prosedur, diru...
# 50   [serangkaian, sekelompok, mesin, elektronik, r...
# 51             [komputer, alat, mengolah, data, angka]
# 52   [alat, elektronik, hardware, software, mejalan...
#
#                         Jawaban Tanpa Negasi Not Token  \
# No
# 1    komputer serangkaian sekelompok mesin elektron...
# 2                            komputer mesin penghitung
# 3    mesin membantu manusia menjalankan segara peke...
# 4    komputer alat komputasi diciptakan menghitung ...
# 5                             alat memudahkan masnusia
# 6    komputer alat dipakai mengolah data prosedur d...
# 7    komputer alat mengolah data perhitungan aritma...
# 8    komputer alat dipakai mengolah data prosedur d...
# 9    komputer alat dipakai mengolah data prosedur d...
# 10   komputer serangkaian sekelompok mesin elektron...
# 11   komputer alat dipakai mengolah data prosedur d...
# 12      alat dipakai mengolah data prosedur dirumuskan
# 13   komputer barang elektronik pintar dikembangkan...
# 14   komputer alat dipakai mengolah data prosedur d...
# 15            alat bantu mempermudah pekerjaan manusia
# 16   komputer alat mempermudah manusia aktivitas shari
# 17   komputer perangkat keperluan fungsi komputer d...
# 18   serangkaian sekelompok mesin elektronik ratusa...
# 19   komputer serangkaian sekelompok mesin elektron...
# 20                     alat membantu manusia pekerjaan
# 21   komputer alat dipakai mengolah data prosedur d...
# 22                                 komputer 13 kalimat
# 23   komputer alat mengolah data prosedur dirumuska...
# 24                                      mesin mengerti
# 25       komputer alat pengolah data prosedur rumuskan
# 26   komputer alat elektronik memiliki komputasi sp...
# 27   komputer alat bantu hitung manusia dikembangka...
# 28   alat elektronik menghitung menganalisa data ce...
# 29                         alat dipakai mengelola data
# 30   alat dipakai mengolah data prosedur dirumuskan...
# 31   komputer mesin hitung memudahkan pekerjaan man...
# 32   komputer mesin hitung komputer mengolah data m...
# 33   komputer alat dipakai mengolah data prosedur d...
# 34   alat dipakai mengolah data prosedur dirumuskan...
# 35   komputer sekumpulan alat elektronik dimana ter...
# 36   komputer alat dipakai mengolah data prosedur d...
# 37   komputer alat dipakai mengolah data prosedur d...
# 38   komputer alat dipakai mengolah data prosedur d...
# 39   alat dipakai mengolah data prosedur dirumuskan...
# 40                         menerima mengolah informasi
# 41                              menerima mengolah data
# 42   komputer alat manipulasi data komputer berisi ...
# 43   komputer mesin berfungsi mempermudah pekerjaan...
# 44                                       mesin pegolah
# 45     komputer hardware yg berfungsi membantu manusia
# 46   alat mempermudah pekerjaan manusia alat memper...
# 47   komputer alat bantu manusia mempermudah pekerj...
# 48   komputer alat komputasi elektronik berguna mer...
# 49   alat dipakai mengolah data prosedur dirumuskan...
# 50   serangkaian sekelompok mesin elektronik ribuan...
# 51                   komputer alat mengolah data angka
# 52   alat elektronik hardware software mejalankan t...
#
#                                        Jawaban Stemmed  \
# No
# 1    [komputer, rangkai, kelompok, mesin, elektroni...
# 2                            [komputer, mesin, hitung]
# 3        [mesin, bantu, manusia, jalan, segara, kerja]
# 4     [komputer, alat, komputasi, cipta, hitung, kali]
# 5                              [alat, mudah, masnusia]
# 6    [komputer, alat, pakai, olah, data, prosedur, ...
# 7    [komputer, alat, olah, data, hitung, aritmatik...
# 8    [komputer, alat, pakai, olah, data, prosedur, ...
# 9    [komputer, alat, pakai, olah, data, prosedur, ...
# 10   [komputer, rangkai, kelompok, mesin, elektroni...
# 11   [komputer, alat, pakai, olah, data, prosedur, ...
# 12          [alat, pakai, olah, data, prosedur, rumus]
# 13   [komputer, barang, elektronik, pintar, kembang...
# 14   [komputer, alat, pakai, olah, data, prosedur, ...
# 15                [alat, bantu, mudah, kerja, manusia]
# 16   [komputer, alat, mudah, manusia, aktivitas, sh...
# 17   [komputer, perangkat, perlu, fungsi, komputer,...
# 18   [rangkai, kelompok, mesin, elektronik, ratus, ...
# 19   [komputer, rangkai, kelompok, mesin, elektroni...
# 20                       [alat, bantu, manusia, kerja]
# 21   [komputer, alat, pakai, olah, data, prosedur, ...
# 22                             [komputer, 13, kalimat]
# 23   [komputer, alat, olah, data, prosedur, rumus, ...
# 24                                       [mesin, erti]
# 25       [komputer, alat, olah, data, prosedur, rumus]
# 26   [komputer, alat, elektronik, milik, komputasi,...
# 27   [komputer, alat, bantu, hitung, manusia, kemba...
# 28   [alat, elektronik, hitung, menganalisa, data, ...
# 29                         [alat, pakai, kelola, data]
# 30   [alat, pakai, olah, data, prosedur, rumus, com...
# 31   [komputer, mesin, hitung, mudah, kerja, manusi...
# 32   [komputer, mesin, hitung, komputer, olah, data...
# 33   [komputer, alat, pakai, olah, data, prosedur, ...
# 34   [alat, pakai, olah, data, prosedur, rumus, man...
# 35   [komputer, kumpul, alat, elektronik, mana, koo...
# 36   [komputer, alat, pakai, olah, data, prosedur, ...
# 37   [komputer, alat, pakai, olah, data, prosedur, ...
# 38   [komputer, alat, pakai, olah, data, prosedur, ...
# 39   [alat, pakai, olah, data, prosedur, rumus, com...
# 40                           [terima, olah, informasi]
# 41                                [terima, olah, data]
# 42   [komputer, alat, manipulasi, data, komputer, i...
# 43   [komputer, mesin, fungsi, mudah, kerja, manusi...
# 44                                       [mesin, pego]
# 45    [komputer, hardware, yg, fungsi, bantu, manusia]
# 46   [alat, mudah, kerja, manusia, alat, singkat, k...
# 47   [komputer, alat, bantu, manusia, mudah, kerja,...
# 48   [komputer, alat, komputasi, elektronik, guna, ...
# 49   [alat, pakai, olah, data, prosedur, rumus, com...
# 50   [rangkai, kelompok, mesin, elektronik, ribu, j...
# 51                 [komputer, alat, olah, data, angka]
# 52   [alat, elektronik, hardware, software, mejalan...
#
#                              Jawaban Stemmed Not Token
# No
# 1    komputer rangkai kelompok mesin elektronik rib...
# 2                                komputer mesin hitung
# 3               mesin bantu manusia jalan segara kerja
# 4            komputer alat komputasi cipta hitung kali
# 5                                  alat mudah masnusia
# 6    komputer alat pakai olah data prosedur rumus c...
# 7    komputer alat olah data hitung aritmatika kerj...
# 8    komputer alat pakai olah data prosedur rumus c...
# 9    komputer alat pakai olah data prosedur rumus c...
# 10   komputer rangkai kelompok mesin elektronik rib...
# 11   komputer alat pakai olah data prosedur rumus k...
# 12                 alat pakai olah data prosedur rumus
# 13   komputer barang elektronik pintar kembang fitu...
# 14   komputer alat pakai olah data prosedur rumus c...
# 15                      alat bantu mudah kerja manusia
# 16         komputer alat mudah manusia aktivitas shari
# 17   komputer perangkat perlu fungsi komputer dasar...
# 18    rangkai kelompok mesin elektronik ratus komponen
# 19   komputer rangkai kelompok mesin elektronik rib...
# 20                            alat bantu manusia kerja
# 21   komputer alat pakai olah data prosedur rumus c...
# 22                                 komputer 13 kalimat
# 23   komputer alat olah data prosedur rumus kompute...
# 24                                          mesin erti
# 25              komputer alat olah data prosedur rumus
# 26   komputer alat elektronik milik komputasi spesi...
# 27   komputer alat bantu hitung manusia kembang ban...
# 28   alat elektronik hitung menganalisa data cepat ...
# 29                              alat pakai kelola data
# 30   alat pakai olah data prosedur rumus computer g...
# 31   komputer mesin hitung mudah kerja manusia komp...
# 32   komputer mesin hitung komputer olah data mengg...
# 33   komputer alat pakai olah data prosedur rumus c...
# 34   alat pakai olah data prosedur rumus mana kompu...
# 35   komputer kumpul alat elektronik mana koordinas...
# 36   komputer alat pakai olah data prosedur rumus c...
# 37   komputer alat pakai olah data prosedur rumus c...
# 38        komputer alat pakai olah data prosedur rumus
# 39   alat pakai olah data prosedur rumus computer g...
# 40                               terima olah informasi
# 41                                    terima olah data
# 42   komputer alat manipulasi data komputer isi har...
# 43   komputer mesin fungsi mudah kerja manusia mesi...
# 44                                          mesin pego
# 45           komputer hardware yg fungsi bantu manusia
# 46         alat mudah kerja manusia alat singkat kerja
# 47     komputer alat bantu manusia mudah kerja manusia
# 48   komputer alat komputasi elektronik guna ringan...
# 49   alat pakai olah data prosedur rumus computer g...
# 50   rangkai kelompok mesin elektronik ribu juta ko...
# 51                       komputer alat olah data angka
# 52   alat elektronik hardware software mejalankan t...

# %%
# Convert ke dataset
for i, df in enumerate(list_df_teknologi):
    df[['Jawaban Lowercase', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']].to_csv(f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Lower Case/Teknologi/Soal_LC_Teknologi_{i+1}.csv', index=False)

# %%
# Convert ke dataset
for i, df in enumerate(list_df_teknologi):
    df[['Jawaban tanpa Punctuation', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']].to_csv(f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Remove Punctuation/Teknologi/Soal_RP_Teknologi_{i+1}.csv', index=False)

# %%
# Convert ke dataset
for i, df in enumerate(list_df_teknologi):
    df[['Jawaban Tanpa Stopword Not Tokenization', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']].to_csv(f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Stopword Remove/Teknologi/Soal_SW_Teknologi_{i+1}.csv', index=False)

# %%
# Convert ke dataset
for i, df in enumerate(list_df_teknologi):
    df[['Jawaban Tanpa Negasi Not Token', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']].to_csv(f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Convert Negation/Teknologi/Soal_CV_Teknologi_{i+1}.csv', index=False)

# %%
# Convert ke dataset
for i, df in enumerate(list_df_teknologi):
    df[['Jawaban Tanpa Negasi Not Token', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']].to_csv(f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Stemming/Teknologi/Soal_Stemm_Teknologi_{i+1}.csv', index=False)

# %%
pip install nlp_id
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nlp_id in /usr/local/lib/python3.9/dist-packages (0.1.13.0)
# Requirement already satisfied: nltk==3.4.5 in /usr/local/lib/python3.9/dist-packages (from nlp_id) (3.4.5)
# Requirement already satisfied: wget==3.2 in /usr/local/lib/python3.9/dist-packages (from nlp_id) (3.2)
# Requirement already satisfied: scikit-learn==1.1.0 in /usr/local/lib/python3.9/dist-packages (from nlp_id) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from nltk==3.4.5->nlp_id) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.0->nlp_id) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.0->nlp_id) (1.1.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.0->nlp_id) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.0->nlp_id) (1.10.1)

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.27.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)

# %%
import re
import random
import pandas as pd
import torch
import tensorflow as tf
import numpy as np

from nlp_id.lemmatizer import Lemmatizer
from nltk.corpus import stopwords
from tqdm import tqdm
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.metrics import f1_score, cohen_kappa_score
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Dense
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import AdamW, get_linear_schedule_with_warmup
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from nltk.corpus import stopwords

# %%
seed_val = 17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def qwk_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return cohen_kappa_score(labels_flat, preds_flat)

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in label_dict.items()}

    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

def evaluate(dataloader_val, device, model):

    model.eval()

    loss_val_total = 0
    predictions, true_vals = [], []

    for batch in dataloader_val:

        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():
            outputs = model(**inputs)

        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)

    loss_val_avg = loss_val_total/len(dataloader_val)

    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)

    return loss_val_avg, predictions, true_vals

def train_eval(df_final, pretrainedmodel):
    # bin nilai (continuous variable) into intervals
    df_final['nilai'] = pd.qcut(df_final['nilai'], 5, labels=False)


    # make sure that the training set and test set ratio is 80:20
    add = len(df_final[df_final['tipe'] == 'test']) - (round(0.15*(len(df_final[df_final['tipe'] == 'train'])+len(df_final[df_final['tipe'] == 'test']))))
    for i in df_final[df_final['tipe'] == 'test'].sample(n = add).itertuples():
        df_final.at[i.Index, 'tipe'] = 'train'

    # load model and tokenizer
    tokenizer = BertTokenizer.from_pretrained(pretrainedmodel, ignore_mismatched_sizes=True)

    encoded_data_train = tokenizer.batch_encode_plus(
        df_final[df_final.tipe=='train']['jawaban'].values,
        add_special_tokens=True,
        return_attention_mask=True,
        pad_to_max_length=True,
        truncation=True,
        max_length=256,
        padding='max_length',
        return_tensors='pt'
    )

    encoded_data_val = tokenizer.batch_encode_plus(
        df_final[df_final.tipe=='test']['jawaban'].values,
        add_special_tokens=True,
        return_attention_mask=True,
        pad_to_max_length=True,
        truncation=True,
        max_length=256,
        padding='max_length',
        return_tensors='pt'
    )

    input_ids_train = encoded_data_train['input_ids']
    attention_masks_train = encoded_data_train['attention_mask']
    labels_train = torch.tensor(df_final[df_final.tipe=='train'].nilai.values)

    input_ids_val = encoded_data_val['input_ids']
    attention_masks_val = encoded_data_val['attention_mask']
    labels_val = torch.tensor(df_final[df_final.tipe=='test'].nilai.values)

    dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
    dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)

    model = BertForSequenceClassification.from_pretrained(pretrainedmodel,
                                                          num_labels=5,
                                                          output_attentions=False,
                                                          output_hidden_states=False, ignore_mismatched_sizes=True)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)

    batch_size = 4

    dataloader_train = DataLoader(dataset_train,
                                  sampler=RandomSampler(dataset_train),
                                  batch_size=batch_size)

    dataloader_validation = DataLoader(dataset_val,
                                       sampler=SequentialSampler(dataset_val),
                                       batch_size=batch_size)

    optimizer = torch.optim.AdamW(model.parameters(),
                      lr=2e-5,
                      eps=1e-8)

    epochs = 4

    scheduler = get_linear_schedule_with_warmup(optimizer,
                                                num_warmup_steps=0,
                                                num_training_steps=len(dataloader_train)*epochs)

    for epoch in tqdm(range(1, epochs+1)):

        model.train()

        loss_train_total = 0

        progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
        for batch in progress_bar:

            model.zero_grad()

            batch = tuple(b.to(device) for b in batch)

            inputs = {'input_ids':      batch[0],
                      'attention_mask': batch[1],
                      'labels':         batch[2],
                     }

            outputs = model(**inputs)

            loss = outputs[0]
            loss_train_total += loss.item()
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

            optimizer.step()
            scheduler.step()

            progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})


        torch.save(model.state_dict(), f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/finetuned_BERT_{df_final["path"]}_epoch_{epoch}.model')

        tqdm.write(f'\nEpoch {epoch}')

        loss_train_avg = loss_train_total/len(dataloader_train)
        tqdm.write(f'Training loss: {loss_train_avg}')

        val_loss, predictions, true_vals = evaluate(dataloader_validation, device, model)
        val_f1 = f1_score_func(predictions, true_vals)
        val_qwk = qwk_score_func(predictions, true_vals)
        tqdm.write(f'Validation loss: {val_loss}')
        tqdm.write(f'F1 Score (Weighted): {val_f1}')
        tqdm.write(f'QWK Score: {val_qwk}')

# %%
def asag_systems(path_dir):
    list_pre_trained_model = ['indobenchmark/indobert-lite-base-p2']
    list_dir = os.listdir(path_dir)
    for m in list_pre_trained_model:
        print(m)
        for idx, ele in enumerate(list_dir):
            df_raw = pd.read_csv(path_dir + '/' +ele)
            
            df_raw = df_raw
            list_final = []
    
            for i in df_raw.itertuples():
                list_final.append(
                    {
                        'jawaban': i[1],
                        'nilai': 100,
                        'tipe': 'train',
                        'path': f'{path_dir} {ele}',
                    }
                )
                df_tmp =  pd.read_csv(path_dir + '/' +ele)
                
                df_tmp = df_tmp.dropna()
                for j in df_tmp.itertuples():
                    list_final.append(
                        {
                            'jawaban': j[1],
                            'nilai': j[5],
                            'tipe': 'test',
                            'path': f'{path_dir} {ele}',
                        }
                    )
            if idx == 0:
                df_final = pd.DataFrame(list_final)
            else:
                df_final.append(pd.DataFrame(list_final), ignore_index=True)
    
            train_eval(df_final, m)

# %%
asag_systems('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Lower Case/Teknologi')
# Out:
# indobenchmark/indobert-lite-base-p2
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/225k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.54k [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'AlbertTokenizerFast'.
# The class this function is called from is 'BertTokenizer'.
# You are using a model of type albert to instantiate a model of type bert. This is not supported for all configurations of models and can yield errors.
# Downloading pytorch_model.bin:   0%|          | 0.00/46.7M [00:00<?, ?B/s]
# Some weights of the model checkpoint at indobenchmark/indobert-lite-base-p2 were not used when initializing BertForSequenceClassification: ['encoder.albert_layer_groups.0.albert_layers.0.attention.key.weight', 'encoder.embedding_hidden_mapping_in.weight', 'pooler.bias', 'encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.weight', 'encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.bias', 'pooler.weight', 'encoder.albert_layer_groups.0.albert_layers.0.attention.query.bias', 'encoder.albert_layer_groups.0.albert_layers.0.ffn_output.weight', 'encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.bias', 'encoder.albert_layer_groups.0.albert_layers.0.attention.dense.bias', 'encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.weight', 'encoder.albert_layer_groups.0.albert_layers.0.attention.value.bias', 'encoder.albert_layer_groups.0.albert_layers.0.attention.query.weight', 'encoder.albert_layer_groups.0.albert_layers.0.attention.value.weight', 'encoder.albert_layer_groups.0.albert_layers.0.attention.dense.weight', 'encoder.albert_layer_groups.0.albert_layers.0.ffn.bias', 'encoder.albert_layer_groups.0.albert_layers.0.ffn_output.bias', 'encoder.embedding_hidden_mapping_in.bias', 'encoder.albert_layer_groups.0.albert_layers.0.attention.key.bias', 'encoder.albert_layer_groups.0.albert_layers.0.ffn.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-lite-base-p2 and are newly initialized: ['encoder.layer.7.attention.self.key.bias', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.5.attention.self.key.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.3.attention.self.value.weight', 'encoder.layer.9.attention.self.key.bias', 'encoder.layer.6.attention.self.value.weight', 'encoder.layer.9.output.LayerNorm.bias', 'encoder.layer.9.attention.self.query.weight', 'encoder.layer.6.output.LayerNorm.bias', 'encoder.layer.7.output.LayerNorm.bias', 'encoder.layer.7.attention.self.query.weight', 'encoder.layer.7.intermediate.dense.bias', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.9.output.LayerNorm.weight', 'encoder.layer.8.attention.output.LayerNorm.weight', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.2.attention.self.query.weight', 'encoder.layer.5.attention.output.dense.weight', 'encoder.layer.7.attention.self.value.bias', 'encoder.layer.2.output.dense.weight', 'encoder.layer.4.attention.self.key.bias', 'encoder.layer.6.attention.output.dense.weight', 'encoder.layer.3.output.dense.weight', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.7.output.LayerNorm.weight', 'encoder.layer.11.attention.self.value.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.5.output.dense.weight', 'encoder.layer.6.attention.self.query.bias', 'encoder.layer.2.attention.output.LayerNorm.weight', 'encoder.layer.7.attention.output.dense.bias', 'encoder.layer.4.attention.self.query.weight', 'encoder.layer.7.attention.output.dense.weight', 'encoder.layer.8.output.LayerNorm.weight', 'encoder.layer.9.attention.output.dense.weight', 'encoder.layer.10.attention.output.LayerNorm.bias', 'encoder.layer.5.attention.self.query.bias', 'encoder.layer.7.intermediate.dense.weight', 'encoder.layer.8.output.LayerNorm.bias', 'encoder.layer.9.intermediate.dense.weight', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.11.attention.output.dense.weight', 'encoder.layer.5.output.LayerNorm.weight', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.5.attention.output.LayerNorm.bias', 'encoder.layer.6.output.LayerNorm.weight', 'encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.layer.2.attention.self.value.weight', 'encoder.layer.4.attention.self.key.weight', 'encoder.layer.3.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.9.attention.self.value.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.6.output.dense.bias', 'encoder.layer.11.attention.self.key.bias', 'encoder.layer.7.output.dense.bias', 'encoder.layer.8.attention.output.LayerNorm.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.3.attention.output.LayerNorm.weight', 'encoder.layer.3.attention.self.query.bias', 'encoder.layer.4.attention.output.dense.bias', 'encoder.layer.5.attention.self.value.bias', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.3.output.LayerNorm.weight', 'encoder.layer.2.attention.self.key.weight', 'encoder.layer.6.attention.self.value.bias', 'encoder.layer.5.attention.self.query.weight', 'encoder.layer.8.attention.self.query.weight', 'encoder.layer.5.attention.self.key.weight', 'encoder.layer.2.output.dense.bias', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.attention.output.dense.weight', 'encoder.layer.6.attention.self.key.bias', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.7.attention.output.LayerNorm.bias', 'encoder.layer.0.intermediate.dense.weight', 'encod ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-lite-base-p2 and are newly initialized because the shapes did not match:
# - embeddings.word_embeddings.weight: found shape torch.Size([30000, 128]) in the checkpoint and torch.Size([30000, 768]) in the model instantiated
# - embeddings.position_embeddings.weight: found shape torch.Size([512, 128]) in the checkpoint and torch.Size([512, 768]) in the model instantiated
# - embeddings.token_type_embeddings.weight: found shape torch.Size([2, 128]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# - embeddings.LayerNorm.weight: found shape torch.Size([128]) in the checkpoint and torch.Size([768]) in the model instantiated
# - embeddings.LayerNorm.bias: found shape torch.Size([128]) in the checkpoint and torch.Size([768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/586 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/586 [00:44<?, ?it/s, training_loss=0.594]
# Epoch 1:   0%|          | 1/586 [00:44<7:16:31, 44.77s/it, training_loss=0.594]
# Epoch 1:   0%|          | 1/586 [01:08<7:16:31, 44.77s/it, training_loss=0.753]
# Epoch 1:   0%|          | 2/586 [01:08<5:15:18, 32.39s/it, training_loss=0.753]
# Epoch 1:   0%|          | 2/586 [01:35<5:15:18, 32.39s/it, training_loss=0.785]
# Epoch 1:   1%|          | 3/586 [01:35<4:51:07, 29.96s/it, training_loss=0.785]
# Epoch 1:   1%|          | 3/586 [02:00<4:51:07, 29.96s/it, training_loss=0.478]
# Epoch 1:   1%|          | 4/586 [02:00<4:32:15, 28.07s/it, training_loss=0.478]
# Epoch 1:   1%|          | 4/586 [02:25<4:32:15, 28.07s/it, training_loss=0.650]
# Epoch 1:   1%|          | 5/586 [02:25<4:21:11, 26.97s/it, training_loss=0.650]
# Epoch 1:   1%|          | 5/586 [02:49<4:21:11, 26.97s/it, training_loss=0.630]
# Epoch 1:   1%|          | 6/586 [02:49<4:08:30, 25.71s/it, training_loss=0.630]
# Epoch 1:   1%|          | 6/586 [03:14<4:08:30, 25.71s/it, training_loss=0.579]
# Epoch 1:   1%|          | 7/586 [03:14<4:05:58, 25.49s/it, training_loss=0.579]
# Epoch 1:   1%|          | 7/586 [03:39<4:05:58, 25.49s/it, training_loss=0.441]
# Epoch 1:   1%|▏         | 8/586 [03:39<4:04:24, 25.37s/it, training_loss=0.441]
# Epoch 1:   1%|▏         | 8/586 [04:02<4:04:24, 25.37s/it, training_loss=0.523]
# Epoch 1:   2%|▏         | 9/586 [04:02<3:57:36, 24.71s/it, training_loss=0.523]
# Epoch 1:   2%|▏         | 9/586 [04:27<3:57:36, 24.71s/it, training_loss=0.625]
# Epoch 1:   2%|▏         | 10/586 [04:27<3:58:21, 24.83s/it, training_loss=0.625]
# Epoch 1:   2%|▏         | 10/586 [04:52<3:58:21, 24.83s/it, training_loss=0.605]
# Epoch 1:   2%|▏         | 11/586 [04:52<3:58:24, 24.88s/it, training_loss=0.605]
# Epoch 1:   2%|▏         | 11/586 [05:16<3:58:24, 24.88s/it, training_loss=0.326]
# Epoch 1:   2%|▏         | 12/586 [05:16<3:54:30, 24.51s/it, training_loss=0.326]
# Epoch 1:   2%|▏         | 12/586 [05:40<3:54:30, 24.51s/it, training_loss=0.464]
# Epoch 1:   2%|▏         | 13/586 [05:40<3:53:32, 24.45s/it, training_loss=0.464]
# Epoch 1:   2%|▏         | 13/586 [06:05<3:53:32, 24.45s/it, training_loss=0.256]
# Epoch 1:   2%|▏         | 14/586 [06:05<3:54:49, 24.63s/it, training_loss=0.256]
# Epoch 1:   2%|▏         | 14/586 [06:30<3:54:49, 24.63s/it, training_loss=0.540]
# Epoch 1:   3%|▎         | 15/586 [06:30<3:54:33, 24.65s/it, training_loss=0.540]
# Epoch 1:   3%|▎         | 15/586 [06:53<3:54:33, 24.65s/it, training_loss=0.882]
# Epoch 1:   3%|▎         | 16/586 [06:53<3:51:11, 24.34s/it, training_loss=0.882]
# Epoch 1:   3%|▎         | 16/586 [07:18<3:51:11, 24.34s/it, training_loss=0.664]
# Epoch 1:   3%|▎         | 17/586 [07:18<3:52:45, 24.54s/it, training_loss=0.664]
# Epoch 1:   3%|▎         | 17/586 [07:45<3:52:45, 24.54s/it, training_loss=0.507]
# Epoch 1:   3%|▎         | 18/586 [07:45<3:57:02, 25.04s/it, training_loss=0.507]
# Epoch 1:   3%|▎         | 18/586 [08:08<3:57:02, 25.04s/it, training_loss=0.414]
# Epoch 1:   3%|▎         | 19/586 [08:08<3:51:39, 24.51s/it, training_loss=0.414]
# Epoch 1:   3%|▎         | 19/586 [08:33<3:51:39, 24.51s/it, training_loss=0.763]
# Epoch 1:   3%|▎         | 20/586 [08:33<3:53:25, 24.74s/it, training_loss=0.763]
# Epoch 1:   3%|▎         | 20/586 [08:59<3:53:25, 24.74s/it, training_loss=0.844]
# Epoch 1:   4%|▎         | 21/586 [08:59<3:55:18, 24.99s/it, training_loss=0.844]
# Epoch 1:   4%|▎         | 21/586 [09:23<3:55:18, 24.99s/it, training_loss=0.783]
# Epoch 1:   4%|▍         | 22/586 [09:23<3:53:53, 24.88s/it, training_loss=0.783]
# Epoch 1:   4%|▍         | 22/586 [09:47<3:53:53, 24.88s/it, training_loss=0.567]
# Epoch 1:   4%|▍         | 23/586 [09:47<3:50:19, 24.55s/it, training_loss=0.567]
# Epoch 1:   4%|▍         | 23/586 [10:12<3:50:19, 24.55s/it, training_loss=0.456]
# Epoch 1:   4%|▍         | 24/586 [10:12<3:51:14, 24.69s/it, training_loss=0.456]
# Epoch 1:   4%|▍         | 24/586 [10:37<3:51:14, 24.69s/it, training_loss=0.439]
# Epoch 1:   4%|▍         | 25/586 [10:37<3:52:05, 24.82s/it, training_loss=0.439]
# Epoch 1:   4%|▍         | 25/586 [11:01<3:52:05, 24.82s/it, training_loss=0.577]
# Epoch 1:   4%|▍         | 26/586 [11:01<3:47:23, 24.36s/it, training_loss=0.577]
# Epoch 1:   4%|▍         | 26/586 [11:26<3:47:23, 24.36s/it, training_loss=0.524]
# Epoch 1:   5%|▍         | 27/586 [11:26<3:48:53, 24.57s/it, training_loss=0.524]
# Epoch 1:   5%|▍         | 27/586 [11:51<3:48:53, 24.57s/it, training_loss=0.480]
# Epoch 1:   5%|▍         | 28/586 [11:51<3:49:43, 24.70s/it, training_loss=0.480]
# Epoch 1:   5%|▍         | 28/586 [12:14<3:49:43, 24.70s/it, training_loss=0.500]
# Epoch 1:   5%|▍         | 29/586 [12:14<3:45:12, 24.26s/it, training_loss=0.500]
# Epoch 1:   5%|▍         | 29/586 [12:39<3:45:12, 24.26s/it, training_loss=0.457]
# Epoch 1:   5%|▌         | 30/586 [12:39<3:47:13, 24.52s/it, training_loss=0.457]
# Epoch 1:   5%|▌         | 30/586 [13:05<3:47:13, 24.52s/it, training_loss=0.327]
# Epoch 1:   5%|▌         | 31/586 [13:05<3:50:48, 24.95s/it, training_loss=0.327]
# Epoch 1:   5%|▌         | 31/586 [13:29<3:50:48, 24.95s/it, training_loss=0.578]
# Epoch 1:   5%|▌         | 32/586 [13:29<3:49:01, 24.80s/it, training_loss=0.578]
# Epoch 1:   5%|▌         | 32/586 [13:54<3:49:01, 24.80s/it, training_loss=0.805]
# Epoch 1:   6%|▌         | 33/586 [13:54<3:47:20, 24.67s/it, training_loss=0.805]
# Epoch 1:   6%|▌         | 33/586 [14:19<3:47:20, 24.67s/it, training_loss=0.781]
# Epoch 1:   6%|▌         | 34/586 [14:19<3:48:19, 24.82s/it, training_loss=0.781]
# Epoch 1:   6%|▌         | 34/586 [14:44<3:48:19, 24.82s/it, training_loss=0.543]
# Epoch 1:   6%|▌         | 35/586 [14:44<3:48:39, 24.90s/it, training_loss=0.543]
# Epoch 1:   6%|▌         | 35/586 [15:07<3:48:39, 24.90s/it, training_loss=0.462]
# Epoch 1:   6%|▌         | 36/586 [15:07<3:43:47, 24.41s/it, training_loss=0.462]
# Epoch 1:   6%|▌         | 36/586 [15:32<3:43:47, 24.41s/it, training_loss=0.716]
# Epoch 1:   6%|▋         | 37/586 [15:32<3:45:07, 24.60s/it, training_loss=0.716]
# Epoch 1:   6%|▋         | 37/586 [15:57<3:45:07, 24.60s/it, training_loss=0.737]
# Epoch 1:   6%|▋         | 38/586 [15:57<3:45:56, 24.74s/it, training_loss=0.737]
# Epoch 1:   6%|▋         | 38/586 [16:21<3:45:56, 24.74s/it, training_loss=0.553]
# Epoch 1:   7%|▋         | 39/586 [16:21<3:41:44, 24.32s/it, training_loss=0.553]
# Epoch 1:   7%|▋         | 39/586 [16:46<3:41:44, 24.32s/it, training_loss=0.512]
# Epoch 1:   7%|▋         | 40/586 [16:46<3:43:01, 24.51s/it, training_loss=0.512]
# Epoch 1:   7%|▋         | 40/586 [17:11<3:43:01, 24.51s/it, training_loss=0.339]
# Epoch 1:   7%|▋         | 41/586 [17:11<3:44:11, 24.68s/it, training_loss=0.339]
# Epoch 1:   7%|▋         | 41/586 [17:35<3:44:11, 24.68s/it, training_loss=0.430]
# Epoch 1:   7%|▋         | 42/586 [17:35<3:41:36, 24.44s/it, training_loss=0.430]
# Epoch 1:   7%|▋         | 42/586 [17:59<3:41:36, 24.44s/it, training_loss=0.572]
# Epoch 1:   7%|▋         | 43/586 [17:59<3:40:31, 24.37s/it, training_loss=0.572]
# Epoch 1:   7%|▋         | 43/586 [18:24<3:40:31, 24.37s/it, training_loss=0.495]
# Epoch 1:   8%|▊         | 44/586 [18:24<3:42:07, 24.59s/it, training_loss=0.495]
# Epoch 1:   8%|▊         | 44/586 [18:49<3:42:07, 24.59s/it, training_loss=0.480]
# Epoch 1:   8%|▊         | 45/586 [18:49<3:42:23, 24.66s/it, training_loss=0.480]
# Epoch 1:   8%|▊         | 45/586 [19:12<3:42:23, 24.66s/it, training_loss=0.154]
# Epoch 1:   8%|▊         | 46/586 [19:12<3:38:54, 24.32s/it, training_loss=0.154]
# Epoch 1:   8%|▊         | 46/586 [19:37<3:38:54, 24.32s/it, training_loss=0.595]
# Epoch 1:   8%|▊         | 47/586 [19:37<3:40:22, 24.53s/it, training_loss=0.595]
# Epoch 1:   8%|▊         | 47/586 [20:02<3:40:22, 24.53s/it, training_loss=0.506]
# Epoch 1:   8%|▊         | 48/586 [20:02<3:41:15, 24.68s/it, training_loss=0.506]
# Epoch 1:   8%|▊         | 48/586 [20:25<3:41:15, 24.68s/it, training_loss=0.420]
# Epoch 1:   8%|▊         | 49/586 [20:25<3:36:48, 24.23s/it, training_loss=0.420]
# Epoch 1:   8%|▊         | 49/586 [20:51<3:36:48, 24.23s/it, training_loss=0.458]
# Epoch 1:   9%|▊         | 50/586 [20:51<3:38:36, 24.47s/it, training_loss=0.458]
# Epoch 1:   9%|▊         | 50/586 [21:16<3:38:36, 24.47s/it, training_loss=0.530]
# Epoch 1:   9%|▊         | 51/586 [21:16<3:39:55, 24.66s/it, training_loss=0.530]
# Epoch 1:   9%|▊         | 51/586 [21:39<3:39:55, 24.66s/it, training_loss=0.630]
# Epoch 1:   9%|▉         | 52/586 [21:39<3:35:51, 24.25s/it, training_loss=0.630]
# Epoch 1:   9%|▉         | 52/586 [22:04<3:35:51, 24.25s/it, training_loss=0.567]
# Epoch 1:   9%|▉         | 53/586 [22:04<3:36:51, 24.41s/it, training_loss=0.567]
# Epoch 1:   9%|▉         | 53/586 [22:29<3:36:51, 24.41s/it, training_loss=0.356]
# Epoch 1:   9%|▉         | 54/586 [22:29<3:38:10, 24.61s/it, training_loss=0.356]
# Epoch 1:   9%|▉         | 54/586 [22:53<3:38:10, 24.61s/it, training_loss=0.482]
# Epoch 1:   9%|▉         | 55/586 [22:53<3:36:12, 24.43s/it, training_loss=0.482]
# Epoch 1:   9%|▉         | 55/586 [23:17<3:36:12, 24.43s/it, training_loss=0.503]
# Epoch 1:  10%|▉         | 56/586 [23:17<3:34:23, 24.27s/it, training_loss=0.503]
# Epoch 1:  10%|▉         | 56/586 [23:42<3:34:23, 24.27s/it, training_loss=0.412]
# Epoch 1:  10%|▉         | 57/586 [23:42<3:35:59, 24.50s/it, training_loss=0.412]
# Epoch 1:  10%|▉         | 57/586 [24:07<3:35:59, 24.50s/it, training_loss=0.310]
# Epoch 1:  10%|▉         | 58/586 [24:07<3:36:39, 24.62s/it, training_loss=0.310]
# Epoch 1:  10%|▉         | 58/586 [24:30<3:36:39, 24.62s/it, training_loss=0.386]
# Epoch 1:  10%|█         | 59/586 [24:30<3:33:04, 24.26s/it, training_loss=0.386]
# Epoch 1:  10%|█         | 59/586 [24:55<3:33:04, 24.26s/it, training_loss=0.494]
# Epoch 1:  10%|█         | 60/586 [24:55<3:34:40, 24.49s/it, training_loss=0.494]
# Epoch 1:  10%|█         | 60/586 [25:20<3:34:40, 24.49s/it, training_loss=0.237]
# Epoch 1:  10%|█         | 61/586 [25:20<3:35:48, 24.66s/it, training_loss=0.237]
# Epoch 1:  10%|█         | 61/586 [25:43<3:35:48, 24.66s/it, training_loss=0.422]
# Epoch 1:  11%|█         | 62/586 [25:43<3:31:41, 24.24s/it, training_loss=0.422]
# Epoch 1:  11%|█         | 62/586 [26:09<3:31:41, 24.24s/it, training_loss=0.454]
# Epoch 1:  11%|█         | 63/586 [26:09<3:33:34, 24.50s/it, training_loss=0.454]
# Epoch 1:  11%|█         | 63/586 [26:34<3:33:34, 24.50s/it, training_loss=0.323]
# Epoch 1:  11%|█         | 64/586 [26:34<3:34:52, 24.70s/it, training_loss=0.323]
# Epoch 1:  11%|█         | 64/586 [26:57<3:34:52, 24.70s/it, training_loss=0.175]
# Epoch 1:  11%|█         | 65/586 [26:57<3:31:15, 24.33s/it, training_loss=0.175]
# Epoch 1:  11%|█         | 65/586 [27:22<3:31:15, 24.33s/it, training_loss=0.269]
# Epoch 1:  11%|█▏        | 66/586 [27:22<3:31:53, 24.45s/it, training_loss=0.269]
# Epoch 1:  11%|█▏        | 66/586 [27:47<3:31:53, 24.45s/it, training_loss=0.412]
# Epoch 1:  11%|█▏        | 67/586 [27:47<3:33:04, 24.63s/it, training_loss=0.412]
# Epoch 1:  11%|█▏        | 67/586 [28:11<3:33:04, 24.63s/it, training_loss=0.112]
# Epoch 1:  12%|█▏        | 68/586 [28:11<3:32:19, 24.59s/it, training_loss=0.112]
# Epoch 1:  12%|█▏        | 68/586 [28:36<3:32:19, 24.59s/it, training_loss=0.399]
# Epoch 1:  12%|█▏        | 69/586 [28:36<3:31:09, 24.51s/it, training_loss=0.399]
# Epoch 1:  12%|█▏        | 69/586 [29:02<3:31:09, 24.51s/it, training_loss=0.195]
# Epoch 1:  12%|█▏        | 70/586 [29:02<3:35:58, 25.11s/it, training_loss=0.195]
# Epoch 1:  12%|█▏        | 70/586 [29:28<3:35:58, 25.11s/it, training_loss=0.417]
# Epoch 1:  12%|█▏        | 71/586 [29:28<3:35:57, 25.16s/it, training_loss=0.417]
# Epoch 1:  12%|█▏        | 71/586 [29:53<3:35:57, 25.16s/it, training_loss=0.363]
# Epoch 1:  12%|█▏        | 72/586 [29:53<3:35:04, 25.11s/it, training_loss=0.363]
# Epoch 1:  12%|█▏        | 72/586 [30:16<3:35:04, 25.11s/it, training_loss=0.260]
# Epoch 1:  12%|█▏        | 73/586 [30:16<3:31:21, 24.72s/it, training_loss=0.260]
# Epoch 1:  12%|█▏        | 73/586 [30:41<3:31:21, 24.72s/it, training_loss=0.662]
# Epoch 1:  13%|█▎        | 74/586 [30:41<3:31:53, 24.83s/it, training_loss=0.662]
# Epoch 1:  13%|█▎        | 74/586 [31:07<3:31:53, 24.83s/it, training_loss=0.167]
# Epoch 1:  13%|█▎        | 75/586 [31:07<3:32:20, 24.93s/it, training_loss=0.167]
# Epoch 1:  13%|█▎        | 75/586 [31:39<3:32:20, 24.93s/it, training_loss=0.261]
# Epoch 1:  13%|█▎        | 76/586 [31:39<3:51:18, 27.21s/it, training_loss=0.261]
# Epoch 1:  13%|█▎        | 76/586 [32:04<3:51:18, 27.21s/it, training_loss=0.173]
# Epoch 1:  13%|█▎        | 77/586 [32:04<3:43:52, 26.39s/it, training_loss=0.173]
# Epoch 1:  13%|█▎        | 77/586 [32:29<3:43:52, 26.39s/it, training_loss=0.323]
# Epoch 1:  13%|█▎        | 78/586 [32:29<3:39:53, 25.97s/it, training_loss=0.323]
# Epoch 1:  13%|█▎        | 78/586 [32:54<3:39:53, 25.97s/it, training_loss=0.341]
# Epoch 1:  13%|█▎        | 79/586 [32:54<3:37:17, 25.72s/it, training_loss=0.341]
# Epoch 1:  13%|█▎        | 79/586 [33:19<3:37:17, 25.72s/it, training_loss=0.280]
# Epoch 1:  14%|█▎        | 80/586 [33:19<3:35:08, 25.51s/it, training_loss=0.280]
# Epoch 1:  14%|█▎        | 80/586 [33:42<3:35:08, 25.51s/it, training_loss=0.495]
# Epoch 1:  14%|█▍        | 81/586 [33:42<3:29:11, 24.86s/it, training_loss=0.495]
# Epoch 1:  14%|█▍        | 81/586 [34:07<3:29:11, 24.86s/it, training_loss=0.498]
# Epoch 1:  14%|█▍        | 82/586 [34:07<3:29:04, 24.89s/it, training_loss=0.498]
# Epoch 1:  14%|█▍        | 82/586 [34:34<3:29:04, 24.89s/it, training_loss=0.397]
# Epoch 1:  14%|█▍        | 83/586 [34:34<3:34:19, 25.57s/it, training_loss=0.397]
# Epoch 1:  14%|█▍        | 83/586 [35:00<3:34:19, 25.57s/it, training_loss=0.131]
# Epoch 1:  14%|█▍        | 84/586 [35:00<3:33:55, 25.57s/it, training_loss=0.131]
# Epoch 1:  14%|█▍        | 84/586 [35:23<3:33:55, 25.57s/it, training_loss=0.272]
# Epoch 1:  15%|█▍        | 85/586 [35:23<3:27:53, 24.90s/it, training_loss=0.272]
# Epoch 1:  15%|█▍        | 85/586 [35:48<3:27:53, 24.90s/it, training_loss=0.492]
# Epoch 1:  15%|█▍        | 86/586 [35:48<3:27:57, 24.96s/it, training_loss=0.492]
# Epoch 1:  15%|█▍        | 86/586 [36:13<3:27:57, 24.96s/it, training_loss=0.137]
# Epoch 1:  15%|█▍        | 87/586 [36:13<3:27:59, 25.01s/it, training_loss=0.137]
# Epoch 1:  15%|█▍        | 87/586 [36:37<3:27:59, 25.01s/it, training_loss=0.151]
# Epoch 1:  15%|█▌        | 88/586 [36:37<3:23:16, 24.49s/it, training_loss=0.151]
# Epoch 1:  15%|█▌        | 88/586 [37:02<3:23:16, 24.49s/it, training_loss=0.224]
# Epoch 1:  15%|█▌        | 89/586 [37:02<3:24:24, 24.68s/it, training_loss=0.224]
# Epoch 1:  15%|█▌        | 89/586 [37:27<3:24:24, 24.68s/it, training_loss=0.623]
# Epoch 1:  15%|█▌        | 90/586 [37:27<3:25:13, 24.83s/it, training_loss=0.623]
# Epoch 1:  15%|█▌        | 90/586 [37:52<3:25:13, 24.83s/it, training_loss=0.236]
# Epoch 1:  16%|█▌        | 91/586 [37:52<3:26:21, 25.01s/it, training_loss=0.236]
# Epoch 1:  16%|█▌        | 91/586 [38:16<3:26:21, 25.01s/it, training_loss=0.395]
# Epoch 1:  16%|█▌        | 92/586 [38:16<3:22:42, 24.62s/it, training_loss=0.395]
# Epoch 1:  16%|█▌        | 92/586 [38:41<3:22:42, 24.62s/it, training_loss=0.305]
# Epoch 1:  16%|█▌        | 93/586 [38:41<3:23:24, 24.76s/it, training_loss=0.305]
# Epoch 1:  16%|█▌        | 93/586 [39:06<3:23:24, 24.76s/it, training_loss=0.581]
# Epoch 1:  16%|█▌        | 94/586 [39:06<3:23:50, 24.86s/it, training_loss=0.581]
# Epoch 1:  16%|█▌        | 94/586 [39:29<3:23:50, 24.86s/it, training_loss=0.435]
# Epoch 1:  16%|█▌        | 95/586 [39:29<3:19:12, 24.34s/it, training_loss=0.435]
# Epoch 1:  16%|█▌        | 95/586 [39:54<3:19:12, 24.34s/it, training_loss=0.478]
# Epoch 1:  16%|█▋        | 96/586 [39:54<3:20:38, 24.57s/it, training_loss=0.478]
# Epoch 1:  16%|█▋        | 96/586 [40:20<3:20:38, 24.57s/it, training_loss=0.260]
# Epoch 1:  17%|█▋        | 97/586 [40:20<3:21:47, 24.76s/it, training_loss=0.260]
# Epoch 1:  17%|█▋        | 97/586 [40:43<3:21:47, 24.76s/it, training_loss=0.382]
# Epoch 1:  17%|█▋        | 98/586 [40:43<3:18:16, 24.38s/it, training_loss=0.382]
# Epoch 1:  17%|█▋        | 98/586 [41:08<3:18:16, 24.38s/it, training_loss=0.452]
# Epoch 1:  17%|█▋        | 99/586 [41:08<3:19:25, 24.57s/it, training_loss=0.452]
# Epoch 1:  17%|█▋        | 99/586 [41:33<3:19:25, 24.57s/it, training_loss=0.234]
# Epoch 1:  17%|█▋        | 100/586 [41:33<3:20:33, 24.76s/it, training_loss=0.234]
# Epoch 1:  17%|█▋        | 100/586 [41:58<3:20:33, 24.76s/it, training_loss=0.238]
# Epoch 1:  17%|█▋        | 101/586 [41:58<3:19:49, 24.72s/it, training_loss=0.238]
# Epoch 1:  17%|█▋        | 101/586 [42:22<3:19:49, 24.72s/it, training_loss=0.215]
# Epoch 1:  17%|█▋        | 102/586 [42:22<3:17:17, 24.46s/it, training_loss=0.215]
# Epoch 1:  17%|█▋        | 102/586 [42:47<3:17:17, 24.46s/it, training_loss=0.254]
# Epoch 1:  18%|█▊        | 103/586 [42:47<3:18:45, 24.69s/it, training_loss=0.254]
# Epoch 1:  18%|█▊        | 103/586 [43:12<3:18:45, 24.69s/it, training_loss=0.182]
# Epoch 1:  18%|█▊        | 104/586 [43:12<3:19:27, 24.83s/it, training_loss=0.182]
# Epoch 1:  18%|█▊        | 104/586 [43:36<3:19:27, 24.83s/it, training_loss=0.221]
# Epoch 1:  18%|█▊        | 105/586 [43:36<3:15:21, 24.37s/it, training_loss=0.221]
# Epoch 1:  18%|█▊        | 105/586 [44:01<3:15:21, 24.37s/it, training_loss=0.341]
# Epoch 1:  18%|█▊        | 106/586 [44:01<3:16:46, 24.60s/it, training_loss=0.341]
# Epoch 1:  18%|█▊        | 106/586 [44:26<3:16:46, 24.60s/it, training_loss=0.416]
# Epoch 1:  18%|█▊        | 107/586 [44:26<3:17:39, 24.76s/it, training_loss=0.416]
# Epoch 1:  18%|█▊        | 107/586 [44:49<3:17:39, 24.76s/it, training_loss=0.217]
# Epoch 1:  18%|█▊        | 108/586 [44:49<3:14:07, 24.37s/it, training_loss=0.217]
# Epoch 1:  18%|█▊        | 108/586 [45:14<3:14:07, 24.37s/it, training_loss=0.316]
# Epoch 1:  19%|█▊        | 109/586 [45:14<3:14:48, 24.50s/it, training_loss=0.316]
# Epoch 1:  19%|█▊        | 109/586 [45:39<3:14:48, 24.50s/it, training_loss=0.352]
# Epoch 1:  19%|█▉        | 110/586 [45:39<3:16:11, 24.73s/it, training_loss=0.352]
# Epoch 1:  19%|█▉        | 110/586 [46:04<3:16:11, 24.73s/it, training_loss=0.241]
# Epoch 1:  19%|█▉        | 111/586 [46:04<3:14:45, 24.60s/it, training_loss=0.241]
# Epoch 1:  19%|█▉        | 111/586 [46:28<3:14:45, 24.60s/it, training_loss=0.055]
# Epoch 1:  19%|█▉        | 112/586 [46:28<3:12:48, 24.41s/it, training_loss=0.055]
# Epoch 1:  19%|█▉        | 112/586 [46:53<3:12:48, 24.41s/it, training_loss=0.197]
# Epoch 1:  19%|█▉        | 113/586 [46:53<3:14:26, 24.66s/it, training_loss=0.197]
# Epoch 1:  19%|█▉        | 113/586 [47:18<3:14:26, 24.66s/it, training_loss=0.138]
# Epoch 1:  19%|█▉        | 114/586 [47:18<3:15:01, 24.79s/it, training_loss=0.138]
# Epoch 1:  19%|█▉        | 114/586 [47:41<3:15:01, 24.79s/it, training_loss=0.267]
# Epoch 1:  20%|█▉        | 115/586 [47:41<3:11:00, 24.33s/it, training_loss=0.267]
# Epoch 1:  20%|█▉        | 115/586 [48:06<3:11:00, 24.33s/it, training_loss=0.193]
# Epoch 1:  20%|█▉        | 116/586 [48:06<3:12:32, 24.58s/it, training_loss=0.193]
# Epoch 1:  20%|█▉        | 116/586 [48:32<3:12:32, 24.58s/it, training_loss=0.119]
# Epoch 1:  20%|█▉        | 117/586 [48:32<3:13:30, 24.76s/it, training_loss=0.119]
# Epoch 1:  20%|█▉        | 117/586 [48:55<3:13:30, 24.76s/it, training_loss=0.171]
# Epoch 1:  20%|██        | 118/586 [48:55<3:09:44, 24.33s/it, training_loss=0.171]
#   0%|          | 0/4 [49:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-bf5a5c3d21e7> in <module>
# ----> 1 asag_systems('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Lower Case/Teknologi')
#
# <ipython-input-31-f84e458daf9f> in asag_systems(path_dir)
#      36                 df_final.append(pd.DataFrame(list_final), ignore_index=True)
#      37
# ---> 38             train_eval(df_final, m)
#
# <ipython-input-30-e9ceefad838f> in train_eval(df_final, pretrainedmodel)
#     154                      }
#     155
# --> 156             outputs = model(**inputs)
#     157
#     158             loss = outputs[0]
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1560         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1561
# -> 1562         outputs = self.bert(
#    1563             input_ids,
#    1564             attention_mask=attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1018             past_key_values_length=past_key_values_length,
#    1019         )
# -> 1020         encoder_outputs = self.encoder(
#    1021             embedding_output,
#    1022             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     608                 )
#     609             else:
# --> 610                 layer_outputs = layer_module(
#     611                     hidden_states,
#     612                     attention_mask,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     535             present_key_value = present_key_value + cross_attn_present_key_value
#     536
# --> 537         layer_output = apply_chunking_to_forward(
#     538             self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     539         )
#
# /usr/local/lib/python3.9/dist-packages/transformers/pytorch_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     246         return torch.cat(output_chunks, dim=chunk_dim)
#     247
# --> 248     return forward_fn(*input_tensors)
#     249
#     250
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py in feed_forward_chunk(self, attention_output)
#     547
#     548     def feed_forward_chunk(self, attention_output):
# --> 549         intermediate_output = self.intermediate(attention_output)
#     550         layer_output = self.output(intermediate_output, attention_output)
#     551         return layer_output
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states)
#     447
#     448     def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 449         hidden_states = self.dense(hidden_states)
#     450         hidden_states = self.intermediate_act_fn(hidden_states)
#     451         return hidden_states
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
