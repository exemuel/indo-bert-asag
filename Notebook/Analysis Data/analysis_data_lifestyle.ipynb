# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sastrawi in /usr/local/lib/python3.9/dist-packages (1.0.1)

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.1.1)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import os
import re
import nltk
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from nltk.tokenize import sent_tokenize, LineTokenizer, RegexpTokenizer
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

print(os.listdir("/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/"))
factory = StemmerFactory()
stemmer = factory.create_stemmer()
import string
from nltk.stem import PorterStemmer, WordNetLemmatizer
stopwords_indonesia = stopwords.words('indonesian')
stop_words = set(stopwords.words('indonesian'))
import sys
import os

py_file_location = "/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/"
sys.path.append(os.path.abspath(py_file_location))

# !cp /MyDrive/Paper_TA_ASAG/DATASET_TA/dataset.py
# from google.colab import files
# src = list(files.upload().values())[0]
# open('dataset.py','wb').write(src)
# Out:
# ['Indonesian Query Answering Dataset for Online Essay Test System.zip', 'Preprocessing', 'Analysis Data', 'Text Preprocessing', 'Data', 'dataset.py', '__pycache__', 'dict.json']
# cp: missing destination file operand after '/MyDrive/Paper_TA_ASAG/DATASET_TA/dataset.py'
# Try 'cp --help' for more information.

# %%
import dataset

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
result_lifestyle = []

# loop untuk setiap sheet pada dataframe
for df in dataset.Lifestyle_all_sheets:
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    # periksa maksimum, minimum, dan rata-rata panjang jawaban dan panjang soal pada setiap kategori
    for column in ['Jawaban']:
        # hitung panjang jawaban/soal dalam jumlah kata
        lengths = df[column].apply(lambda x: len(word_tokenize(x)))
        max_len = lengths.max()
        min_len = lengths.min()
        avg_len = lengths.mean()
        result_lifestyle.append({
            'Max Length': max_len,
            'Min Length': min_len,
            'Average Length': avg_len
        })

result_lifestyle = pd.DataFrame(result_lifestyle)

# %%
result_lifestyle
# Out:
#    Max Length  Min Length  Average Length
# 0         142           1       17.964912
# 1         293           1       26.071429
# 2         432           2       48.666667
# 3         287           2       28.385965
# 4         212           4       36.719298
# 5          60           2       16.385965
# 6         365           1       35.631579
# 7         258           1       32.192982
# 8         239           1       21.160714
# 9         304           1       24.642857

# %%
max_length_answer_lifestyle = result_lifestyle['Max Length'].max()
min_length_answer_lifestyle = result_lifestyle['Min Length'].min()
average_length_answer_lifestyle = result_lifestyle['Average Length'].mean()

# %%
result_soal_lifestyle = []

lengths = dataset.Lifestyle_Soal['Soal'].apply(lambda x: len(word_tokenize(x)))
max_len = lengths.max()
min_len = lengths.min()
avg_len = lengths.mean()
result_soal_lifestyle.append({
    'Max Length': max_len,
    'Min Length': min_len,
    'Average Length': avg_len
})
        
result_soal_lifestyle = pd.DataFrame(result_soal_lifestyle)

# %%
result_soal_lifestyle
# Out:
#    Max Length  Min Length  Average Length
# 0          12           7             9.5

# %%
result_lifestyle_case = []

i = 0
# loop untuk setiap sheet pada dataframe
for df in dataset.Lifestyle_all_sheets:
    i = i + 1
    capital_words = {}
    lower_words = {}
    other_words = {}
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    # periksa maksimum, minimum, dan rata-rata panjang jawaban dan panjang soal pada setiap kategori
    for token in df["Jawaban"]:
        if isinstance(token, str):
            if token.isupper():
                capital_words[token] = capital_words.get(token, 0) + 1
            elif token.islower():
                lower_words[token] = lower_words.get(token, 0) + 1
            else:
                other_words[token] = other_words.get(token, 0) + 1

    # Menampilkan hasil
    print(f'Soal {i}')
    print("Jumlah kata berhuruf kapital: ", len(capital_words))
    print("Jumlah kata berhuruf kecil: ", len(lower_words))
    print("Jumlah kata lainnya: ", len(other_words))
    print('\n')
# Out:
# Soal 1
# Jumlah kata berhuruf kapital:  0
# Jumlah kata berhuruf kecil:  31
# Jumlah kata lainnya:  25
#
#
# Soal 2
# Jumlah kata berhuruf kapital:  0
# Jumlah kata berhuruf kecil:  28
# Jumlah kata lainnya:  28
#
#
# Soal 3
# Jumlah kata berhuruf kapital:  0
# Jumlah kata berhuruf kecil:  31
# Jumlah kata lainnya:  26
#
#
# Soal 4
# Jumlah kata berhuruf kapital:  0
# Jumlah kata berhuruf kecil:  30
# Jumlah kata lainnya:  26
#
#
# Soal 5
# Jumlah kata berhuruf kapital:  0
# Jumlah kata berhuruf kecil:  30
# Jumlah kata lainnya:  26
#
#
# Soal 6
# Jumlah kata berhuruf kapital:  0
# Jumlah kata berhuruf kecil:  34
# Jumlah kata lainnya:  22
#
#
# Soal 7
# Jumlah kata berhuruf kapital:  0
# Jumlah kata berhuruf kecil:  28
# Jumlah kata lainnya:  27
#
#
# Soal 8
# Jumlah kata berhuruf kapital:  0
# Jumlah kata berhuruf kecil:  35
# Jumlah kata lainnya:  21
#
#
# Soal 9
# Jumlah kata berhuruf kapital:  0
# Jumlah kata berhuruf kecil:  43
# Jumlah kata lainnya:  12
#
#
# Soal 10
# Jumlah kata berhuruf kapital:  0
# Jumlah kata berhuruf kecil:  39
# Jumlah kata lainnya:  16

# %%
result_lifestyle_unrater = []

soal_lifestyle = 0
# loop untuk setiap sheet pada dataframe
for df in dataset.Lifestyle_all_sheets:
    soal_lifestyle = soal_lifestyle + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    unrated_answers = df[df[['Manual 1', 'Manual 2', 'Manual 3']].isnull().all(axis=1)]
    result_lifestyle_unrater.append({
        'Soal': soal_lifestyle,
        'Column': 'Jawaban',
        'Unrated Answers': len(unrated_answers)
    })

# tampilkan hasil analisis
for r in result_lifestyle_unrater:
    print(f"{r['Soal']} - Unrated Answers: {r['Unrated Answers']}")
# Out:
# 1 - Unrated Answers: 0
# 2 - Unrated Answers: 0
# 3 - Unrated Answers: 0
# 4 - Unrated Answers: 0
# 5 - Unrated Answers: 0
# 6 - Unrated Answers: 0
# 7 - Unrated Answers: 0
# 8 - Unrated Answers: 0
# 9 - Unrated Answers: 0
# 10 - Unrated Answers: 0

# %%
l = 0
for df in dataset.Lifestyle_all_sheets:
    l = l + 1
    df.rename(columns= {'Siswa ': 'Siswa', 'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Siswa', 'Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    # Mengecek duplikasi pada kolom jawaban
        
    duplicate_jawaban_rate_lifestyle = df[df.duplicated(['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual'], keep=False)]
    if not duplicate_jawaban_rate_lifestyle.empty:
        print(f"Duplikasi pada kolom soal {l}:")
        print(duplicate_jawaban_rate_lifestyle[['Siswa', 'Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']])
        print('\n')
# Out:
# Duplikasi pada kolom soal 4:
#         Siswa                                            Jawaban  Manual 1  \
# No
# 6    siswa_8   refreshing sejenak,minum air putih agar segar,...      16.0
# 7    siswa_9   refreshing sejenak,minum air putih agar segar,...      16.0
#
#      Manual 2  Manual 3  Rata Manual
# No
# 6        26.0      25.0    22.333333
# 7        26.0      25.0    22.333333
#
#
# Duplikasi pada kolom soal 5:
#         Siswa                                            Jawaban  Manual 1  \
# No
# 6    siswa_8   jangan terlalu menghabiskan uang untuk satu ba...      35.0
# 7    siswa_9   jangan terlalu menghabiskan uang untuk satu ba...      35.0
#
#      Manual 2  Manual 3  Rata Manual
# No
# 6        30.0      25.0         30.0
# 7        30.0      25.0         30.0
#
#
# Duplikasi pada kolom soal 6:
#         Siswa                                            Jawaban  Manual 1  \
# No
# 6    siswa_8   gaya hedonism adalah gaya hidup yang tidak ter...      10.0
# 7    siswa_9   gaya hedonism adalah gaya hidup yang tidak ter...      10.0
#
#      Manual 2  Manual 3  Rata Manual
# No
# 6         5.0      10.0     8.333333
# 7         5.0      10.0     8.333333
#
#
# Duplikasi pada kolom soal 7:
#         Siswa                                            Jawaban  Manual 1  \
# No
# 6    siswa_8   candi borobudur merupakan keajaiban di Indones...      15.0
# 7    siswa_9   candi borobudur merupakan keajaiban di Indones...      15.0
#
#      Manual 2  Manual 3  Rata Manual
# No
# 6         5.0      10.0         10.0
# 7         5.0      10.0         10.0
#
#
# Duplikasi pada kolom soal 8:
#         Siswa                                            Jawaban  Manual 1  \
# No
# 6    siswa_8   sabar,menasehati,mendengar curhatan anak,akrab...      19.0
# 7    siswa_9   sabar,menasehati,mendengar curhatan anak,akrab...      19.0
#
#      Manual 2  Manual 3  Rata Manual
# No
# 6        15.0      25.0    19.666667
# 7        15.0      25.0    19.666667
#
#
# Duplikasi pada kolom soal 9:
#         Siswa                                Jawaban  Manual 1  Manual 2  \
# No
# 6    siswa_8   karbohidrat,lemak,protein,telur,susu       30.0      25.0
# 7    siswa_9   karbohidrat,lemak,protein,telur,susu       30.0      25.0
#
#      Manual 3  Rata Manual
# No
# 6        25.0    26.666667
# 7        25.0    26.666667
#
#
# Duplikasi pada kolom soal 10:
#         Siswa                               Jawaban  Manual 1  Manual 2  \
# No
# 6    siswa_8   makan-makanan yang bergizi,olahraga        5.0       5.0
# 7    siswa_9   makan-makanan yang bergizi,olahraga        5.0       5.0
#
#      Manual 3  Rata Manual
# No
# 6        10.0     6.666667
# 7        10.0     6.666667

# %%
total_punctuation = 0
total_stopword = 0
total_berimbuhan = 0
total_non_lemma = 0
soal_lifestyle = 0

for df in dataset.Lifestyle_all_sheets:
    soal_lifestyle = soal_lifestyle + 1
    freq_punctuation = 0
    freq_stopword = 0
    freq_berimbuhan = 0
    freq_non_lemma = 0
    
    # proses setiap jawaban siswa pada sheet
    for jawaban in df['Jawaban']:
        # hitung frekuensi punctuation
        freq_punctuation += sum([1 for char in jawaban if char in string.punctuation])
        
        # hitung frekuensi stopword
        tokenized = word_tokenize(jawaban)
        freq_stopword += sum([1 for word in tokenized if word in stop_words])
        
        # hitung frekuensi kata berimbuhan
        freq_berimbuhan += sum([1 for word in tokenized if '-' in word or 'nya' in word or 'ku' in word or 'mu' in word or 'lah' in word or 'kah' in word])
        
        # hitung frekuensi kata non-lemma
        stemmed = [stemmer.stem(word) for word in tokenized]
        freq_non_lemma += sum([1 for i in range(len(tokenized)) if tokenized[i] != stemmed[i]])
    
    # tambahkan frekuensi pada variabel total
    total_punctuation += freq_punctuation
    total_stopword += freq_stopword
    total_berimbuhan += freq_berimbuhan
    total_non_lemma += freq_non_lemma
    
    # tampilkan frekuensi untuk sheet saat ini
    print(f"Soal: {soal_lifestyle}:")
    print(f"Frekuensi Punctuation: {freq_punctuation}")
    print(f"Frekuensi Stopword: {freq_stopword}")
    print(f"Frekuensi Kata Berimbuhan: {freq_berimbuhan}")
    print(f"Frekuensi Kata Non-Lemma: {freq_non_lemma}")
    print()
    
# tampilkan total frekuensi untuk seluruh file excel
print("Total:")
print(f"Frekuensi Punctuation: {total_punctuation}")
print(f"Frekuensi Stopword: {total_stopword}")
print(f"Frekuensi Kata Berimbuhan: {total_berimbuhan}")
print(f"Frekuensi Kata Non-Lemma: {total_non_lemma}")
# Out:
# Soal: 1:
# Frekuensi Punctuation: 155
# Frekuensi Stopword: 253
# Frekuensi Kata Berimbuhan: 83
# Frekuensi Kata Non-Lemma: 436
#
# Soal: 2:
# Frekuensi Punctuation: 253
# Frekuensi Stopword: 354
# Frekuensi Kata Berimbuhan: 145
# Frekuensi Kata Non-Lemma: 643
#
# Soal: 3:
# Frekuensi Punctuation: 527
# Frekuensi Stopword: 722
# Frekuensi Kata Berimbuhan: 305
# Frekuensi Kata Non-Lemma: 1037
#
# Soal: 4:
# Frekuensi Punctuation: 405
# Frekuensi Stopword: 354
# Frekuensi Kata Berimbuhan: 237
# Frekuensi Kata Non-Lemma: 687
#
# Soal: 5:
# Frekuensi Punctuation: 364
# Frekuensi Stopword: 699
# Frekuensi Kata Berimbuhan: 227
# Frekuensi Kata Non-Lemma: 763
#
# Soal: 6:
# Frekuensi Punctuation: 83
# Frekuensi Stopword: 369
# Frekuensi Kata Berimbuhan: 121
# Frekuensi Kata Non-Lemma: 374
#
# Soal: 7:
# Frekuensi Punctuation: 195
# Frekuensi Stopword: 674
# Frekuensi Kata Berimbuhan: 158
# Frekuensi Kata Non-Lemma: 901
#
# Soal: 8:
# Frekuensi Punctuation: 331
# Frekuensi Stopword: 594
# Frekuensi Kata Berimbuhan: 223
# Frekuensi Kata Non-Lemma: 733
#
# Soal: 9:
# Frekuensi Punctuation: 269
# Frekuensi Stopword: 279
# Frekuensi Kata Berimbuhan: 83
# Frekuensi Kata Non-Lemma: 499
#
# Soal: 10:
# Frekuensi Punctuation: 152
# Frekuensi Stopword: 602
# Frekuensi Kata Berimbuhan: 115
# Frekuensi Kata Non-Lemma: 465
#
# Total:
# Frekuensi Punctuation: 2734
# Frekuensi Stopword: 4900
# Frekuensi Kata Berimbuhan: 1697
# Frekuensi Kata Non-Lemma: 6538
