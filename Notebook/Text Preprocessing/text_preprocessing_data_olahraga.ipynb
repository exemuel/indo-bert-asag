# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sastrawi in /usr/local/lib/python3.9/dist-packages (1.0.1)

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.4.5)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from nltk) (1.16.0)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import os
import re
import nltk
import random
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from nltk.tokenize import sent_tokenize, LineTokenizer, RegexpTokenizer
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

print(os.listdir("/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/"))
factory = StemmerFactory()
stemmer = factory.create_stemmer()
import string
from nltk.stem import PorterStemmer, WordNetLemmatizer
stopwords_indonesia = stopwords.words('indonesian')
stop_words = set(stopwords.words('indonesian'))
import sys
import os
# Out:
# ['Text Preprocessing', 'Indonesian Query Answering Dataset for Online Essay Test System.zip', 'dict.json', 'Preprocessing', 'Analysis Data', 'Data', 'dataset.py', '__pycache__']

# %%
sheets_dict_Lifestyle = pd.read_excel('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Data/Analisis_Essay_Grading_Lifestyle.xlsx', sheet_name=None, index_col=1, skiprows = 1)
sheets_dict_Olahraga = pd.read_excel('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Data/Analisis_Essay_Grading_Olahraga.xlsx', sheet_name=None, index_col=1, skiprows = 1)
sheets_dict_Politik = pd.read_excel('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Data/Analisis_Essay_Grading_Politik.xlsx', sheet_name=None, index_col=1, skiprows = 1)
sheets_dict_Teknologi = pd.read_excel('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Data/Analisis_Essay_Grading_Teknologi.xlsx', sheet_name=None, index_col=1, skiprows = 1)

Lifestyle_keys = list(sheets_dict_Lifestyle.keys())
Olahraga_keys = list(sheets_dict_Olahraga.keys())
Politik_keys = list(sheets_dict_Politik.keys())
Teknologi_keys = list(sheets_dict_Teknologi.keys())


Lifestyle_Soal = sheets_dict_Lifestyle[Lifestyle_keys[0]].drop(['Unnamed: 0'], axis = 1)
Olahraga_Soal = sheets_dict_Olahraga[Olahraga_keys[0]].drop(['Unnamed: 0'], axis = 1)
Politik_Soal = sheets_dict_Politik[Politik_keys[0]].drop(['Unnamed: 0'], axis = 1)
Teknologi_Soal = sheets_dict_Teknologi[Teknologi_keys[0]].drop(['Unnamed: 0'], axis = 1)


Lifestyle_all_sheets = []
index = 1
for keys in Lifestyle_keys[index:len(Lifestyle_keys)-1]:
    new_sheets = sheets_dict_Lifestyle[keys].drop(['Unnamed: 0'], axis = 1)
    new_sheets = new_sheets.dropna()
    Lifestyle_all_sheets.append(new_sheets)

Olahraga_all_sheets = []
index = 1
for keys in Olahraga_keys[index:len(Olahraga_keys)-1]:
    new_sheets = sheets_dict_Olahraga[keys].drop(['Unnamed: 0'], axis = 1)
    new_sheets = new_sheets.dropna()
    Olahraga_all_sheets.append(new_sheets)



Politik_all_sheets = []
index = 1
for keys in Politik_keys[index:len(Politik_keys)-1]:
    new_sheets = sheets_dict_Politik[keys].drop(['Unnamed: 0'], axis = 1)
    new_sheets = new_sheets.dropna()
    Politik_all_sheets.append(new_sheets)

Teknologi_all_sheets = []
index = 1
for keys in Teknologi_keys[index:len(Teknologi_keys)-1]:
    new_sheets = sheets_dict_Teknologi[keys].drop(['Unnamed: 0'], axis = 1)
    new_sheets = new_sheets.dropna()
    Teknologi_all_sheets.append(new_sheets)

# %% [markdown]
# ### Lowercasing

# %%
list_df_olahraga = []

soal_olahraga = 0
# Loop untuk setiap sheet dalam file Excel
for df in Olahraga_all_sheets:
    soal_olahraga = soal_olahraga + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    print(f"Soal: {soal_olahraga}:")
    print(df[['Jawaban', 'Jawaban Lowercase']].head())
    list_df_olahraga.append(df)
# Out:
# Soal: 1:
#                                                Jawaban  \
# No
# 1    - Menyehatkan tubuh - Memperkuat otot-otot - M...
# 2    1. Meringankan Kerja Jantung. 2. Melancarkan A...
# 3    refresing, kesehatan otot, syaraf-syaraf mejad...
# 4    1. Menjaga kondisi fisik tetap prima. 2. Mengh...
# 5                                               sehat
#
#                                      Jawaban Lowercase
# No
# 1    - menyehatkan tubuh - memperkuat otot-otot - m...
# 2    1. meringankan kerja jantung. 2. melancarkan a...
# 3    refresing, kesehatan otot, syaraf-syaraf mejad...
# 4    1. menjaga kondisi fisik tetap prima. 2. mengh...
# 5                                               sehat
# Soal: 2:
#                                                Jawaban  \
# No
# 1    PSSI adalah Persatuan Sepak Bola Seluruh Indon...
# 2    PSSI adalah Perstuan Sepak Bola Seluruh Indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    PSSI merupakan Persatuan Sepakbola Seluruh Ind...
# 5              persatuan sepak bola seluruh indonesia
#
#                                      Jawaban Lowercase
# No
# 1    pssi adalah persatuan sepak bola seluruh indon...
# 2    pssi adalah perstuan sepak bola seluruh indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    pssi merupakan persatuan sepakbola seluruh ind...
# 5              persatuan sepak bola seluruh indonesia
# Soal: 3:
#                                               Jawaban  \
# o
# 1   Rio Heryanto merupakan seorang pebalap berkeba...
# 2   Rio Haryanto (lahir di Solo, Jawa Tengah, 22 J...
# 3   lahir di solo, besar sebagai pembalap f1, ayah...
# 4   Lahir di kota Surakarta, 22 Januari 1993. Kari...
# 5                                        pembalap F1
#
#                                     Jawaban Lowercase
# o
# 1   rio heryanto merupakan seorang pebalap berkeba...
# 2   rio haryanto (lahir di solo, jawa tengah, 22 j...
# 3   lahir di solo, besar sebagai pembalap f1, ayah...
# 4   lahir di kota surakarta, 22 januari 1993. kari...
# 5                                        pembalap f1
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Block atau membendung merupakan suatu upaya pe...
# 2    Block (blocking) adalah upaya untuk membendung...
# 3    menghadang bola agar jatuh ke daerah lawan . d...
# 4    Block adalah posisi untuk menahan serangan dar...
# 5                                               stock
#
#                                      Jawaban Lowercase
# No
# 1    block atau membendung merupakan suatu upaya pe...
# 2    block (blocking) adalah upaya untuk membendung...
# 3    menghadang bola agar jatuh ke daerah lawan . d...
# 4    block adalah posisi untuk menahan serangan dar...
# 5                                               stock
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Memulai pertandingan - Terjadinya gol - Memu...
# 2    1. awal pertandingan babak pertama, 2. awal pe...
# 3    setelah gol, pembukaan babak pertama, pembukaa...
# 4    1. Pertama kali dimulainnya permainan babak pe...
# 5                                             offside
#
#                                      Jawaban Lowercase
# No
# 1    - memulai pertandingan - terjadinya gol - memu...
# 2    1. awal pertandingan babak pertama, 2. awal pe...
# 3    setelah gol, pembukaan babak pertama, pembukaa...
# 4    1. pertama kali dimulainnya permainan babak pe...
# 5                                             offside
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Christiano Ronaldo terlahir dengan nama lengka...
# 2    Cristiano Ronaldo dos Santos Aveiro (lahir di ...
# 3    lahir di portugal sebagai warga negara portuga...
# 4    Lahir di Santo Antonio, Portugal 5 Februari 19...
# 5                               pemain sepak bola pro
#
#                                      Jawaban Lowercase
# No
# 1    christiano ronaldo terlahir dengan nama lengka...
# 2    cristiano ronaldo dos santos aveiro (lahir di ...
# 3    lahir di portugal sebagai warga negara portuga...
# 4    lahir di santo antonio, portugal 5 februari 19...
# 5                               pemain sepak bola pro
# Soal: 7:
#                                                Jawaban  \
# No
# 1    Keper adalah penjaga gawang. Defender adalah p...
# 2    1. penjaga gawang. 2. bek. 3. gelandang. 4. pe...
# 3    kiper: menjaga gawang, beck:menjaga kedalaman ...
# 4    1. Goal Keeper. 2. Deffense. 3. Center. 4. Str...
# 5                                          hebak umak
#
#                                      Jawaban Lowercase
# No
# 1    keper adalah penjaga gawang. defender adalah p...
# 2    1. penjaga gawang. 2. bek. 3. gelandang. 4. pe...
# 3    kiper: menjaga gawang, beck:menjaga kedalaman ...
# 4    1. goal keeper. 2. deffense. 3. center. 4. str...
# 5                                          hebak umak
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Airnya bersih, Airnya tidak mengandung karpori...
# 2    1. Tidak bocor 2. Sirkulasi air dan sistem fil...
# 3                      kebersihan,keindahan,kedalaman
# 4    1. Air yang digunakan tidak menggandung kapur....
# 5                            tidak bau , bisa diminum
#
#                                      Jawaban Lowercase
# No
# 1    airnya bersih, airnya tidak mengandung karpori...
# 2    1. tidak bocor 2. sirkulasi air dan sistem fil...
# 3                      kebersihan,keindahan,kedalaman
# 4    1. air yang digunakan tidak menggandung kapur....
# 5                            tidak bau , bisa diminum
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Tunggal putra, tunggal putri, ganda putra, gan...
# 2    -ganda putra, -ganda putri, -ganda campuran, -...
# 3    ganda putra/putri, ganda campuran,single putra...
# 4    1. Tunggal Putra. 2. Tunggal Putri. 3. Ganda P...
# 5                                   gerindra , hanura
#
#                                      Jawaban Lowercase
# No
# 1    tunggal putra, tunggal putri, ganda putra, gan...
# 2    -ganda putra, -ganda putri, -ganda campuran, -...
# 3    ganda putra/putri, ganda campuran,single putra...
# 4    1. tunggal putra. 2. tunggal putri. 3. ganda p...
# 5                                   gerindra , hanura
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Parkour adalah seni bergerak dan metode latiha...
# 2    Parkour adalah aktivitas yang bertujuan untuk ...
# 3    keindahan dan kelenturan dalam melewati rintan...
# 4    Parkour adalah aktivitas yang bertujuan untuk ...
# 5                             loncat loncat di gedung
#
#                                      Jawaban Lowercase
# No
# 1    parkour adalah seni bergerak dan metode latiha...
# 2    parkour adalah aktivitas yang bertujuan untuk ...
# 3    keindahan dan kelenturan dalam melewati rintan...
# 4    parkour adalah aktivitas yang bertujuan untuk ...
# 5                             loncat loncat di gedung
# <ipython-input-8-aea89b587e7f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-aea89b587e7f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-aea89b587e7f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-aea89b587e7f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-aea89b587e7f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-aea89b587e7f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-aea89b587e7f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-aea89b587e7f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-aea89b587e7f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-8-aea89b587e7f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())

# %%
list_df_olahraga[1]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    PSSI adalah Persatuan Sepak Bola Seluruh Indon...      40.0      60.0
# 2    PSSI adalah Perstuan Sepak Bola Seluruh Indone...      40.0      60.0
# 3    pssi adalah persatuan sepak bola seluruh indon...      30.0      25.0
# 4    PSSI merupakan Persatuan Sepakbola Seluruh Ind...      35.0      40.0
# 5              persatuan sepak bola seluruh indonesia       20.0      25.0
# 6    Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 7    PSSI atau singkatan dari Persatuan Sepak bola ...      60.0      65.0
# 8    Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 9    Persatuan Sepak Bola Seluruh Indonesia, dising...      70.0      85.0
# 10   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 11   PSSI atau Persatuan Sepak bola Seluruh Indones...      50.0      70.0
# 12                     Organisasi sepakbola indonesia       20.0      10.0
# 13   setahuku itu adalah organisasi persatuan sepak...      18.0      10.0
# 14   PSSI adalah Persatuan Sepakbola Seluruh Indone...      25.0      30.0
# 15   organisasi yang menuangi tentang sepak bola in...      20.0      10.0
# 16   PSSI adalah singkatan dari Persatuan Sepakbola...      45.0      30.0
# 17   -Ketua Umum PSSI saat ini La Naylla Mataliti -...      60.0      48.0
# 18   Persatuan Sepak Bola Seluruh Indonesia, dising...      45.0      48.0
# 19   organisasi induk yang bertugas mengatur kegiat...      30.0      25.0
# 20   - PSSI adalah singkatan dari persatuan sepak b...      45.0      30.0
# 21               perersatuan indonesia seluruh malang       18.0       5.0
# 22   PSSI adalah singkatan dari Persatuan Sepakbola...      55.0      50.0
# 23   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 24   PSSI (Persatuan Sepak Bola Seluruh Indonesia) ...      50.0      40.0
# 25   PSSI adalah persatuan sepak bola seluruh Indon...      85.0      80.0
# 26   PSSI adalah organisasi untuk menaungi cabang o...      20.0      25.0
# 27   Apa yang anda ketahui mengenai PSSI? (Termasuk...      10.0       0.0
# 28   Persatuan Sepakbola Seluruh Indonesia yang men...      35.0      40.0
# 29   PSSI Persatuan Sepakbola Seluruh Indonesia ada...      40.0      45.0
# 30   Persatuan Sepakbola Seluruh Indonesia ialah fe...      42.0      45.0
# 31   organisasi induk yang bertugas mengatur kegiat...      40.0      48.0
# 32   PSSI adalah organisasi induk yang bertugas men...      70.0      70.0
# 33   PSSI adalah singkatan dari Persatuan Sepak Bol...      50.0      53.0
# 34   Persatuan sepak bola seluruh indonesia adalah ...      30.0      40.0
# 35   Persatuan Sepak Bola Seluruh Indonesia, dising...      40.0      30.0
# 36   SSI, adalah organisasi induk yang bertugas men...      80.0      95.0
# 37   Persatuan Sepak Bola Seluruh Indonesia, dising...      45.0      40.0
# 38   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 39   organisasi induk yang bertugas mengatur kegiat...      75.0      70.0
# 40   Persatuan Sepak Bola Seluruh Indonesia, dising...      55.0      60.0
# 41   PSSI adalah organisasi yang menaungi olahraga ...      40.0      25.0
# 42   PSSI adalah organisasi yang menaungi olah raga...      40.0      25.0
# 43   persatuan sepakbola seluruh indonesia merupaka...      30.0      15.0
# 44   pssi adalah singkatan dari persatuan sepakbola...      20.0      15.0
# 45   PSSI adalah Organisasi Persatuan Sepak Bola Se...      35.0      30.0
# 46   Persatuan Sepakbola Seluruh Indonesia dan dike...      25.0      25.0
# 47   persatuan sepak bola seluruh indonesia, seluru...      22.0      20.0
# 48   PSSI yg sekarang tidak bertanggung jawab atas ...      40.0      30.0
# 49   PSSI adalah induk olahraga sepak bola Indonesi...      35.0      25.0
# 50   PSSI adalah persatuan sepakbola yang ada di in...      40.0      40.0
# 51   persatuan sepakbola seluruh indonesia. organis...      30.0      25.0
# 52   Persatuan Sepakbola Seluruh Indonesia Organisa...      25.0      20.0
# 53   ersatuan Sepak Bola Seluruh Indonesia, disingk...      40.0      25.0
# 54   pssi adalah organisasi sepak bola yang ada di ...      25.0      15.0
# 55   pssi (persatuan persebak bola indonesia) adala...      35.0      19.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase
# No
# 1        50.0    50.000000  pssi adalah persatuan sepak bola seluruh indon...
# 2        50.0    50.000000  pssi adalah perstuan sepak bola seluruh indone...
# 3        25.0    26.666667  pssi adalah persatuan sepak bola seluruh indon...
# 4        50.0    41.666667  pssi merupakan persatuan sepakbola seluruh ind...
# 5        25.0    23.333333            persatuan sepak bola seluruh indonesia
# 6        90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 7        75.0    66.666667  pssi atau singkatan dari persatuan sepak bola ...
# 8        90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 9        75.0    76.666667  persatuan sepak bola seluruh indonesia, dising...
# 10       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 11       75.0    65.000000  pssi atau persatuan sepak bola seluruh indones...
# 12       10.0    13.333333                    organisasi sepakbola indonesia
# 13       10.0    12.666667  setahuku itu adalah organisasi persatuan sepak...
# 14       25.0    26.666667  pssi adalah persatuan sepakbola seluruh indone...
# 15       10.0    13.333333  organisasi yang menuangi tentang sepak bola in...
# 16       50.0    41.666667  pssi adalah singkatan dari persatuan sepakbola...
# 17       50.0    52.666667  -ketua umum pssi saat ini la naylla mataliti -...
# 18       50.0    47.666667  persatuan sepak bola seluruh indonesia, dising...
# 19       25.0    26.666667  organisasi induk yang bertugas mengatur kegiat...
# 20       50.0    41.666667  - pssi adalah singkatan dari persatuan sepak b...
# 21       10.0    11.000000              perersatuan indonesia seluruh malang
# 22       50.0    51.666667  pssi adalah singkatan dari persatuan sepakbola...
# 23       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 24       50.0    46.666667  pssi (persatuan sepak bola seluruh indonesia) ...
# 25       85.0    83.333333  pssi adalah persatuan sepak bola seluruh indon...
# 26       25.0    23.333333  pssi adalah organisasi untuk menaungi cabang o...
# 27        0.0     3.333333  apa yang anda ketahui mengenai pssi? (termasuk...
# 28       50.0    41.666667  persatuan sepakbola seluruh indonesia yang men...
# 29       50.0    45.000000  pssi persatuan sepakbola seluruh indonesia ada...
# 30       50.0    45.666667  persatuan sepakbola seluruh indonesia ialah fe...
# 31       50.0    46.000000  organisasi induk yang bertugas mengatur kegiat...
# 32       75.0    71.666667  pssi adalah organisasi induk yang bertugas men...
# 33       50.0    51.000000  pssi adalah singkatan dari persatuan sepak bol...
# 34       50.0    40.000000  persatuan sepak bola seluruh indonesia adalah ...
# 35       50.0    40.000000  persatuan sepak bola seluruh indonesia, dising...
# 36       90.0    88.333333  ssi, adalah organisasi induk yang bertugas men...
# 37       50.0    45.000000  persatuan sepak bola seluruh indonesia, dising...
# 38       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 39       75.0    73.333333  organisasi induk yang bertugas mengatur kegiat...
# 40       50.0    55.000000  persatuan sepak bola seluruh indonesia, dising...
# 41       50.0    38.333333  pssi adalah organisasi yang menaungi olahraga ...
# 42       50.0    38.333333  pssi adalah organisasi yang menaungi olah raga...
# 43       25.0    23.333333  persatuan sepakbola seluruh indonesia merupaka...
# 44       25.0    20.000000  pssi adalah singkatan dari persatuan sepakbola...
# 45       25.0    30.000000  pssi adalah organisasi persatuan sepak bola se...
# 46       25.0    25.000000  persatuan sepakbola seluruh indonesia dan dike...
# 47       25.0    22.333333  persatuan sepak bola seluruh indonesia, seluru...
# 48       50.0    40.000000  pssi yg sekarang tidak bertanggung jawab atas ...
# 49       25.0    28.333333  pssi adalah induk olahraga sepak bola indonesi...
# 50       50.0    43.333333  pssi adalah persatuan sepakbola yang ada di in...
# 51       25.0    26.666667  persatuan sepakbola seluruh indonesia. organis...
# 52       25.0    23.333333  persatuan sepakbola seluruh indonesia organisa...
# 53       25.0    30.000000  ersatuan sepak bola seluruh indonesia, disingk...
# 54       25.0    21.666667  pssi adalah organisasi sepak bola yang ada di ...
# 55       25.0    26.333333  pssi (persatuan persebak bola indonesia) adala...

# %% [markdown]
# ### Remove Punctuation

# %%
import re

list_df_olahraga = []
# Membuat list punctuation yang akan dihapus
punctuation = r'[^\w\s]'

soal_olahraga = 0
for df in Olahraga_all_sheets:
    soal_olahraga = soal_olahraga + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
    
    print(f"Soal: {soal_olahraga}:")
    print(df[['Jawaban', 'Jawaban tanpa Punctuation']].head())
    list_df_olahraga.append(df)
# Out:
# Soal: 1:
#                                                Jawaban  \
# No
# 1    - Menyehatkan tubuh - Memperkuat otot-otot - M...
# 2    1. Meringankan Kerja Jantung. 2. Melancarkan A...
# 3    refresing, kesehatan otot, syaraf-syaraf mejad...
# 4    1. Menjaga kondisi fisik tetap prima. 2. Mengh...
# 5                                               sehat
#
#                              Jawaban tanpa Punctuation
# No
# 1     menyehatkan tubuh  memperkuat otototot  menje...
# 2    1 meringankan kerja jantung 2 melancarkan alir...
# 3    refresing kesehatan otot syarafsyaraf mejadi s...
# 4    1 menjaga kondisi fisik tetap prima 2 menghila...
# 5                                               sehat
# Soal: 2:
#                                                Jawaban  \
# No
# 1    PSSI adalah Persatuan Sepak Bola Seluruh Indon...
# 2    PSSI adalah Perstuan Sepak Bola Seluruh Indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    PSSI merupakan Persatuan Sepakbola Seluruh Ind...
# 5              persatuan sepak bola seluruh indonesia
#
#                              Jawaban tanpa Punctuation
# No
# 1    pssi adalah persatuan sepak bola seluruh indon...
# 2    pssi adalah perstuan sepak bola seluruh indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    pssi merupakan persatuan sepakbola seluruh ind...
# 5              persatuan sepak bola seluruh indonesia
# Soal: 3:
#                                               Jawaban  \
# o
# 1   Rio Heryanto merupakan seorang pebalap berkeba...
# 2   Rio Haryanto (lahir di Solo, Jawa Tengah, 22 J...
# 3   lahir di solo, besar sebagai pembalap f1, ayah...
# 4   Lahir di kota Surakarta, 22 Januari 1993. Kari...
# 5                                        pembalap F1
#
#                             Jawaban tanpa Punctuation
# o
# 1   rio heryanto merupakan seorang pebalap berkeba...
# 2   rio haryanto lahir di solo jawa tengah 22 janu...
# 3   lahir di solo besar sebagai pembalap f1 ayah r...
# 4   lahir di kota surakarta 22 januari 1993 karir ...
# 5                                        pembalap f1
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Block atau membendung merupakan suatu upaya pe...
# 2    Block (blocking) adalah upaya untuk membendung...
# 3    menghadang bola agar jatuh ke daerah lawan . d...
# 4    Block adalah posisi untuk menahan serangan dar...
# 5                                               stock
#
#                              Jawaban tanpa Punctuation
# No
# 1    block atau membendung merupakan suatu upaya pe...
# 2    block blocking adalah upaya untuk membendung s...
# 3    menghadang bola agar jatuh ke daerah lawan  da...
# 4    block adalah posisi untuk menahan serangan dar...
# 5                                               stock
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Memulai pertandingan - Terjadinya gol - Memu...
# 2    1. awal pertandingan babak pertama, 2. awal pe...
# 3    setelah gol, pembukaan babak pertama, pembukaa...
# 4    1. Pertama kali dimulainnya permainan babak pe...
# 5                                             offside
#
#                              Jawaban tanpa Punctuation
# No
# 1     memulai pertandingan  terjadinya gol  memulai...
# 2    1 awal pertandingan babak pertama 2 awal perta...
# 3    setelah gol pembukaan babak pertama pembukaan ...
# 4    1 pertama kali dimulainnya permainan babak per...
# 5                                             offside
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Christiano Ronaldo terlahir dengan nama lengka...
# 2    Cristiano Ronaldo dos Santos Aveiro (lahir di ...
# 3    lahir di portugal sebagai warga negara portuga...
# 4    Lahir di Santo Antonio, Portugal 5 Februari 19...
# 5                               pemain sepak bola pro
#
#                              Jawaban tanpa Punctuation
# No
# 1    christiano ronaldo terlahir dengan nama lengka...
# 2    cristiano ronaldo dos santos aveiro lahir di f...
# 3    lahir di portugal sebagai warga negara portuga...
# 4    lahir di santo antonio portugal 5 februari 198...
# 5                               pemain sepak bola pro
# Soal: 7:
#                                                Jawaban  \
# No
# 1    Keper adalah penjaga gawang. Defender adalah p...
# 2    1. penjaga gawang. 2. bek. 3. gelandang. 4. pe...
# 3    kiper: menjaga gawang, beck:menjaga kedalaman ...
# 4    1. Goal Keeper. 2. Deffense. 3. Center. 4. Str...
# 5                                          hebak umak
#
#                              Jawaban tanpa Punctuation
# No
# 1    keper adalah penjaga gawang defender adalah pe...
# 2      1 penjaga gawang 2 bek 3 gelandang 4 penyerang
# 3    kiper menjaga gawang beckmenjaga kedalaman dar...
# 4         1 goal keeper 2 deffense 3 center 4 striker
# 5                                          hebak umak
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Airnya bersih, Airnya tidak mengandung karpori...
# 2    1. Tidak bocor 2. Sirkulasi air dan sistem fil...
# 3                      kebersihan,keindahan,kedalaman
# 4    1. Air yang digunakan tidak menggandung kapur....
# 5                            tidak bau , bisa diminum
#
#                              Jawaban tanpa Punctuation
# No
# 1    airnya bersih airnya tidak mengandung karporit...
# 2    1 tidak bocor 2 sirkulasi air dan sistem filte...
# 3                        kebersihankeindahankedalaman
# 4    1 air yang digunakan tidak menggandung kapur 2...
# 5                             tidak bau  bisa diminum
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Tunggal putra, tunggal putri, ganda putra, gan...
# 2    -ganda putra, -ganda putri, -ganda campuran, -...
# 3    ganda putra/putri, ganda campuran,single putra...
# 4    1. Tunggal Putra. 2. Tunggal Putri. 3. Ganda P...
# 5                                   gerindra , hanura
#
#                              Jawaban tanpa Punctuation
# No
# 1    tunggal putra tunggal putri ganda putra ganda ...
# 2    ganda putra ganda putri ganda campuran single ...
# 3    ganda putraputri ganda campuransingle putraputri
# 4    1 tunggal putra 2 tunggal putri 3 ganda putra ...
# 5                                    gerindra  hanura
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Parkour adalah seni bergerak dan metode latiha...
# 2    Parkour adalah aktivitas yang bertujuan untuk ...
# 3    keindahan dan kelenturan dalam melewati rintan...
# 4    Parkour adalah aktivitas yang bertujuan untuk ...
# 5                             loncat loncat di gedung
#
#                              Jawaban tanpa Punctuation
# No
# 1    parkour adalah seni bergerak dan metode latiha...
# 2    parkour adalah aktivitas yang bertujuan untuk ...
# 3    keindahan dan kelenturan dalam melewati rintan...
# 4    parkour adalah aktivitas yang bertujuan untuk ...
# 5                             loncat loncat di gedung
# <ipython-input-10-6271482dc8db>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-6271482dc8db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-6271482dc8db>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-6271482dc8db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-6271482dc8db>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-6271482dc8db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-6271482dc8db>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-6271482dc8db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-6271482dc8db>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-6271482dc8db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-6271482dc8db>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-6271482dc8db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-6271482dc8db>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-6271482dc8db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-6271482dc8db>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-6271482dc8db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-6271482dc8db>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-6271482dc8db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-10-6271482dc8db>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-10-6271482dc8db>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))

# %%
list_df_olahraga[1]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    PSSI adalah Persatuan Sepak Bola Seluruh Indon...      40.0      60.0
# 2    PSSI adalah Perstuan Sepak Bola Seluruh Indone...      40.0      60.0
# 3    pssi adalah persatuan sepak bola seluruh indon...      30.0      25.0
# 4    PSSI merupakan Persatuan Sepakbola Seluruh Ind...      35.0      40.0
# 5              persatuan sepak bola seluruh indonesia       20.0      25.0
# 6    Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 7    PSSI atau singkatan dari Persatuan Sepak bola ...      60.0      65.0
# 8    Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 9    Persatuan Sepak Bola Seluruh Indonesia, dising...      70.0      85.0
# 10   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 11   PSSI atau Persatuan Sepak bola Seluruh Indones...      50.0      70.0
# 12                     Organisasi sepakbola indonesia       20.0      10.0
# 13   setahuku itu adalah organisasi persatuan sepak...      18.0      10.0
# 14   PSSI adalah Persatuan Sepakbola Seluruh Indone...      25.0      30.0
# 15   organisasi yang menuangi tentang sepak bola in...      20.0      10.0
# 16   PSSI adalah singkatan dari Persatuan Sepakbola...      45.0      30.0
# 17   -Ketua Umum PSSI saat ini La Naylla Mataliti -...      60.0      48.0
# 18   Persatuan Sepak Bola Seluruh Indonesia, dising...      45.0      48.0
# 19   organisasi induk yang bertugas mengatur kegiat...      30.0      25.0
# 20   - PSSI adalah singkatan dari persatuan sepak b...      45.0      30.0
# 21               perersatuan indonesia seluruh malang       18.0       5.0
# 22   PSSI adalah singkatan dari Persatuan Sepakbola...      55.0      50.0
# 23   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 24   PSSI (Persatuan Sepak Bola Seluruh Indonesia) ...      50.0      40.0
# 25   PSSI adalah persatuan sepak bola seluruh Indon...      85.0      80.0
# 26   PSSI adalah organisasi untuk menaungi cabang o...      20.0      25.0
# 27   Apa yang anda ketahui mengenai PSSI? (Termasuk...      10.0       0.0
# 28   Persatuan Sepakbola Seluruh Indonesia yang men...      35.0      40.0
# 29   PSSI Persatuan Sepakbola Seluruh Indonesia ada...      40.0      45.0
# 30   Persatuan Sepakbola Seluruh Indonesia ialah fe...      42.0      45.0
# 31   organisasi induk yang bertugas mengatur kegiat...      40.0      48.0
# 32   PSSI adalah organisasi induk yang bertugas men...      70.0      70.0
# 33   PSSI adalah singkatan dari Persatuan Sepak Bol...      50.0      53.0
# 34   Persatuan sepak bola seluruh indonesia adalah ...      30.0      40.0
# 35   Persatuan Sepak Bola Seluruh Indonesia, dising...      40.0      30.0
# 36   SSI, adalah organisasi induk yang bertugas men...      80.0      95.0
# 37   Persatuan Sepak Bola Seluruh Indonesia, dising...      45.0      40.0
# 38   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 39   organisasi induk yang bertugas mengatur kegiat...      75.0      70.0
# 40   Persatuan Sepak Bola Seluruh Indonesia, dising...      55.0      60.0
# 41   PSSI adalah organisasi yang menaungi olahraga ...      40.0      25.0
# 42   PSSI adalah organisasi yang menaungi olah raga...      40.0      25.0
# 43   persatuan sepakbola seluruh indonesia merupaka...      30.0      15.0
# 44   pssi adalah singkatan dari persatuan sepakbola...      20.0      15.0
# 45   PSSI adalah Organisasi Persatuan Sepak Bola Se...      35.0      30.0
# 46   Persatuan Sepakbola Seluruh Indonesia dan dike...      25.0      25.0
# 47   persatuan sepak bola seluruh indonesia, seluru...      22.0      20.0
# 48   PSSI yg sekarang tidak bertanggung jawab atas ...      40.0      30.0
# 49   PSSI adalah induk olahraga sepak bola Indonesi...      35.0      25.0
# 50   PSSI adalah persatuan sepakbola yang ada di in...      40.0      40.0
# 51   persatuan sepakbola seluruh indonesia. organis...      30.0      25.0
# 52   Persatuan Sepakbola Seluruh Indonesia Organisa...      25.0      20.0
# 53   ersatuan Sepak Bola Seluruh Indonesia, disingk...      40.0      25.0
# 54   pssi adalah organisasi sepak bola yang ada di ...      25.0      15.0
# 55   pssi (persatuan persebak bola indonesia) adala...      35.0      19.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase  \
# No
# 1        50.0    50.000000  pssi adalah persatuan sepak bola seluruh indon...
# 2        50.0    50.000000  pssi adalah perstuan sepak bola seluruh indone...
# 3        25.0    26.666667  pssi adalah persatuan sepak bola seluruh indon...
# 4        50.0    41.666667  pssi merupakan persatuan sepakbola seluruh ind...
# 5        25.0    23.333333            persatuan sepak bola seluruh indonesia
# 6        90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 7        75.0    66.666667  pssi atau singkatan dari persatuan sepak bola ...
# 8        90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 9        75.0    76.666667  persatuan sepak bola seluruh indonesia, dising...
# 10       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 11       75.0    65.000000  pssi atau persatuan sepak bola seluruh indones...
# 12       10.0    13.333333                    organisasi sepakbola indonesia
# 13       10.0    12.666667  setahuku itu adalah organisasi persatuan sepak...
# 14       25.0    26.666667  pssi adalah persatuan sepakbola seluruh indone...
# 15       10.0    13.333333  organisasi yang menuangi tentang sepak bola in...
# 16       50.0    41.666667  pssi adalah singkatan dari persatuan sepakbola...
# 17       50.0    52.666667  -ketua umum pssi saat ini la naylla mataliti -...
# 18       50.0    47.666667  persatuan sepak bola seluruh indonesia, dising...
# 19       25.0    26.666667  organisasi induk yang bertugas mengatur kegiat...
# 20       50.0    41.666667  - pssi adalah singkatan dari persatuan sepak b...
# 21       10.0    11.000000              perersatuan indonesia seluruh malang
# 22       50.0    51.666667  pssi adalah singkatan dari persatuan sepakbola...
# 23       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 24       50.0    46.666667  pssi (persatuan sepak bola seluruh indonesia) ...
# 25       85.0    83.333333  pssi adalah persatuan sepak bola seluruh indon...
# 26       25.0    23.333333  pssi adalah organisasi untuk menaungi cabang o...
# 27        0.0     3.333333  apa yang anda ketahui mengenai pssi? (termasuk...
# 28       50.0    41.666667  persatuan sepakbola seluruh indonesia yang men...
# 29       50.0    45.000000  pssi persatuan sepakbola seluruh indonesia ada...
# 30       50.0    45.666667  persatuan sepakbola seluruh indonesia ialah fe...
# 31       50.0    46.000000  organisasi induk yang bertugas mengatur kegiat...
# 32       75.0    71.666667  pssi adalah organisasi induk yang bertugas men...
# 33       50.0    51.000000  pssi adalah singkatan dari persatuan sepak bol...
# 34       50.0    40.000000  persatuan sepak bola seluruh indonesia adalah ...
# 35       50.0    40.000000  persatuan sepak bola seluruh indonesia, dising...
# 36       90.0    88.333333  ssi, adalah organisasi induk yang bertugas men...
# 37       50.0    45.000000  persatuan sepak bola seluruh indonesia, dising...
# 38       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 39       75.0    73.333333  organisasi induk yang bertugas mengatur kegiat...
# 40       50.0    55.000000  persatuan sepak bola seluruh indonesia, dising...
# 41       50.0    38.333333  pssi adalah organisasi yang menaungi olahraga ...
# 42       50.0    38.333333  pssi adalah organisasi yang menaungi olah raga...
# 43       25.0    23.333333  persatuan sepakbola seluruh indonesia merupaka...
# 44       25.0    20.000000  pssi adalah singkatan dari persatuan sepakbola...
# 45       25.0    30.000000  pssi adalah organisasi persatuan sepak bola se...
# 46       25.0    25.000000  persatuan sepakbola seluruh indonesia dan dike...
# 47       25.0    22.333333  persatuan sepak bola seluruh indonesia, seluru...
# 48       50.0    40.000000  pssi yg sekarang tidak bertanggung jawab atas ...
# 49       25.0    28.333333  pssi adalah induk olahraga sepak bola indonesi...
# 50       50.0    43.333333  pssi adalah persatuan sepakbola yang ada di in...
# 51       25.0    26.666667  persatuan sepakbola seluruh indonesia. organis...
# 52       25.0    23.333333  persatuan sepakbola seluruh indonesia organisa...
# 53       25.0    30.000000  ersatuan sepak bola seluruh indonesia, disingk...
# 54       25.0    21.666667  pssi adalah organisasi sepak bola yang ada di ...
# 55       25.0    26.333333  pssi (persatuan persebak bola indonesia) adala...
#
#                              Jawaban tanpa Punctuation
# No
# 1    pssi adalah persatuan sepak bola seluruh indon...
# 2    pssi adalah perstuan sepak bola seluruh indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    pssi merupakan persatuan sepakbola seluruh ind...
# 5              persatuan sepak bola seluruh indonesia
# 6    persatuan sepak bola seluruh indonesia disingk...
# 7    pssi atau singkatan dari persatuan sepak bola ...
# 8    persatuan sepak bola seluruh indonesia disingk...
# 9    persatuan sepak bola seluruh indonesia disingk...
# 10   persatuan sepak bola seluruh indonesia disingk...
# 11   pssi atau persatuan sepak bola seluruh indones...
# 12                     organisasi sepakbola indonesia
# 13   setahuku itu adalah organisasi persatuan sepak...
# 14   pssi adalah persatuan sepakbola seluruh indone...
# 15   organisasi yang menuangi tentang sepak bola in...
# 16   pssi adalah singkatan dari persatuan sepakbola...
# 17   ketua umum pssi saat ini la naylla mataliti ps...
# 18   persatuan sepak bola seluruh indonesia disingk...
# 19   organisasi induk yang bertugas mengatur kegiat...
# 20    pssi adalah singkatan dari persatuan sepak bo...
# 21               perersatuan indonesia seluruh malang
# 22   pssi adalah singkatan dari persatuan sepakbola...
# 23   persatuan sepak bola seluruh indonesia disingk...
# 24   pssi persatuan sepak bola seluruh indonesia or...
# 25   pssi adalah persatuan sepak bola seluruh indon...
# 26   pssi adalah organisasi untuk menaungi cabang o...
# 27   apa yang anda ketahui mengenai pssi termasuk p...
# 28   persatuan sepakbola seluruh indonesia yang men...
# 29   pssi persatuan sepakbola seluruh indonesia ada...
# 30   persatuan sepakbola seluruh indonesia ialah fe...
# 31   organisasi induk yang bertugas mengatur kegiat...
# 32   pssi adalah organisasi induk yang bertugas men...
# 33   pssi adalah singkatan dari persatuan sepak bol...
# 34   persatuan sepak bola seluruh indonesia adalah ...
# 35   persatuan sepak bola seluruh indonesia disingk...
# 36   ssi adalah organisasi induk yang bertugas meng...
# 37   persatuan sepak bola seluruh indonesia disingk...
# 38   persatuan sepak bola seluruh indonesia disingk...
# 39   organisasi induk yang bertugas mengatur kegiat...
# 40   persatuan sepak bola seluruh indonesia disingk...
# 41   pssi adalah organisasi yang menaungi olahraga ...
# 42   pssi adalah organisasi yang menaungi olah raga...
# 43   persatuan sepakbola seluruh indonesia merupaka...
# 44   pssi adalah singkatan dari persatuan sepakbola...
# 45   pssi adalah organisasi persatuan sepak bola se...
# 46   persatuan sepakbola seluruh indonesia dan dike...
# 47   persatuan sepak bola seluruh indonesia seluruh...
# 48   pssi yg sekarang tidak bertanggung jawab atas ...
# 49   pssi adalah induk olahraga sepak bola indonesi...
# 50   pssi adalah persatuan sepakbola yang ada di in...
# 51   persatuan sepakbola seluruh indonesia organisa...
# 52   persatuan sepakbola seluruh indonesia organisa...
# 53   ersatuan sepak bola seluruh indonesia disingka...
# 54   pssi adalah organisasi sepak bola yang ada di ...
# 55   pssi persatuan persebak bola indonesia adalah ...

# %% [markdown]
# ### Tokenization

# %%
import nltk
list_df_olahraga = []

soal_olahraga = 0
for df in Olahraga_all_sheets:
    soal_olahraga = soal_olahraga + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
    df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
    
    print(f"Soal: {soal_olahraga}:")
    print(df[['Jawaban', 'Jawaban Tokenization']].head())
    list_df_olahraga.append(df)
# Out:
# <ipython-input-12-5c80eabedf5a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-5c80eabedf5a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-5c80eabedf5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-5c80eabedf5a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-5c80eabedf5a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-5c80eabedf5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-5c80eabedf5a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-5c80eabedf5a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-5c80eabedf5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-5c80eabedf5a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-5c80eabedf5a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-5c80eabedf5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-5c80eabedf5a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-5c80eabedf5a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# Soal: 1:
#                                                Jawaban  \
# No
# 1    - Menyehatkan tubuh - Memperkuat otot-otot - M...
# 2    1. Meringankan Kerja Jantung. 2. Melancarkan A...
# 3    refresing, kesehatan otot, syaraf-syaraf mejad...
# 4    1. Menjaga kondisi fisik tetap prima. 2. Mengh...
# 5                                               sehat
#
#                                   Jawaban Tokenization
# No
# 1    [menyehatkan, tubuh, memperkuat, otototot, men...
# 2    [1, meringankan, kerja, jantung, 2, melancarka...
# 3    [refresing, kesehatan, otot, syarafsyaraf, mej...
# 4    [1, menjaga, kondisi, fisik, tetap, prima, 2, ...
# 5                                              [sehat]
# Soal: 2:
#                                                Jawaban  \
# No
# 1    PSSI adalah Persatuan Sepak Bola Seluruh Indon...
# 2    PSSI adalah Perstuan Sepak Bola Seluruh Indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    PSSI merupakan Persatuan Sepakbola Seluruh Ind...
# 5              persatuan sepak bola seluruh indonesia
#
#                                   Jawaban Tokenization
# No
# 1    [pssi, adalah, persatuan, sepak, bola, seluruh...
# 2    [pssi, adalah, perstuan, sepak, bola, seluruh,...
# 3    [pssi, adalah, persatuan, sepak, bola, seluruh...
# 4    [pssi, merupakan, persatuan, sepakbola, seluru...
# 5         [persatuan, sepak, bola, seluruh, indonesia]
# Soal: 3:
#                                               Jawaban  \
# o
# 1   Rio Heryanto merupakan seorang pebalap berkeba...
# 2   Rio Haryanto (lahir di Solo, Jawa Tengah, 22 J...
# 3   lahir di solo, besar sebagai pembalap f1, ayah...
# 4   Lahir di kota Surakarta, 22 Januari 1993. Kari...
# 5                                        pembalap F1
#
#                                  Jawaban Tokenization
# o
# 1   [rio, heryanto, merupakan, seorang, pebalap, b...
# 2   [rio, haryanto, lahir, di, solo, jawa, tengah,...
# 3   [lahir, di, solo, besar, sebagai, pembalap, f1...
# 4   [lahir, di, kota, surakarta, 22, januari, 1993...
# 5                                      [pembalap, f1]
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Block atau membendung merupakan suatu upaya pe...
# 2    Block (blocking) adalah upaya untuk membendung...
# 3    menghadang bola agar jatuh ke daerah lawan . d...
# 4    Block adalah posisi untuk menahan serangan dar...
# 5                                               stock
#
#                                   Jawaban Tokenization
# No
# 1    [block, atau, membendung, merupakan, suatu, up...
# 2    [block, blocking, adalah, upaya, untuk, memben...
# 3    [menghadang, bola, agar, jatuh, ke, daerah, la...
# 4    [block, adalah, posisi, untuk, menahan, serang...
# 5                                              [stock]
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Memulai pertandingan - Terjadinya gol - Memu...
# 2    1. awal pertandingan babak pertama, 2. awal pe...
# 3    setelah gol, pembukaan babak pertama, pembukaa...
# 4    1. Pertama kali dimulainnya permainan babak pe...
# 5                                             offside
#
#                                   Jawaban Tokenization
# No
# 1    [memulai, pertandingan, terjadinya, gol, memul...
# 2    [1, awal, pertandingan, babak, pertama, 2, awa...
# 3    [setelah, gol, pembukaan, babak, pertama, pemb...
# 4    [1, pertama, kali, dimulainnya, permainan, bab...
# 5                                            [offside]
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Christiano Ronaldo terlahir dengan nama lengka...
# 2    Cristiano Ronaldo dos Santos Aveiro (lahir di ...
# 3    lahir di portugal sebagai warga negara portuga...
# 4    Lahir di Santo Antonio, Portugal 5 Februari 19...
# 5                               pemain sepak bola pro
#
#                                   Jawaban Tokenization
# No
# 1    [christiano, ronaldo, terlahir, dengan, nama, ...
# 2    [cristiano, ronaldo, dos, santos, aveiro, lahi...
# 3    [lahir, di, portugal, sebagai, warga, negara, ...
# 4    [lahir, di, santo, antonio, portugal, 5, febru...
# 5                           [pemain, sepak, bola, pro]
# <ipython-input-12-5c80eabedf5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-5c80eabedf5a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-5c80eabedf5a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-5c80eabedf5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-5c80eabedf5a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-5c80eabedf5a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-5c80eabedf5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-5c80eabedf5a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-5c80eabedf5a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-5c80eabedf5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-5c80eabedf5a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-5c80eabedf5a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-12-5c80eabedf5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-12-5c80eabedf5a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-12-5c80eabedf5a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# Soal: 7:
#                                                Jawaban  \
# No
# 1    Keper adalah penjaga gawang. Defender adalah p...
# 2    1. penjaga gawang. 2. bek. 3. gelandang. 4. pe...
# 3    kiper: menjaga gawang, beck:menjaga kedalaman ...
# 4    1. Goal Keeper. 2. Deffense. 3. Center. 4. Str...
# 5                                          hebak umak
#
#                                   Jawaban Tokenization
# No
# 1    [keper, adalah, penjaga, gawang, defender, ada...
# 2    [1, penjaga, gawang, 2, bek, 3, gelandang, 4, ...
# 3    [kiper, menjaga, gawang, beckmenjaga, kedalama...
# 4    [1, goal, keeper, 2, deffense, 3, center, 4, s...
# 5                                        [hebak, umak]
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Airnya bersih, Airnya tidak mengandung karpori...
# 2    1. Tidak bocor 2. Sirkulasi air dan sistem fil...
# 3                      kebersihan,keindahan,kedalaman
# 4    1. Air yang digunakan tidak menggandung kapur....
# 5                            tidak bau , bisa diminum
#
#                                   Jawaban Tokenization
# No
# 1    [airnya, bersih, airnya, tidak, mengandung, ka...
# 2    [1, tidak, bocor, 2, sirkulasi, air, dan, sist...
# 3                       [kebersihankeindahankedalaman]
# 4    [1, air, yang, digunakan, tidak, menggandung, ...
# 5                          [tidak, bau, bisa, diminum]
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Tunggal putra, tunggal putri, ganda putra, gan...
# 2    -ganda putra, -ganda putri, -ganda campuran, -...
# 3    ganda putra/putri, ganda campuran,single putra...
# 4    1. Tunggal Putra. 2. Tunggal Putri. 3. Ganda P...
# 5                                   gerindra , hanura
#
#                                   Jawaban Tokenization
# No
# 1    [tunggal, putra, tunggal, putri, ganda, putra,...
# 2    [ganda, putra, ganda, putri, ganda, campuran, ...
# 3    [ganda, putraputri, ganda, campuransingle, put...
# 4    [1, tunggal, putra, 2, tunggal, putri, 3, gand...
# 5                                   [gerindra, hanura]
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Parkour adalah seni bergerak dan metode latiha...
# 2    Parkour adalah aktivitas yang bertujuan untuk ...
# 3    keindahan dan kelenturan dalam melewati rintan...
# 4    Parkour adalah aktivitas yang bertujuan untuk ...
# 5                             loncat loncat di gedung
#
#                                   Jawaban Tokenization
# No
# 1    [parkour, adalah, seni, bergerak, dan, metode,...
# 2    [parkour, adalah, aktivitas, yang, bertujuan, ...
# 3    [keindahan, dan, kelenturan, dalam, melewati, ...
# 4    [parkour, adalah, aktivitas, yang, bertujuan, ...
# 5                         [loncat, loncat, di, gedung]
# <ipython-input-12-5c80eabedf5a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)

# %%
list_df_olahraga[1]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    PSSI adalah Persatuan Sepak Bola Seluruh Indon...      40.0      60.0
# 2    PSSI adalah Perstuan Sepak Bola Seluruh Indone...      40.0      60.0
# 3    pssi adalah persatuan sepak bola seluruh indon...      30.0      25.0
# 4    PSSI merupakan Persatuan Sepakbola Seluruh Ind...      35.0      40.0
# 5              persatuan sepak bola seluruh indonesia       20.0      25.0
# 6    Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 7    PSSI atau singkatan dari Persatuan Sepak bola ...      60.0      65.0
# 8    Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 9    Persatuan Sepak Bola Seluruh Indonesia, dising...      70.0      85.0
# 10   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 11   PSSI atau Persatuan Sepak bola Seluruh Indones...      50.0      70.0
# 12                     Organisasi sepakbola indonesia       20.0      10.0
# 13   setahuku itu adalah organisasi persatuan sepak...      18.0      10.0
# 14   PSSI adalah Persatuan Sepakbola Seluruh Indone...      25.0      30.0
# 15   organisasi yang menuangi tentang sepak bola in...      20.0      10.0
# 16   PSSI adalah singkatan dari Persatuan Sepakbola...      45.0      30.0
# 17   -Ketua Umum PSSI saat ini La Naylla Mataliti -...      60.0      48.0
# 18   Persatuan Sepak Bola Seluruh Indonesia, dising...      45.0      48.0
# 19   organisasi induk yang bertugas mengatur kegiat...      30.0      25.0
# 20   - PSSI adalah singkatan dari persatuan sepak b...      45.0      30.0
# 21               perersatuan indonesia seluruh malang       18.0       5.0
# 22   PSSI adalah singkatan dari Persatuan Sepakbola...      55.0      50.0
# 23   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 24   PSSI (Persatuan Sepak Bola Seluruh Indonesia) ...      50.0      40.0
# 25   PSSI adalah persatuan sepak bola seluruh Indon...      85.0      80.0
# 26   PSSI adalah organisasi untuk menaungi cabang o...      20.0      25.0
# 27   Apa yang anda ketahui mengenai PSSI? (Termasuk...      10.0       0.0
# 28   Persatuan Sepakbola Seluruh Indonesia yang men...      35.0      40.0
# 29   PSSI Persatuan Sepakbola Seluruh Indonesia ada...      40.0      45.0
# 30   Persatuan Sepakbola Seluruh Indonesia ialah fe...      42.0      45.0
# 31   organisasi induk yang bertugas mengatur kegiat...      40.0      48.0
# 32   PSSI adalah organisasi induk yang bertugas men...      70.0      70.0
# 33   PSSI adalah singkatan dari Persatuan Sepak Bol...      50.0      53.0
# 34   Persatuan sepak bola seluruh indonesia adalah ...      30.0      40.0
# 35   Persatuan Sepak Bola Seluruh Indonesia, dising...      40.0      30.0
# 36   SSI, adalah organisasi induk yang bertugas men...      80.0      95.0
# 37   Persatuan Sepak Bola Seluruh Indonesia, dising...      45.0      40.0
# 38   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 39   organisasi induk yang bertugas mengatur kegiat...      75.0      70.0
# 40   Persatuan Sepak Bola Seluruh Indonesia, dising...      55.0      60.0
# 41   PSSI adalah organisasi yang menaungi olahraga ...      40.0      25.0
# 42   PSSI adalah organisasi yang menaungi olah raga...      40.0      25.0
# 43   persatuan sepakbola seluruh indonesia merupaka...      30.0      15.0
# 44   pssi adalah singkatan dari persatuan sepakbola...      20.0      15.0
# 45   PSSI adalah Organisasi Persatuan Sepak Bola Se...      35.0      30.0
# 46   Persatuan Sepakbola Seluruh Indonesia dan dike...      25.0      25.0
# 47   persatuan sepak bola seluruh indonesia, seluru...      22.0      20.0
# 48   PSSI yg sekarang tidak bertanggung jawab atas ...      40.0      30.0
# 49   PSSI adalah induk olahraga sepak bola Indonesi...      35.0      25.0
# 50   PSSI adalah persatuan sepakbola yang ada di in...      40.0      40.0
# 51   persatuan sepakbola seluruh indonesia. organis...      30.0      25.0
# 52   Persatuan Sepakbola Seluruh Indonesia Organisa...      25.0      20.0
# 53   ersatuan Sepak Bola Seluruh Indonesia, disingk...      40.0      25.0
# 54   pssi adalah organisasi sepak bola yang ada di ...      25.0      15.0
# 55   pssi (persatuan persebak bola indonesia) adala...      35.0      19.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase  \
# No
# 1        50.0    50.000000  pssi adalah persatuan sepak bola seluruh indon...
# 2        50.0    50.000000  pssi adalah perstuan sepak bola seluruh indone...
# 3        25.0    26.666667  pssi adalah persatuan sepak bola seluruh indon...
# 4        50.0    41.666667  pssi merupakan persatuan sepakbola seluruh ind...
# 5        25.0    23.333333            persatuan sepak bola seluruh indonesia
# 6        90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 7        75.0    66.666667  pssi atau singkatan dari persatuan sepak bola ...
# 8        90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 9        75.0    76.666667  persatuan sepak bola seluruh indonesia, dising...
# 10       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 11       75.0    65.000000  pssi atau persatuan sepak bola seluruh indones...
# 12       10.0    13.333333                    organisasi sepakbola indonesia
# 13       10.0    12.666667  setahuku itu adalah organisasi persatuan sepak...
# 14       25.0    26.666667  pssi adalah persatuan sepakbola seluruh indone...
# 15       10.0    13.333333  organisasi yang menuangi tentang sepak bola in...
# 16       50.0    41.666667  pssi adalah singkatan dari persatuan sepakbola...
# 17       50.0    52.666667  -ketua umum pssi saat ini la naylla mataliti -...
# 18       50.0    47.666667  persatuan sepak bola seluruh indonesia, dising...
# 19       25.0    26.666667  organisasi induk yang bertugas mengatur kegiat...
# 20       50.0    41.666667  - pssi adalah singkatan dari persatuan sepak b...
# 21       10.0    11.000000              perersatuan indonesia seluruh malang
# 22       50.0    51.666667  pssi adalah singkatan dari persatuan sepakbola...
# 23       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 24       50.0    46.666667  pssi (persatuan sepak bola seluruh indonesia) ...
# 25       85.0    83.333333  pssi adalah persatuan sepak bola seluruh indon...
# 26       25.0    23.333333  pssi adalah organisasi untuk menaungi cabang o...
# 27        0.0     3.333333  apa yang anda ketahui mengenai pssi? (termasuk...
# 28       50.0    41.666667  persatuan sepakbola seluruh indonesia yang men...
# 29       50.0    45.000000  pssi persatuan sepakbola seluruh indonesia ada...
# 30       50.0    45.666667  persatuan sepakbola seluruh indonesia ialah fe...
# 31       50.0    46.000000  organisasi induk yang bertugas mengatur kegiat...
# 32       75.0    71.666667  pssi adalah organisasi induk yang bertugas men...
# 33       50.0    51.000000  pssi adalah singkatan dari persatuan sepak bol...
# 34       50.0    40.000000  persatuan sepak bola seluruh indonesia adalah ...
# 35       50.0    40.000000  persatuan sepak bola seluruh indonesia, dising...
# 36       90.0    88.333333  ssi, adalah organisasi induk yang bertugas men...
# 37       50.0    45.000000  persatuan sepak bola seluruh indonesia, dising...
# 38       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 39       75.0    73.333333  organisasi induk yang bertugas mengatur kegiat...
# 40       50.0    55.000000  persatuan sepak bola seluruh indonesia, dising...
# 41       50.0    38.333333  pssi adalah organisasi yang menaungi olahraga ...
# 42       50.0    38.333333  pssi adalah organisasi yang menaungi olah raga...
# 43       25.0    23.333333  persatuan sepakbola seluruh indonesia merupaka...
# 44       25.0    20.000000  pssi adalah singkatan dari persatuan sepakbola...
# 45       25.0    30.000000  pssi adalah organisasi persatuan sepak bola se...
# 46       25.0    25.000000  persatuan sepakbola seluruh indonesia dan dike...
# 47       25.0    22.333333  persatuan sepak bola seluruh indonesia, seluru...
# 48       50.0    40.000000  pssi yg sekarang tidak bertanggung jawab atas ...
# 49       25.0    28.333333  pssi adalah induk olahraga sepak bola indonesi...
# 50       50.0    43.333333  pssi adalah persatuan sepakbola yang ada di in...
# 51       25.0    26.666667  persatuan sepakbola seluruh indonesia. organis...
# 52       25.0    23.333333  persatuan sepakbola seluruh indonesia organisa...
# 53       25.0    30.000000  ersatuan sepak bola seluruh indonesia, disingk...
# 54       25.0    21.666667  pssi adalah organisasi sepak bola yang ada di ...
# 55       25.0    26.333333  pssi (persatuan persebak bola indonesia) adala...
#
#                              Jawaban tanpa Punctuation  \
# No
# 1    pssi adalah persatuan sepak bola seluruh indon...
# 2    pssi adalah perstuan sepak bola seluruh indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    pssi merupakan persatuan sepakbola seluruh ind...
# 5              persatuan sepak bola seluruh indonesia
# 6    persatuan sepak bola seluruh indonesia disingk...
# 7    pssi atau singkatan dari persatuan sepak bola ...
# 8    persatuan sepak bola seluruh indonesia disingk...
# 9    persatuan sepak bola seluruh indonesia disingk...
# 10   persatuan sepak bola seluruh indonesia disingk...
# 11   pssi atau persatuan sepak bola seluruh indones...
# 12                     organisasi sepakbola indonesia
# 13   setahuku itu adalah organisasi persatuan sepak...
# 14   pssi adalah persatuan sepakbola seluruh indone...
# 15   organisasi yang menuangi tentang sepak bola in...
# 16   pssi adalah singkatan dari persatuan sepakbola...
# 17   ketua umum pssi saat ini la naylla mataliti ps...
# 18   persatuan sepak bola seluruh indonesia disingk...
# 19   organisasi induk yang bertugas mengatur kegiat...
# 20    pssi adalah singkatan dari persatuan sepak bo...
# 21               perersatuan indonesia seluruh malang
# 22   pssi adalah singkatan dari persatuan sepakbola...
# 23   persatuan sepak bola seluruh indonesia disingk...
# 24   pssi persatuan sepak bola seluruh indonesia or...
# 25   pssi adalah persatuan sepak bola seluruh indon...
# 26   pssi adalah organisasi untuk menaungi cabang o...
# 27   apa yang anda ketahui mengenai pssi termasuk p...
# 28   persatuan sepakbola seluruh indonesia yang men...
# 29   pssi persatuan sepakbola seluruh indonesia ada...
# 30   persatuan sepakbola seluruh indonesia ialah fe...
# 31   organisasi induk yang bertugas mengatur kegiat...
# 32   pssi adalah organisasi induk yang bertugas men...
# 33   pssi adalah singkatan dari persatuan sepak bol...
# 34   persatuan sepak bola seluruh indonesia adalah ...
# 35   persatuan sepak bola seluruh indonesia disingk...
# 36   ssi adalah organisasi induk yang bertugas meng...
# 37   persatuan sepak bola seluruh indonesia disingk...
# 38   persatuan sepak bola seluruh indonesia disingk...
# 39   organisasi induk yang bertugas mengatur kegiat...
# 40   persatuan sepak bola seluruh indonesia disingk...
# 41   pssi adalah organisasi yang menaungi olahraga ...
# 42   pssi adalah organisasi yang menaungi olah raga...
# 43   persatuan sepakbola seluruh indonesia merupaka...
# 44   pssi adalah singkatan dari persatuan sepakbola...
# 45   pssi adalah organisasi persatuan sepak bola se...
# 46   persatuan sepakbola seluruh indonesia dan dike...
# 47   persatuan sepak bola seluruh indonesia seluruh...
# 48   pssi yg sekarang tidak bertanggung jawab atas ...
# 49   pssi adalah induk olahraga sepak bola indonesi...
# 50   pssi adalah persatuan sepakbola yang ada di in...
# 51   persatuan sepakbola seluruh indonesia organisa...
# 52   persatuan sepakbola seluruh indonesia organisa...
# 53   ersatuan sepak bola seluruh indonesia disingka...
# 54   pssi adalah organisasi sepak bola yang ada di ...
# 55   pssi persatuan persebak bola indonesia adalah ...
#
#                                   Jawaban Tokenization
# No
# 1    [pssi, adalah, persatuan, sepak, bola, seluruh...
# 2    [pssi, adalah, perstuan, sepak, bola, seluruh,...
# 3    [pssi, adalah, persatuan, sepak, bola, seluruh...
# 4    [pssi, merupakan, persatuan, sepakbola, seluru...
# 5         [persatuan, sepak, bola, seluruh, indonesia]
# 6    [persatuan, sepak, bola, seluruh, indonesia, d...
# 7    [pssi, atau, singkatan, dari, persatuan, sepak...
# 8    [persatuan, sepak, bola, seluruh, indonesia, d...
# 9    [persatuan, sepak, bola, seluruh, indonesia, d...
# 10   [persatuan, sepak, bola, seluruh, indonesia, d...
# 11   [pssi, atau, persatuan, sepak, bola, seluruh, ...
# 12                  [organisasi, sepakbola, indonesia]
# 13   [setahuku, itu, adalah, organisasi, persatuan,...
# 14   [pssi, adalah, persatuan, sepakbola, seluruh, ...
# 15   [organisasi, yang, menuangi, tentang, sepak, b...
# 16   [pssi, adalah, singkatan, dari, persatuan, sep...
# 17   [ketua, umum, pssi, saat, ini, la, naylla, mat...
# 18   [persatuan, sepak, bola, seluruh, indonesia, d...
# 19   [organisasi, induk, yang, bertugas, mengatur, ...
# 20   [pssi, adalah, singkatan, dari, persatuan, sep...
# 21           [perersatuan, indonesia, seluruh, malang]
# 22   [pssi, adalah, singkatan, dari, persatuan, sep...
# 23   [persatuan, sepak, bola, seluruh, indonesia, d...
# 24   [pssi, persatuan, sepak, bola, seluruh, indone...
# 25   [pssi, adalah, persatuan, sepak, bola, seluruh...
# 26   [pssi, adalah, organisasi, untuk, menaungi, ca...
# 27   [apa, yang, anda, ketahui, mengenai, pssi, ter...
# 28   [persatuan, sepakbola, seluruh, indonesia, yan...
# 29   [pssi, persatuan, sepakbola, seluruh, indonesi...
# 30   [persatuan, sepakbola, seluruh, indonesia, ial...
# 31   [organisasi, induk, yang, bertugas, mengatur, ...
# 32   [pssi, adalah, organisasi, induk, yang, bertug...
# 33   [pssi, adalah, singkatan, dari, persatuan, sep...
# 34   [persatuan, sepak, bola, seluruh, indonesia, a...
# 35   [persatuan, sepak, bola, seluruh, indonesia, d...
# 36   [ssi, adalah, organisasi, induk, yang, bertuga...
# 37   [persatuan, sepak, bola, seluruh, indonesia, d...
# 38   [persatuan, sepak, bola, seluruh, indonesia, d...
# 39   [organisasi, induk, yang, bertugas, mengatur, ...
# 40   [persatuan, sepak, bola, seluruh, indonesia, d...
# 41   [pssi, adalah, organisasi, yang, menaungi, ola...
# 42   [pssi, adalah, organisasi, yang, menaungi, ola...
# 43   [persatuan, sepakbola, seluruh, indonesia, mer...
# 44   [pssi, adalah, singkatan, dari, persatuan, sep...
# 45   [pssi, adalah, organisasi, persatuan, sepak, b...
# 46   [persatuan, sepakbola, seluruh, indonesia, dan...
# 47   [persatuan, sepak, bola, seluruh, indonesia, s...
# 48   [pssi, yg, sekarang, tidak, bertanggung, jawab...
# 49   [pssi, adalah, induk, olahraga, sepak, bola, i...
# 50   [pssi, adalah, persatuan, sepakbola, yang, ada...
# 51   [persatuan, sepakbola, seluruh, indonesia, org...
# 52   [persatuan, sepakbola, seluruh, indonesia, org...
# 53   [ersatuan, sepak, bola, seluruh, indonesia, di...
# 54   [pssi, adalah, organisasi, sepak, bola, yang, ...
# 55   [pssi, persatuan, persebak, bola, indonesia, a...

# %% [markdown]
# ### Remove Stopword

# %%
def remove_stopword(token):
    return ' '. join(token)

# %%
list_df_olahraga = []

soal_olahraga = 0
for df in Olahraga_all_sheets:
    soal_olahraga = soal_olahraga + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    
    
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
    df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
    df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
    df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
    
    print(f"Soal: {soal_olahraga}:")
    print(df[['Jawaban', 'Jawaban Tanpa Stopword']].head())
    list_df_olahraga.append(df)
# Out:
# <ipython-input-15-eb7adbeb2fa0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-eb7adbeb2fa0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-eb7adbeb2fa0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-eb7adbeb2fa0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-eb7adbeb2fa0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-eb7adbeb2fa0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-eb7adbeb2fa0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-eb7adbeb2fa0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-eb7adbeb2fa0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-eb7adbeb2fa0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-eb7adbeb2fa0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-eb7adbeb2fa0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# Soal: 1:
#                                                Jawaban  \
# No
# 1    - Menyehatkan tubuh - Memperkuat otot-otot - M...
# 2    1. Meringankan Kerja Jantung. 2. Melancarkan A...
# 3    refresing, kesehatan otot, syaraf-syaraf mejad...
# 4    1. Menjaga kondisi fisik tetap prima. 2. Mengh...
# 5                                               sehat
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [menyehatkan, tubuh, memperkuat, otototot, men...
# 2    [1, meringankan, kerja, jantung, 2, melancarka...
# 3    [refresing, kesehatan, otot, syarafsyaraf, mej...
# 4    [1, menjaga, kondisi, fisik, prima, 2, menghil...
# 5                                              [sehat]
# Soal: 2:
#                                                Jawaban  \
# No
# 1    PSSI adalah Persatuan Sepak Bola Seluruh Indon...
# 2    PSSI adalah Perstuan Sepak Bola Seluruh Indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    PSSI merupakan Persatuan Sepakbola Seluruh Ind...
# 5              persatuan sepak bola seluruh indonesia
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [pssi, persatuan, sepak, bola, indonesia, ketu...
# 2    [pssi, perstuan, sepak, bola, indonesia, ketua...
# 3    [pssi, persatuan, sepak, bola, indonesia, pssi...
# 4    [pssi, persatuan, sepakbola, indonesia, badan,...
# 5                  [persatuan, sepak, bola, indonesia]
# <ipython-input-15-eb7adbeb2fa0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-eb7adbeb2fa0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-eb7adbeb2fa0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-eb7adbeb2fa0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-eb7adbeb2fa0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-eb7adbeb2fa0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-eb7adbeb2fa0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-eb7adbeb2fa0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-eb7adbeb2fa0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-eb7adbeb2fa0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-eb7adbeb2fa0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-eb7adbeb2fa0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-eb7adbeb2fa0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-eb7adbeb2fa0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-eb7adbeb2fa0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-eb7adbeb2fa0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-eb7adbeb2fa0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-eb7adbeb2fa0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# Soal: 3:
#                                               Jawaban  \
# o
# 1   Rio Heryanto merupakan seorang pebalap berkeba...
# 2   Rio Haryanto (lahir di Solo, Jawa Tengah, 22 J...
# 3   lahir di solo, besar sebagai pembalap f1, ayah...
# 4   Lahir di kota Surakarta, 22 Januari 1993. Kari...
# 5                                        pembalap F1
#
#                                Jawaban Tanpa Stopword
# o
# 1   [rio, heryanto, pebalap, berkebangsaan, indone...
# 2   [rio, haryanto, lahir, solo, jawa, 22, januari...
# 3   [lahir, solo, pembalap, f1, ayah, rio, memilik...
# 4   [lahir, kota, surakarta, 22, januari, 1993, ka...
# 5                                      [pembalap, f1]
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Block atau membendung merupakan suatu upaya pe...
# 2    Block (blocking) adalah upaya untuk membendung...
# 3    menghadang bola agar jatuh ke daerah lawan . d...
# 4    Block adalah posisi untuk menahan serangan dar...
# 5                                               stock
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [block, membendung, upaya, pemain, menutup, da...
# 2    [block, blocking, upaya, membendung, serangan,...
# 3    [menghadang, bola, jatuh, daerah, lawan, lawan...
# 4    [block, posisi, menahan, serangan, musuh, lomp...
# 5                                              [stock]
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Memulai pertandingan - Terjadinya gol - Memu...
# 2    1. awal pertandingan babak pertama, 2. awal pe...
# 3    setelah gol, pembukaan babak pertama, pembukaa...
# 4    1. Pertama kali dimulainnya permainan babak pe...
# 5                                             offside
#
#                                 Jawaban Tanpa Stopword
# No
# 1      [pertandingan, gol, babak, babak, perpanjangan]
# 2    [1, pertandingan, babak, 2, pertandingan, baba...
# 3            [gol, pembukaan, babak, pembukaan, babak]
# 4    [1, kali, dimulainnya, permainan, babak, 2, ka...
# 5                                            [offside]
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Christiano Ronaldo terlahir dengan nama lengka...
# 2    Cristiano Ronaldo dos Santos Aveiro (lahir di ...
# 3    lahir di portugal sebagai warga negara portuga...
# 4    Lahir di Santo Antonio, Portugal 5 Februari 19...
# 5                               pemain sepak bola pro
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [christiano, ronaldo, terlahir, nama, lengkap,...
# 2    [cristiano, ronaldo, dos, santos, aveiro, lahi...
# 3    [lahir, portugal, warga, negara, portugal, kar...
# 4    [lahir, santo, antonio, portugal, 5, februari,...
# 5                           [pemain, sepak, bola, pro]
# Soal: 7:
#                                                Jawaban  \
# No
# 1    Keper adalah penjaga gawang. Defender adalah p...
# 2    1. penjaga gawang. 2. bek. 3. gelandang. 4. pe...
# 3    kiper: menjaga gawang, beck:menjaga kedalaman ...
# 4    1. Goal Keeper. 2. Deffense. 3. Center. 4. Str...
# 5                                          hebak umak
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [keper, penjaga, gawang, defender, pemain, ber...
# 2    [1, penjaga, gawang, 2, bek, 3, gelandang, 4, ...
# 3    [kiper, menjaga, gawang, beckmenjaga, kedalama...
# 4    [1, goal, keeper, 2, deffense, 3, center, 4, s...
# 5                                        [hebak, umak]
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Airnya bersih, Airnya tidak mengandung karpori...
# 2    1. Tidak bocor 2. Sirkulasi air dan sistem fil...
# 3                      kebersihan,keindahan,kedalaman
# 4    1. Air yang digunakan tidak menggandung kapur....
# 5                            tidak bau , bisa diminum
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [airnya, bersih, airnya, mengandung, karporit,...
# 2    [1, bocor, 2, sirkulasi, air, sistem, filteras...
# 3                       [kebersihankeindahankedalaman]
# 4    [1, air, menggandung, kapur, 2, kebersihan, ko...
# 5                                       [bau, diminum]
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Tunggal putra, tunggal putri, ganda putra, gan...
# 2    -ganda putra, -ganda putri, -ganda campuran, -...
# 3    ganda putra/putri, ganda campuran,single putra...
# 4    1. Tunggal Putra. 2. Tunggal Putri. 3. Ganda P...
# 5                                   gerindra , hanura
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [tunggal, putra, tunggal, putri, ganda, putra,...
# 2    [ganda, putra, ganda, putri, ganda, campuran, ...
# 3    [ganda, putraputri, ganda, campuransingle, put...
# 4    [1, tunggal, putra, 2, tunggal, putri, 3, gand...
# 5                                   [gerindra, hanura]
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Parkour adalah seni bergerak dan metode latiha...
# 2    Parkour adalah aktivitas yang bertujuan untuk ...
# 3    keindahan dan kelenturan dalam melewati rintan...
# 4    Parkour adalah aktivitas yang bertujuan untuk ...
# 5                             loncat loncat di gedung
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [parkour, seni, bergerak, metode, latihan, nat...
# 2    [parkour, aktivitas, bertujuan, berpindah, efi...
# 3    [keindahan, kelenturan, melewati, rintangan, p...
# 4    [parkour, aktivitas, bertujuan, berpindah, efi...
# 5                             [loncat, loncat, gedung]
# <ipython-input-15-eb7adbeb2fa0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-eb7adbeb2fa0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-eb7adbeb2fa0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-eb7adbeb2fa0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-eb7adbeb2fa0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-eb7adbeb2fa0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-eb7adbeb2fa0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-eb7adbeb2fa0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-eb7adbeb2fa0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-eb7adbeb2fa0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-eb7adbeb2fa0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-eb7adbeb2fa0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-eb7adbeb2fa0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-eb7adbeb2fa0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-eb7adbeb2fa0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-15-eb7adbeb2fa0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-15-eb7adbeb2fa0>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-15-eb7adbeb2fa0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-15-eb7adbeb2fa0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-15-eb7adbeb2fa0>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))

# %%
list_df_olahraga[1]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    PSSI adalah Persatuan Sepak Bola Seluruh Indon...      40.0      60.0
# 2    PSSI adalah Perstuan Sepak Bola Seluruh Indone...      40.0      60.0
# 3    pssi adalah persatuan sepak bola seluruh indon...      30.0      25.0
# 4    PSSI merupakan Persatuan Sepakbola Seluruh Ind...      35.0      40.0
# 5              persatuan sepak bola seluruh indonesia       20.0      25.0
# 6    Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 7    PSSI atau singkatan dari Persatuan Sepak bola ...      60.0      65.0
# 8    Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 9    Persatuan Sepak Bola Seluruh Indonesia, dising...      70.0      85.0
# 10   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 11   PSSI atau Persatuan Sepak bola Seluruh Indones...      50.0      70.0
# 12                     Organisasi sepakbola indonesia       20.0      10.0
# 13   setahuku itu adalah organisasi persatuan sepak...      18.0      10.0
# 14   PSSI adalah Persatuan Sepakbola Seluruh Indone...      25.0      30.0
# 15   organisasi yang menuangi tentang sepak bola in...      20.0      10.0
# 16   PSSI adalah singkatan dari Persatuan Sepakbola...      45.0      30.0
# 17   -Ketua Umum PSSI saat ini La Naylla Mataliti -...      60.0      48.0
# 18   Persatuan Sepak Bola Seluruh Indonesia, dising...      45.0      48.0
# 19   organisasi induk yang bertugas mengatur kegiat...      30.0      25.0
# 20   - PSSI adalah singkatan dari persatuan sepak b...      45.0      30.0
# 21               perersatuan indonesia seluruh malang       18.0       5.0
# 22   PSSI adalah singkatan dari Persatuan Sepakbola...      55.0      50.0
# 23   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 24   PSSI (Persatuan Sepak Bola Seluruh Indonesia) ...      50.0      40.0
# 25   PSSI adalah persatuan sepak bola seluruh Indon...      85.0      80.0
# 26   PSSI adalah organisasi untuk menaungi cabang o...      20.0      25.0
# 27   Apa yang anda ketahui mengenai PSSI? (Termasuk...      10.0       0.0
# 28   Persatuan Sepakbola Seluruh Indonesia yang men...      35.0      40.0
# 29   PSSI Persatuan Sepakbola Seluruh Indonesia ada...      40.0      45.0
# 30   Persatuan Sepakbola Seluruh Indonesia ialah fe...      42.0      45.0
# 31   organisasi induk yang bertugas mengatur kegiat...      40.0      48.0
# 32   PSSI adalah organisasi induk yang bertugas men...      70.0      70.0
# 33   PSSI adalah singkatan dari Persatuan Sepak Bol...      50.0      53.0
# 34   Persatuan sepak bola seluruh indonesia adalah ...      30.0      40.0
# 35   Persatuan Sepak Bola Seluruh Indonesia, dising...      40.0      30.0
# 36   SSI, adalah organisasi induk yang bertugas men...      80.0      95.0
# 37   Persatuan Sepak Bola Seluruh Indonesia, dising...      45.0      40.0
# 38   Persatuan Sepak Bola Seluruh Indonesia, dising...      80.0      95.0
# 39   organisasi induk yang bertugas mengatur kegiat...      75.0      70.0
# 40   Persatuan Sepak Bola Seluruh Indonesia, dising...      55.0      60.0
# 41   PSSI adalah organisasi yang menaungi olahraga ...      40.0      25.0
# 42   PSSI adalah organisasi yang menaungi olah raga...      40.0      25.0
# 43   persatuan sepakbola seluruh indonesia merupaka...      30.0      15.0
# 44   pssi adalah singkatan dari persatuan sepakbola...      20.0      15.0
# 45   PSSI adalah Organisasi Persatuan Sepak Bola Se...      35.0      30.0
# 46   Persatuan Sepakbola Seluruh Indonesia dan dike...      25.0      25.0
# 47   persatuan sepak bola seluruh indonesia, seluru...      22.0      20.0
# 48   PSSI yg sekarang tidak bertanggung jawab atas ...      40.0      30.0
# 49   PSSI adalah induk olahraga sepak bola Indonesi...      35.0      25.0
# 50   PSSI adalah persatuan sepakbola yang ada di in...      40.0      40.0
# 51   persatuan sepakbola seluruh indonesia. organis...      30.0      25.0
# 52   Persatuan Sepakbola Seluruh Indonesia Organisa...      25.0      20.0
# 53   ersatuan Sepak Bola Seluruh Indonesia, disingk...      40.0      25.0
# 54   pssi adalah organisasi sepak bola yang ada di ...      25.0      15.0
# 55   pssi (persatuan persebak bola indonesia) adala...      35.0      19.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase  \
# No
# 1        50.0    50.000000  pssi adalah persatuan sepak bola seluruh indon...
# 2        50.0    50.000000  pssi adalah perstuan sepak bola seluruh indone...
# 3        25.0    26.666667  pssi adalah persatuan sepak bola seluruh indon...
# 4        50.0    41.666667  pssi merupakan persatuan sepakbola seluruh ind...
# 5        25.0    23.333333            persatuan sepak bola seluruh indonesia
# 6        90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 7        75.0    66.666667  pssi atau singkatan dari persatuan sepak bola ...
# 8        90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 9        75.0    76.666667  persatuan sepak bola seluruh indonesia, dising...
# 10       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 11       75.0    65.000000  pssi atau persatuan sepak bola seluruh indones...
# 12       10.0    13.333333                    organisasi sepakbola indonesia
# 13       10.0    12.666667  setahuku itu adalah organisasi persatuan sepak...
# 14       25.0    26.666667  pssi adalah persatuan sepakbola seluruh indone...
# 15       10.0    13.333333  organisasi yang menuangi tentang sepak bola in...
# 16       50.0    41.666667  pssi adalah singkatan dari persatuan sepakbola...
# 17       50.0    52.666667  -ketua umum pssi saat ini la naylla mataliti -...
# 18       50.0    47.666667  persatuan sepak bola seluruh indonesia, dising...
# 19       25.0    26.666667  organisasi induk yang bertugas mengatur kegiat...
# 20       50.0    41.666667  - pssi adalah singkatan dari persatuan sepak b...
# 21       10.0    11.000000              perersatuan indonesia seluruh malang
# 22       50.0    51.666667  pssi adalah singkatan dari persatuan sepakbola...
# 23       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 24       50.0    46.666667  pssi (persatuan sepak bola seluruh indonesia) ...
# 25       85.0    83.333333  pssi adalah persatuan sepak bola seluruh indon...
# 26       25.0    23.333333  pssi adalah organisasi untuk menaungi cabang o...
# 27        0.0     3.333333  apa yang anda ketahui mengenai pssi? (termasuk...
# 28       50.0    41.666667  persatuan sepakbola seluruh indonesia yang men...
# 29       50.0    45.000000  pssi persatuan sepakbola seluruh indonesia ada...
# 30       50.0    45.666667  persatuan sepakbola seluruh indonesia ialah fe...
# 31       50.0    46.000000  organisasi induk yang bertugas mengatur kegiat...
# 32       75.0    71.666667  pssi adalah organisasi induk yang bertugas men...
# 33       50.0    51.000000  pssi adalah singkatan dari persatuan sepak bol...
# 34       50.0    40.000000  persatuan sepak bola seluruh indonesia adalah ...
# 35       50.0    40.000000  persatuan sepak bola seluruh indonesia, dising...
# 36       90.0    88.333333  ssi, adalah organisasi induk yang bertugas men...
# 37       50.0    45.000000  persatuan sepak bola seluruh indonesia, dising...
# 38       90.0    88.333333  persatuan sepak bola seluruh indonesia, dising...
# 39       75.0    73.333333  organisasi induk yang bertugas mengatur kegiat...
# 40       50.0    55.000000  persatuan sepak bola seluruh indonesia, dising...
# 41       50.0    38.333333  pssi adalah organisasi yang menaungi olahraga ...
# 42       50.0    38.333333  pssi adalah organisasi yang menaungi olah raga...
# 43       25.0    23.333333  persatuan sepakbola seluruh indonesia merupaka...
# 44       25.0    20.000000  pssi adalah singkatan dari persatuan sepakbola...
# 45       25.0    30.000000  pssi adalah organisasi persatuan sepak bola se...
# 46       25.0    25.000000  persatuan sepakbola seluruh indonesia dan dike...
# 47       25.0    22.333333  persatuan sepak bola seluruh indonesia, seluru...
# 48       50.0    40.000000  pssi yg sekarang tidak bertanggung jawab atas ...
# 49       25.0    28.333333  pssi adalah induk olahraga sepak bola indonesi...
# 50       50.0    43.333333  pssi adalah persatuan sepakbola yang ada di in...
# 51       25.0    26.666667  persatuan sepakbola seluruh indonesia. organis...
# 52       25.0    23.333333  persatuan sepakbola seluruh indonesia organisa...
# 53       25.0    30.000000  ersatuan sepak bola seluruh indonesia, disingk...
# 54       25.0    21.666667  pssi adalah organisasi sepak bola yang ada di ...
# 55       25.0    26.333333  pssi (persatuan persebak bola indonesia) adala...
#
#                              Jawaban tanpa Punctuation  \
# No
# 1    pssi adalah persatuan sepak bola seluruh indon...
# 2    pssi adalah perstuan sepak bola seluruh indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    pssi merupakan persatuan sepakbola seluruh ind...
# 5              persatuan sepak bola seluruh indonesia
# 6    persatuan sepak bola seluruh indonesia disingk...
# 7    pssi atau singkatan dari persatuan sepak bola ...
# 10   [persatuan, sepak, bola, seluruh, indonesia, d...
# 11   [pssi, atau, persatuan, sepak, bola, seluruh, ...
# 12                  [organisasi, sepakbola, indonesia]
# 13   [setahuku, itu, adalah, organisasi, persatuan,...
# 14   [pssi, adalah, persatuan, sepakbola, seluruh, ...
# 15   [organisasi, yang, menuangi, tentang, sepak, b...
# 16   [pssi, adalah, singkatan, dari, persatuan, sep...
# 17   [ketua, umum, pssi, saat, ini, la, naylla, mat...
# 18   [persatuan, sepak, bola, seluruh, indonesia, d...
# 19   [organisasi, induk, yang, bertugas, mengatur, ...
# 20   [pssi, adalah, singkatan, dari, persatuan, sep...
# 21           [perersatuan, indonesia, seluruh, malang]
# 22   [pssi, adalah, singkatan, dari, persatuan, sep...
# 23   [persatuan, sepak, bola, seluruh, indonesia, d...
# 24   [pssi, persatuan, sepak, bola, seluruh, indone...
# 25   [pssi, adalah, persatuan, sepak, bola, seluruh...
# 26   [pssi, adalah, organisasi, untuk, menaungi, ca...
# 27   [apa, yang, anda, ketahui, mengenai, pssi, ter...
# 28   [persatuan, sepakbola, seluruh, indonesia, yan...
# 29   [pssi, persatuan, sepakbola, seluruh, indonesi...
# 30   [persatuan, sepakbola, seluruh, indonesia, ial...
# 31   [organisasi, induk, yang, bertugas, mengatur, ...
# 32   [pssi, adalah, organisasi, induk, yang, bertug...
# 33   [pssi, adalah, singkatan, dari, persatuan, sep...
# 34   [persatuan, sepak, bola, seluruh, indonesia, a...
# 35   [persatuan, sepak, bola, seluruh, indonesia, d...
# 36   [ssi, adalah, organisasi, induk, yang, bertuga...
# 37   [persatuan, sepak, bola, seluruh, indonesia, d...
# 38   [persatuan, sepak, bola, seluruh, indonesia, d...
# 39   [organisasi, induk, yang, bertugas, mengatur, ...
# 40   [persatuan, sepak, bola, seluruh, indonesia, d...
# 41   [pssi, adalah, organisasi, yang, menaungi, ola...
# 42   [pssi, adalah, organisasi, yang, menaungi, ola...
# 43   [persatuan, sepakbola, seluruh, indonesia, mer...
# 44   [pssi, adalah, singkatan, dari, persatuan, sep...
# 45   [pssi, adalah, organisasi, persatuan, sepak, b...
# 46   [persatuan, sepakbola, seluruh, indonesia, dan...
# 47   [persatuan, sepak, bola, seluruh, indonesia, s...
# 48   [pssi, yg, sekarang, tidak, bertanggung, jawab...
# 49   [pssi, adalah, induk, olahraga, sepak, bola, i...
# 50   [pssi, adalah, persatuan, sepakbola, yang, ada...
# 51   [persatuan, sepakbola, seluruh, indonesia, org...
# 52   [persatuan, sepakbola, seluruh, indonesia, org...
# 53   [ersatuan, sepak, bola, seluruh, indonesia, di...
# 54   [pssi, adalah, organisasi, sepak, bola, yang, ...
# 55   [pssi, persatuan, persebak, bola, indonesia, a...
#
#                                 Jawaban Tanpa Stopword  \
# No
# 1    [pssi, persatuan, sepak, bola, indonesia, ketu...
# 2    [pssi, perstuan, sepak, bola, indonesia, ketua...
# 3    [pssi, persatuan, sepak, bola, indonesia, pssi...
# 4    [pssi, persatuan, sepakbola, indonesia, badan,...
# 5                  [persatuan, sepak, bola, indonesia]
# 6    [persatuan, sepak, bola, indonesia, disingkat,...
# 7    [pssi, singkatan, persatuan, sepak, bola, indo...
# 8    [persatuan, sepak, bola, indonesia, disingkat,...
# 9    [persatuan, sepak, bola, indonesia, disingkat,...
# 10   [persatuan, sepak, bola, indonesia, disingkat,...
# 11   [pssi, persatuan, sepak, bola, indonesia, orga...
# 12                  [organisasi, sepakbola, indonesia]
# 13   [setahuku, organisasi, persatuan, sepak, nola,...
# 14   [pssi, persatuan, sepakbola, indonesia, ketua,...
# 15      [organisasi, menuangi, sepak, bola, indonesia]
# 16   [pssi, singkatan, persatuan, sepakbola, indone...
# 17   [ketua, pssi, la, naylla, mataliti, pssi, orga...
# 18   [persatuan, sepak, bola, indonesia, disingkat,...
# 19   [organisasi, induk, bertugas, mengatur, kegiat...
# 20   [pssi, singkatan, persatuan, sepak, bola, indo...
# 21                    [perersatuan, indonesia, malang]
# 22   [pssi, singkatan, persatuan, sepakbola, indone...
# 23   [persatuan, sepak, bola, indonesia, disingkat,...
# 24   [pssi, persatuan, sepak, bola, indonesia, orga...
# 25   [pssi, persatuan, sepak, bola, indonesia, indu...
# 26   [pssi, organisasi, menaungi, cabang, olahraga,...
# 27   [ketahui, pssi, pengertian, organisasi, tergab...
# 28   [persatuan, sepakbola, indonesia, menaungi, kl...
# 29   [pssi, persatuan, sepakbola, indonesia, persat...
# 30   [persatuan, sepakbola, indonesia, federasi, se...
# 31   [organisasi, induk, bertugas, mengatur, kegiat...
# 32   [pssi, organisasi, induk, bertugas, mengatur, ...
# 33   [pssi, singkatan, persatuan, sepak, bola, indo...
# 34   [persatuan, sepak, bola, indonesia, organisasi...
# 35   [persatuan, sepak, bola, indonesia, disingkat,...
# 36   [ssi, organisasi, induk, bertugas, mengatur, k...
# 37   [persatuan, sepak, bola, indonesia, disingkat,...
# 38   [persatuan, sepak, bola, indonesia, disingkat,...
# 39   [organisasi, induk, bertugas, mengatur, kegiat...
# 40   [persatuan, sepak, bola, indonesia, disingkat,...
# 41   [pssi, organisasi, menaungi, olahraga, sepak, ...
# 42   [pssi, organisasi, menaungi, olah, raga, sepak...
# 43   [persatuan, sepakbola, indonesia, organisasi, ...
# 44   [pssi, singkatan, persatuan, sepakbola, indone...
# 45   [pssi, organisasi, persatuan, sepak, bola, ind...
# 46   [persatuan, sepakbola, indonesia, diketuai, la...
# 47   [persatuan, sepak, bola, indonesia, club, sepa...
# 48   [pssi, yg, bertanggung, bola, pssi, persatuan,...
# 49   [pssi, induk, olahraga, sepak, bola, indonesia...
# 50   [pssi, persatuan, sepakbola, indonesia, pssi, ...
# 51   [persatuan, sepakbola, indonesia, organisasi, ...
# 52   [persatuan, sepakbola, indonesia, organisasi, ...
# 53   [ersatuan, sepak, bola, indonesia, disingkat, ...
# 54   [pssi, organisasi, sepak, bola, indonesia, ket...
# 55   [pssi, persatuan, persebak, bola, indonesia, b...
#
#                Jawaban Tanpa Stopword Not Tokenization
# No
# 1    pssi persatuan sepak bola indonesia ketua la n...
    # melakukan split kalimat menjadi token
    result = []
    negate = False
    for word in kalimat:
        if any(neg == word for neg in negasi):
            negate = True
        elif negate and word not in string.punctuation:
            word = 'tidak_' + word
            negate = False
        result.append(word)
    return result

# %%
list_df_olahraga = []

soal_olahraga = 0
for df in Olahraga_all_sheets:
    soal_olahraga = soal_olahraga + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
    df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
    df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
    df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
    df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
    df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
    
    print(f"Soal: {soal_olahraga}:")
    print(df[['Jawaban', 'Jawaban Tanpa Stopword']].head())
    list_df_olahraga.append(df)
# Out:
# <ipython-input-18-c993e41759b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-c993e41759b4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-c993e41759b4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-c993e41759b4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-c993e41759b4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-c993e41759b4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-c993e41759b4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-c993e41759b4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-c993e41759b4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-c993e41759b4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-c993e41759b4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-c993e41759b4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-c993e41759b4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-c993e41759b4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-c993e41759b4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-c993e41759b4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-c993e41759b4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-c993e41759b4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-c993e41759b4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-c993e41759b4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-c993e41759b4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-c993e41759b4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-c993e41759b4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-c993e41759b4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-c993e41759b4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-c993e41759b4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-c993e41759b4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-c993e41759b4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-c993e41759b4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-c993e41759b4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-c993e41759b4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-c993e41759b4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-c993e41759b4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-c993e41759b4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-c993e41759b4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-c993e41759b4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-c993e41759b4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-c993e41759b4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-c993e41759b4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-c993e41759b4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-c993e41759b4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-c993e41759b4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-18-c993e41759b4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-c993e41759b4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-c993e41759b4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-c993e41759b4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-18-c993e41759b4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] = df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# Soal: 1:
#                                                Jawaban  \
# No
# 1    - Menyehatkan tubuh - Memperkuat otot-otot - M...
# 2    1. Meringankan Kerja Jantung. 2. Melancarkan A...
# 3    refresing, kesehatan otot, syaraf-syaraf mejad...
# 4    1. Menjaga kondisi fisik tetap prima. 2. Mengh...
# 5                                               sehat
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [menyehatkan, tubuh, memperkuat, otototot, men...
# 2    [1, meringankan, kerja, jantung, 2, melancarka...
# 3    [refresing, kesehatan, otot, syarafsyaraf, mej...
# 4    [1, menjaga, kondisi, fisik, prima, 2, menghil...
# 5                                              [sehat]
# Soal: 2:
#                                                Jawaban  \
# No
# 1    PSSI adalah Persatuan Sepak Bola Seluruh Indon...
# 2    PSSI adalah Perstuan Sepak Bola Seluruh Indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    PSSI merupakan Persatuan Sepakbola Seluruh Ind...
# 5              persatuan sepak bola seluruh indonesia
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [pssi, persatuan, sepak, bola, indonesia, ketu...
# 2    [pssi, perstuan, sepak, bola, indonesia, ketua...
# 3    [pssi, persatuan, sepak, bola, indonesia, pssi...
# 4    [pssi, persatuan, sepakbola, indonesia, badan,...
# 5                  [persatuan, sepak, bola, indonesia]
# Soal: 3:
#                                               Jawaban  \
# o
# 1   Rio Heryanto merupakan seorang pebalap berkeba...
# 2   Rio Haryanto (lahir di Solo, Jawa Tengah, 22 J...
# 3   lahir di solo, besar sebagai pembalap f1, ayah...
# 4   Lahir di kota Surakarta, 22 Januari 1993. Kari...
# 5                                        pembalap F1
#
#                                Jawaban Tanpa Stopword
# o
# 1   [rio, heryanto, pebalap, berkebangsaan, indone...
# 2   [rio, haryanto, lahir, solo, jawa, 22, januari...
# 3   [lahir, solo, pembalap, f1, ayah, rio, memilik...
# 4   [lahir, kota, surakarta, 22, januari, 1993, ka...
# 5                                      [pembalap, f1]
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Block atau membendung merupakan suatu upaya pe...
# 2    Block (blocking) adalah upaya untuk membendung...
# 3    menghadang bola agar jatuh ke daerah lawan . d...
# 4    Block adalah posisi untuk menahan serangan dar...
# 5                                               stock
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [block, membendung, upaya, pemain, menutup, da...
# 2    [block, blocking, upaya, membendung, serangan,...
# 3    [menghadang, bola, jatuh, daerah, lawan, lawan...
# 4    [block, posisi, menahan, serangan, musuh, lomp...
# 5                                              [stock]
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Memulai pertandingan - Terjadinya gol - Memu...
# 2    1. awal pertandingan babak pertama, 2. awal pe...
# 3    setelah gol, pembukaan babak pertama, pembukaa...
# 4    1. Pertama kali dimulainnya permainan babak pe...
# 5                                             offside
#
#                                 Jawaban Tanpa Stopword
# No
# 1      [pertandingan, gol, babak, babak, perpanjangan]
# 2    [1, pertandingan, babak, 2, pertandingan, baba...
# 3            [gol, pembukaan, babak, pembukaan, babak]
# 4    [1, kali, dimulainnya, permainan, babak, 2, ka...
# 5                                            [offside]
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Christiano Ronaldo terlahir dengan nama lengka...
# 2    Cristiano Ronaldo dos Santos Aveiro (lahir di ...
# 3    lahir di portugal sebagai warga negara portuga...
# 4    Lahir di Santo Antonio, Portugal 5 Februari 19...
# 5                               pemain sepak bola pro
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [christiano, ronaldo, terlahir, nama, lengkap,...
# 2    [cristiano, ronaldo, dos, santos, aveiro, lahi...
# 3    [lahir, portugal, warga, negara, portugal, kar...
# 4    [lahir, santo, antonio, portugal, 5, februari,...
# 5                           [pemain, sepak, bola, pro]
# Soal: 7:
#                                                Jawaban  \
# No
# 1    Keper adalah penjaga gawang. Defender adalah p...
# 2    1. penjaga gawang. 2. bek. 3. gelandang. 4. pe...
# 3    kiper: menjaga gawang, beck:menjaga kedalaman ...
# 4    1. Goal Keeper. 2. Deffense. 3. Center. 4. Str...
# 5                                          hebak umak
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [keper, penjaga, gawang, defender, pemain, ber...
# 2    [1, penjaga, gawang, 2, bek, 3, gelandang, 4, ...
# 3    [kiper, menjaga, gawang, beckmenjaga, kedalama...
# 4    [1, goal, keeper, 2, deffense, 3, center, 4, s...
# 5                                        [hebak, umak]
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Airnya bersih, Airnya tidak mengandung karpori...
# 2    1. Tidak bocor 2. Sirkulasi air dan sistem fil...
# 3                      kebersihan,keindahan,kedalaman
# 4    1. Air yang digunakan tidak menggandung kapur....
# 5                            tidak bau , bisa diminum
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [airnya, bersih, airnya, mengandung, karporit,...
# 2    [1, bocor, 2, sirkulasi, air, sistem, filteras...
# 3                       [kebersihankeindahankedalaman]
# 4    [1, air, menggandung, kapur, 2, kebersihan, ko...
# 5                                       [bau, diminum]
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Tunggal putra, tunggal putri, ganda putra, gan...
# 2    -ganda putra, -ganda putri, -ganda campuran, -...
# 3    ganda putra/putri, ganda campuran,single putra...
# 4    1. Tunggal Putra. 2. Tunggal Putri. 3. Ganda P...
# 5                                   gerindra , hanura
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [tunggal, putra, tunggal, putri, ganda, putra,...
# 2    [ganda, putra, ganda, putri, ganda, campuran, ...
# 3    [ganda, putraputri, ganda, campuransingle, put...
# 4    [1, tunggal, putra, 2, tunggal, putri, 3, gand...
# 5                                   [gerindra, hanura]
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Parkour adalah seni bergerak dan metode latiha...
# 2    Parkour adalah aktivitas yang bertujuan untuk ...
# 3    keindahan dan kelenturan dalam melewati rintan...
# 4    Parkour adalah aktivitas yang bertujuan untuk ...
# 5                             loncat loncat di gedung
#
#                                 Jawaban Tanpa Stopword
# No
# 1    [parkour, seni, bergerak, metode, latihan, nat...
# 2    [parkour, aktivitas, bertujuan, berpindah, efi...
# 3    [keindahan, kelenturan, melewati, rintangan, p...
# 4    [parkour, aktivitas, bertujuan, berpindah, efi...
# 5                             [loncat, loncat, gedung]
# <ipython-input-18-c993e41759b4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-18-c993e41759b4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-18-c993e41759b4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-18-c993e41759b4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-18-c993e41759b4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))

# %%
list_df_olahraga[3]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    Block atau membendung merupakan suatu upaya pe...      45.0      50.0
# 2    Block (blocking) adalah upaya untuk membendung...      40.0      50.0
# 3    menghadang bola agar jatuh ke daerah lawan . d...      45.0      45.0
# 4    Block adalah posisi untuk menahan serangan dar...      60.0      70.0
# 5                                               stock        0.0       0.0
# 6    Bola voli adalah olahraga permainan yang dimai...      50.0      60.0
# 7    block adalah upaya untuk membendung serangan d...      45.0      50.0
# 8    Bola voli merupakan salah satu permainan bola ...      40.0      40.0
# 9    Blok ganda adalah membendung bola yang dilakuk...      50.0      50.0
# 10   Pengertian blok dalam permainan bola voli adal...      60.0      80.0
# 11   Block adalah proses menghadang bola yang beras...      40.0      45.0
# 12   Membendung bola atau menahan bola,pemain yang ...      30.0      30.0
# 13   block dalam permainan bola voli adalah pertaha...      35.0      40.0
# 14   adalah teknik membendung atau menutup arah dat...      40.0      50.0
# 15        untung mengeblock bola dari lawan , blocker       28.0      40.0
# 16   pemain yang berfungsi sebagai pemain bertahan,...      20.0      25.0
# 17   Block adalah sebuah cara untuk menangkis bola ...      48.0      50.0
# 18   Pengertian blok dalam permainan bola voli adal...      58.0      65.0
# 19   untuk menghadang serangan dari spike lawan ada...      32.0      25.0
# 20   block adalah suatu kondisi dimana pemain lawan...      28.0      40.0
# 21                                           uppercut        0.0       0.0
# 22   Pengertian Block adalah upaya untuk membendung...      47.0      36.0
# 23   Blocking atau membendung bola merupakan upaya ...      52.0      50.0
# 24   Block merupakan suatu upaya pemain untuk menut...      32.0      30.0
# 25   Blocking adalah suatu teknik yang dilakukan un...      38.0      30.0
# 26   Block dalam bola voli adalah kesempatan menyer...      20.0      30.0
# 27   block adalah cara menahan bola saat di udara p...      55.0      50.0
# 28   memblock datangnya bola dari lawan disaat lawa...      29.0      25.0
# 29   Block adalah menghalau bola lawan agar tidak d...      28.0      30.0
# 30   block dalam bola voli adalah menghalau smash l...      25.0      30.0
# 31            penjaga posisi pada permainan bola voli       20.0      10.0
# 32   Block adalah suatu gerakan untuk menahan bola ...      30.0      30.0
# 33   gerakan menahan bola dari tembakan lawan. posi...      31.0      25.0
# 34   Block adalah posisi membendung serangan lawan ...      49.0      25.0
# 35   Pengertian blok dalam permainan bola voli adal...      45.0      28.0
# 36   Pengertian blok dalam permainan bola voli adal...      65.0      68.0
# 37   yang di maksud block dalam permainan bola voli...      40.0      40.0
# 38   lock adalah upaya untuk membendung serangan da...      35.0      40.0
# 39   upaya untuk membendung serangan dari lawan,str...      28.0      15.0
# 40   Pengertian blok dalam permainan bola voli adal...      48.0      40.0
# 41   Pengertian Block dalam permainan bola voly ada...      45.0      44.0
# 42   mengahalau smash dari lawan dan bisa dilakukan...      20.0      15.0
# 43   block merupakan menahan suatu smash dari lawan...      38.0      35.0
# 44   block menahan serangan lawan yang melakuakan i...      49.0      25.0
# 45   Block dalam bola voli adalah merupakan teknik ...      55.0      38.0
# 46   block adalah sebuah teknik dalam menghalau bol...      65.0      45.0
# 47   block dalam bola voli ialah menahan serangan d...      27.0      45.0
# 48   block dalam bola voli ialah menahan serangan d...      27.0      25.0
# 49   mengeblock bola dari musuh , posisi depan bisa...      20.0      15.0
# 50   Block adalah posisi menghalangi smash yang dil...      30.0      15.0
# 51   block adalah salah satu cara yang digunakan pa...      35.0      29.0
# 52                           posisi menghalangi lawan       28.0      15.0
# 53                     penghalang dari serangan musuh       22.0      15.0
# 54   Blocker adalah pemain yang pada dasarnya bertu...      30.0      25.0
# 55    untuk mengeblock bola agar tidak masuk ke dalam       29.0      15.0
# 56   blok adalah dimana saat lawan melakukan serang...      38.0      30.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase  \
# No
# 1        50.0    48.333333  block atau membendung merupakan suatu upaya pe...
# 2        50.0    46.666667  block (blocking) adalah upaya untuk membendung...
# 3        50.0    46.666667  menghadang bola agar jatuh ke daerah lawan . d...
# 4        75.0    68.333333  block adalah posisi untuk menahan serangan dar...
# 5         0.0     1.000000                                             stock
# 6        75.0    61.666667  bola voli adalah olahraga permainan yang dimai...
# 7        50.0    48.333333  block adalah upaya untuk membendung serangan d...
# 8        50.0    43.333333  bola voli merupakan salah satu permainan bola ...
# 9        50.0    50.000000  blok ganda adalah membendung bola yang dilakuk...
# 10       90.0    76.666667  pengertian blok dalam permainan bola voli adal...
# 11       50.0    45.000000  block adalah proses menghadang bola yang beras...
# 12       25.0    28.333333  membendung bola atau menahan bola,pemain yang ...
# 13       50.0    41.666667  block dalam permainan bola voli adalah pertaha...
# 14       50.0    46.666667  adalah teknik membendung atau menutup arah dat...
# 15       50.0    39.333333       untung mengeblock bola dari lawan , blocker
# 16       25.0    23.333333  pemain yang berfungsi sebagai pemain bertahan,...
# 17       50.0    49.333333  block adalah sebuah cara untuk menangkis bola ...
# 18       75.0    66.000000  pengertian blok dalam permainan bola voli adal...
# 19       25.0    27.333333  untuk menghadang serangan dari spike lawan ada...
# 20       25.0    31.000000  block adalah suatu kondisi dimana pemain lawan...
# 21        0.0     1.000000                                          uppercut
# 22       50.0    44.333333  pengertian block adalah upaya untuk membendung...
# 23       50.0    50.666667  blocking atau membendung bola merupakan upaya ...
# 24       25.0    29.000000  block merupakan suatu upaya pemain untuk menut...
# 25       25.0    31.000000  blocking adalah suatu teknik yang dilakukan un...
# 26       25.0    25.000000  block dalam bola voli adalah kesempatan menyer...
# 27       50.0    51.666667  block adalah cara menahan bola saat di udara p...
# 28       25.0    26.333333  memblock datangnya bola dari lawan disaat lawa...
# 29       25.0    27.666667  block adalah menghalau bola lawan agar tidak d...
# 30       25.0    26.666667  block dalam bola voli adalah menghalau smash l...
# 31       25.0    18.333333           penjaga posisi pada permainan bola voli
# 32       25.0    28.333333  block adalah suatu gerakan untuk menahan bola ...
# 33       25.0    27.000000  gerakan menahan bola dari tembakan lawan. posi...
# 34       50.0    41.333333  block adalah posisi membendung serangan lawan ...
# 35       50.0    41.000000  pengertian blok dalam permainan bola voli adal...
# 36       75.0    69.333333  pengertian blok dalam permainan bola voli adal...
# 37       50.0    43.333333  yang di maksud block dalam permainan bola voli...
# 38       50.0    41.666667  lock adalah upaya untuk membendung serangan da...
# 39       25.0    22.666667  upaya untuk membendung serangan dari lawan,str...
# 40       50.0    46.000000  pengertian blok dalam permainan bola voli adal...
# 41       50.0    46.333333  pengertian block dalam permainan bola voly ada...
# 42       25.0    20.000000  mengahalau smash dari lawan dan bisa dilakukan...
# 43       50.0    41.000000  block merupakan menahan suatu smash dari lawan...
# 44       50.0    41.333333  block menahan serangan lawan yang melakuakan i...
# 45       50.0    47.666667  block dalam bola voli adalah merupakan teknik ...
# 46       50.0    53.333333  block adalah sebuah teknik dalam menghalau bol...
# 47       50.0    40.666667  block dalam bola voli ialah menahan serangan d...
# 48       25.0    25.666667  block dalam bola voli ialah menahan serangan d...
# 49       25.0    20.000000  mengeblock bola dari musuh , posisi depan bisa...
# 50       25.0    23.333333  block adalah posisi menghalangi smash yang dil...
# 51       25.0    29.666667  block adalah salah satu cara yang digunakan pa...
# 52       25.0    22.666667                          posisi menghalangi lawan
# 53       25.0    20.666667                    penghalang dari serangan musuh
# 54       25.0    26.666667  blocker adalah pemain yang pada dasarnya bertu...
# 55       25.0    23.000000   untuk mengeblock bola agar tidak masuk ke dalam
# 56       25.0    31.000000  blok adalah dimana saat lawan melakukan serang...
#
#                              Jawaban tanpa Punctuation  \
# No
# 1    block atau membendung merupakan suatu upaya pe...
# 2    block blocking adalah upaya untuk membendung s...
# 3    menghadang bola agar jatuh ke daerah lawan  da...
# 4    block adalah posisi untuk menahan serangan dar...
# 5                                               stock
# 6    bola voli adalah olahraga permainan yang dimai...
# 7    block adalah upaya untuk membendung serangan d...
# 8    bola voli merupakan salah satu permainan bola ...
# 9    blok ganda adalah membendung bola yang dilakuk...
# 10   pengertian blok dalam permainan bola voli adal...
# 11   block adalah proses menghadang bola yang beras...
# 12   membendung bola atau menahan bolapemain yang b...
# 13   block dalam permainan bola voli adalah pertaha...
# 14   adalah teknik membendung atau menutup arah dat...
# 15         untung mengeblock bola dari lawan  blocker
# 16   pemain yang berfungsi sebagai pemain bertahan ...
# 17   block adalah sebuah cara untuk menangkis bola ...
# 18   pengertian blok dalam permainan bola voli adal...
# 19   untuk menghadang serangan dari spike lawan ada...
# 20   block adalah suatu kondisi dimana pemain lawan...
# 21                                           uppercut
# 22   pengertian block adalah upaya untuk membendung...
# 23   blocking atau membendung bola merupakan upaya ...
# 24   block merupakan suatu upaya pemain untuk menut...
# 25   blocking adalah suatu teknik yang dilakukan un...
# 26   block dalam bola voli adalah kesempatan menyer...
# 27   block adalah cara menahan bola saat di udara p...
# 28   memblock datangnya bola dari lawan disaat lawa...
# 29   block adalah menghalau bola lawan agar tidak d...
# 30   block dalam bola voli adalah menghalau smash l...
# 31            penjaga posisi pada permainan bola voli
# 32   block adalah suatu gerakan untuk menahan bola ...
# 33   gerakan menahan bola dari tembakan lawan posis...
# 34   block adalah posisi membendung serangan lawan ...
# 35   pengertian blok dalam permainan bola voli adal...
# 36   pengertian blok dalam permainan bola voli adal...
# 37   yang di maksud block dalam permainan bola voli...
# 38   lock adalah upaya untuk membendung serangan da...
# 39   upaya untuk membendung serangan dari lawanstri...
# 40   pengertian blok dalam permainan bola voli adal...
# 41   pengertian block dalam permainan bola voly ada...
# 42   mengahalau smash dari lawan dan bisa dilakukan...
# 43   block merupakan menahan suatu smash dari lawan...
# 44   block menahan serangan lawan yang melakuakan i...
# 45   block dalam bola voli adalah merupakan teknik ...
# 46   block adalah sebuah teknik dalam menghalau bol...
# 47   block dalam bola voli ialah menahan serangan d...
# 48   block dalam bola voli ialah menahan serangan d...
# 49   mengeblock bola dari musuh  posisi depan bisa ...
# 50   block adalah posisi menghalangi smash yang dil...
# 51   block adalah salah satu cara yang digunakan pa...
# 52                           posisi menghalangi lawan
# 53                     penghalang dari serangan musuh
# 54   blocker adalah pemain yang pada dasarnya bertu...
# 55    untuk mengeblock bola agar tidak masuk ke dalam
# 56   blok adalah dimana saat lawan melakukan serang...
#
#                                   Jawaban Tokenization  \
# No
# 1    [block, atau, membendung, merupakan, suatu, up...
# 2    [block, blocking, adalah, upaya, untuk, memben...
# 3    [menghadang, bola, agar, jatuh, ke, daerah, la...
# 4    [block, adalah, posisi, untuk, menahan, serang...
# 5                                              [stock]
# 6    [bola, voli, adalah, olahraga, permainan, yang...
# 7    [block, adalah, upaya, untuk, membendung, sera...
# 8    [bola, voli, merupakan, salah, satu, permainan...
# 9    [blok, ganda, adalah, membendung, bola, yang, ...
# 10   [pengertian, blok, dalam, permainan, bola, vol...
# 11   [block, adalah, proses, menghadang, bola, yang...
# 12   [membendung, bola, atau, menahan, bolapemain, ...
# 13   [block, dalam, permainan, bola, voli, adalah, ...
# 14   [adalah, teknik, membendung, atau, menutup, ar...
# 15    [untung, mengeblock, bola, dari, lawan, blocker]
# 16   [pemain, yang, berfungsi, sebagai, pemain, ber...
# 17   [block, adalah, sebuah, cara, untuk, menangkis...
# 18   [pengertian, blok, dalam, permainan, bola, vol...
# 19   [untuk, menghadang, serangan, dari, spike, law...
# 20   [block, adalah, suatu, kondisi, dimana, pemain...
# 21                                          [uppercut]
# 22   [pengertian, block, adalah, upaya, untuk, memb...
# 23   [blocking, atau, membendung, bola, merupakan, ...
# 24   [block, merupakan, suatu, upaya, pemain, untuk...
# 25   [blocking, adalah, suatu, teknik, yang, dilaku...
# 26   [block, dalam, bola, voli, adalah, kesempatan,...
# 27   [block, adalah, cara, menahan, bola, saat, di,...
# 28   [memblock, datangnya, bola, dari, lawan, disaa...
# 29   [block, adalah, menghalau, bola, lawan, agar, ...
# 30   [block, dalam, bola, voli, adalah, menghalau, ...
# 31      [penjaga, posisi, pada, permainan, bola, voli]
# 32   [block, adalah, suatu, gerakan, untuk, menahan...
# 33   [gerakan, menahan, bola, dari, tembakan, lawan...
# 34   [block, adalah, posisi, membendung, serangan, ...
# 35   [pengertian, blok, dalam, permainan, bola, vol...
# 36   [pengertian, blok, dalam, permainan, bola, vol...
# 37   [yang, di, maksud, block, dalam, permainan, bo...
# 38   [lock, adalah, upaya, untuk, membendung, seran...
# 39   [upaya, untuk, membendung, serangan, dari, law...
# 40   [pengertian, blok, dalam, permainan, bola, vol...
# 41   [pengertian, block, dalam, permainan, bola, vo...
# 42   [mengahalau, smash, dari, lawan, dan, bisa, di...
# 43   [block, merupakan, menahan, suatu, smash, dari...
# 44   [block, menahan, serangan, lawan, yang, melaku...
# 45   [block, dalam, bola, voli, adalah, merupakan, ...
# 46   [block, adalah, sebuah, teknik, dalam, menghal...
# 47   [block, dalam, bola, voli, ialah, menahan, ser...
# 48   [block, dalam, bola, voli, ialah, menahan, ser...
# 49   [mengeblock, bola, dari, musuh, posisi, depan,...
# 50   [block, adalah, posisi, menghalangi, smash, ya...
# 51   [block, adalah, salah, satu, cara, yang, digun...
# 52                        [posisi, menghalangi, lawan]
# 53                 [penghalang, dari, serangan, musuh]
# 54   [blocker, adalah, pemain, yang, pada, dasarnya...
# 55   [untuk, mengeblock, bola, agar, tidak, masuk, ...
# 56   [blok, adalah, dimana, saat, lawan, melakukan,...
#
#                                 Jawaban Tanpa Stopword  \
# No
# 1    [block, membendung, upaya, pemain, menutup, da...
# 2    [block, blocking, upaya, membendung, serangan,...
# 3    [menghadang, bola, jatuh, daerah, lawan, lawan...
# 4    [block, posisi, menahan, serangan, musuh, lomp...
# 5                                              [stock]
# 6    [bola, voli, olahraga, permainan, dimainkan, g...
# 7    [block, upaya, membendung, serangan, lawan, pe...
# 8    [bola, voli, salah, permainan, bola, dimainkan...
# 9    [blok, ganda, membendung, bola, orang, pemain,...
# 10   [pengertian, blok, permainan, bola, voli, usah...
# 11   [block, proses, menghadang, bola, berasal, law...
# 12             [membendung, bola, menahan, bolapemain]
# 13   [block, permainan, bola, voli, pertahanan, sma...
# 14   [teknik, membendung, menutup, arah, datangnya,...
# 15          [untung, mengeblock, bola, lawan, blocker]
# 16   [pemain, berfungsi, pemain, bertahan, gunanya,...
# 17   [block, menangkis, bola, serve, lawan, mencega...
# 18   [pengertian, blok, permainan, bola, voli, usah...
# 19   [menghadang, serangan, spike, lawan, blocker, ...
# 20   [block, kondisi, dimana, pemain, lawan, smash,...
# 21                                          [uppercut]
# 22   [pengertian, block, upaya, membendung, seranga...
# 23   [blocking, membendung, bola, upaya, pertahanan...
# 24   [block, upaya, pemain, menutup, arah, datangny...
# 25   [blocking, teknik, membendung, upaya, pemain, ...
# 26   [block, bola, voli, kesempatan, menyerang, ula...
# 27   [block, menahan, bola, udara, pemain, lawan, s...
# 28   [memblock, datangnya, bola, lawan, disaat, law...
# 29               [block, menghalau, bola, lawan, poin]
# 30   [block, bola, voli, menghalau, smash, lawan, d...
# 31            [penjaga, posisi, permainan, bola, voli]
# 32   [block, gerakan, menahan, bola, masuk, daerah,...
# 33   [gerakan, menahan, bola, tembakan, lawan, posi...
# 34   [block, posisi, membendung, serangan, lawan, m...
# 35   [pengertian, blok, permainan, bola, voli, usah...
# 36   [pengertian, blok, permainan, bola, voli, usah...
# 37   [maksud, block, permainan, bola, voli, pemain,...
# 38   [lock, upaya, membendung, serangan, lawan, blo...
# 39         [upaya, membendung, serangan, lawanstriker]
# 40   [pengertian, blok, permainan, bola, voli, usah...
# 41   [pengertian, block, permainan, bola, voly, upa...
# 42             [mengahalau, smash, lawan, pemain, net]
# 43   [block, menahan, smash, lawan, lawan, berhasil...
# 44   [block, menahan, serangan, lawan, melakuakan, ...
# 45   [block, bola, voli, teknik, menghadang, smash,...
# 46   [block, teknik, menghalau, bola, masuk, daerah...
# 47   [block, bola, voli, menahan, serangan, musuh, ...
# 48   [block, bola, voli, menahan, serangan, musuh, ...
# 49   [mengeblock, bola, musuh, posisi, kanan, kiri,...
# 50   [block, posisi, menghalangi, smash, lawan, pos...
# 51   [block, salah, voli, menghentikan, smash, pema...
# 52                        [posisi, menghalangi, lawan]
# 53                       [penghalang, serangan, musuh]
# 54   [blocker, pemain, dasarnya, bertugas, menahan,...
# 55                           [mengeblock, bola, masuk]
# 56   [blok, dimana, lawan, serangan, bisasanya, sma...
#
#                Jawaban Tanpa Stopword Not Tokenization  \
# No
# 1    block membendung upaya pemain menutup datangny...
# 2    block blocking upaya membendung serangan lawan...
# 12             [membendung, bola, menahan, bolapemain]
# 13   [block, permainan, bola, voli, pertahanan, sma...
# 14   [teknik, membendung, menutup, arah, datangnya,...
# 15          [untung, mengeblock, bola, lawan, blocker]
# 16   [pemain, berfungsi, pemain, bertahan, gunanya,...
# 17   [block, menangkis, bola, serve, lawan, mencega...
# 18   [pengertian, blok, permainan, bola, voli, usah...
# 19   [menghadang, serangan, spike, lawan, blocker, ...
# 20   [block, kondisi, dimana, pemain, lawan, smash,...
# 21                                          [uppercut]
# 22   [pengertian, block, upaya, membendung, seranga...
# 23   [blocking, membendung, bola, upaya, pertahanan...
# 24   [block, upaya, pemain, menutup, arah, datangny...
# 25   [blocking, teknik, membendung, upaya, pemain, ...
# 26   [block, bola, voli, kesempatan, menyerang, ula...
# 27   [block, menahan, bola, udara, pemain, lawan, s...
# 28   [memblock, datangnya, bola, lawan, disaat, law...
# 29               [block, menghalau, bola, lawan, poin]
# 30   [block, bola, voli, menghalau, smash, lawan, d...
# 31            [penjaga, posisi, permainan, bola, voli]
# 32   [block, gerakan, menahan, bola, masuk, daerah,...
# 33   [gerakan, menahan, bola, tembakan, lawan, posi...
# 34   [block, posisi, membendung, serangan, lawan, m...
# 35   [pengertian, blok, permainan, bola, voli, usah...
# 36   [pengertian, blok, permainan, bola, voli, usah...
# 37   [maksud, block, permainan, bola, voli, pemain,...
# 38   [lock, upaya, membendung, serangan, lawan, blo...
# 39         [upaya, membendung, serangan, lawanstriker]
# 40   [pengertian, blok, permainan, bola, voli, usah...
# 41   [pengertian, block, permainan, bola, voly, upa...
# 42             [mengahalau, smash, lawan, pemain, net]
# 43   [block, menahan, smash, lawan, lawan, berhasil...
# 44   [block, menahan, serangan, lawan, melakuakan, ...
# 45   [block, bola, voli, teknik, menghadang, smash,...
# 46   [block, teknik, menghalau, bola, masuk, daerah...
# 47   [block, bola, voli, menahan, serangan, musuh, ...
# 48   [block, bola, voli, menahan, serangan, musuh, ...
# 49   [mengeblock, bola, musuh, posisi, kanan, kiri,...
# 50   [block, posisi, menghalangi, smash, lawan, pos...
# 51   [block, salah, voli, menghentikan, smash, pema...
# 52                        [posisi, menghalangi, lawan]
# 53                       [penghalang, serangan, musuh]
# 54   [blocker, pemain, dasarnya, bertugas, menahan,...
# 55                           [mengeblock, bola, masuk]
# 56   [blok, dimana, lawan, serangan, bisasanya, sma...
#
#                         Jawaban Tanpa Negasi Not Token
# No
# 1    block membendung upaya pemain menutup datangny...
# 2    block blocking upaya membendung serangan lawan...
# 3    menghadang bola jatuh daerah lawan lawan posis...
# 4    block posisi menahan serangan musuh lompat men...
# 5                                                stock
# 6    bola voli olahraga permainan dimainkan grup be...
# 7    block upaya membendung serangan lawan pemain m...
# 8    bola voli salah permainan bola dimainkan bereg...
# 9    blok ganda membendung bola orang pemain diperh...
# 10   pengertian blok permainan bola voli usaha memb...
# 11   block proses menghadang bola berasal lawan lap...
# 12                  membendung bola menahan bolapemain
# 13   block permainan bola voli pertahanan smas lawa...
# 14   teknik membendung menutup arah datangnya bola ...
# 15                untung mengeblock bola lawan blocker
# 16   pemain berfungsi pemain bertahan gunanya bola ...
# 17   block menangkis bola serve lawan mencegah bola...
# 18   pengertian blok permainan bola voli usaha memb...
# 19   menghadang serangan spike lawan blocker middle...
# 20   block kondisi dimana pemain lawan smash smash ...
# 21                                            uppercut
# 22   pengertian block upaya membendung serangan law...
# 23   blocking membendung bola upaya pertahanan sera...
# 24   block upaya pemain menutup arah datangnya bola...
# 25   blocking teknik membendung upaya pemain menutu...
# 26   block bola voli kesempatan menyerang ulang pos...
# 27   block menahan bola udara pemain lawan smash bo...
# 28   memblock datangnya bola lawan disaat lawan tek...
# 29                     block menghalau bola lawan poin
# 30      block bola voli menghalau smash lawan duel net
# 31                  penjaga posisi permainan bola voli
# 32   block gerakan menahan bola masuk daerah musuh ...
# 33   gerakan menahan bola tembakan lawan posisi center
# 34   block posisi membendung serangan lawan mengulu...
# 35   pengertian blok permainan bola voli usaha memb...
# 36   pengertian blok permainan bola voli usaha memb...
# 37   maksud block permainan bola voli pemain lawan ...
# 38   lock upaya membendung serangan lawan block ben...
# 39              upaya membendung serangan lawanstriker
# 40   pengertian blok permainan bola voli usaha memb...
# 41   pengertian block permainan bola voly upaya mem...
# 42                   mengahalau smash lawan pemain net
# 43   block menahan smash lawan lawan berhasil mudah...
# 44      block menahan serangan lawan melakuakan libero
# 45   block bola voli teknik menghadang smash lawan ...
# 46   block teknik menghalau bola masuk daerah lawan...
# 47   block bola voli menahan serangan musuh posisi 4 2
# 48   block bola voli menahan serangan musuh posisi 4 2
# 49   mengeblock bola musuh posisi kanan kiri tukang...
# 50   block posisi menghalangi smash lawan posisi st...
# 51   block salah voli menghentikan smash pemain law...
# 52                            posisi menghalangi lawan
# 53                           penghalang serangan musuh
# 54   blocker pemain dasarnya bertugas menahan seran...
# 55                               mengeblock bola masuk
# 56   blok dimana lawan serangan bisasanya smash pem...

# %% [markdown]
# ### Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

list_df_olahraga = []

soal_olahraga = 0
for df in Olahraga_all_sheets:
    soal_olahraga = soal_olahraga + 1
    df.rename(columns= {'Jawaban ' : 'Jawaban', 'Manual 1 ' : 'Manual 1', 'Manual 2 ' : 'Manual 2', 'Manual 3 ' : 'Manual 3', 
                        ' Manual 3' : 'Manual 3', 'Manual  3' : 'Manual 3'}, inplace = True)
    df = df[['Jawaban', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']]
    
    df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
    df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
    df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
    df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
    df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
    df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
    df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))    
    df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
    df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
    
    print(f"Soal: {soal_olahraga}:")
    print(df[['Jawaban', 'Jawaban Stemmed']].head())
    list_df_olahraga.append(df)
# Out:
# <ipython-input-20-9da03d9bd0fc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-9da03d9bd0fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-9da03d9bd0fc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-9da03d9bd0fc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-9da03d9bd0fc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-9da03d9bd0fc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-9da03d9bd0fc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-9da03d9bd0fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-9da03d9bd0fc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-9da03d9bd0fc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-9da03d9bd0fc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-9da03d9bd0fc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 1:
#                                                Jawaban  \
# No
# 1    - Menyehatkan tubuh - Memperkuat otot-otot - M...
# 2    1. Meringankan Kerja Jantung. 2. Melancarkan A...
# 3    refresing, kesehatan otot, syaraf-syaraf mejad...
# 4    1. Menjaga kondisi fisik tetap prima. 2. Mengh...
# 5                                               sehat
#
#                                        Jawaban Stemmed
# No
# 1    [sehat, tubuh, kuat, otototot, jernih, pikir, ...
# 2    [1, ringan, kerja, jantung, 2, lancar, alir, d...
# 3    [refresing, sehat, otot, syarafsyaraf, mejadi,...
# 4    [1, jaga, kondisi, fisik, prima, 2, hilang, st...
# 5                                              [sehat]
# <ipython-input-20-9da03d9bd0fc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-9da03d9bd0fc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-9da03d9bd0fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-9da03d9bd0fc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-9da03d9bd0fc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-9da03d9bd0fc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-9da03d9bd0fc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 2:
#                                                Jawaban  \
# No
# 1    PSSI adalah Persatuan Sepak Bola Seluruh Indon...
# 2    PSSI adalah Perstuan Sepak Bola Seluruh Indone...
# 3    pssi adalah persatuan sepak bola seluruh indon...
# 4    PSSI merupakan Persatuan Sepakbola Seluruh Ind...
# 5              persatuan sepak bola seluruh indonesia
#
#                                        Jawaban Stemmed
# No
# 1    [pssi, satu, sepak, bola, indonesia, ketua, la...
# 2    [pssi, perstuan, sepak, bola, indonesia, ketua...
# 3    [pssi, satu, sepak, bola, indonesia, pssi, tal...
# 4    [pssi, satu, sepakbola, indonesia, badan, olah...
# 5                       [satu, sepak, bola, indonesia]
# <ipython-input-20-9da03d9bd0fc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-9da03d9bd0fc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-9da03d9bd0fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-9da03d9bd0fc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-9da03d9bd0fc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-9da03d9bd0fc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-9da03d9bd0fc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 3:
#                                               Jawaban  \
# o
# 1   Rio Heryanto merupakan seorang pebalap berkeba...
# 2   Rio Haryanto (lahir di Solo, Jawa Tengah, 22 J...
# 3   lahir di solo, besar sebagai pembalap f1, ayah...
# 4   Lahir di kota Surakarta, 22 Januari 1993. Kari...
# 5                                        pembalap F1
#
#                                       Jawaban Stemmed
# o
# 1   [rio, heryanto, balap, bangsa, indonesia, bala...
# 2   [rio, haryanto, lahir, solo, jawa, 22, januari...
# 3   [lahir, solo, balap, f1, ayah, rio, milik, pab...
# 4   [lahir, kota, surakarta, 22, januari, 1993, ka...
# 5                                         [balap, f1]
# <ipython-input-20-9da03d9bd0fc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-9da03d9bd0fc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-9da03d9bd0fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-9da03d9bd0fc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-9da03d9bd0fc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-9da03d9bd0fc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-9da03d9bd0fc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 4:
#                                                Jawaban  \
# No
# 1    Block atau membendung merupakan suatu upaya pe...
# 2    Block (blocking) adalah upaya untuk membendung...
# 3    menghadang bola agar jatuh ke daerah lawan . d...
# 4    Block adalah posisi untuk menahan serangan dar...
# 5                                               stock
#
#                                        Jawaban Stemmed
# No
# 1    [block, bendung, upaya, main, tutup, datang, b...
# 2    [block, blocking, upaya, bendung, serang, lawa...
# 3    [menghadang, bola, jatuh, daerah, lawan, lawan...
# 4    [block, posisi, tahan, serang, musuh, lompat, ...
# 5                                              [stock]
# <ipython-input-20-9da03d9bd0fc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-9da03d9bd0fc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-9da03d9bd0fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-9da03d9bd0fc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-9da03d9bd0fc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-9da03d9bd0fc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-9da03d9bd0fc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 5:
#                                                Jawaban  \
# No
# 1    - Memulai pertandingan - Terjadinya gol - Memu...
# 2    1. awal pertandingan babak pertama, 2. awal pe...
# 3    setelah gol, pembukaan babak pertama, pembukaa...
# 4    1. Pertama kali dimulainnya permainan babak pe...
# 5                                             offside
#
#                                        Jawaban Stemmed
# No
# 1                [tanding, gol, babak, babak, panjang]
# 2       [1, tanding, babak, 2, tanding, babak, 3, gol]
# 3                      [gol, buka, babak, buka, babak]
# 4    [1, kali, dimulainnya, main, babak, 2, kali, d...
# 5                                            [offside]
# <ipython-input-20-9da03d9bd0fc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-9da03d9bd0fc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-9da03d9bd0fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-9da03d9bd0fc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-9da03d9bd0fc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-9da03d9bd0fc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-9da03d9bd0fc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 6:
#                                                Jawaban  \
# No
# 1    Christiano Ronaldo terlahir dengan nama lengka...
# 2    Cristiano Ronaldo dos Santos Aveiro (lahir di ...
# 3    lahir di portugal sebagai warga negara portuga...
# 4    Lahir di Santo Antonio, Portugal 5 Februari 19...
# 5                               pemain sepak bola pro
#
#                                        Jawaban Stemmed
# No
# 1    [christiano, ronaldo, lahir, nama, lengkap, cr...
# 2    [cristiano, ronaldo, dos, santos, aveiro, lahi...
# 3    [lahir, portugal, warga, negara, portugal, kar...
# 4    [lahir, santo, antonio, portugal, 5, februari,...
# 5                             [main, sepak, bola, pro]
# <ipython-input-20-9da03d9bd0fc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-9da03d9bd0fc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-9da03d9bd0fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-9da03d9bd0fc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-9da03d9bd0fc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-9da03d9bd0fc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-9da03d9bd0fc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 7:
#                                                Jawaban  \
# No
# 1    Keper adalah penjaga gawang. Defender adalah p...
# 2    1. penjaga gawang. 2. bek. 3. gelandang. 4. pe...
# 3    kiper: menjaga gawang, beck:menjaga kedalaman ...
# 4    1. Goal Keeper. 2. Deffense. 3. Center. 4. Str...
# 5                                          hebak umak
#
#                                        Jawaban Stemmed
# No
# 1    [keper, jaga, gawang, defender, main, tahan, c...
# 2    [1, jaga, gawang, 2, bek, 3, gelandang, 4, ser...
# 3    [kiper, jaga, gawang, beckmenjaga, dalam, dare...
# 4    [1, goal, keeper, 2, deffense, 3, center, 4, s...
# 5                                        [hebak, umak]
# <ipython-input-20-9da03d9bd0fc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-9da03d9bd0fc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-9da03d9bd0fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-9da03d9bd0fc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-9da03d9bd0fc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-9da03d9bd0fc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-9da03d9bd0fc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 8:
#                                                Jawaban  \
# No
# 1    Airnya bersih, Airnya tidak mengandung karpori...
# 2    1. Tidak bocor 2. Sirkulasi air dan sistem fil...
# 3                      kebersihan,keindahan,kedalaman
# 4    1. Air yang digunakan tidak menggandung kapur....
# 5                            tidak bau , bisa diminum
#
#                                        Jawaban Stemmed
# No
# 1    [air, bersih, air, kandung, karporit, dalam, s...
# 2    [1, bocor, 2, sirkulasi, air, sistem, filteras...
# 3                       [kebersihankeindahankedalaman]
# 4    [1, air, gandung, kapur, 2, bersih, kolam, ren...
# 5                                         [bau, minum]
# <ipython-input-20-9da03d9bd0fc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-9da03d9bd0fc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Lowercase'] = df['Jawaban'].apply(lambda x: x.lower())
# <ipython-input-20-9da03d9bd0fc>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban tanpa Punctuation'] =     df['Jawaban Lowercase'].apply(lambda x: re.sub(punctuation, '', x))
# <ipython-input-20-9da03d9bd0fc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tokenization'] = df['Jawaban tanpa Punctuation'].apply(nltk.word_tokenize)
# <ipython-input-20-9da03d9bd0fc>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword'] = df['Jawaban Tokenization'].apply(lambda x: [word for word in x if word not in stop_words])
# <ipython-input-20-9da03d9bd0fc>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Stopword Not Tokenization'] = df['Jawaban Tanpa Stopword'].apply(lambda x: remove_stopword(x))
# <ipython-input-20-9da03d9bd0fc>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi'] = df['Jawaban Tanpa Stopword'].apply(lambda x: hapus_kata_negasi(x))
# <ipython-input-20-9da03d9bd0fc>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Tanpa Negasi Not Token'] = df['Jawaban Tanpa Negasi'].apply(lambda x: remove_stopword(x))
# Soal: 9:
#                                                Jawaban  \
# No
# 1    Tunggal putra, tunggal putri, ganda putra, gan...
# 2    -ganda putra, -ganda putri, -ganda campuran, -...
# 3    ganda putra/putri, ganda campuran,single putra...
# 4    1. Tunggal Putra. 2. Tunggal Putri. 3. Ganda P...
# 5                                   gerindra , hanura
#
#                                        Jawaban Stemmed
# No
# 1    [tunggal, putra, tunggal, putri, ganda, putra,...
# 2    [ganda, putra, ganda, putri, ganda, campur, si...
# 3    [ganda, putraputri, ganda, campuransingle, put...
# 4    [1, tunggal, putra, 2, tunggal, putri, 3, gand...
# 5                                   [gerindra, hanura]
# Soal: 10:
#                                                Jawaban  \
# No
# 1    Parkour adalah seni bergerak dan metode latiha...
# 2    Parkour adalah aktivitas yang bertujuan untuk ...
# 3    keindahan dan kelenturan dalam melewati rintan...
# 4    Parkour adalah aktivitas yang bertujuan untuk ...
# 5                             loncat loncat di gedung
#
#                                        Jawaban Stemmed
# No
# 1    [parkour, seni, gerak, metode, latih, natural,...
# 2    [parkour, aktivitas, tuju, pindah, efisien, se...
# 3    [indah, lentur, lewat, rintang, pakai, gedung,...
# 4    [parkour, aktivitas, tuju, pindah, efisien, se...
# 5                             [loncat, loncat, gedung]
# <ipython-input-20-9da03d9bd0fc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed'] = df['Jawaban Tanpa Negasi'].apply(lambda x: [stemmer.stem(token) for token in x])
# <ipython-input-20-9da03d9bd0fc>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jawaban Stemmed Not Token'] = df['Jawaban Stemmed'].apply(lambda x: remove_stopword(x))

# %%
list_df_olahraga[0]
# Out:
#                                                Jawaban  Manual 1  Manual 2  \
# No
# 1    - Menyehatkan tubuh - Memperkuat otot-otot - M...      40.0      50.0
# 2    1. Meringankan Kerja Jantung. 2. Melancarkan A...      15.0      20.0
# 3    refresing, kesehatan otot, syaraf-syaraf mejad...      28.0      15.0
# 4    1. Menjaga kondisi fisik tetap prima. 2. Mengh...      35.0      25.0
# 5                                               sehat        9.0       0.0
# 6    Membantu mengontrol berat badan, Meningkatkan ...      38.0      32.0
# 7    untuk memperlancar sistem peredaran darah, mem...      48.0      35.0
# 8    Manfaat olahraga untuk kesehatan tubuh kita me...      28.0      15.0
# 9    Melancarkan Aliran Darah Meningkatkan Pertumbu...      25.0      15.0
# 10   1. Berolahraga akan Meningkatkan Kapasitas Ota...      33.0      20.0
# 11   menjaga kesehatan tulang, menurunkan berat bad...      38.0      23.0
# 12   menjaga metabolisme tubuh,menambah daya ingat ...      22.0      10.0
# 13   Menyehatkan jantung,,merampingkan tubuh,mambak...      27.0      15.0
# 14   membuat otot tubuh menjadi rilex, membuat tubu...      38.0      25.0
# 15   1. Untuk menyehatkan badan 2. Supaya terhindar...      47.0      55.0
# 16   untuk menyegarkan pikiran , organ tubuh menjad...      45.0      45.0
# 17   menjaga kesehatan, menambah daya tahan tubuh, ...      58.0      65.0
# 18   -Membuat suasana hati menjadi senang. -Membaka...      43.0      50.0
# 19   Meringankan Kerja Jantung, Melancarkan Aliran ...      15.0      10.0
# 20   dapat membantu meningkatkat kecerdasan otak, d...      38.0      22.0
# 21   1. menjadikan badan kembali bugar 2. pikiran m...      40.0      40.0
# 22   1. untuk menyegargan badan dan pikiran 2. meny...      55.0      48.0
# 23   membantu mengontrol berat badan. membantu meni...      38.0      46.0
# 24   Berolahraga akan Meningkatkan Kapasitas Otak A...      60.0      65.0
# 25   -Membantu mengontrol berat badan -Mencegah ber...      38.0      40.0
# 26   -untuk menyegarkan pikiran -untuk melepas stre...      45.0      40.0
# 27   Lima manfaat olahraga bagi tubuh adalah yakni,...      30.0      35.0
# 28   Sebutkan 5 manfaat olahraga bagi tubuh. (Terma...      25.0       0.0
# 29   pikiran menjadi fresh, otot terlatih dengan ba...      30.0      15.0
# 30   Segar, Sehat, Bugar, Bertenaga, Tidak mudah le...      20.0       7.0
# 31   -meningkatkan pembentukan otot tubuh. -menjadi...      38.0      30.0
# 32   - Menyehatkan tubuh - mengisi waktu luang - me...      35.0      28.0
# 33   - merefresh pikiran - menambah stamina kita - ...      44.0      30.0
# 34   - Membakar kolesterol - menguatkan otot - meny...      55.0      60.0
# 35   -Sebagai anti struk -agar tubuh sehat -agar fi...      19.0      10.0
# 36   - meningkatkan daya tahan tubuh - meningkatkan...      70.0      60.0
# 37   - Menggerakkan tubuh Membantu Mencairkan stres...      50.0      50.0
# 38   -memfokuskan pikiran -Membentuk otot agar sema...      35.0      30.0
# 39   - Berolahraga akan meningkatkan Kapasitas otak...      40.0      30.0
# 40   membantu meningkatan kecerdasaan otak,membantu...      46.0      42.0
# 41   - Membuat tubuh yang lebih sehat - memiliki da...      56.0      50.0
# 42   - Menyehatkan jantung - Membuat Metabolisme tu...      38.0      30.0
# 43   -Menyehatkan jantung -Membuat Metabolisme tubu...      30.0      45.0
# 44   membuat suasan hati menjadi senang, menyehatka...      25.0      37.0
# 45   -menjadi lebih sehat -terhindah dari penyakit ...      30.0      30.0
# 46   Menyehatkan badan, menyegarkan fikiran, melent...      38.0      34.0
# 47   menyegarkan kita dalam berfikir, menyehatkan b...      34.0      40.0
# 48   -Membantu mengontrol berat badan -Olahraga Mem...      40.0      45.0
# 49   - agar tubuh sehat - otot tidak tegang - saraf...      20.0      18.0
# 50   menyehatkan tubuh , menguatkan otot tubuh , me...      42.0      30.0
# 51   merefresh pikiran. melancarkan pernafasan. men...      18.0      15.0
# 52   menyegarkan, menyehatkan, agar sehat dan bugar...      22.0      20.0
# 53   Menyegarkan pikiran menyegarkan otot relaksasi...      42.0      37.0
# 54   membantu encerdaskan otak. memelihara kekebala...      50.0      45.0
# 55   1. menambah kebugaran 2. kesehatan 3. membentu...      39.0      45.0
# 56   -sehat -tidak gampang lelah -tidak gampang sak...      33.0      20.0
#
#      Manual 3  Rata Manual                                  Jawaban Lowercase  \
# No
# 1        50.0    46.666667  - menyehatkan tubuh - memperkuat otot-otot - m...
# 2        25.0    20.000000  1. meringankan kerja jantung. 2. melancarkan a...
# 3        25.0    22.666667  refresing, kesehatan otot, syaraf-syaraf mejad...
# 4        25.0    28.333333  1. menjaga kondisi fisik tetap prima. 2. mengh...
# 5        10.0     6.333333                                             sehat
# 6        25.0    31.666667  membantu mengontrol berat badan, meningkatkan ...
# 7        50.0    44.333333  untuk memperlancar sistem peredaran darah, mem...
# 8        25.0    22.666667  manfaat olahraga untuk kesehatan tubuh kita me...
# 9        25.0    21.666667  melancarkan aliran darah meningkatkan pertumbu...
# 10       25.0    26.000000  1. berolahraga akan meningkatkan kapasitas ota...
# 11       25.0    28.666667  menjaga kesehatan tulang, menurunkan berat bad...
# 12       25.0    19.000000  menjaga metabolisme tubuh,menambah daya ingat ...
# 13       25.0    22.333333  menyehatkan jantung,,merampingkan tubuh,mambak...
# 14       25.0    29.333333  membuat otot tubuh menjadi rilex, membuat tubu...
# 15       50.0    50.666667  1. untuk menyehatkan badan 2. supaya terhindar...
# 16       50.0    46.666667  untuk menyegarkan pikiran , organ tubuh menjad...
# 17       75.0    66.000000  menjaga kesehatan, menambah daya tahan tubuh, ...
# 18       50.0    47.666667  -membuat suasana hati menjadi senang. -membaka...
# 19       10.0    11.666667  meringankan kerja jantung, melancarkan aliran ...
# 20       25.0    28.333333  dapat membantu meningkatkat kecerdasan otak, d...
# 21       50.0    43.333333  1. menjadikan badan kembali bugar 2. pikiran m...
# 22       50.0    51.000000  1. untuk menyegargan badan dan pikiran 2. meny...
# 23       50.0    44.666667  membantu mengontrol berat badan. membantu meni...
# 24       75.0    66.666667  berolahraga akan meningkatkan kapasitas otak a...
# 25       50.0    42.666667  -membantu mengontrol berat badan -mencegah ber...
# 26       50.0    45.000000  -untuk menyegarkan pikiran -untuk melepas stre...
# 27       25.0    30.000000  lima manfaat olahraga bagi tubuh adalah yakni,...
# 28        0.0     8.333333  sebutkan 5 manfaat olahraga bagi tubuh. (terma...
# 29       25.0    23.333333  pikiran menjadi fresh, otot terlatih dengan ba...
# 30       10.0    12.333333  segar, sehat, bugar, bertenaga, tidak mudah le...
# 31       25.0    31.000000  -meningkatkan pembentukan otot tubuh. -menjadi...
# 32       25.0    29.333333  - menyehatkan tubuh - mengisi waktu luang - me...
# 33       50.0    41.333333  - merefresh pikiran - menambah stamina kita - ...
# 34       50.0    55.000000  - membakar kolesterol - menguatkan otot - meny...
# 35       10.0    13.000000  -sebagai anti struk -agar tubuh sehat -agar fi...
# 36       75.0    68.333333  - meningkatkan daya tahan tubuh - meningkatkan...
# 37       50.0    50.000000  - menggerakkan tubuh membantu mencairkan stres...
# 38       25.0    30.000000  -memfokuskan pikiran -membentuk otot agar sema...
# 39       50.0    40.000000  - berolahraga akan meningkatkan kapasitas otak...
# 40       50.0    46.000000  membantu meningkatan kecerdasaan otak,membantu...
# 41       50.0    52.000000  - membuat tubuh yang lebih sehat - memiliki da...
# 42       25.0    31.000000  - menyehatkan jantung - membuat metabolisme tu...
# 43       50.0    41.666667  -menyehatkan jantung -membuat metabolisme tubu...
# 44       25.0    29.000000  membuat suasan hati menjadi senang, menyehatka...
# 45       25.0    28.333333  -menjadi lebih sehat -terhindah dari penyakit ...
# 46       25.0    32.333333  menyehatkan badan, menyegarkan fikiran, melent...
# 47       25.0    33.000000  menyegarkan kita dalam berfikir, menyehatkan b...
# 48       50.0    45.000000  -membantu mengontrol berat badan -olahraga mem...
# 49       25.0    21.000000  - agar tubuh sehat - otot tidak tegang - saraf...
# 50       50.0    40.666667  menyehatkan tubuh , menguatkan otot tubuh , me...
# 51       25.0    19.333333  merefresh pikiran. melancarkan pernafasan. men...
# 52       25.0    22.333333  menyegarkan, menyehatkan, agar sehat dan bugar...
# 53       50.0    43.000000  menyegarkan pikiran menyegarkan otot relaksasi...
# 54       50.0    48.333333  membantu encerdaskan otak. memelihara kekebala...
# 55       50.0    44.666667  1. menambah kebugaran 2. kesehatan 3. membentu...
# 56       25.0    26.000000  -sehat -tidak gampang lelah -tidak gampang sak...
#
#                              Jawaban tanpa Punctuation  \
# No
# 1     menyehatkan tubuh  memperkuat otototot  menje...
# 2    1 meringankan kerja jantung 2 melancarkan alir...
# 3    refresing kesehatan otot syarafsyaraf mejadi s...
# 4    1 menjaga kondisi fisik tetap prima 2 menghila...
# 5                                               sehat
# 6    membantu mengontrol berat badan meningkatkan e...
# 7    untuk memperlancar sistem peredaran darah memb...
# 8    manfaat olahraga untuk kesehatan tubuh kita me...
# 9    melancarkan aliran darah meningkatkan pertumbu...
# 10   1 berolahraga akan meningkatkan kapasitas otak...
# 11   menjaga kesehatan tulang menurunkan berat bada...
# 12   menjaga metabolisme tubuhmenambah daya ingat o...
# 13   menyehatkan jantungmerampingkan tubuhmambakar ...
# 14   membuat otot tubuh menjadi rilex membuat tubuh...
# 15   1 untuk menyehatkan badan 2 supaya terhindar d...
# 16   untuk menyegarkan pikiran  organ tubuh menjadi...
# 15   [1, untuk, menyehatkan, badan, 2, supaya, terh...
# 16   [untuk, menyegarkan, pikiran, organ, tubuh, me...
# 17   [menjaga, kesehatan, menambah, daya, tahan, tu...
# 18   [membuat, suasana, hati, menjadi, senang, memb...
# 19   [meringankan, kerja, jantung, melancarkan, ali...
# 20   [dapat, membantu, meningkatkat, kecerdasan, ot...
# 21   [1, menjadikan, badan, kembali, bugar, 2, piki...
# 22   [1, untuk, menyegargan, badan, dan, pikiran, 2...
# 23   [membantu, mengontrol, berat, badan, membantu,...
# 24   [berolahraga, akan, meningkatkan, kapasitas, o...
# 25   [membantu, mengontrol, berat, badan, mencegah,...
# 26   [untuk, menyegarkan, pikiran, untuk, melepas, ...
# 27   [lima, manfaat, olahraga, bagi, tubuh, adalah,...
# 28   [sebutkan, 5, manfaat, olahraga, bagi, tubuh, ...
# 29   [pikiran, menjadi, fresh, otot, terlatih, deng...
# 30   [segar, sehat, bugar, bertenaga, tidak, mudah,...
# 31   [meningkatkan, pembentukan, otot, tubuh, menja...
# 32   [menyehatkan, tubuh, mengisi, waktu, luang, me...
# 33   [merefresh, pikiran, menambah, stamina, kita, ...
# 34   [membakar, kolesterol, menguatkan, otot, menye...
# 35   [sebagai, anti, struk, agar, tubuh, sehat, aga...
# 36   [meningkatkan, daya, tahan, tubuh, meningkatka...
# 37   [menggerakkan, tubuh, membantu, mencairkan, st...
# 38   [memfokuskan, pikiran, membentuk, otot, agar, ...
# 39   [berolahraga, akan, meningkatkan, kapasitas, o...
# 40   [membantu, meningkatan, kecerdasaan, otakmemba...
# 41   [membuat, tubuh, yang, lebih, sehat, memiliki,...
# 42   [menyehatkan, jantung, membuat, metabolisme, t...
# 43   [menyehatkan, jantung, membuat, metabolisme, t...
# 44   [membuat, suasan, hati, menjadi, senang, menye...
# 45   [menjadi, lebih, sehat, terhindah, dari, penya...
# 46   [menyehatkan, badan, menyegarkan, fikiran, mel...
# 47   [menyegarkan, kita, dalam, berfikir, menyehatk...
# 48   [membantu, mengontrol, berat, badan, olahraga,...
# 49   [agar, tubuh, sehat, otot, tidak, tegang, sara...
# 50   [menyehatkan, tubuh, menguatkan, otot, tubuh, ...
# 51   [merefresh, pikiran, melancarkan, pernafasan, ...
# 52   [menyegarkan, menyehatkan, agar, sehat, dan, b...
# 53   [menyegarkan, pikiran, menyegarkan, otot, rela...
# 54   [membantu, encerdaskan, otak, memelihara, keke...
# 55   [1, menambah, kebugaran, 2, kesehatan, 3, memb...
# 56   [sehat, tidak, gampang, lelah, tidak, gampang,...
#
#                                 Jawaban Tanpa Stopword  \
# No
# 1    [menyehatkan, tubuh, memperkuat, otototot, men...
# 2    [1, meringankan, kerja, jantung, 2, melancarka...
# 3    [refresing, kesehatan, otot, syarafsyaraf, mej...
# 4    [1, menjaga, kondisi, fisik, prima, 2, menghil...
# 5                                              [sehat]
# 6    [membantu, mengontrol, berat, badan, meningkat...
# 7    [memperlancar, sistem, peredaran, darah, energ...
# 8    [manfaat, olahraga, kesehatan, tubuh, terbukti...
# 9    [melancarkan, aliran, darah, meningkatkan, per...
# 3    [refresing, kesehatan, otot, syarafsyaraf, mej...
# 4    [1, menjaga, kondisi, fisik, prima, 2, menghil...
# 5                                              [sehat]
# 6    [membantu, mengontrol, berat, badan, meningkat...
# 7    [memperlancar, sistem, peredaran, darah, energ...
# 8    [manfaat, olahraga, kesehatan, tubuh, terbukti...
# 9    [melancarkan, aliran, darah, meningkatkan, per...
# 10   [1, berolahraga, meningkatkan, kapasitas, otak...
# 11   [menjaga, kesehatan, tulang, menurunkan, berat...
# 12   [menjaga, metabolisme, tubuhmenambah, daya, ot...
# 13   [menyehatkan, jantungmerampingkan, tubuhmambak...
# 14   [otot, tubuh, rilex, tubuh, sehat, otak, bersi...
# 15   [1, menyehatkan, badan, 2, terhindar, penyakit...
# 16   [menyegarkan, pikiran, organ, tubuh, sehat, ot...
# 17   [menjaga, kesehatan, menambah, daya, tahan, tu...
# 18   [suasana, hati, senang, membakar, kalori, meny...
# 19   [meringankan, kerja, jantung, melancarkan, ali...
# 20   [membantu, meningkatkat, kecerdasan, otak, mem...
# 21   [1, menjadikan, badan, bugar, 2, pikiran, fres...
# 22   [1, menyegargan, badan, pikiran, 2, menyehatka...
# 23   [membantu, mengontrol, berat, badan, membantu,...
# 24   [berolahraga, meningkatkan, kapasitas, otak, m...
# 25   [membantu, mengontrol, berat, badan, mencegah,...
# 26   [menyegarkan, pikiran, melepas, stress, lingku...
# 27   [manfaat, olahraga, tubuh, menjadikan, tubuh, ...
# 28   [sebutkan, 5, manfaat, olahraga, tubuh, pikira...
# 29   [pikiran, fresh, otot, terlatih, otot, kuat, b...
# 30      [segar, sehat, bugar, bertenaga, mudah, lemas]
# 31   [meningkatkan, pembentukan, otot, tubuh, menja...
# 32   [menyehatkan, tubuh, mengisi, luang, mebuat, p...
# 33   [merefresh, pikiran, menambah, stamina, merega...
# 34   [membakar, kolesterol, menguatkan, otot, menye...
# 35         [anti, struk, tubuh, sehat, fikiran, fresh]
# 36   [meningkatkan, daya, tahan, tubuh, meningkatka...
# 37   [menggerakkan, tubuh, membantu, mencairkan, st...
# 38   [memfokuskan, pikiran, membentuk, otot, kencan...
# 39   [berolahraga, meningkatkan, kapasitas, otak, m...
# 40   [membantu, meningkatan, kecerdasaan, otakmemba...
# 41   [tubuh, sehat, memiliki, daya, tahan, tubuh, j...
# 42   [menyehatkan, jantung, metabolisme, tubuh, men...
# 43   [menyehatkan, jantung, metabolisme, tubuh, men...
# 44   [suasan, hati, senang, menyehatkan, jantung, m...
# 45   [sehat, terhindah, penyakit, pikiran, jernih, ...
# 46   [menyehatkan, badan, menyegarkan, fikiran, mel...
# 47   [menyegarkan, berfikir, menyehatkan, badan, me...
# 48   [membantu, mengontrol, berat, badan, olahraga,...
# 49   [tubuh, sehat, otot, tegang, saraf, otak, biar...
# 50   [menyehatkan, tubuh, menguatkan, otot, tubuh, ...
# 51   [merefresh, pikiran, melancarkan, pernafasan, ...
# 52   [menyegarkan, menyehatkan, sehat, bugar, meref...
# 53   [menyegarkan, pikiran, menyegarkan, otot, rela...
# 53   menyegarkan pikiran menyegarkan otot relaksasi...
# 54   membantu encerdaskan otak memelihara kekebalan...
# 55   1 menambah kebugaran 2 kesehatan 3 membentuk o...
# 56   sehat gampang lelah gampang sakit kesehatan pi...
#
#                                        Jawaban Stemmed  \
# No
# 1    [sehat, tubuh, kuat, otototot, jernih, pikir, ...
# 2    [1, ringan, kerja, jantung, 2, lancar, alir, d...
# 3    [refresing, sehat, otot, syarafsyaraf, mejadi,...
# 4    [1, jaga, kondisi, fisik, prima, 2, hilang, st...
# 5                                              [sehat]
# 6    [bantu, kontrol, berat, badan, tingkat, energi...
# 7    [lancar, sistem, edar, darah, energi, tubuh, h...
# 8    [manfaat, olahraga, sehat, tubuh, bukti, latih...
# 9    [lancar, alir, darah, tingkat, tumbuh, tulang,...
# 10   [1, olahraga, tingkat, kapasitas, otak, 2, ger...
# 11   [jaga, sehat, tulang, turun, berat, badan, men...
# 12   [jaga, metabolisme, tubuhmenambah, daya, otakm...
# 13   [sehat, jantungmerampingkan, tubuhmambakar, le...
# 14   [otot, tubuh, rilex, tubuh, sehat, otak, siner...
# 15   [1, sehat, badan, 2, hindar, sakit, 3, badan, ...
# 16   [segar, pikir, organ, tubuh, sehat, otot, kuat...
# 17   [jaga, sehat, tambah, daya, tahan, tubuh, baik...
# 18   [suasana, hati, senang, bakar, kalori, sehat, ...
# 19   [ringan, kerja, jantung, lancar, alir, darah, ...
# 20   [bantu, meningkatkat, cerdas, otak, bantu, pel...
# 21   [1, jadi, badan, bugar, 2, pikir, fresh, 3, ot...
# 22   [1, menyegargan, badan, pikir, 2, sehat, tubuh...
# 23   [bantu, kontrol, berat, badan, bantu, tingkat,...
# 24   [olahraga, tingkat, kapasitas, otak, gerak, tu...
# 25   [bantu, kontrol, berat, badan, cegah, sakit, b...
# 26   [segar, pikir, lepas, stress, lingkung, kerja,...
# 27   [manfaat, olahraga, tubuh, jadi, tubuh, badan,...
# 28   [sebut, 5, manfaat, olahraga, tubuh, pikir, ot...
# 29   [pikir, fresh, otot, latih, otot, kuat, badan,...
# 30         [segar, sehat, bugar, tenaga, mudah, lemas]
# 31   [tingkat, bentuk, otot, tubuh, jadi, kulit, se...
# 32   [sehat, tubuh, isi, luang, mebuat, pikir, sega...
# 33   [merefresh, pikir, tambah, stamina, regang, ot...
# 34   [bakar, kolesterol, kuat, otot, segar, badan, ...
# 35         [anti, struk, tubuh, sehat, fikiran, fresh]
# 36   [tingkat, daya, tahan, tubuh, tingkat, mampu, ...
# 37   [gerak, tubuh, bantu, cair, stres, olahraga, t...
# 38   [fokus, pikir, bentuk, otot, kencang, organ, l...
# 39   [olahraga, tingkat, kapasitas, otak, gerak, tu...
# 40   [bantu, tingkat, kecerdasaan, otakmembantu, pe...
# 41   [tubuh, sehat, milik, daya, tahan, tubuh, jant...
# 42   [sehat, jantung, metabolisme, tubuh, tingkat, ...
# 43   [sehat, jantung, metabolisme, tubuh, tingkat, ...
# 44   [suasan, hati, senang, sehat, jantung, jaga, m...
# 45   [sehat, terhindah, sakit, pikir, jernih, teman...
# 42   sehat jantung metabolisme tubuh tingkat normal...
# 43   sehat jantung metabolisme tubuh tingkat rampin...
# 44   suasan hati senang sehat jantung jaga metaboli...
# 45   sehat terhindah sakit pikir jernih teman otot ...
# 46   sehat badan segar fikiran lentur otot segar or...
# 47   segar berfikir sehat badan latih otot tubuh ot...
# 48   bantu kontrol berat badan olahraga bantu tingk...
# 49   tubuh sehat otot tegang saraf otak biar edar d...
# 50   sehat tubuh kuat otot tubuh segar pikir tubuh ...
# 51   merefresh pikir lancar nafas jaga sirkulasi da...
# 52       segar sehat sehat bugar merefresh otak stabil
# 53   segar pikir segar otot relaksasi otot sehat or...
# 54   bantu encerdaskan otak pelihara kebal tubuh ba...
# 55   1 tambah bugar 2 sehat 3 bentuk otot 4 jernih ...
# 56   sehat gampang lelah gampang sakit sehat pikir ...

# %%
# Convert ke dataset
for i, df in enumerate(list_df_olahraga):
    df[['Jawaban Lowercase', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']].to_csv(f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Lower Case/Olahraga/Soal_LC_Olahraga_{i+1}.csv', index=False)

# %%
# Convert ke dataset
for i, df in enumerate(list_df_olahraga):
    df[['Jawaban tanpa Punctuation', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']].to_csv(f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Remove Punctuation/Olahraga/Soal_RP_Olahraga_{i+1}.csv', index=False)

# %%
# Convert ke dataset
for i, df in enumerate(list_df_olahraga):
    df[['Jawaban Tanpa Stopword Not Tokenization', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']].to_csv(f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Stopword Remove/Olahraga/Soal_SW_Olahraga_{i+1}.csv', index=False)

# %%
# Convert ke dataset
for i, df in enumerate(list_df_olahraga):
    df[['Jawaban Tanpa Negasi Not Token', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']].to_csv(f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Convert Negation/Olahraga/Soal_CV_Olahraga_{i+1}.csv', index=False)

# %%
# Convert ke dataset
for i, df in enumerate(list_df_olahraga):
    df[['Jawaban Tanpa Negasi Not Token', 'Manual 1', 'Manual 2', 'Manual 3', 'Rata Manual']].to_csv(f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Stemming/Olahraga/Soal_Stemm_Olahraga_{i+1}.csv', index=False)

# %%
pip install nlp_id
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nlp_id in /usr/local/lib/python3.9/dist-packages (0.1.13.0)
# Requirement already satisfied: wget==3.2 in /usr/local/lib/python3.9/dist-packages (from nlp_id) (3.2)
# Requirement already satisfied: scikit-learn==1.1.0 in /usr/local/lib/python3.9/dist-packages (from nlp_id) (1.1.0)
# Requirement already satisfied: nltk==3.4.5 in /usr/local/lib/python3.9/dist-packages (from nlp_id) (3.4.5)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from nltk==3.4.5->nlp_id) (1.16.0)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.0->nlp_id) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.0->nlp_id) (1.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.0->nlp_id) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.1.0->nlp_id) (3.1.0)

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.3-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 25.2 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 26.9 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 62.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.3 tokenizers-0.13.2 transformers-4.27.3

# %%
import re
import random
import pandas as pd
import torch
import tensorflow as tf
import numpy as np

from nlp_id.lemmatizer import Lemmatizer
from nltk.corpus import stopwords
from tqdm import tqdm
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.metrics import f1_score, cohen_kappa_score
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Dense
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import AdamW, get_linear_schedule_with_warmup
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from nltk.corpus import stopwords

# %%
seed_val = 17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def qwk_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return cohen_kappa_score(labels_flat, preds_flat)

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in label_dict.items()}

    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

def evaluate(dataloader_val, device, model):

    model.eval()

    loss_val_total = 0
    predictions, true_vals = [], []

    for batch in dataloader_val:

        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():
            outputs = model(**inputs)

        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)

    loss_val_avg = loss_val_total/len(dataloader_val)

    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)

    return loss_val_avg, predictions, true_vals

def train_eval(df_final, pretrainedmodel):
    # bin nilai (continuous variable) into intervals
    df_final['nilai'] = pd.qcut(df_final['nilai'], 5, labels=False)


    # make sure that the training set and test set ratio is 80:20
    add = len(df_final[df_final['tipe'] == 'test']) - (round(0.15*(len(df_final[df_final['tipe'] == 'train'])+len(df_final[df_final['tipe'] == 'test']))))
    for i in df_final[df_final['tipe'] == 'test'].sample(n = add).itertuples():
        df_final.at[i.Index, 'tipe'] = 'train'

    # load model and tokenizer
    tokenizer = BertTokenizer.from_pretrained(pretrainedmodel, ignore_mismatched_sizes=True)

    encoded_data_train = tokenizer.batch_encode_plus(
        df_final[df_final.tipe=='train']['jawaban'].values,
        add_special_tokens=True,
        return_attention_mask=True,
        pad_to_max_length=True,
        truncation=True,
        max_length=256,
        padding='max_length',
        return_tensors='pt'
    )

    encoded_data_val = tokenizer.batch_encode_plus(
        df_final[df_final.tipe=='test']['jawaban'].values,
        add_special_tokens=True,
        return_attention_mask=True,
        pad_to_max_length=True,
        truncation=True,
        max_length=256,
        padding='max_length',
        return_tensors='pt'
    )

    input_ids_train = encoded_data_train['input_ids']
    attention_masks_train = encoded_data_train['attention_mask']
    labels_train = torch.tensor(df_final[df_final.tipe=='train'].nilai.values)

    input_ids_val = encoded_data_val['input_ids']
    attention_masks_val = encoded_data_val['attention_mask']
    labels_val = torch.tensor(df_final[df_final.tipe=='test'].nilai.values)

    dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
    dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)

    model = BertForSequenceClassification.from_pretrained(pretrainedmodel,
                                                          num_labels=5,
                                                          output_attentions=False,
                                                          output_hidden_states=False, ignore_mismatched_sizes=True)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)

    batch_size = 4

    dataloader_train = DataLoader(dataset_train,
                                  sampler=RandomSampler(dataset_train),
                                  batch_size=batch_size)

    dataloader_validation = DataLoader(dataset_val,
                                       sampler=SequentialSampler(dataset_val),
                                       batch_size=batch_size)

    optimizer = torch.optim.AdamW(model.parameters(),
                      lr=2e-5,
                      eps=1e-8)

    epochs = 4

    scheduler = get_linear_schedule_with_warmup(optimizer,
                                                num_warmup_steps=0,
                                                num_training_steps=len(dataloader_train)*epochs)

    for epoch in tqdm(range(1, epochs+1)):

        model.train()

        loss_train_total = 0

        progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
        for batch in progress_bar:

            model.zero_grad()

            batch = tuple(b.to(device) for b in batch)

            inputs = {'input_ids':      batch[0],
                      'attention_mask': batch[1],
                      'labels':         batch[2],
                     }

            outputs = model(**inputs)

            loss = outputs[0]
            loss_train_total += loss.item()
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

            optimizer.step()
            scheduler.step()

            progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})


        torch.save(model.state_dict(), f'/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/finetuned_BERT_{df_final["path"]}_epoch_{epoch}.model')

        tqdm.write(f'\nEpoch {epoch}')

        loss_train_avg = loss_train_total/len(dataloader_train)
        tqdm.write(f'Training loss: {loss_train_avg}')

        val_loss, predictions, true_vals = evaluate(dataloader_validation, device, model)
        val_f1 = f1_score_func(predictions, true_vals)
        val_qwk = qwk_score_func(predictions, true_vals)
        tqdm.write(f'Validation loss: {val_loss}')
        tqdm.write(f'F1 Score (Weighted): {val_f1}')
        tqdm.write(f'QWK Score: {val_qwk}')

# %%
def asag_systems(path_dir):
    list_pre_trained_model = ['indobenchmark/indobert-lite-base-p2']
    list_dir = os.listdir(path_dir)
    for m in list_pre_trained_model:
        print(m)
        for idx, ele in enumerate(list_dir):
            df_raw = pd.read_csv(path_dir + '/' +ele)
            
            df_raw = df_raw
            list_final = []
    
            for i in df_raw.itertuples():
                list_final.append(
                    {
                        'jawaban': i[1],
                        'nilai': 100,
                        'tipe': 'train',
                        'path': f'{path_dir} {ele}',
                    }
                )
                df_tmp =  pd.read_csv(path_dir + '/' +ele)
                
                df_tmp = df_tmp.dropna()
                for j in df_tmp.itertuples():
                    list_final.append(
                        {
                            'jawaban': j[1],
                            'nilai': j[5],
                            'tipe': 'test',
                            'path': f'{path_dir} {ele}',
                        }
                    )
            if idx == 0:
                df_final = pd.DataFrame(list_final)
            else:
                df_final.append(pd.DataFrame(list_final), ignore_index=True)
    
            train_eval(df_final, m)

# %%
asag_systems('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Lower Case/Teknologi')
# Out:
# indobenchmark/indobert-lite-base-p2
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/225k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.54k [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'AlbertTokenizerFast'.
# The class this function is called from is 'BertTokenizer'.
# You are using a model of type albert to instantiate a model of type bert. This is not supported for all configurations of models and can yield errors.
# Downloading pytorch_model.bin:   0%|          | 0.00/46.7M [00:00<?, ?B/s]
# Some weights of the model checkpoint at indobenchmark/indobert-lite-base-p2 were not used when initializing BertForSequenceClassification: ['encoder.albert_layer_groups.0.albert_layers.0.attention.query.bias', 'encoder.embedding_hidden_mapping_in.weight', 'encoder.albert_layer_groups.0.albert_layers.0.attention.value.weight', 'encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.weight', 'encoder.albert_layer_groups.0.albert_layers.0.ffn_output.weight', 'encoder.albert_layer_groups.0.albert_layers.0.attention.key.bias', 'pooler.weight', 'encoder.albert_layer_groups.0.albert_layers.0.attention.dense.weight', 'encoder.albert_layer_groups.0.albert_layers.0.ffn_output.bias', 'encoder.albert_layer_groups.0.albert_layers.0.attention.query.weight', 'encoder.albert_layer_groups.0.albert_layers.0.ffn.weight', 'encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.bias', 'encoder.embedding_hidden_mapping_in.bias', 'encoder.albert_layer_groups.0.albert_layers.0.attention.dense.bias', 'encoder.albert_layer_groups.0.albert_layers.0.attention.key.weight', 'encoder.albert_layer_groups.0.albert_layers.0.attention.LayerNorm.weight', 'encoder.albert_layer_groups.0.albert_layers.0.ffn.bias', 'encoder.albert_layer_groups.0.albert_layers.0.full_layer_layer_norm.bias', 'encoder.albert_layer_groups.0.albert_layers.0.attention.value.bias', 'pooler.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-lite-base-p2 and are newly initialized: ['encoder.layer.10.attention.output.LayerNorm.bias', 'encoder.layer.11.attention.self.query.bias', 'encoder.layer.1.attention.output.LayerNorm.bias', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.11.attention.self.query.weight', 'encoder.layer.5.intermediate.dense.bias', 'encoder.layer.3.intermediate.dense.bias', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.2.attention.self.query.weight', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.5.attention.output.LayerNorm.weight', 'classifier.weight', 'encoder.layer.0.output.dense.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.2.attention.output.dense.weight', 'encoder.layer.4.output.LayerNorm.weight', 'encoder.layer.10.output.dense.weight', 'encoder.layer.10.output.LayerNorm.bias', 'encoder.layer.8.attention.output.dense.weight', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.4.attention.self.key.bias', 'encoder.layer.11.output.LayerNorm.weight', 'encoder.layer.5.attention.self.value.weight', 'encoder.layer.6.attention.output.LayerNorm.weight', 'encoder.layer.6.output.dense.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.8.attention.self.query.bias', 'encoder.layer.4.attention.self.key.weight', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.2.attention.self.value.bias', 'encoder.layer.2.attention.self.value.weight', 'encoder.layer.11.attention.output.dense.bias', 'encoder.layer.7.attention.self.key.weight', 'encoder.layer.10.attention.self.query.bias', 'encoder.layer.5.output.dense.bias', 'encoder.layer.9.attention.self.value.bias', 'encoder.layer.8.output.LayerNorm.weight', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.7.attention.output.LayerNorm.bias', 'encoder.layer.8.attention.output.LayerNorm.weight', 'encoder.layer.4.attention.output.dense.weight', 'encoder.layer.0.attention.output.LayerNorm.bias', 'encoder.layer.10.attention.output.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.9.attention.output.LayerNorm.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.9.attention.self.query.weight', 'encoder.layer.4.output.dense.weight', 'encoder.layer.11.output.dense.weight', 'encoder.layer.4.attention.output.LayerNorm.weight', 'encoder.layer.3.output.LayerNorm.bias', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.5.attention.self.value.bias', 'encoder.layer.5.output.dense.weight', 'encoder.layer.7.attention.output.LayerNorm.weight', 'encoder.layer.8.attention.self.query.weight', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.1.output.LayerNorm.weight', 'classifier.bias', 'encoder.layer.9.attention.output.LayerNorm.weight', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.6.attention.self.query.bias', 'encoder.layer.8.intermediate.dense.weight', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.10.attention.output.dense.weight', 'encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.layer.4.intermediate.dense.weight', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.10.attention.self.query.weight', 'encoder.layer.6.attention.self.value.weight', 'encoder.layer.3.attention.output.LayerNorm.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.9.attention.self.key.weight', 'encoder.layer.11.attention.self.key.bias', 'encoder.layer.1.output.dense.bias', 'encoder.layer.2.attention.self.key.weight', 'encoder.layer.5.attention.self.key.bias', 'encoder.layer.2.attention.self.query.bias', 'encoder.layer.5.attention.self.key.weight', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.1.output.dense.weight', 'encoder.layer.6.output.LayerNorm.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.9.output.LayerNorm.weight', 'encoder.layer.7.a ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-lite-base-p2 and are newly initialized because the shapes did not match:
# - embeddings.word_embeddings.weight: found shape torch.Size([30000, 128]) in the checkpoint and torch.Size([30000, 768]) in the model instantiated
# - embeddings.position_embeddings.weight: found shape torch.Size([512, 128]) in the checkpoint and torch.Size([512, 768]) in the model instantiated
# - embeddings.token_type_embeddings.weight: found shape torch.Size([2, 128]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# - embeddings.LayerNorm.weight: found shape torch.Size([128]) in the checkpoint and torch.Size([768]) in the model instantiated
# - embeddings.LayerNorm.bias: found shape torch.Size([128]) in the checkpoint and torch.Size([768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/586 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/586 [00:23<?, ?it/s, training_loss=0.594]
# Epoch 1:   0%|          | 1/586 [00:23<3:50:50, 23.68s/it, training_loss=0.594]
# Epoch 1:   0%|          | 1/586 [00:40<3:50:50, 23.68s/it, training_loss=0.753]
# Epoch 1:   0%|          | 2/586 [00:40<3:11:08, 19.64s/it, training_loss=0.753]
# Epoch 1:   0%|          | 2/586 [00:52<3:11:08, 19.64s/it, training_loss=0.785]
# Epoch 1:   1%|          | 3/586 [00:52<2:35:19, 15.99s/it, training_loss=0.785]
# Epoch 1:   1%|          | 3/586 [01:01<2:35:19, 15.99s/it, training_loss=0.478]
# Epoch 1:   1%|          | 4/586 [01:01<2:11:28, 13.55s/it, training_loss=0.478]
# Epoch 1:   1%|          | 4/586 [01:12<2:11:28, 13.55s/it, training_loss=0.650]
# Epoch 1:   1%|          | 5/586 [01:12<1:59:35, 12.35s/it, training_loss=0.650]
# Epoch 1:   1%|          | 5/586 [01:23<1:59:35, 12.35s/it, training_loss=0.630]
# Epoch 1:   1%|          | 6/586 [01:23<1:56:10, 12.02s/it, training_loss=0.630]
# Epoch 1:   1%|          | 6/586 [01:32<1:56:10, 12.02s/it, training_loss=0.579]
# Epoch 1:   1%|          | 7/586 [01:32<1:47:38, 11.16s/it, training_loss=0.579]
# Epoch 1:   1%|          | 7/586 [01:43<1:47:38, 11.16s/it, training_loss=0.441]
# Epoch 1:   1%|▏         | 8/586 [01:43<1:46:10, 11.02s/it, training_loss=0.441]
# Epoch 1:   1%|▏         | 8/586 [01:55<1:46:10, 11.02s/it, training_loss=0.523]
# Epoch 1:   2%|▏         | 9/586 [01:55<1:47:11, 11.15s/it, training_loss=0.523]
# Epoch 1:   2%|▏         | 9/586 [02:08<1:47:11, 11.15s/it, training_loss=0.625]
# Epoch 1:   2%|▏         | 10/586 [02:08<1:53:23, 11.81s/it, training_loss=0.625]
# Epoch 1:   2%|▏         | 10/586 [02:17<1:53:23, 11.81s/it, training_loss=0.605]
# Epoch 1:   2%|▏         | 11/586 [02:17<1:46:14, 11.09s/it, training_loss=0.605]
# Epoch 1:   2%|▏         | 11/586 [02:29<1:46:14, 11.09s/it, training_loss=0.326]
# Epoch 1:  28%|██▊       | 164/586 [29:12<1:14:43, 10.63s/it, training_loss=0.207]
# Epoch 1:  28%|██▊       | 165/586 [29:12<1:12:24, 10.32s/it, training_loss=0.207]
# Epoch 1:  28%|██▊       | 165/586 [29:24<1:12:24, 10.32s/it, training_loss=0.476]
# Epoch 1:  28%|██▊       | 166/586 [29:24<1:14:33, 10.65s/it, training_loss=0.476]
# Epoch 1:  28%|██▊       | 166/586 [29:34<1:14:33, 10.65s/it, training_loss=0.195]
# Epoch 1:  28%|██▊       | 167/586 [29:34<1:13:10, 10.48s/it, training_loss=0.195]
# Epoch 1:  28%|██▊       | 167/586 [29:44<1:13:10, 10.48s/it, training_loss=0.234]
# Epoch 1:  29%|██▊       | 168/586 [29:44<1:11:46, 10.30s/it, training_loss=0.234]
# Epoch 1:  29%|██▊       | 168/586 [29:55<1:11:46, 10.30s/it, training_loss=0.030]
# Epoch 1:  29%|██▉       | 169/586 [29:55<1:13:52, 10.63s/it, training_loss=0.030]
# Epoch 1:  29%|██▉       | 169/586 [30:05<1:13:52, 10.63s/it, training_loss=0.074]
# Epoch 1:  29%|██▉       | 170/586 [30:05<1:11:37, 10.33s/it, training_loss=0.074]
# Epoch 1:  29%|██▉       | 170/586 [30:15<1:11:37, 10.33s/it, training_loss=0.089]
# Epoch 1:  29%|██▉       | 171/586 [30:15<1:11:42, 10.37s/it, training_loss=0.089]
# Epoch 1:  29%|██▉       | 171/586 [30:27<1:11:42, 10.37s/it, training_loss=0.196]
# Epoch 1:  29%|██▉       | 172/586 [30:27<1:13:51, 10.71s/it, training_loss=0.196]
# Epoch 1:  29%|██▉       | 172/586 [30:36<1:13:51, 10.71s/it, training_loss=0.171]
# Epoch 1:  30%|██▉       | 173/586 [30:36<1:10:18, 10.21s/it, training_loss=0.171]
# Epoch 1:  30%|██▉       | 173/586 [30:47<1:10:18, 10.21s/it, training_loss=0.062]
# Epoch 1:  30%|██▉       | 174/586 [30:47<1:11:41, 10.44s/it, training_loss=0.062]
# Epoch 1:  30%|██▉       | 174/586 [30:58<1:11:41, 10.44s/it, training_loss=0.016]
# Epoch 1:  30%|██▉       | 175/586 [30:58<1:13:18, 10.70s/it, training_loss=0.016]
#   0%|          | 0/4 [31:06<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-bf5a5c3d21e7> in <module>
# ----> 1 asag_systems('/content/drive/MyDrive/Paper_TA_ASAG/DATASET_TA/Text Preprocessing/Dataset Text Preprocessing/Lower Case/Teknologi')
#
# <ipython-input-31-f84e458daf9f> in asag_systems(path_dir)
#      36                 df_final.append(pd.DataFrame(list_final), ignore_index=True)
#      37
# ---> 38             train_eval(df_final, m)
#
# <ipython-input-30-e9ceefad838f> in train_eval(df_final, pretrainedmodel)
#     158             loss = outputs[0]
#     159             loss_train_total += loss.item()
# --> 160             loss.backward()
#     161
#     162             torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#
# /usr/local/lib/python3.9/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     486                 inputs=inputs,
#     487             )
# --> 488         torch.autograd.backward(
#     489             self, gradient, retain_graph, create_graph, inputs=inputs
#     490         )
#
# /usr/local/lib/python3.9/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     # some Python versions print out the first line of a multi-line function
#     196     # calls in the traceback and some print out the last line
# --> 197     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:
